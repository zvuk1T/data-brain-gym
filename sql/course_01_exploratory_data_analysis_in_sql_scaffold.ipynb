# %% [markdown]
# # Exploratory Data Analysis in SQL
#
# **Source:** DataCamp
# **Course link:** https://www.datacamp.com/courses/exploratory-data-analysis-in-sql
# **Created:** 2026-05-30
#
# ## Purpose
#
# This notebook is a local learning scaffold for practicing **Exploratory Data Analysis in SQL** from VS Code.
#
# The goal is not to replace the DataCamp course. The goal is to create a structured local workspace where each course exercise has:
#
# 1. a short learning prompt,
# 2. a place for your own notes,
# 3. an empty code cell for your own SQL/Python work.
#
# ## Recommended workflow
#
# 1. Open the related lesson on DataCamp.
# 2. Read/watch the original instruction there.
# 3. Use this notebook as your local workspace.
# 4. Write your own code in the empty code cells.
# 5. Move final SQL queries into `.sql` files when they are clean.
#
# ## Local database idea
#
# Recommended setup:
#
# ```text
# CSV / course resources
# ↓
# PostgreSQL local database
# ↓
# SQLAlchemy connection in Python
# ↓
# SQL query execution
# ↓
# pandas DataFrame display
# ```
#
# ## Starter connection template
#
# Edit this once you have your local PostgreSQL database ready.

# %%
# Optional setup cell
# Uncomment and adapt when your local database is ready.

# import pandas as pd
# from sqlalchemy import create_engine, text
# from pathlib import Path

# engine = create_engine(
#     "postgresql+psycopg2://postgres:YOUR_PASSWORD@localhost:5432/datacamp_eda"
# )

# def run_sql(query: str):
#     """Run a SQL query against the local PostgreSQL database and return a DataFrame."""
#     return pd.read_sql_query(text(query), engine)

# %% [markdown]
# ## Course learning objectives
#
# By the end of this course, you should be able to:
#
# - inspect database structure before analysis,
# - identify tables, keys, relationships, and column types,
# - summarize numeric variables,
# - clean and summarize categorical/text data,
# - analyze dates and timestamps,
# - use SQL as the primary tool for exploratory analysis.
#
# ✅ **Notes for Students**
#
# Good EDA starts before writing complicated queries. First understand what tables exist, what each column means, what is missing, and what types of values you have.

# %% [markdown]
# # Chapter 1: What's in the Database?
#
# ## Chapter focus
#
# Start by inspecting the database: tables, relationships, missing values, row counts, joins, keys, casting, and coalescing.
#
# ## Skills checklist
#
# - [ ] Identify available tables and columns
# - [ ] Count rows and inspect table size
# - [ ] Check missing values
# - [ ] Understand keys and relationships
# - [ ] Use joins, casts, and COALESCE
#
# ✅ **Notes for Students**
#
# Do not rush to the final answer. For each exercise, first write down:
# **What table do I need? What columns matter? What is the question really asking?**

# %% [markdown]
# ## Exercise 1.1: What's in the database?
#
# ### Local learning prompt
#
# Warm-up: understand what data is available and what questions can be asked.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 1.1: What's in the database?
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 1.2: Explore table sizes
#
# ### Local learning prompt
#
# Inspect how many observations are stored in the available tables.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 1.2: Explore table sizes
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 1.3: Count missing values
#
# ### Local learning prompt
#
# Check columns for missing or incomplete values.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 1.3: Count missing values
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 1.4: Join tables
#
# ### Local learning prompt
#
# Combine related tables to create a more useful analysis table.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 1.4: Join tables
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 1.5: The keys to the database
#
# ### Local learning prompt
#
# Understand how primary and foreign keys connect tables.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 1.5: The keys to the database
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 1.6: Foreign keys
#
# ### Local learning prompt
#
# Identify relationships between tables through foreign keys.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 1.6: Foreign keys
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 1.7: Read an entity relationship diagram
#
# ### Local learning prompt
#
# Use an ERD to understand database structure before writing SQL.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 1.7: Read an entity relationship diagram
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 1.8: Coalesce
#
# ### Local learning prompt
#
# Use COALESCE to replace missing values with fallback values.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 1.8: Coalesce
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 1.9: Column types and constraints
#
# ### Local learning prompt
#
# Inspect data types and understand how constraints affect analysis.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 1.9: Column types and constraints
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 1.10: Effects of casting
#
# ### Local learning prompt
#
# Convert values between data types and observe how results change.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 1.10: Effects of casting
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 1.11: Summarize the distribution of numeric values
#
# ### Local learning prompt
#
# Use summary statistics to understand numeric variables.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 1.11: Summarize the distribution of numeric values
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# # Chapter 2: Summarizing and Aggregating Numeric Data
#
# ## Chapter focus
#
# Build stronger numeric EDA skills with averages, variance, correlation, percentiles, rounding, truncation, generated series, and temporary tables.
#
# ## Skills checklist
#
# - [ ] Use numeric aggregation functions
# - [ ] Compare grouped statistics
# - [ ] Explore distributions
# - [ ] Calculate correlation and median
# - [ ] Create temporary tables for cleaner workflows
#
# ✅ **Notes for Students**
#
# Do not rush to the final answer. For each exercise, first write down:
# **What table do I need? What columns matter? What is the question really asking?**

# %% [markdown]
# ## Exercise 2.1: Numeric data types and summary functions
#
# ### Local learning prompt
#
# Review numeric types and common functions for descriptive statistics.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 2.1: Numeric data types and summary functions
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 2.2: Division
#
# ### Local learning prompt
#
# Practice division carefully and understand integer vs decimal behavior.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 2.2: Division
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 2.3: Explore with division
#
# ### Local learning prompt
#
# Use division to create ratios and meaningful derived metrics.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 2.3: Explore with division
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 2.4: Summarize numeric columns
#
# ### Local learning prompt
#
# Calculate min, max, average, and other summary values.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 2.4: Summarize numeric columns
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 2.5: Summarize group statistics
#
# ### Local learning prompt
#
# Compare numeric summaries across groups.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 2.5: Summarize group statistics
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 2.6: Exploring distributions
#
# ### Local learning prompt
#
# Inspect spread, shape, and unusual values in numeric data.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 2.6: Exploring distributions
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 2.7: Truncate
#
# ### Local learning prompt
#
# Use truncation to group numeric values into useful ranges.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 2.7: Truncate
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 2.8: Generate series
#
# ### Local learning prompt
#
# Generate numeric ranges for distribution analysis or missing-bin checks.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 2.8: Generate series
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 2.9: More summary functions
#
# ### Local learning prompt
#
# Extend descriptive statistics with additional SQL functions.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 2.9: More summary functions
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 2.10: Correlation
#
# ### Local learning prompt
#
# Measure the relationship between two numeric variables.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 2.10: Correlation
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 2.11: Mean and Median
#
# ### Local learning prompt
#
# Compare average and median as different views of center.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 2.11: Mean and Median
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 2.12: Creating temporary tables
#
# ### Local learning prompt
#
# Use temporary tables to store intermediate analysis results.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 2.12: Creating temporary tables
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 2.13: Create a temp table
#
# ### Local learning prompt
#
# Create a temporary table for repeated analysis steps.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 2.13: Create a temp table
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 2.14: Create a temp table to simplify a query
#
# ### Local learning prompt
#
# Break a complex query into easier, reusable pieces.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 2.14: Create a temp table to simplify a query
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 2.15: Insert into a temp table
#
# ### Local learning prompt
#
# Add data into a temporary table as part of an analysis workflow.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 2.15: Insert into a temp table
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# # Chapter 3: Exploring Categorical Data and Unstructured Text
#
# ## Chapter focus
#
# Work with messy text and categorical variables: inconsistent spacing/case, delimiters, recoding, grouping, indicators, and extracting meaning from text fields.
#
# ## Skills checklist
#
# - [ ] Count categories
# - [ ] Detect messy text values
# - [ ] Clean strings with trimming and case transformations
# - [ ] Split and concatenate text
# - [ ] Recode categories and create indicators
#
# ✅ **Notes for Students**
#
# Do not rush to the final answer. For each exercise, first write down:
# **What table do I need? What columns matter? What is the question really asking?**

# %% [markdown]
# ## Exercise 3.1: Character data types and common issues
#
# ### Local learning prompt
#
# Understand common problems with text data and categorical values.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 3.1: Character data types and common issues
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 3.2: Count the categories
#
# ### Local learning prompt
#
# Count distinct values and category frequencies.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 3.2: Count the categories
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 3.3: Spotting character data problems
#
# ### Local learning prompt
#
# Look for inconsistent spelling, spaces, case, or formatting.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 3.3: Spotting character data problems
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 3.4: Cases and spaces
#
# ### Local learning prompt
#
# Normalize text by handling case and extra spaces.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 3.4: Cases and spaces
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 3.5: Trimming
#
# ### Local learning prompt
#
# Remove unwanted spaces around text values.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 3.5: Trimming
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 3.6: Exploring unstructured text
#
# ### Local learning prompt
#
# Inspect free-text fields and look for recurring patterns.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 3.6: Exploring unstructured text
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 3.7: Splitting and concatenating text
#
# ### Local learning prompt
#
# Create or separate text fields using delimiters.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 3.7: Splitting and concatenating text
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 3.8: Concatenate strings
#
# ### Local learning prompt
#
# Combine multiple text columns into one useful value.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 3.8: Concatenate strings
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 3.9: Split strings on a delimiter
#
# ### Local learning prompt
#
# Extract pieces of text from structured strings.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 3.9: Split strings on a delimiter
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 3.10: Shorten long strings
#
# ### Local learning prompt
#
# Create shorter readable versions of long text fields.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 3.10: Shorten long strings
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 3.11: Strategies for multiple transformations
#
# ### Local learning prompt
#
# Plan several cleaning steps without losing readability.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 3.11: Strategies for multiple transformations
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 3.12: Create an 'other' category
#
# ### Local learning prompt
#
# Group rare categories into a broader category for analysis.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 3.12: Create an 'other' category
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 3.13: Group and recode values
#
# ### Local learning prompt
#
# Standardize messy category values into clean groups.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 3.13: Group and recode values
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 3.14: Create a table with indicator variables
#
# ### Local learning prompt
#
# Create yes/no flags from text or category conditions.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 3.14: Create a table with indicator variables
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# # Chapter 4: Working with Dates and Timestamps
#
# ## Chapter focus
#
# Analyze time-based data with date comparisons, arithmetic, date parts, truncation, time series, missing dates, custom periods, and gaps between events.
#
# ## Skills checklist
#
# - [ ] Compare dates and timestamps
# - [ ] Use date arithmetic and intervals
# - [ ] Extract date parts
# - [ ] Aggregate by hour, day, month, or year
# - [ ] Find missing dates and time gaps
#
# ✅ **Notes for Students**
#
# Do not rush to the final answer. For each exercise, first write down:
# **What table do I need? What columns matter? What is the question really asking?**

# %% [markdown]
# ## Exercise 4.1: Date/time types and formats
#
# ### Local learning prompt
#
# Understand date and timestamp formats used in SQL databases.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 4.1: Date/time types and formats
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 4.2: ISO 8601
#
# ### Local learning prompt
#
# Recognize standard date/time formatting conventions.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 4.2: ISO 8601
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 4.3: Date comparisons
#
# ### Local learning prompt
#
# Filter and compare values using dates.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 4.3: Date comparisons
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 4.4: Date arithmetic
#
# ### Local learning prompt
#
# Add, subtract, and calculate intervals between dates.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 4.4: Date arithmetic
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 4.5: Completion time by category
#
# ### Local learning prompt
#
# Analyze durations and compare time-to-completion across groups.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 4.5: Completion time by category
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 4.6: Date/time components and aggregation
#
# ### Local learning prompt
#
# Extract parts of dates and aggregate by time units.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 4.6: Date/time components and aggregation
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 4.7: Date parts
#
# ### Local learning prompt
#
# Use date parts such as day, month, year, hour, or weekday.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 4.7: Date parts
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 4.8: Variation by day of week
#
# ### Local learning prompt
#
# Compare patterns across weekdays.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 4.8: Variation by day of week
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 4.9: Date truncation
#
# ### Local learning prompt
#
# Group timestamps into larger periods such as month or year.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 4.9: Date truncation
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 4.10: Aggregating with date/time series
#
# ### Local learning prompt
#
# Create time-series summaries and identify trends.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 4.10: Aggregating with date/time series
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 4.11: Find missing dates
#
# ### Local learning prompt
#
# Detect gaps where expected dates are absent.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 4.11: Find missing dates
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 4.12: Custom aggregation periods
#
# ### Local learning prompt
#
# Build non-standard time buckets for analysis.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 4.12: Custom aggregation periods
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 4.13: Monthly average with missing dates
#
# ### Local learning prompt
#
# Handle missing time periods when calculating monthly metrics.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 4.13: Monthly average with missing dates
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 4.14: Time between events
#
# ### Local learning prompt
#
# Calculate the elapsed time between records or events.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 4.14: Time between events
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 4.15: Longest gap
#
# ### Local learning prompt
#
# Find the maximum gap between events.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 4.15: Longest gap
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 4.16: Rats!
#
# ### Local learning prompt
#
# Apply date/time analysis to a practical example.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 4.16: Rats!
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# ## Exercise 4.17: Wrap-up
#
# ### Local learning prompt
#
# Review the main date/time analysis concepts from the course.
#
# ### Your task
#
# Use the original DataCamp exercise as the source of truth, then write your own SQL/Python solution below.
#
# ### Before coding, answer briefly
#
# - What table(s) do I need?
# - What columns are relevant?
# - What should the output show?
# - Is this EDA, cleaning, aggregation, or date/time analysis?
#
# ### Notes
#
# Write your own explanation here after solving.

# %%
# Exercise 4.17: Wrap-up
# Write your SQL/Python solution here.

# Example pattern:
# query = """
# SELECT *
# FROM table_name
# LIMIT 5;
# """
# run_sql(query)

# %% [markdown]
# # Final Course Reflection
#
# ## What I learned
#
# Write 5–10 bullet points about what this course improved in your SQL thinking.
#
# ## SQL concepts I should practice again
#
# -
# -
# -
#
# ## Portfolio transfer
#
# How can I apply these EDA concepts to my own projects, for example `manufacturing-process`?
#
# ✅ **Notes for Students**
#
# A course is complete only when you can explain what changed in your thinking. The GitHub value is not only the code — it is the evidence that you understand the workflow.

# %% [markdown]
# Data Storytelling — Skill Track

# %% [markdown]
# # Communicating Data Insights

# %% [markdown]
# ## Communicating Information

# %% [markdown]
# ### How is knowledge shared

# %% [markdown]
# ### Communication types

# %% [markdown]
# ### Communication journey

# %% [markdown]
# ### Becoming a more effective communicator

# %% [markdown]
# ### Data insights

# %% [markdown]
# ### Insightful characteristics

# %% [markdown]
# ### Insightful journey

# %% [markdown]
# ### Getting to know your audience

# %% [markdown]
# ### Audience information

# %% [markdown]
# ### Factoring importance

# %% [markdown]
# ### Communication framework

# %% [markdown]
# ## Effective Data Visuals

# %% [markdown]
# ### Visualizing Success

# %% [markdown]
# ### Visual impact

# %% [markdown]
# ### Building a plan

# %% [markdown]
# ### Beginning visualization

# %% [markdown]
# ### Charting basics

# %% [markdown]
# ### Plotting the course

# %% [markdown]
# ### Advanced visuals

# %% [markdown]
# ### Seeking Alignment

# %% [markdown]
# ### Finding a vision

# %% [markdown]
# ### Guiding principles of visualization

# %% [markdown]
# ### Navigating priorities

# %% [markdown]
# ### Visualization best practices

# %% [markdown]
# ## Storytelling with Data

# %% [markdown]
# ### Data storytelling

# %% [markdown]
# ### Building a story

# %% [markdown]
# ### Important call

# %% [markdown]
# ### Keys to a good story

# %% [markdown]
# ### Defining the goal

# %% [markdown]
# ### Narrative and context

# %% [markdown]
# ### Storytelling in action

# %% [markdown]
# ### Telling a good story

# %% [markdown]
# ### Guiding a story

# %% [markdown]
# ### Delivering a story

# %% [markdown]
# ### Data storytelling group framework

# %% [markdown]
# ### Organizing success

# %% [markdown]
# ### Aligning roles

# %% [markdown]
# ### Teamwork for success

# %% [markdown]
# ### Wrap-up

# %% [markdown]
# # Data Storytelling Concepts

# %% [markdown]
# ## Telling a Great Story

# %% [markdown]
# ### Why tell a story?

# %% [markdown]
# ### The straight story

# %% [markdown]
# ### The very human basis for data stories

# %% [markdown]
# ### Story power

# %% [markdown]
# ### The magic of stories

# %% [markdown]
# ### Building a blockbuster story

# %% [markdown]
# ### What kind of data story component is it?

# %% [markdown]
# ### Data story qualities

# %% [markdown]
# ### Freytag's story structure

# %% [markdown]
# ## Data Story Components

# %% [markdown]
# ### Know your audience

# %% [markdown]
# ### Audience impact

# %% [markdown]
# ### Who is my audience?

# %% [markdown]
# ### Non-technical vs. technical audiences

# %% [markdown]
# ### Set the scene

# %% [markdown]
# ### Well, this presents a problem

# %% [markdown]
# ### Operational or strategic?

# %% [markdown]
# ### Making a scene

# %% [markdown]
# ### Building tension

# %% [markdown]
# ### Order the inductive reasoning steps

# %% [markdown]
# ### Inductive versus deductive reasoning

# %% [markdown]
# ### The tension is mounting...

# %% [markdown]
# ### The climax and moving forward

# %% [markdown]
# ### The natural order of analysis

# %% [markdown]
# ### Click to start here!

# %% [markdown]
# ### Forming the narrative

# %% [markdown]
# ## Visualizing Your Story

# %% [markdown]
# ### Starting smartly with charts

# %% [markdown]
# ### What kind of chart would you use?

# %% [markdown]
# ### Chart your course

# %% [markdown]
# ### Chart smart

# %% [markdown]
# ### Credibility in visualizations

# %% [markdown]
# ### Being completely credible

# %% [markdown]
# ### Must be seen to be believed

# %% [markdown]
# ### In data we trust

# %% [markdown]
# ### Eliminate clutter and focus attention

# %% [markdown]
# ### Decluttering in practice

# %% [markdown]
# ### Declutter, focus attention, and spark joy

# %% [markdown]
# ### Focusing attention in a good way

# %% [markdown]
# ### Storyboard your results

# %% [markdown]
# ### There is a storyboard to be told

# %% [markdown]
# ### Storyboard game

# %% [markdown]
# ### Board of the Rings: one story to rule them all

# %% [markdown]
# ### Wrap-up

# %% [markdown]
# # Data Storytelling Case Study: College Majors

# %% [markdown]
# ## Welcome Storytellers!

# %% [markdown]
# ### Introduction to data storytelling

# %% [markdown]
# ### The case for storytelling

# %% [markdown]
# ### Data storytelling maturity

# %% [markdown]
# ### Data story requirements

# %% [markdown]
# ### Data Storytelling Elements

# %% [markdown]
# ### Employing data elements, pt. 1

# %% [markdown]
# ### Employing data elements, pt. 2

# %% [markdown]
# ### College is only the beginning...

# %% [markdown]
# ## College Majors Case Study

# %% [markdown]
# ### College major outcomes analysis

# %% [markdown]
# ### Stakeholder requirements

# %% [markdown]
# ### Getting organized

# %% [markdown]
# ### Data exploration

# %% [markdown]
# ### Insights fundamentals

# %% [markdown]
# ### KPI review

# %% [markdown]
# ### Visualization review

# %% [markdown]
# ### KPI or visualization?

# %% [markdown]
# ### Student debt

# %% [markdown]
# ### Putting it all together

# %% [markdown]
# ### Unemployment analysis

# %% [markdown]
# ### Main point revealed

# %% [markdown]
# ### Recommendations

# %% [markdown]
# ### Congratulations!

# %% [markdown]
# # Data Storytelling Case Study: Green Businesses

# %% [markdown]
# ## Effective Data Storytelling

# %% [markdown]
# ### The importance of stories

# %% [markdown]
# ### Data storytelling in action

# %% [markdown]
# ### Getting the message across

# %% [markdown]
# ### Planning for success

# %% [markdown]
# ### Applying the workflow

# %% [markdown]
# ### Defining your audience

# %% [markdown]
# ### Green businesses in Colombia

# %% [markdown]
# ### Evaluating a question

# %% [markdown]
# ### Can I answer this?

# %% [markdown]
# ### A preview

# %% [markdown]
# ## Creating a Story

# %% [markdown]
# ### Let's tell a story

# %% [markdown]
# ### Variables, variables, variables

# %% [markdown]
# ### New metrics

# %% [markdown]
# ### Choosing a visualization

# %% [markdown]
# ### Useful attributes

# %% [markdown]
# ### The best plot?

# %% [markdown]
# ### Less is sometimes more

# %% [markdown]
# ### Best practices

# %% [markdown]
# ### Use of labels

# %% [markdown]
# ### Use of color

# %% [markdown]
# ### Color blindness

# %% [markdown]
# ### Wrap-up

# %% [markdown]
# # Data-Driven Decision Making in SQL
#
# **Platform:** DataCamp
# **Track:** SQL for Business Analysts (Course 2 of 5)
# **Level:** Intermediate
# **Duration:** 4 hours | 15 videos | 54 exercises
# **Database:** PostgreSQL
# **Dataset:** MovieNow — fictional online movie rental company
#
# ---
#
# **Course Description:**
# Learn how to use SQL to support decision making. Based on a case study about an online movie rental company (MovieNow).
# Topics: customer preferences, customer engagement, sales development, OLAP extensions (CUBE, ROLLUP, GROUPING SETS).
#
# ---
#
# ## Table of Contents
# 1. [Chapter 1: Introduction to Business Intelligence for an Online Movie Rental Database](#chapter-1)
# 2. [Chapter 2: Decision Making with Simple SQL Queries](#chapter-2)
# 3. [Chapter 3: Data Driven Decision Making with Advanced SQL Queries](#chapter-3)
# 4. [Chapter 4: Data Driven Decision Making with OLAP SQL Queries](#chapter-4)

# %% [markdown]
# ---
# # Chapter 1: Introduction to Business Intelligence for an Online Movie Rental Database
#
# Introduction to the MovieNow use case. Simple SQL queries to extract and aggregate data.
# **Tables:** `customers`, `movies`, `renting`, `actors`, `actsin`

# %% [markdown]
# ## Exercise 1 — Introduction to data driven decision making *(Video / 50 XP)*

# %%
# Exercise 1 — Introduction to data driven decision making

# %% [markdown]
# ## Exercise 2 — Exploring the database *(50 XP)*

# %%
# Exercise 2 — Exploring the database

# %% [markdown]
# ## Exercise 3 — Exploring the table renting *(100 XP)*

# %%
# Exercise 3 — Exploring the table renting

# %% [markdown]
# ## Exercise 4 — Filtering and ordering *(50 XP)*

# %%
# Exercise 4 — Filtering and ordering

# %% [markdown]
# ## Exercise 5 — Working with dates *(100 XP)*

# %%
# Exercise 5 — Working with dates

# %% [markdown]
# ## Exercise 6 — Selecting movies *(100 XP)*

# %%
# Exercise 6 — Selecting movies

# %% [markdown]
# ## Exercise 7 — Select from renting *(100 XP)*

# %%
# Exercise 7 — Select from renting

# %% [markdown]
# ## Exercise 8 — Aggregations - summarizing data *(Video / 50 XP)*

# %%
# Exercise 8 — Aggregations - summarizing data

# %% [markdown]
# ## Exercise 9 — Summarizing customer information *(100 XP)*

# %%
# Exercise 9 — Summarizing customer information

# %% [markdown]
# ## Exercise 10 — Ratings of movie 25 *(100 XP)*

# %%
# Exercise 10 — Ratings of movie 25

# %% [markdown]
# ## Exercise 11 — Examining annual rentals *(100 XP)*

# %%
# Exercise 11 — Examining annual rentals

# %% [markdown]
# ---
# # Chapter 2: Decision Making with Simple SQL Queries
#
# Use GROUP BY, JOINs, and subqueries to extract KPIs and support business decisions.

# %% [markdown]
# ## Exercise 1 — Grouping movies *(Video / 50 XP)*

# %%
# Exercise 1 — Grouping movies

# %% [markdown]
# ## Exercise 2 — First account for each country *(100 XP)*

# %%
# Exercise 2 — First account for each country

# %% [markdown]
# ## Exercise 3 — Average movie ratings *(100 XP)*

# %%
# Exercise 3 — Average movie ratings

# %% [markdown]
# ## Exercise 4 — Average rating per customer *(100 XP)*

# %%
# Exercise 4 — Average rating per customer

# %% [markdown]
# ## Exercise 5 — Joining movie ratings with customer data *(Video / 50 XP)*

# %%
# Exercise 5 — Joining movie ratings with customer data

# %% [markdown]
# ## Exercise 6 — Join renting and customers *(100 XP)*

# %%
# Exercise 6 — Join renting and customers

# %% [markdown]
# ## Exercise 7 — Aggregating revenue, rentals and active customers *(100 XP)*

# %%
# Exercise 7 — Aggregating revenue, rentals and active customers

# %% [markdown]
# ## Exercise 8 — Movies and actors *(100 XP)*

# %%
# Exercise 8 — Movies and actors

# %% [markdown]
# ## Exercise 9 — Money spent per customer with sub-queries *(Video / 50 XP)*

# %%
# Exercise 9 — Money spent per customer with sub-queries

# %% [markdown]
# ## Exercise 10 — Income from movies *(100 XP)*

# %%
# Exercise 10 — Income from movies

# %% [markdown]
# ## Exercise 11 — Age of actors from the USA *(100 XP)*

# %%
# Exercise 11 — Age of actors from the USA

# %% [markdown]
# ## Exercise 12 — Identify favorite actors of customer groups *(100 XP)*

# %%
# Exercise 12 — Identify favorite actors of customer groups

# %% [markdown]
# ## Exercise 13 — Identify favorite movies for a group of customers *(100 XP)*

# %%
# Exercise 13 — Identify favorite movies for a group of customers

# %% [markdown]
# ## Exercise 14 — Identify favorite actors for Spain *(100 XP)*

# %%
# Exercise 14 — Identify favorite actors for Spain

# %% [markdown]
# ## Exercise 15 — KPIs per country *(100 XP)*

# %%
# Exercise 15 — KPIs per country

# %% [markdown]
# ---
# # Chapter 3: Data Driven Decision Making with Advanced SQL Queries
#
# Correlated subqueries, EXISTS, UNION, INTERSECT — for deeper business analysis.

# %% [markdown]
# ## Exercise 1 — Nested query *(Video / 50 XP)*

# %%
# Exercise 1 — Nested query

# %% [markdown]
# ## Exercise 2 — Often rented movies *(100 XP)*

# %%
# Exercise 2 — Often rented movies

# %% [markdown]
# ## Exercise 3 — Frequent customers *(100 XP)*

# %%
# Exercise 3 — Frequent customers

# %% [markdown]
# ## Exercise 4 — Movies with rating above average *(100 XP)*

# %%
# Exercise 4 — Movies with rating above average

# %% [markdown]
# ## Exercise 5 — Correlated nested queries *(Video / 50 XP)*

# %%
# Exercise 5 — Correlated nested queries

# %% [markdown]
# ## Exercise 6 — Analyzing customer behavior *(100 XP)*

# %%
# Exercise 6 — Analyzing customer behavior

# %% [markdown]
# ## Exercise 7 — Customers who gave low ratings *(100 XP)*

# %%
# Exercise 7 — Customers who gave low ratings

# %% [markdown]
# ## Exercise 8 — Movies and ratings with correlated queries *(100 XP)*

# %%
# Exercise 8 — Movies and ratings with correlated queries

# %% [markdown]
# ## Exercise 9 — Queries with EXISTS *(Video / 50 XP)*

# %%
# Exercise 9 — Queries with EXISTS

# %% [markdown]
# ## Exercise 10 — Customers with at least one rating *(100 XP)*

# %%
# Exercise 10 — Customers with at least one rating

# %% [markdown]
# ## Exercise 11 — Actors in comedies *(100 XP)*

# %%
# Exercise 11 — Actors in comedies

# %% [markdown]
# ## Exercise 12 — Queries with UNION and INTERSECT *(Video / 50 XP)*

# %%
# Exercise 12 — Queries with UNION and INTERSECT

# %% [markdown]
# ## Exercise 13 — Young actors not coming from the USA *(100 XP)*

# %%
# Exercise 13 — Young actors not coming from the USA

# %% [markdown]
# ## Exercise 14 — Dramas with high ratings *(100 XP)*

# %%
# Exercise 14 — Dramas with high ratings

# %% [markdown]
# ---
# # Chapter 4: Data Driven Decision Making with OLAP SQL Queries
#
# OLAP extensions for multidimensional aggregation: CUBE, ROLLUP, GROUPING SETS.

# %% [markdown]
# ## Exercise 1 — OLAP: CUBE operator *(Video / 50 XP)*

# %%
# Exercise 1 — OLAP: CUBE operator

# %% [markdown]
# ## Exercise 2 — Groups of customers *(100 XP)*

# %%
# Exercise 2 — Groups of customers

# %% [markdown]
# ## Exercise 3 — Categories of movies *(100 XP)*

# %%
# Exercise 3 — Categories of movies

# %% [markdown]
# ## Exercise 4 — Analyzing average ratings *(100 XP)*

# %%
# Exercise 4 — Analyzing average ratings

# %% [markdown]
# ## Exercise 5 — ROLLUP *(Video / 50 XP)*

# %%
# Exercise 5 — ROLLUP

# %% [markdown]
# ## Exercise 6 — Number of customers *(100 XP)*

# %%
# Exercise 6 — Number of customers

# %% [markdown]
# ## Exercise 7 — Analyzing preferences of genres across countries *(100 XP)*

# %%
# Exercise 7 — Analyzing preferences of genres across countries

# %% [markdown]
# ## Exercise 8 — GROUPING SETS *(Video / 50 XP)*

# %%
# Exercise 8 — GROUPING SETS

# %% [markdown]
# ## Exercise 9 — Queries with GROUPING SETS *(100 XP)*

# %%
# Exercise 9 — Queries with GROUPING SETS

# %% [markdown]
# ## Exercise 10 — Exploring nationality and gender of actors *(100 XP)*

# %%
# Exercise 10 — Exploring nationality and gender of actors

# %% [markdown]
# ## Exercise 11 — Exploring rating by country and gender *(100 XP)*

# %%
# Exercise 11 — Exploring rating by country and gender

# %% [markdown]
# ## Exercise 12 — Bringing it all together *(100 XP)*

# %%
# Exercise 12 — Bringing it all together

# %% [markdown]
# ## Exercise 13 — Customer preference for genres *(100 XP)*

# %%
# Exercise 13 — Customer preference for genres

# %% [markdown]
# ## Exercise 14 — Customer preference for actors *(100 XP)*

# %%
# Exercise 14 — Customer preference for actors

# %% [markdown]
# # Data Manipulation in SQL
#
# **Platform:** DataCamp
# **Track:** SQL for Business Analysts — **Prerequisite course (00)**
# **Level:** Intermediate
# **Duration:** 4 hours | 15 videos | 55 exercises
# **Database:** PostgreSQL
# **Dataset:** European Soccer Database — 25,000+ matches, 300 teams, 10,000 players (2008–2016)
# **Tables:** `country`, `league`, `team`, `match`
#
# ---
#
# **Course Description:**
# Master the complex SQL queries necessary to answer a wide variety of data science questions and prepare robust data sets for analysis.
# Topics: CASE WHEN statements, simple and correlated subqueries, CTEs (WITH), window functions.
#
# ---
#
# ## Table of Contents
# 1. [Chapter 1: We'll take the CASE](#chapter-1)
# 2. [Chapter 2: Short and Simple Subqueries](#chapter-2)
# 3. [Chapter 3: Correlated Queries, Nested Queries, and Common Table Expressions](#chapter-3)
# 4. [Chapter 4: Window Functions](#chapter-4)

# %% [markdown]
# ---
# # Chapter 1: We'll take the CASE
#
# Use CASE WHEN to create categorical variables, aggregate data with multiple filtering conditions, and calculate counts and percentages.
# **Pattern:** `CASE WHEN condition THEN result ELSE fallback END AS alias`

# %% [markdown]
# ## Exercise 1 — We'll take the CASE *(Video / 50 XP)*

# %%
# Exercise 1 — We'll take the CASE

# %% [markdown]
# ## Exercise 2 — Basic CASE statements *(100 XP)*

# %%
# Exercise 2 — Basic CASE statements

# %% [markdown]
# ## Exercise 3 — CASE statements comparing column values *(100 XP)*

# %%
# Exercise 3 — CASE statements comparing column values

# %% [markdown]
# ## Exercise 4 — CASE statements comparing two column values part 2 *(100 XP)*

# %%
# Exercise 4 — CASE statements comparing two column values part 2

# %% [markdown]
# ## Exercise 5 — In CASE things get more complex *(Video / 50 XP)*

# %%
# Exercise 5 — In CASE things get more complex

# %% [markdown]
# ## Exercise 6 — In CASE of rivalry *(100 XP)*

# %%
# Exercise 6 — In CASE of rivalry

# %% [markdown]
# ## Exercise 7 — Filtering your CASE statement *(100 XP)*

# %%
# Exercise 7 — Filtering your CASE statement

# %% [markdown]
# ## Exercise 8 — CASE WHEN with aggregate functions *(Video / 50 XP)*

# %%
# Exercise 8 — CASE WHEN with aggregate functions

# %% [markdown]
# ## Exercise 9 — COUNT using CASE WHEN *(100 XP)*

# %%
# Exercise 9 — COUNT using CASE WHEN

# %% [markdown]
# ## Exercise 10 — Conditional selection and summation with CASE WHEN *(100 XP)*

# %%
# Exercise 10 — Conditional selection and summation with CASE WHEN

# %% [markdown]
# ## Exercise 11 — Using CASE and AVG to derive fractions *(100 XP)*

# %%
# Exercise 11 — Using CASE and AVG to derive fractions

# %% [markdown]
# ---
# # Chapter 2: Short and Simple Subqueries
#
# Subqueries in WHERE, FROM, and SELECT clauses.
# **When to use:** scalar values (WHERE), derived tables (FROM), computed columns (SELECT).

# %% [markdown]
# ## Exercise 1 — WHERE are the Subqueries? *(Video / 50 XP)*

# %%
# Exercise 1 — WHERE are the Subqueries?

# %% [markdown]
# ## Exercise 2 — Filtering using scalar subqueries *(100 XP)*

# %%
# Exercise 2 — Filtering using scalar subqueries

# %% [markdown]
# ## Exercise 3 — Filtering using a subquery with a list *(100 XP)*

# %%
# Exercise 3 — Filtering using a subquery with a list

# %% [markdown]
# ## Exercise 4 — Filtering with more complex subquery conditions *(100 XP)*

# %%
# Exercise 4 — Filtering with more complex subquery conditions

# %% [markdown]
# ## Exercise 5 — Subqueries in FROM *(Video / 50 XP)*

# %%
# Exercise 5 — Subqueries in FROM

# %% [markdown]
# ## Exercise 6 — Joining Subqueries in FROM *(100 XP)*

# %%
# Exercise 6 — Joining Subqueries in FROM

# %% [markdown]
# ## Exercise 7 — Building on Subqueries in FROM *(100 XP)*

# %%
# Exercise 7 — Building on Subqueries in FROM

# %% [markdown]
# ## Exercise 8 — Subqueries in SELECT *(Video / 50 XP)*

# %%
# Exercise 8 — Subqueries in SELECT

# %% [markdown]
# ## Exercise 9 — Add a subquery to the SELECT clause *(100 XP)*

# %%
# Exercise 9 — Add a subquery to the SELECT clause

# %% [markdown]
# ## Exercise 10 — Subqueries in Select for Calculations *(100 XP)*

# %%
# Exercise 10 — Subqueries in Select for Calculations

# %% [markdown]
# ## Exercise 11 — Subqueries everywhere! And best practices! *(Video / 50 XP)*

# %%
# Exercise 11 — Subqueries everywhere! And best practices!

# %% [markdown]
# ## Exercise 12 — ALL the subqueries EVERYWHERE *(100 XP)*

# %%
# Exercise 12 — ALL the subqueries EVERYWHERE

# %% [markdown]
# ## Exercise 13 — Add a subquery in FROM *(100 XP)*

# %%
# Exercise 13 — Add a subquery in FROM

# %% [markdown]
# ## Exercise 14 — Add a subquery in SELECT *(100 XP)*

# %%
# Exercise 14 — Add a subquery in SELECT

# %% [markdown]
# ---
# # Chapter 3: Correlated Queries, Nested Queries, and Common Table Expressions
#
# Advanced subquery techniques: correlated (reference outer query), nested, and CTEs with WITH.
# **Key question:** When to use subquery vs correlated subquery vs CTE?

# %% [markdown]
# ## Exercise 1 — Correlated subqueries *(Video / 50 XP)*

# %%
# Exercise 1 — Correlated subqueries

# %% [markdown]
# ## Exercise 2 — Getting started with correlated subqueries *(100 XP)*

# %%
# Exercise 2 — Getting started with correlated subqueries

# %% [markdown]
# ## Exercise 3 — Correlated subquery with multiple conditions *(100 XP)*

# %%
# Exercise 3 — Correlated subquery with multiple conditions

# %% [markdown]
# ## Exercise 4 — Nested subqueries *(Video / 50 XP)*

# %%
# Exercise 4 — Nested subqueries

# %% [markdown]
# ## Exercise 5 — Getting started with nested subqueries *(100 XP)*

# %%
# Exercise 5 — Getting started with nested subqueries

# %% [markdown]
# ## Exercise 6 — Nest a subquery in FROM *(100 XP)*

# %%
# Exercise 6 — Nest a subquery in FROM

# %% [markdown]
# ## Exercise 7 — Common Table Expressions *(Video / 50 XP)*

# %%
# Exercise 7 — Common Table Expressions

# %% [markdown]
# ## Exercise 8 — Clean up with CTEs *(100 XP)*

# %%
# Exercise 8 — Clean up with CTEs

# %% [markdown]
# ## Exercise 9 — Organizing with CTEs *(100 XP)*

# %%
# Exercise 9 — Organizing with CTEs

# %% [markdown]
# ## Exercise 10 — CTEs with nested subqueries *(100 XP)*

# %%
# Exercise 10 — CTEs with nested subqueries

# %% [markdown]
# ## Exercise 11 — Deciding on techniques to use *(Video / 50 XP)*

# %%
# Exercise 11 — Deciding on techniques to use

# %% [markdown]
# ## Exercise 12 — Get team names with a subquery *(100 XP)*

# %%
# Exercise 12 — Get team names with a subquery

# %% [markdown]
# ## Exercise 13 — Get team names with correlated subqueries *(100 XP)*

# %%
# Exercise 13 — Get team names with correlated subqueries

# %% [markdown]
# ## Exercise 14 — Get team names with CTEs *(100 XP)*

# %%
# Exercise 14 — Get team names with CTEs

# %% [markdown]
# ## Exercise 15 — Which technique to use? *(50 XP)*

# %%
# Exercise 15 — Which technique to use?

# %% [markdown]
# ---
# # Chapter 4: Window Functions
#
# OVER(), PARTITION BY, sliding windows (ROWS BETWEEN), and combining CTEs with window functions.
# **Key difference from GROUP BY:** window functions don't collapse rows.

# %% [markdown]
# ## Exercise 1 — It's OVER *(Video / 50 XP)*

# %%
# Exercise 1 — It's OVER

# %% [markdown]
# ## Exercise 2 — The match is OVER *(100 XP)*

# %%
# Exercise 2 — The match is OVER

# %% [markdown]
# ## Exercise 3 — What's OVER here? *(100 XP)*

# %%
# Exercise 3 — What's OVER here?

# %% [markdown]
# ## Exercise 4 — Flip OVER your results *(100 XP)*

# %%
# Exercise 4 — Flip OVER your results

# %% [markdown]
# ## Exercise 5 — OVER with a PARTITION *(Video / 50 XP)*

# %%
# Exercise 5 — OVER with a PARTITION

# %% [markdown]
# ## Exercise 6 — PARTITION BY a column *(100 XP)*

# %%
# Exercise 6 — PARTITION BY a column

# %% [markdown]
# ## Exercise 7 — PARTITION BY multiple columns *(100 XP)*

# %%
# Exercise 7 — PARTITION BY multiple columns

# %% [markdown]
# ## Exercise 8 — Sliding windows *(Video / 50 XP)*

# %%
# Exercise 8 — Sliding windows

# %% [markdown]
# ## Exercise 9 — Slide to the left *(100 XP)*

# %%
# Exercise 9 — Slide to the left

# %% [markdown]
# ## Exercise 10 — Slide to the right *(100 XP)*

# %%
# Exercise 10 — Slide to the right

# %% [markdown]
# ## Exercise 11 — Bringing it all together *(Video / 50 XP)*

# %%
# Exercise 11 — Bringing it all together

# %% [markdown]
# ## Exercise 12 — Setting up the home team CTE *(100 XP)*

# %%
# Exercise 12 — Setting up the home team CTE

# %% [markdown]
# ## Exercise 13 — Setting up the away team CTE *(100 XP)*

# %%
# Exercise 13 — Setting up the away team CTE

# %% [markdown]
# ## Exercise 14 — Putting the CTEs together *(100 XP)*

# %%
# Exercise 14 — Putting the CTEs together

# %% [markdown]
# ## Exercise 15 — Add a window function *(100 XP)*

# %%
# Exercise 15 — Add a window function

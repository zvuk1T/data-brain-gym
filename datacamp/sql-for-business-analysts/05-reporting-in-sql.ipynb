# %% [markdown]
# # Reporting in SQL
#
# **Platform:** DataCamp
# **Track:** SQL for Business Analysts (Course 5 of 5)
# **Level:** Intermediate
# **Duration:** 4 hours | 15 videos | 54 exercises
# **Database:** PostgreSQL
# **Dataset:** Olympics — global sports event database
#
# ---
#
# **Course Description:**
# Build real-world SQL reports and dashboards for a sports marketing company (DataBallers).
# Topics: base reports, UNION/JOIN combinations, CASE statements, data cleaning & validation, window functions, performance index calculations.
#
# ---
#
# ## Table of Contents
# 1. [Chapter 1: Exploring the Olympics Dataset](#chapter-1)
# 2. [Chapter 2: Creating Reports](#chapter-2)
# 3. [Chapter 3: Cleaning & Validation](#chapter-3)
# 4. [Chapter 4: Complex Calculations](#chapter-4)

# %% [markdown]
# ---
# # Chapter 1: Exploring the Olympics Dataset
#
# Use ER diagrams and data exploration techniques to understand the dataset before building reports.
# **Goal:** Build Report 1 — Most decorated summer athletes.

# %% [markdown]
# ## Exercise 1 — Case study *(Video / 50 XP)*

# %%
# Exercise 1 — Case study

# %% [markdown]
# ## Exercise 2 — Identifying the base report *(50 XP)*

# %%
# Exercise 2 — Identifying the base report

# %% [markdown]
# ## Exercise 3 — Building the base report *(100 XP)*

# %%
# Exercise 3 — Building the base report

# %% [markdown]
# ## Exercise 4 — Athletes vs events by sport *(100 XP)*

# %%
# Exercise 4 — Athletes vs events by sport

# %% [markdown]
# ## Exercise 5 — The Olympics dataset *(Video / 50 XP)*

# %%
# Exercise 5 — The Olympics dataset

# %% [markdown]
# ## Exercise 6 — Planning queries with an E:R diagram *(50 XP)*

# %%
# Exercise 6 — Planning queries with an E:R diagram

# %% [markdown]
# ## Exercise 7 — Age of oldest athlete by region *(100 XP)*

# %%
# Exercise 7 — Age of oldest athlete by region

# %% [markdown]
# ## Exercise 8 — Number of events in each sport *(100 XP)*

# %%
# Exercise 8 — Number of events in each sport

# %% [markdown]
# ## Exercise 9 — Exploring our data *(Video / 50 XP)*

# %%
# Exercise 9 — Exploring our data

# %% [markdown]
# ## Exercise 10 — Exploring summer_games *(100 XP)*

# %%
# Exercise 10 — Exploring summer_games

# %% [markdown]
# ## Exercise 11 — Validating our query *(100 XP)*

# %%
# Exercise 11 — Validating our query

# %% [markdown]
# ## Exercise 12 — Report 1: Most decorated summer athletes *(100 XP)*

# %%
# Exercise 12 — Report 1: Most decorated summer athletes

# %% [markdown]
# ---
# # Chapter 2: Creating Reports
#
# Build complex reports using UNION, JOIN combinations, and CASE statements.
# **Goal:** Build Report 2 — Top athletes in Nobel-prized countries.

# %% [markdown]
# ## Exercise 1 — Planning the query *(Video / 50 XP)*

# %%
# Exercise 1 — Planning the query

# %% [markdown]
# ## Exercise 2 — Planning the SELECT statement *(50 XP)*

# %%
# Exercise 2 — Planning the SELECT statement

# %% [markdown]
# ## Exercise 3 — Planning the filter *(50 XP)*

# %%
# Exercise 3 — Planning the filter

# %% [markdown]
# ## Exercise 4 — Combining tables *(Video / 50 XP)*

# %%
# Exercise 4 — Combining tables

# %% [markdown]
# ## Exercise 5 — JOIN then UNION query *(100 XP)*

# %%
# Exercise 5 — JOIN then UNION query

# %% [markdown]
# ## Exercise 6 — UNION then JOIN query *(100 XP)*

# %%
# Exercise 6 — UNION then JOIN query

# %% [markdown]
# ## Exercise 7 — Creating custom fields *(Video / 50 XP)*

# %%
# Exercise 7 — Creating custom fields

# %% [markdown]
# ## Exercise 8 — CASE statement refresher *(50 XP)*

# %%
# Exercise 8 — CASE statement refresher

# %% [markdown]
# ## Exercise 9 — BMI bucket by sport *(100 XP)*

# %%
# Exercise 9 — BMI bucket by sport

# %% [markdown]
# ## Exercise 10 — Troubleshooting CASE statements *(100 XP)*

# %%
# Exercise 10 — Troubleshooting CASE statements

# %% [markdown]
# ## Exercise 11 — Filtering and finishing touches *(Video / 50 XP)*

# %%
# Exercise 11 — Filtering and finishing touches

# %% [markdown]
# ## Exercise 12 — Filtering with a JOIN *(100 XP)*

# %%
# Exercise 12 — Filtering with a JOIN

# %% [markdown]
# ## Exercise 13 — Filtering with a subquery *(100 XP)*

# %%
# Exercise 13 — Filtering with a subquery

# %% [markdown]
# ## Exercise 14 — Report 2: Top athletes in Nobel-prized countries *(100 XP)*

# %%
# Exercise 14 — Report 2: Top athletes in Nobel-prized countries

# %% [markdown]
# ---
# # Chapter 3: Cleaning & Validation
#
# Ensure reports are accurate: type conversion, string cleaning, null handling, deduplication.
# **Goal:** Build Report 3 — Countries with high medal rates.

# %% [markdown]
# ## Exercise 1 — Converting data types *(Video / 50 XP)*

# %%
# Exercise 1 — Converting data types

# %% [markdown]
# ## Exercise 2 — Identifying data types *(50 XP)*

# %%
# Exercise 2 — Identifying data types

# %% [markdown]
# ## Exercise 3 — Interpreting error messages *(50 XP)*

# %%
# Exercise 3 — Interpreting error messages

# %% [markdown]
# ## Exercise 4 — Using date functions on strings *(100 XP)*

# %%
# Exercise 4 — Using date functions on strings

# %% [markdown]
# ## Exercise 5 — Cleaning strings *(Video / 50 XP)*

# %%
# Exercise 5 — Cleaning strings

# %% [markdown]
# ## Exercise 6 — String functions *(50 XP)*

# %%
# Exercise 6 — String functions

# %% [markdown]
# ## Exercise 7 — Replacing and removing substrings *(100 XP)*

# %%
# Exercise 7 — Replacing and removing substrings

# %% [markdown]
# ## Exercise 8 — Fixing incorrect groupings *(100 XP)*

# %%
# Exercise 8 — Fixing incorrect groupings

# %% [markdown]
# ## Exercise 9 — Dealing with nulls *(Video / 50 XP)*

# %%
# Exercise 9 — Dealing with nulls

# %% [markdown]
# ## Exercise 10 — Filtering out nulls *(100 XP)*

# %%
# Exercise 10 — Filtering out nulls

# %% [markdown]
# ## Exercise 11 — Fixing calculations with coalesce *(100 XP)*

# %%
# Exercise 11 — Fixing calculations with coalesce

# %% [markdown]
# ## Exercise 12 — Report duplication *(Video / 50 XP)*

# %%
# Exercise 12 — Report duplication

# %% [markdown]
# ## Exercise 13 — Identifying duplication *(100 XP)*

# %%
# Exercise 13 — Identifying duplication

# %% [markdown]
# ## Exercise 14 — Fixing duplication through a JOIN *(100 XP)*

# %%
# Exercise 14 — Fixing duplication through a JOIN

# %% [markdown]
# ## Exercise 15 — Report 3: Countries with high medal rates *(100 XP)*

# %%
# Exercise 15 — Report 3: Countries with high medal rates

# %% [markdown]
# ---
# # Chapter 4: Complex Calculations
#
# Window functions, percent of total, performance index, month-over-month comparisons.
# **Goal:** Build Report 4 — Tallest athletes and % GDP by region.

# %% [markdown]
# ## Exercise 1 — Building complex calculations *(Video / 50 XP)*

# %%
# Exercise 1 — Building complex calculations

# %% [markdown]
# ## Exercise 2 — Testing out window functions *(100 XP)*

# %%
# Exercise 2 — Testing out window functions

# %% [markdown]
# ## Exercise 3 — Average total country medals by region *(100 XP)*

# %%
# Exercise 3 — Average total country medals by region

# %% [markdown]
# ## Exercise 4 — Most decorated athlete per region *(100 XP)*

# %%
# Exercise 4 — Most decorated athlete per region

# %% [markdown]
# ## Exercise 5 — Comparing groups *(Video / 50 XP)*

# %%
# Exercise 5 — Comparing groups

# %% [markdown]
# ## Exercise 6 — Volume vs efficiency metrics *(50 XP)*

# %%
# Exercise 6 — Volume vs efficiency metrics

# %% [markdown]
# ## Exercise 7 — Percent of GDP per country *(100 XP)*

# %%
# Exercise 7 — Percent of GDP per country

# %% [markdown]
# ## Exercise 8 — GDP per capita performance index *(100 XP)*

# %%
# Exercise 8 — GDP per capita performance index

# %% [markdown]
# ## Exercise 9 — Comparing dates *(Video / 50 XP)*

# %%
# Exercise 9 — Comparing dates

# %% [markdown]
# ## Exercise 10 — Month-over-month comparison *(100 XP)*

# %%
# Exercise 10 — Month-over-month comparison

# %% [markdown]
# ## Exercise 11 — Week-over-week comparison *(100 XP)*

# %%
# Exercise 11 — Week-over-week comparison

# %% [markdown]
# ## Exercise 12 — Report 4: Tallest athletes and % GDP by region *(100 XP)*

# %%
# Exercise 12 — Report 4: Tallest athletes and % GDP by region

# %% [markdown]
# ## Exercise 13 — Course summary *(50 XP)*

# %%
# Exercise 13 — Course summary

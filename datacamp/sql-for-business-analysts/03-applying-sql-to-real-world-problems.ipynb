# %% [markdown]
# # Applying SQL to Real-World Problems
#
# **Platform:** DataCamp
# **Track:** SQL for Business Analysts (Course 3 of 5)
# **Level:** Intermediate
# **Duration:** 4 hours | 13 videos | 47 exercises
# **Database:** PostgreSQL
# **Dataset:** Pagila — DVD rental store database
#
# ---
#
# **Course Description:**
# Synthesize SQL skills into practical, real-world applications.
# Topics: finding tables using information_schema, storing and managing data with tables and views, SQL best practices and readability.
#
# ---
#
# ## Table of Contents
# 1. [Chapter 1: Use Real-World SQL](#chapter-1)
# 2. [Chapter 2: Find Your Data](#chapter-2)
# 3. [Chapter 3: Manage Your Data](#chapter-3)
# 4. [Chapter 4: Best Practices for Writing SQL](#chapter-4)

# %% [markdown]
# ---
# # Chapter 1: Use Real-World SQL
#
# Review of the most commonly used SQL commands.
# Topics: SELECT, FROM, JOIN, WHERE, ORDER BY, aggregate functions, string/numeric transformations.

# %% [markdown]
# ## Exercise 1 — Essential SQL *(Video / 50 XP)*

# %%
# Exercise 1 — Essential SQL

# %% [markdown]
# ## Exercise 2 — Review the essentials *(100 XP)*

# %%
# Exercise 2 — Review the essentials

# %% [markdown]
# ## Exercise 3 — Practice the essentials *(100 XP)*

# %%
# Exercise 3 — Practice the essentials

# %% [markdown]
# ## Exercise 4 — Transforming your results *(Video / 50 XP)*

# %%
# Exercise 4 — Transforming your results

# %% [markdown]
# ## Exercise 5 — Transform numeric & strings *(100 XP)*

# %%
# Exercise 5 — Transform numeric & strings

# %% [markdown]
# ## Exercise 6 — Extract what you need *(100 XP)*

# %%
# Exercise 6 — Extract what you need

# %% [markdown]
# ## Exercise 7 — Working with aggregate functions *(Video / 50 XP)*

# %%
# Exercise 7 — Working with aggregate functions

# %% [markdown]
# ## Exercise 8 — Aggregating finances *(100 XP)*

# %%
# Exercise 8 — Aggregating finances

# %% [markdown]
# ## Exercise 9 — Aggregating strings *(100 XP)*

# %%
# Exercise 9 — Aggregating strings

# %% [markdown]
# ## Exercise 10 — Which tables? *(50 XP)*

# %%
# Exercise 10 — Which tables?

# %% [markdown]
# ---
# # Chapter 2: Find Your Data
#
# Use `information_schema` to discover tables and columns. Build views to organize data access.

# %% [markdown]
# ## Exercise 1 — Find the right table *(Video / 50 XP)*

# %%
# Exercise 1 — Find the right table

# %% [markdown]
# ## Exercise 2 — LIMITing your search *(100 XP)*

# %%
# Exercise 2 — LIMITing your search

# %% [markdown]
# ## Exercise 3 — Which table to use? *(50 XP)*

# %%
# Exercise 3 — Which table to use?

# %% [markdown]
# ## Exercise 4 — What tables are in your database? *(100 XP)*

# %%
# Exercise 4 — What tables are in your database?

# %% [markdown]
# ## Exercise 5 — Determine the monthly income *(100 XP)*

# %%
# Exercise 5 — Determine the monthly income

# %% [markdown]
# ## Exercise 6 — Join the correct tables *(100 XP)*

# %%
# Exercise 6 — Join the correct tables

# %% [markdown]
# ## Exercise 7 — What columns are in your database? *(Video / 50 XP)*

# %%
# Exercise 7 — What columns are in your database?

# %% [markdown]
# ## Exercise 8 — A VIEW of all your columns *(100 XP)*

# %%
# Exercise 8 — A VIEW of all your columns

# %% [markdown]
# ## Exercise 9 — Testing out your new VIEW *(100 XP)*

# %%
# Exercise 9 — Testing out your new VIEW

# %% [markdown]
# ## Exercise 10 — The average length of films by category *(100 XP)*

# %%
# Exercise 10 — The average length of films by category

# %% [markdown]
# ## Exercise 11 — Complex joins *(100 XP)*

# %%
# Exercise 11 — Complex joins

# %% [markdown]
# ## Exercise 12 — Build the entity relationship diagram *(50 XP)*

# %%
# Exercise 12 — Build the entity relationship diagram

# %% [markdown]
# ## Exercise 13 — Which films are most frequently rented? *(100 XP)*

# %%
# Exercise 13 — Which films are most frequently rented?

# %% [markdown]
# ---
# # Chapter 3: Manage Your Data
#
# Create tables, views, INSERT, UPDATE, DELETE — managing data in a real database.

# %% [markdown]
# ## Exercise 1 — Store your data *(Video / 50 XP)*

# %%
# Exercise 1 — Store your data

# %% [markdown]
# ## Exercise 2 — Storing new data *(100 XP)*

# %%
# Exercise 2 — Storing new data

# %% [markdown]
# ## Exercise 3 — Using existing data *(100 XP)*

# %%
# Exercise 3 — Using existing data

# %% [markdown]
# ## Exercise 4 — TABLE vs VIEW *(50 XP)*

# %%
# Exercise 4 — TABLE vs VIEW

# %% [markdown]
# ## Exercise 5 — Update your data *(Video / 50 XP)*

# %%
# Exercise 5 — Update your data

# %% [markdown]
# ## Exercise 6 — What should you modify? *(50 XP)*

# %%
# Exercise 6 — What should you modify?

# %% [markdown]
# ## Exercise 7 — Update the price of rentals *(100 XP)*

# %%
# Exercise 7 — Update the price of rentals

# %% [markdown]
# ## Exercise 8 — Updated based on other tables *(100 XP)*

# %%
# Exercise 8 — Updated based on other tables

# %% [markdown]
# ## Exercise 9 — Delete your data *(Video / 50 XP)*

# %%
# Exercise 9 — Delete your data

# %% [markdown]
# ## Exercise 10 — Deleting all table data *(100 XP)*

# %%
# Exercise 10 — Deleting all table data

# %% [markdown]
# ## Exercise 11 — Delete selected records *(100 XP)*

# %%
# Exercise 11 — Delete selected records

# %% [markdown]
# ## Exercise 12 — A family friendly video store *(100 XP)*

# %%
# Exercise 12 — A family friendly video store

# %% [markdown]
# ---
# # Chapter 4: Best Practices for Writing SQL
#
# Write SQL code that clearly conveys intent and is easy to read and maintain.

# %% [markdown]
# ## Exercise 1 — Convey your intent *(Video / 50 XP)*

# %%
# Exercise 1 — Convey your intent

# %% [markdown]
# ## Exercise 2 — How to convey our intent *(50 XP)*

# %%
# Exercise 2 — How to convey our intent

# %% [markdown]
# ## Exercise 3 — Clarify the intent of this query *(100 XP)*

# %%
# Exercise 3 — Clarify the intent of this query

# %% [markdown]
# ## Exercise 4 — Fix this query - intent *(100 XP)*

# %%
# Exercise 4 — Fix this query - intent

# %% [markdown]
# ## Exercise 5 — Write readable code *(Video / 50 XP)*

# %%
# Exercise 5 — Write readable code

# %% [markdown]
# ## Exercise 6 — How to make code easier to read *(50 XP)*

# %%
# Exercise 6 — How to make code easier to read

# %% [markdown]
# ## Exercise 7 — Make this query easier to read - Part I *(100 XP)*

# %%
# Exercise 7 — Make this query easier to read - Part I

# %% [markdown]
# ## Exercise 8 — Make this query easier to read - Part II *(100 XP)*

# %%
# Exercise 8 — Make this query easier to read - Part II

# %% [markdown]
# ## Exercise 9 — Avoid common mistakes *(Video / 50 XP)*

# %%
# Exercise 9 — Avoid common mistakes

# %% [markdown]
# ## Exercise 10 — What are the don'ts of writing SQL code? *(50 XP)*

# %%
# Exercise 10 — What are the don'ts of writing SQL code?

# %% [markdown]
# ## Exercise 11 — Apply best practices to your code *(100 XP)*

# %%
# Exercise 11 — Apply best practices to your code

# %% [markdown]
# ## Exercise 12 — Recap *(50 XP)*

# %%
# Exercise 12 — Recap

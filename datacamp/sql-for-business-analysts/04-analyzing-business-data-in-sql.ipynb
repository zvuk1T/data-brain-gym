# %% [markdown]
# # Analyzing Business Data in SQL
#
# **Platform:** DataCamp
# **Track:** SQL for Business Analysts (Course 4 of 5)
# **Level:** Intermediate
# **Duration:** 4 hours | 15 videos | 46 exercises
# **Database:** PostgreSQL
# **Dataset:** Delivr — fictional food delivery startup
#
# ---
#
# **Course Description:**
# Learn key business metrics and write SQL queries to calculate them.
# Topics: revenue, cost, profit, CTEs, user-centric KPIs (MAU, retention, growth), ARPU, histograms, percentiles, executive reporting.
#
# ---
#
# ## Table of Contents
# 1. [Chapter 1: Revenue, Cost, and Profit](#chapter-1)
# 2. [Chapter 2: User-Centric KPIs](#chapter-2)
# 3. [Chapter 3: ARPU, Histograms, and Percentiles](#chapter-3)
# 4. [Chapter 4: Generating an Executive Report](#chapter-4)

# %% [markdown]
# ---
# # Chapter 1: Revenue, Cost, and Profit
#
# Calculate revenue and cost, then combine them with CTEs to compute profit.
# **Tables:** `meals`, `orders`
# **Formula:** `Profit = Revenue - Cost`

# %% [markdown]
# ## Exercise 1 — Revenue *(Video / 50 XP)*

# %%
# Exercise 1 — Revenue

# %% [markdown]
# ## Exercise 2 — Revenue per customer *(100 XP)*

# %%
# Exercise 2 — Revenue per customer

# %% [markdown]
# ## Exercise 3 — Revenue per week *(100 XP)*

# %%
# Exercise 3 — Revenue per week

# %% [markdown]
# ## Exercise 4 — Cost and Common Table Expressions (CTEs) *(Video / 50 XP)*

# %%
# Exercise 4 — Cost and Common Table Expressions (CTEs)

# %% [markdown]
# ## Exercise 5 — Total cost *(50 XP)*

# %%
# Exercise 5 — Total cost

# %% [markdown]
# ## Exercise 6 — Top meals by cost *(100 XP)*

# %%
# Exercise 6 — Top meals by cost

# %% [markdown]
# ## Exercise 7 — Using CTEs *(100 XP)*

# %%
# Exercise 7 — Using CTEs

# %% [markdown]
# ## Exercise 8 — Profit *(Video / 50 XP)*

# %%
# Exercise 8 — Profit

# %% [markdown]
# ## Exercise 9 — Profit per eatery *(100 XP)*

# %%
# Exercise 9 — Profit per eatery

# %% [markdown]
# ## Exercise 10 — Profit per month *(100 XP)*

# %%
# Exercise 10 — Profit per month

# %% [markdown]
# ---
# # Chapter 2: User-Centric KPIs
#
# Registrations, Monthly Active Users (MAU), growth rate, retention — key user metrics.

# %% [markdown]
# ## Exercise 1 — Registrations and active users *(Video / 50 XP)*

# %%
# Exercise 1 — Registrations and active users

# %% [markdown]
# ## Exercise 2 — Registrations by month *(100 XP)*

# %%
# Exercise 2 — Registrations by month

# %% [markdown]
# ## Exercise 3 — Monthly active users (MAU) *(100 XP)*

# %%
# Exercise 3 — Monthly active users (MAU)

# %% [markdown]
# ## Exercise 4 — Window functions *(Video / 50 XP)*

# %%
# Exercise 4 — Window functions

# %% [markdown]
# ## Exercise 5 — Registrations running total *(100 XP)*

# %%
# Exercise 5 — Registrations running total

# %% [markdown]
# ## Exercise 6 — MAU monitor (I) *(100 XP)*

# %%
# Exercise 6 — MAU monitor (I)

# %% [markdown]
# ## Exercise 7 — Growth *(Video / 50 XP)*

# %%
# Exercise 7 — Growth

# %% [markdown]
# ## Exercise 8 — MAU monitor (II) *(100 XP)*

# %%
# Exercise 8 — MAU monitor (II)

# %% [markdown]
# ## Exercise 9 — MAU monitor (III) *(100 XP)*

# %%
# Exercise 9 — MAU monitor (III)

# %% [markdown]
# ## Exercise 10 — Order growth rate *(100 XP)*

# %%
# Exercise 10 — Order growth rate

# %% [markdown]
# ## Exercise 11 — Retention *(Video / 50 XP)*

# %%
# Exercise 11 — Retention

# %% [markdown]
# ## Exercise 12 — New, retained, and resurrected users *(100 XP)*

# %%
# Exercise 12 — New, retained, and resurrected users

# %% [markdown]
# ## Exercise 13 — Retention rate *(100 XP)*

# %%
# Exercise 13 — Retention rate

# %% [markdown]
# ---
# # Chapter 3: ARPU, Histograms, and Percentiles
#
# Unit economics: Average Revenue Per User (ARPU), revenue distributions, bucketing, percentiles.

# %% [markdown]
# ## Exercise 1 — Unit economics *(Video / 50 XP)*

# %%
# Exercise 1 — Unit economics

# %% [markdown]
# ## Exercise 2 — Average revenue per user *(100 XP)*

# %%
# Exercise 2 — Average revenue per user

# %% [markdown]
# ## Exercise 3 — ARPU per week *(100 XP)*

# %%
# Exercise 3 — ARPU per week

# %% [markdown]
# ## Exercise 4 — Average orders per user *(100 XP)*

# %%
# Exercise 4 — Average orders per user

# %% [markdown]
# ## Exercise 5 — Histograms *(Video / 50 XP)*

# %%
# Exercise 5 — Histograms

# %% [markdown]
# ## Exercise 6 — Histogram of revenue *(100 XP)*

# %%
# Exercise 6 — Histogram of revenue

# %% [markdown]
# ## Exercise 7 — Histogram of orders *(100 XP)*

# %%
# Exercise 7 — Histogram of orders

# %% [markdown]
# ## Exercise 8 — Bucketing *(Video / 50 XP)*

# %%
# Exercise 8 — Bucketing

# %% [markdown]
# ## Exercise 9 — Bucketing users by revenue *(100 XP)*

# %%
# Exercise 9 — Bucketing users by revenue

# %% [markdown]
# ## Exercise 10 — Bucketing users by orders *(100 XP)*

# %%
# Exercise 10 — Bucketing users by orders

# %% [markdown]
# ## Exercise 11 — Percentiles *(Video / 50 XP)*

# %%
# Exercise 11 — Percentiles

# %% [markdown]
# ## Exercise 12 — Revenue quartiles *(100 XP)*

# %%
# Exercise 12 — Revenue quartiles

# %% [markdown]
# ## Exercise 13 — Interquartile range *(100 XP)*

# %%
# Exercise 13 — Interquartile range

# %% [markdown]
# ---
# # Chapter 4: Generating an Executive Report
#
# Combine all skills to produce a polished, report-ready executive summary.
# Topics: date formatting, RANK, pivoting with CROSSTAB, final report assembly.

# %% [markdown]
# ## Exercise 1 — Survey of useful functions *(Video / 50 XP)*

# %%
# Exercise 1 — Survey of useful functions

# %% [markdown]
# ## Exercise 2 — Formatting dates *(100 XP)*

# %%
# Exercise 2 — Formatting dates

# %% [markdown]
# ## Exercise 3 — Rank users by their count of orders *(100 XP)*

# %%
# Exercise 3 — Rank users by their count of orders

# %% [markdown]
# ## Exercise 4 — Pivoting *(Video / 50 XP)*

# %%
# Exercise 4 — Pivoting

# %% [markdown]
# ## Exercise 5 — Pivoting user revenues by month *(100 XP)*

# %%
# Exercise 5 — Pivoting user revenues by month

# %% [markdown]
# ## Exercise 6 — Costs *(100 XP)*

# %%
# Exercise 6 — Costs

# %% [markdown]
# ## Exercise 7 — Producing executive reports *(Video / 50 XP)*

# %%
# Exercise 7 — Producing executive reports

# %% [markdown]
# ## Exercise 8 — Report readability *(100 XP)*

# %%
# Exercise 8 — Report readability

# %% [markdown]
# ## Exercise 9 — Executive report *(100 XP)*

# %%
# Exercise 9 — Executive report

# %% [markdown]
# ## Exercise 10 — Course recap *(50 XP)*

# %%
# Exercise 10 — Course recap

# %% [markdown]
# ## Course 3: Introduction to Data Literacy <a id="course-3"></a>
#
# **Level:** Basic | **Updated:** 2024
# **Duration:** 4 hr | **Chapters:** 4 | **Instructors:** Jess Ahmet (Ch1–2) · Carl Rosseel (Ch3–4)
# **XP:** 4000 | **Status:** 🔄 In Progress
# **Part of tracks:** Data Literacy Professional
#
# > 🎯 **Key question this course answers:** What does it mean to be data literate — and how do you move from raw data to decisions that matter?
#
# ---
#
# ### 🎯 What you'll learn
# - **Assess** typical data quality issues — including errors, missing values, and bias — and evaluate appropriate cleaning or mitigation strategies
# - **Define** data literacy and its four core abilities of reading, working with, analyzing, and communicating data
# - **Differentiate** descriptive, diagnostic, predictive, and prescriptive analytics to determine the most suitable method for a given problem
# - **Identify** common data sources, data types, and storage options such as relational databases, document stores, data warehouses, and data lakes
# - **Recognize** effective techniques for communicating insights, including selecting suitable visualizations, applying narrative structure, and focusing messages for stakeholders
#
# ---
#
# ### Course description
# Data is all around us, which makes data literacy an essential life skill. It is a skill that empowers you to ask the right questions about data and choose the right tools to read, interpret and communicate data. This non-technical course will equip you with the necessary knowledge and skill to feel confident around data and understand how data can be used to gain actionable insights and drive change.
#
# ---
#
# ### Chapter 1: Data Literacy Basics
#
# *Why should you become data-literate? You'll learn why data literacy is an essential skill, how to get from data to insights, and how data can help with decision-making.*
# *Arc: L1–4 → what data literacy is · L5–8 → DIKW pyramid · L9–13 → data-driven decision making*
#
# | # | Lesson | Type | XP |
# |---|--------|------|----|
# | 1 | Why data literacy is an essential skill | 🎬 Video | 50 |
# | 2 | Defining data literacy | 📝 Exercise | 50 |
# | 3 | The data literacy toolbox | 📝 Exercise | 100 |
# | 4 | Data literacy in action | 🔁 Practice | 50 |
# | 5 | From data to insights | 🎬 Video | 50 |
# | 6 | DIKW pyramid as a process | 📝 Exercise | 100 |
# | 7 | What is insight? | 📝 Exercise | 50 |
# | 8 | The DIKW journey | 🔁 Practice | 50 |
# | 9 | Data-driven decision making | 🎬 Video | 50 |
# | 10 | Becoming data-driven | 📝 Exercise | 50 |
# | 11 | Facts & myths about being data-driven | 📝 Exercise | 100 |
# | 12 | The data-driven process | 🔁 Practice | 50 |
# | 13 | Fitting the problem statement | 🔁 Practice | 50 |
#
# **Chapter 1 XP: 800**
#
# ---
#
# ### Chapter 2: Reading Data
#
# *Data is everywhere — but how do you find the right data for your problem? You'll learn about data sources, common types of data, how to manage data, and what to do about common data problems.*
# *Arc: L1–4 → data sources · L5–8 → data types · L9–12 → managing data · L13–16 → data problems*
#
# | # | Lesson | Type | XP |
# |---|--------|------|----|
# | 1 | Data is all around us | 🎬 Video | 50 |
# | 2 | Finding the right data | 🔁 Practice | 50 |
# | 3 | Finding the right data source | 📝 Exercise | 50 |
# | 4 | Open vs. internal data sources | 📝 Exercise | 100 |
# | 5 | Common data types | 🎬 Video | 50 |
# | 6 | Importance of data types | 📝 Exercise | 50 |
# | 7 | Structured vs. unstructured data | 📝 Exercise | 100 |
# | 8 | Quantitative vs. qualitative data | 🔁 Practice | 50 |
# | 9 | Managing data | 🎬 Video | 50 |
# | 10 | Using databases | 📝 Exercise | 100 |
# | 11 | Storage in the cloud | 📝 Exercise | 50 |
# | 12 | Which tool do you need? | 📝 Exercise | 100 |
# | 13 | Common data problems | 🎬 Video | 50 |
# | 14 | Consequences of data problems | 📝 Exercise | 50 |
# | 15 | Find the data problems | 🔁 Practice | 50 |
# | 16 | Countering dirty data and data bias | 📝 Exercise | 100 |
#
# **Chapter 2 XP: 1050**
#
# ---
#
# ### Chapter 3: Working with and Analyzing Data
#
# *You'll dive deeper into how to analyze data to get the insights you need. You'll learn how and when to use the four types of analytics: descriptive, diagnostic, predictive, and prescriptive.*
# *Arc: L1–4 → descriptive · L5–8 → diagnostic · L9–12 → predictive · L13–16 → prescriptive*
#
# | # | Lesson | Type | XP |
# |---|--------|------|----|
# | 1 | Descriptive analytics | 🎬 Video | 50 |
# | 2 | Reasons (not) to use descriptive analytics | 📝 Exercise | 50 |
# | 3 | Exploring the data | 🔁 Practice | 50 |
# | 4 | Exploring connections | 🔁 Practice | 50 |
# | 5 | Diagnostic analytics | 🎬 Video | 50 |
# | 6 | Finding causes | 📝 Exercise | 50 |
# | 7 | Root cause analysis steps | 📝 Exercise | 100 |
# | 8 | Descriptive vs. diagnostic analytics | 📝 Exercise | 100 |
# | 9 | Predictive analytics | 🎬 Video | 50 |
# | 10 | Are we predicting yet? | 🔁 Practice | 50 |
# | 11 | Building a predictive model | 📝 Exercise | 100 |
# | 12 | Looking into the future | 🔁 Practice | 50 |
# | 13 | Prescriptive analytics | 🎬 Video | 50 |
# | 14 | Characteristics of prescriptive analytics | 📝 Exercise | 50 |
# | 15 | Predictive vs. prescriptive analytics | 📝 Exercise | 100 |
# | 16 | Matching use cases to the type of analytics | 📝 Exercise | 100 |
#
# **Chapter 3 XP: 1050**
#
# ---
#
# ### Chapter 4: Communicating Insights
#
# *In the final chapter, you'll cover communicating the insights you gained from your data. You'll learn how to use visualizations and storytelling to craft an engaging data story and learn about the three keys to communicating effectively.*
# *Arc: L1–5 → visualizations · L6–10 → storytelling · L11–15 → three keys + case study · L16 → wrap-up*
#
# | # | Lesson | Type | XP |
# |---|--------|------|----|
# | 1 | Data visualizations | 🎬 Video | 50 |
# | 2 | The purpose of visualizations | 📝 Exercise | 50 |
# | 3 | Providing context | 📝 Exercise | 100 |
# | 4 | Data storytelling | 🎬 Video | 50 |
# | 5 | (Not) part of the story | 📝 Exercise | 50 |
# | 6 | Crafting a story | 📝 Exercise | 100 |
# | 7 | Three keys to communicating effectively | 🎬 Video | 50 |
# | 8 | Focus on your central message | 📝 Exercise | 100 |
# | 9 | Getting your outline in order | 📝 Exercise | 100 |
# | 10 | The importance of form | 📝 Exercise | 50 |
# | 11 | From data to story: a case study | 🎬 Video | 50 |
# | 12 | Formulating the central message | 📝 Exercise | 50 |
# | 13 | Setting up the narrative structure | 📝 Exercise | 100 |
# | 14 | Choosing visualizations | 🔁 Practice | 50 |
# | 15 | Best and bad practices | 📝 Exercise | 100 |
# | 16 | Wrap-up | 🎬 Video | 50 |
#
# **Chapter 4 XP: 1100**
#
# ---
#
# **Total course XP: 4000 | 4 chapters | 61 lessons**

# %% [markdown]
# ---
#
# ## 📚 Course Knowledge Map — Pre-loaded from PDF Slide Decks
#
# *Source: chapter1.pdf · chapter2.pdf · chapter3.pdf · chapter4.pdf*
# *Purpose: reference map for building lesson cells — do not add lesson content here*
#
# ---
#
# ### CHAPTER 1 — Data Literacy Basics
#
# ```
# DATA LITERACY
# │
# ├── Definition
# │   └── The ability to READ, WORK WITH, ANALYZE, and COMMUNICATE insights with data
# │       ├── Reading data        → identify sources, collect, manage
# │       ├── Working with data   → turn data into insights (analytics)
# │       └── Communicating       → visualizations, storytelling
# │
# ├── DIKW Pyramid (Data → Information → Knowledge → Wisdom)
# │   ├── Data        → raw observations, unorganized, no meaning yet
# │   │                 (e.g. thermometer shows 15°C, dark clouds)
# │   ├── Information → data placed into context, organized/aggregated
# │   │                 (e.g. temp dropped → clouds formed → rain started)
# │   ├── Knowledge   → combine information, detect patterns, generalizations
# │   │                 (e.g. temp drop + dark clouds predicts rain)
# │   └── Wisdom      → applied knowledge to act proactively
# │                     (e.g. I know when rain comes → I bring umbrella)
# │
# │   > Insights are the key output between Knowledge and Wisdom
# │
# └── Data-Driven Decision Making
#     ├── Definition: using data to make informed decisions and act on them
#     ├── Benefits: optimize performance · better understanding · protect against risks
#     ├── Misconceptions:
#     │   ├── NOT only for large organizations
#     │   ├── NOT only the data team's responsibility
#     │   └── NOT always the best or only answer
#     ├── 5-step data-driven process:
#     │   Define problem → Collect data → Analyze data → Draw insights → Take action
#     └── Problem statement qualities: clearly defined · actionable · realistic
#         Categories: describe state · diagnose causes · detect anomalies / predict
# ```
#
# ---
#
# ### CHAPTER 2 — Reading Data
#
# ```
# READING DATA
# │
# ├── Data Sources
# │   ├── Open data   → public databases (data.gov, data.europe.eu), public APIs
# │   │                 (Twitter, Google Maps, IMDB, Wikipedia)
# │   └── Internal data → customer data, transaction data, website data, survey data
# │
# ├── Data Types
# │   ├── Structured vs. Unstructured
# │   │   ├── Structured    → tabular, easy to search, relational databases
# │   │   │                   (spreadsheets, data tables)
# │   │   └── Unstructured  → no pre-defined structure, harder to search
# │   │                       (images, video, sound, text)
# │   │
# │   └── Quantitative vs. Qualitative
# │       ├── Quantitative  → numbers, measurable, wider analysis range
# │       │                   (count of scoops, minutes, length)
# │       └── Qualitative   → categories, observable, restricted analysis range
# │                           (flavor, color, cone or cup)
# │
# ├── Managing Data
# │   ├── DBMS: software for managing databases (data engineer responsibility)
# │   ├── Database types: relational vs. document · data warehouse vs. data lake
# │   ├── Cloud storage: remote servers, cost-effective, third-party security dependency
# │   ├── Pipelines: ETL (Extract → Transform → Load) — automated, keeps data up-to-date
# │   ├── Querying: SQL to access/retrieve data; R or Python for further analysis
# │   └── Dashboards: KPIs at a glance, linked to database, created by data analyst
# │
# └── Common Data Problems (Dirty Data)
#     ├── Dirty data = incorrect · incomplete · inconsistent
#     │   Cause: human error · technical issues · collection process
#     │   Principle: Garbage In, Garbage Out → wrong conclusions
#     │
#     ├── Data errors    → incorrect/inconsistent values or formats
#     │   Counter: correct if original known; drop if unknown
#     ├── Missing data   → incomplete records
#     │   Problematic when: many missing · underlying patterns in missing data
#     │   Counter: drop data OR imputation
#     └── Data bias      → societal bias reflected in data → unrepresentative results
#         Hard to detect and resolve
#         Counter: sound collection process · awareness in conclusions · explainable AI
# ```
#
# > **Cleaning rule:** Not all data problems are fully solvable — but it is always possible to do *some* kind of analysis.
#
# ---
#
# ### CHAPTER 3 — Working with and Analyzing Data
#
# ```
# 4 TYPES OF ANALYTICS
# │
# ├── Descriptive   → WHAT happened?
# │   ├── Goal: get to know data, investigate relationships, prep for advanced techniques
# │   ├── Techniques: descriptive statistics · visualizations · outlier detection · EDA
# │   └── EDA: assess characteristics · find patterns/groups · suggest hypotheses
# │       (valuable on its own, not just prep work)
# │
# ├── Diagnostic    → WHY did it happen?
# │   ├── Goal: find causes, investigate causal relationships, suggest solutions
# │   │   ⚠ Can suggest causes — cannot PROVE causality on its own
# │   ├── Techniques: drill-down · correlation/regression · hypothesis testing · RCA
# │   └── Root Cause Analysis (RCA): structured method to trace event to its source
# │
# ├── Predictive    → WHAT will happen?
# │   ├── Goal: anticipate outcomes, forecast processes, estimate unknowns
# │   │   ⚠ Always a degree of uncertainty — predictions are not certainties
# │   ├── Techniques:
# │   │   ├── ML classification  (predicting subscription cancellations)
# │   │   ├── ML regression      (predicting housing prices)
# │   │   ├── Time series        (predicting sales revenue over time)
# │   │   └── Predictive text    (spam detection)
# │   └── Modeling: data split into training set + test set → evaluate with accuracy metric
# │
# └── Prescriptive  → WHAT should we do?
#     ├── Goal: make informed decisions, optimize processes, mitigate risks
#     ├── Techniques: rule-based systems · reinforcement learning · simulation · recommendation engine
#     └── Recommendation engine: predicts interests from past behavior → provides recommendations
# ```
#
# > **Decision rule:** Match the analytics type to the question — *What happened?* → Descriptive · *Why?* → Diagnostic · *What will?* → Predictive · *What to do?* → Prescriptive
#
# ---
#
# ### CHAPTER 4 — Communicating Insights
#
# ```
# COMMUNICATING INSIGHTS
# │
# ├── Data Visualizations
# │   ├── Purpose: understand complex data at a glance, support EDA, dashboards, infographics
# │   ├── Chart types:
# │   │   ├── Trend          → line chart
# │   │   ├── Relationships  → bar chart, scatter plot
# │   │   └── Distributions  → histogram, box plot
# │   └── What makes a good visualization:
# │       ├── Eliminate clutter  → less is more, clarity and readability
# │       ├── Focus attention    → link to insight, highlight key aspects
# │       └── Provide context    → McCandless technique
# │
# │   McCandless technique (5 steps):
# │   1. Introduce the visualization
# │   2. Anticipate obvious questions
# │   3. State the central insight
# │   4. Provide supporting evidence
# │   5. Closing statement
# │
# ├── Data Storytelling
# │   ├── Why: memorable · keeps attention · convinces audience · motivates action
# │   ├── Components: Visualization + Narrative + Context (same as Course 2)
# │   └── Narrative elements:
# │       ├── Characters  → Stakeholders
# │       ├── Problem     → Business problem
# │       ├── Setting     → Relevant background
# │       ├── Plot        → Central + supporting insights
# │       └── Resolution  → Solution + recommendations
# │
# └── Three Keys to Communicating Effectively
#     ├── Focus     → select right data · right visualizations · keep central message
#     │   Central message = Problem + Insights + Impact (3-sentence formula)
#     ├── Structure → storytelling + McCandless · visual layout · outline as blueprint
#     │   Outline: Introduction (problem, context, objectives) → Body (data, analysis, findings)
#     │            → Conclusions (insights, recommendations)
#     └── Form      → medium (oral vs. written) · language (technical vs. non-technical)
#                     scope (short vs. long-form) · audience (who, what they need, what they want)
# ```
#
# > **Case study pattern (Ch4 wrap-up):** Customer churn problem → formulate central message (Problem + Insights + Impact) → set up narrative structure → choose visualizations per insight → apply McCandless. This is the full pipeline from insight to story.

# %% [markdown]
# ---
#
# ## Chapter 1 — Data Literacy Basics
#
# #### Chapter 1 — Lesson 1: Why data literacy is an essential skill *(Video / 50 XP)*
#
# > 🎬 [Watch on DataCamp](https://campus.datacamp.com/courses/introduction-to-data-literacy/data-literacy-basics?ex=1) *(requires login)*
#
# ---
#
# **🎯 GOAL — What is this lesson about?**
# Data literacy is a life skill for the data era — not a technical skill. This lesson defines what data literacy means, establishes its three core components, and frames the entire course around them.
#
# ---
#
# Data literacy is the ability to **read, work with, analyze, and communicate insights with data**. It has three components:
#
# - **Reading data** — identifying relevant sources, collecting and managing data
# - **Working with and analyzing data** — turning data into insights using analytics (descriptive, predictive, etc.)
# - **Communicating insights** — demonstrating the value of insights and defining actions based on them; tools are visualizations and storytelling
#
# Data literacy is not about coding or understanding the maths behind an analysis. It is about critically thinking about data — understanding its relevance, placing it in context, knowing both its potential and its limits. Like driving a car: you don't need to know what's under the hood, but you must know the difference between the brakes and the gas.
#
# ---
#
# **💡 Why this matters**
# A data analyst who cannot communicate insights produces findings that die in a spreadsheet. Data literacy defines the full chain from source to decision. Understanding the three-component structure helps any professional see where a breakdown happens — and what to fix: is the data being read correctly? Is the analysis appropriate? Is the insight reaching the decision-maker in a usable form?
#
# **✅ RECAP**
# - Data literacy = Read · Work with & Analyze · Communicate — three components, one chain
# - It is a critical thinking skill, not a technical one — relevance, context, potential, limits
# - No insight is valuable without communication — defining actions is as important as finding them
#
# **🔗 Connection**
# - The three components map directly onto the course structure: Ch2 = Reading · Ch3 = Analyzing · Ch4 = Communicating — this lesson is the thesis of the entire course
# - The same three-part chain appears in Course 2 (*Communicating Data Insights*) — data literacy is the frame, storytelling is one execution of it

# %% [markdown]
# #### Chapter 1 — Lesson 2: Defining data literacy *(Exercise / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Can you identify what data literacy explicitly excludes — separating its three genuine components from the common misconception that it requires mathematical or technical skill.
#
# ---
#
# **📋 Scenario**
# Data is all around us; we can learn so much about the world around us through data. Being data literate in today's world is important in helping us understand how data can be combined and connected to create value.
#
# **Task:** What is **not** a component of data literacy?
#
# ---
#
# **✅ Solution**
#
# | Option | Component? | Why |
# |--------|-----------|-----|
# | The ability to communicate insights effectively | ✅ Yes — is a component | Communicating insights is the third component of data literacy |
# | **The ability to read and understand mathematical functions** | ❌ No — correct answer | Data literacy explicitly excludes technical/mathematical skill — it is about critical thinking, not maths |
# | The ability to identify potential data sources | ✅ Yes — is a component | Part of Reading data (identifying relevant sources) |
# | The ability to understand how to get from data to insights | ✅ Yes — is a component | Working with and analyzing data — turning data into insights |
#
# ---
#
# **💡 Why this matters**
# The most common barrier to data literacy adoption is the belief that it requires coding or statistical knowledge. That belief is wrong — and this exercise exists to correct it explicitly. A business analyst, a marketing manager, or a product owner can be fully data literate without writing a single line of code. Knowing this opens the door to data literacy for entire organisations, not just data teams.
#
# **✅ RECAP**
# - Three components: Read · Work with & Analyze · Communicate — mathematical skill is not one of them
# - Data literacy is a critical thinking skill, not a technical qualification
# - This distinction matters for adoption: if data literacy sounds like "learning maths", most people will disengage
#
# **🔗 Connection**
# - This exercise is the first test of L1's key message — the car analogy in action: you don't need to understand the engine
# - The misconception being corrected here reappears in Ch1 L10–L11 (*Facts & myths about being data-driven*) — the same pattern of dismantling false assumptions

# %% [markdown]
# #### Chapter 1 — Lesson 3: The data literacy toolbox *(Exercise / 100 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Can you match the five concrete tools of data literacy to the correct component — proving that the three-component definition maps onto real, named practices.
#
# ---
#
# **📋 Scenario**
# To help us read, analyze and communicate data, there are several tools at our disposal.
#
# **Task:** Link the different tools to the right data literacy component.
#
# ---
#
# **✅ Solution**
#
# | Tool | Component | Why |
# |------|-----------|-----|
# | Database | Reading | Databases store and organize data — the infrastructure for collecting and managing data |
# | Predictive analytics | Analyzing | Forecasts outcomes from data — a core analytical technique |
# | Descriptive analytics | Analyzing | Summarizes what happened in data — the starting point of analysis |
# | Storytelling | Communicating | Structures insights into a narrative that drives action |
# | Visualizations | Communicating | Makes insights visible and understandable at a glance |
#
# ---
#
# **💡 Why this matters**
# Knowing the three components abstractly is not enough — you need to recognize the tools in practice. A database is not just IT infrastructure; it is the reading layer. Predictive and descriptive analytics are not just "data science"; they are the analyzing layer. Storytelling and visualizations are not just presentation skills; they are the communicating layer. This mapping makes data literacy concrete and actionable.
#
# **✅ RECAP**
# - Reading tools: databases (store, organize, manage data)
# - Analyzing tools: descriptive analytics (what happened) + predictive analytics (what will happen)
# - Communicating tools: storytelling + visualizations
# - Five tools, three components — the full toolbox of data literacy
#
# **🔗 Connection**
# - Each tool gets its own chapter: databases in Ch2, analytics types in Ch3, storytelling and visualizations in Ch4 — this exercise is a preview of the entire course in five items
# - Descriptive vs. predictive analytics is introduced here as a pair — Ch3 expands this to four types (adding diagnostic and prescriptive)

# %% [markdown]
# #### Chapter 1 — Lesson 4: Data literacy in action *(Practice / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Recognise that data literacy is universal — not limited to data professionals — by identifying the one thing a marketing manager, HR specialist, nurse, and teacher all have in common.
#
# ---
#
# **📋 Scenario**
# Four professionals from completely different fields — Sarah (marketing manager), Marcus (HR specialist), Elena (registered nurse), James (high school teacher) — all use data literacy in their daily work.
#
# **Task:** What do all four professionals have in common?
#
# ---
#
# **✅ Solution**
#
# | Option | Verdict | Why |
# |--------|---------|-----|
# | They all write code to build databases and analytics tools | ❌ | Technical coding is explicitly excluded from data literacy |
# | **They all critically engage with data to inform their decisions** | ✅ Correct | Data literacy = critically engaging with data — regardless of field or technical background |
# | They all perform complex statistical calculations on datasets | ❌ | Statistical expertise is not a requirement of data literacy |
# | They all create advanced visualizations using specialized software | ❌ | Specialist software skills are not a requirement of data literacy |
#
# > DataCamp: *"This is the core of data literacy: critically engaging with data without needing technical expertise."*
#
# ---
#
# **💡 Why this matters**
# Data literacy is not a job title — it is a capacity. A nurse using patient data to track treatment outcomes, a teacher using test scores to identify struggling students, an HR specialist using turnover data to flag retention risk — these are all data literacy in practice. This universality is the reason data literacy training matters for entire organisations, not just analytics departments.
#
# **✅ RECAP**
# - Data literacy applies across all professions — the field is irrelevant, the critical engagement with data is not
# - The common thread: read → interpret → communicate → decide
# - Technical skill (code, statistics, specialized software) is a distractor — not a component of data literacy
#
# **🔗 Connection**
# - L1–L4 form a complete opening arc: define it (L1) → test the definition (L2) → map the tools (L3) → see it in the real world (L4)
# - The four professionals here reframe data literacy from "a data team skill" to "a life skill" — the same shift the course description makes in its opening line

# %% [markdown]
# #### Chapter 1 — Lesson 5: From data to insights *(Video / 50 XP)*
#
# > 🎬 [Watch on DataCamp](https://campus.datacamp.com/courses/introduction-to-data-literacy/data-literacy-basics?ex=5) *(requires login)*
#
# ---
#
# **🎯 GOAL — What is this lesson about?**
# The DIKW pyramid (Data → Information → Knowledge → Wisdom) explains how raw observations become actionable understanding — and why *insights* are the realistic bridge between knowledge and wisdom.
#
# ---
#
# The **DIKW pyramid** has four levels, each adding something new:
#
# | Level | What it is | What is added | Weather example |
# |-------|-----------|---------------|-----------------|
# | **Data** | Raw observations, unorganized, no meaning yet | — | 15°C · dark clouds · raindrops |
# | **Information** | Data placed into context, organized or aggregated | Context | Temperature dropped → clouds formed → rain started |
# | **Knowledge** | Information combined to detect patterns and make connections | Meaning | Temp drop + dark clouds = rain coming |
# | **Wisdom** | Applied knowledge — acting proactively | Action | I know when rain comes → I bring my umbrella |
#
# The step from Knowledge to Wisdom is the hardest — wisdom implies complete, perfect knowledge, which is never fully reachable. **Insights** are the solution: realistic gold nuggets of applied knowledge that move us closer to wisdom step by step. Each new insight (humidity predicts better than temperature → atmospheric pressure predicts days ahead) improves the picture without requiring perfection.
#
# ---
#
# **💡 Why this matters**
# Every data project sits somewhere on the DIKW pyramid. Raw data from a database is not an insight — it is the starting point. A dashboard showing trends is information. A pattern identified across multiple dashboards is knowledge. A recommendation to a decision-maker — *do this because of what the data shows* — is wisdom. Knowing where your current work sits on the pyramid tells you what the next step is.
#
# **→** *The goal is not perfect wisdom — it's accumulating enough insights to act better than before.*
#
# **✅ RECAP**
# - Data → Information: context is added (organize, aggregate)
# - Information → Knowledge: meaning is added (patterns, connections, predictions)
# - Knowledge → Wisdom: action is added — but perfect wisdom is unreachable
# - Insights bridge the gap: realistic, achievable units of applied knowledge
# - Each new insight brings us one step closer to the full picture
#
# **🔗 Connection**
# - The DIKW pyramid is the theoretical spine of the entire course — Ch2 (reading) operates at the Data/Information level, Ch3 (analyzing) at the Knowledge level, Ch4 (communicating) at the Wisdom/Insight level
# - "Insights" as the output of analysis is the same concept Course 2 built around — storytelling exists to communicate insights, not raw data

# %% [markdown]
# #### Chapter 1 — Lesson 6: DIKW pyramid as a process *(Exercise / 100 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Can you translate the four DIKW levels from abstract labels into concrete actions — matching each step to what you actually *do* at that level.
#
# ---
#
# **📋 Scenario**
# Getting from data to wisdom according to the DIKW framework takes different steps, each taking us one level higher on the pyramid.
#
# **Task:** Order the items to match the DIKW steps: Data · Information · Knowledge · Wisdom.
#
# ---
#
# **✅ Solution**
#
# | Order | DIKW Level | Action |
# |-------|-----------|--------|
# | 1 | **Data** | Make observations and measurements |
# | 2 | **Information** | Put raw data into context |
# | 3 | **Knowledge** | Connect different pieces of information and gain meaning |
# | 4 | **Wisdom** | Apply knowledge to take action |
#
# > DataCamp: *"Gaining meaning is the bridge between information and knowledge."* — the most commonly confused step. Meaning is added at the Knowledge level, not the Information level.
#
# ---
#
# **💡 Why this matters**
# The common failure in data work is stopping at Information — producing a dashboard, a report, a chart — and calling it done. The DIKW framework makes the gap visible: organized data is not insight, and insight is not action. Knowing which step you are currently on tells you exactly what is still missing before a decision can be made.
#
# **→** *If your deliverable doesn't change how someone acts, you haven't reached Wisdom yet — keep going.*
#
# **✅ RECAP**
# - Data = observations and measurements (raw, no meaning)
# - Information = data in context (organized, aggregated)
# - Knowledge = meaning extracted (patterns, connections) — *gaining meaning* is the bridge from Information
# - Wisdom = knowledge in action (proactive, decision-enabling)
# - The most common trap: confusing Information (organized data) with Knowledge (meaning extracted)
#
# **🔗 Connection**
# - This exercise operationalises L5 — the pyramid is no longer a diagram, it's a checklist of what you still need to do
# - "Apply knowledge to take action" is the definition of the Communicating component from L1 — DIKW and the three data literacy components describe the same journey from two angles

# %% [markdown]
# #### Chapter 1 — Lesson 7: What is insight? *(Exercise / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Can you distinguish the precise role of *insight* in the DIKW pyramid — separating what insight does from what wisdom does, since they are easily confused.
#
# ---
#
# **📋 Scenario**
# Insight is the bridge between knowledge and wisdom.
#
# **Task:** What is **not** a characteristic of insight?
#
# ---
#
# **✅ Solution**
#
# | Option | Characteristic of insight? | Why |
# |--------|---------------------------|-----|
# | Insight allows us to get closer to the ideal of wisdom | ✅ Yes | Insights accumulate and bring us step-by-step closer to wisdom |
# | Insight is valuable, and can realistically be achieved | ✅ Yes | Insight is described as the "gold nugget" — achievable, unlike perfect wisdom |
# | **Insight allows us to apply knowledge and take action** | ❌ No — correct answer | Applying knowledge to take action is the definition of *wisdom*, not insight. Insight bridges knowledge and wisdom — the action belongs to wisdom |
# | Wisdom can be approached, but not quite fully reached | ✅ Yes | This is also a property of insight's role — insight is how we approach wisdom without claiming to have reached it |
#
# > DataCamp: *"Insight is the bridge between knowledge and wisdom."* — The trap: option 4 describes the nature of wisdom (unreachable ideal), which is also where insight leads. Option 3 describes the action that belongs to wisdom alone.
#
# ---
#
# **💡 Why this matters**
# In practice, the insight/wisdom boundary matters when presenting findings. Presenting an insight is saying: *"here is what the data shows."* Wisdom is the step after: *"here is what we should do."* A data analyst produces insights — the decision-maker applies them as wisdom. Confusing the two either oversteps the analyst's role or leaves the decision-maker without direction.
#
# **✅ RECAP**
# - Insight = bridge between knowledge and wisdom — valuable, realistic, accumulative
# - Wisdom = applying knowledge to take action — the step insight enables but does not itself perform
# - The trap: "applying knowledge to take action" sounds like insight but is the definition of wisdom
# - Each new insight moves us closer to wisdom; wisdom itself is the destination, never fully reached
#
# **🔗 Connection**
# - This is the sharpest concept distinction in Ch1 — insight vs. wisdom will reappear whenever Course 2's storytelling framework asks: are we presenting findings (insight) or recommending action (wisdom)?
# - The analyst role in the 4-team-role framework (Course 2, Ch3) sits at the insight level — the SME takes it to wisdom

# %% [markdown]
# #### Chapter 1 — Lesson 8: The DIKW journey *(Practice / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Can you identify the precise transformation that occurs at each DIKW transition — distinguishing between them well enough to apply the correct label under pressure, across unfamiliar domains.
#
# ---
#
# **📋 Scenario**
# The **DIKW Explorer** presents the full pyramid applied across three real-world domains: Retail (customer purchase tracking), Fitness (health and activity tracking), and Education (student performance tracking). Each domain shows what the data looks like at all four levels.
#
# **Task:** Based on the examples, what transformation occurs when moving from Information to Knowledge?
#
# ---
#
# **✅ Solution**
#
# | Option | Verdict | Why |
# |--------|---------|-----|
# | Raw observations are collected through measurements | ❌ | Describes the starting point of Data — not a transformation between levels |
# | Data is organized and placed into context | ❌ — trap | This is the Data → Information transformation, not Information → Knowledge. The feedback confirms: *"Close, but that describes the transformation from Data to Information."* |
# | **Patterns are identified and predictions become possible** | ✅ Correct | This is the Information → Knowledge transformation — meaning is extracted, connections emerge, and forecasting becomes possible |
# | Knowledge is applied to make decisions and take action | ❌ | This is the Knowledge → Wisdom transformation |
#
# **DIKW Explorer examples — all three domains:**
#
# | Domain | Data (L1) | Information (L2) | Knowledge (L3) | Wisdom (L4) |
# |--------|-----------|-----------------|---------------|------------|
# | **Retail** | Raw purchase records (transactions, amounts, store, payment method) | Sales summary report (weekly revenue, peak hours, top category, avg transaction) | Customer behavior patterns (headphone buyers 3× more likely to buy cases; weekend shoppers spend 40% more) | Strategic inventory decisions (stock cases near headphones; schedule more staff post-payday) |
# | **Fitness** | Raw activity measurements (heart rate, steps, sleep hours, weight) | Weekly health summary (avg 7,200 steps/day, avg sleep 6.8h, resting HR 69 bpm) | Health trend insights (sleep <7h → steps drop 25%; weekend activity compensates for sedentary weekdays) | Personalized health plan (prioritize 7+ hours sleep; schedule consecutive workout days for recovery) |
# | **Education** | Raw assessment scores (quiz grades, homework submission, attendance count) | Student progress report (current avg 72%, strongest/weakest topic identified) | Learning gap analysis (Ch3 struggles link to missed Ch2 concepts; late submissions correlate with lower scores) | Personalized intervention (review Ch2 prerequisites; set submission reminders; schedule check-in for engagement) |
#
# ---
#
# **💡 Why this matters**
# The trap in this exercise is knowing the label for one transition and misapplying it to an adjacent one — "patterns are identified" sounds plausible for Data→Information because it feels like an improvement. The DIKW Explorer removes the ambiguity: across all three domains, the Information level (sales summary, weekly health summary, student progress report) is organized and aggregated data — not yet patterns. The Knowledge level (customer behavior patterns, health trend insights, learning gap analysis) is where correlations and predictions first appear. Seeing the same structure replicated across retail, fitness, and education makes the pattern portable — not tied to a single example.
#
# **→** *The same transformation — raw → context → patterns → action — repeats in every domain. Once you can name it in one, you can name it in all.*
#
# **✅ RECAP**
# - Data → Information: data organized and placed into context (aggregation, dashboards, summaries)
# - Information → Knowledge: **patterns identified and predictions become possible** — this is the correct answer
# - Knowledge → Wisdom: knowledge applied to make decisions and take action
# - The trap: "organizing into context" describes Data→Information — not Information→Knowledge
# - The DIKW Explorer confirms the pattern is domain-independent: retail, fitness, and education all follow the same four-level structure
#
# **🔗 Connection**
# - L6 established the four DIKW actions as an ordered sequence — this exercise stress-tests whether those actions can be matched correctly under distractor pressure
# - The three-domain format here mirrors the universality argument from L4 (*Data literacy in action*): the same framework applies regardless of field

# %% [markdown]
# #### Chapter 1 — Lesson 9: Data-driven decision making *(Video / 50 XP)*
#
# > 🎬 [Watch on DataCamp](https://campus.datacamp.com/courses/introduction-to-data-literacy/data-literacy-basics?ex=9) *(requires login)*
#
# ---
#
# **🎯 GOAL — What is this lesson about?**
# Data-driven decision making is not a technology — it is a five-step process anchored by a well-crafted problem statement. This lesson defines the process, dismantles three common misconceptions, and shows what a good problem statement looks like in practice.
#
# ---
#
# **Data-driven decision making** is the process of using data to make an informed decision about a specific problem and acting upon it. It serves four purposes: optimising performance, gaining a better understanding of a situation, protecting against risks, and determining the best course of action.
#
# **Three misconceptions — all wrong:**
#
# | Misconception | Why it is wrong |
# |---------------|----------------|
# | Only for large organizations | You can start small — any organization with a problem and data can use it |
# | Only the data team's responsibility | Including people with different backgrounds enriches the process |
# | Always the best option | Data-driven decision making is a strategy — it has advantages and disadvantages; it is not always appropriate |
#
# **The 5-step data-driven process:**
#
# | Step | Action |
# |------|--------|
# | 1 | Define a problem statement |
# | 2 | Collect the necessary data |
# | 3 | Perform data analysis |
# | 4 | Communicate the results |
# | 5 | Take action and reflect |
#
# **The problem statement** is Step 1 — and the most important. It answers: *"What is the problem you want to solve?"* It guides which data to collect, which analysis technique to use, and how results can be acted on. A good problem statement is:
# - **Clearly defined** — specific, not vague
# - **Actionable** — a specific action is possible based on the answer
# - **Realistic** — solvable with available resources
#
# Three guiding questions to craft one: *What is the current situation? What do we need to know? Where do we want to be?*
#
# **Two examples:**
#
# | Context | Starting question | Problem statement |
# |---------|------------------|-------------------|
# | Customer service team | How can we improve customer satisfaction? | Customer satisfaction is currently under our target. We need to know the main reasons for a negative score so we can take measures to improve it. |
# | University | Why are average math scores declining for three years? | Math scores have declined for three years. We need to know the main causes so we can take measures to counter them. |
#
# ---
#
# **💡 Why this matters**
# Most data projects fail not at the analysis stage but at the framing stage — a vague or unmeasurable problem leads to analysis that produces no actionable output. The five-step process makes the sequence explicit: without a good problem statement in Step 1, Steps 2–5 have no direction. In practice, a data analyst who pushes back on a poorly framed request (*"we need to know everything about sales"*) and helps define a crisp problem statement (*"we need to identify the top three reasons for cart abandonment in Q2"*) delivers more value than one who starts querying immediately.
#
# **→** *Step 1 is not preparation — it is the work. A precise problem statement is already half the solution.*
#
# **✅ RECAP**
# - Data-driven decision making = using data to make an informed decision and act on it
# - Three misconceptions: not only for large orgs · not only the data team · not always the best option
# - 5-step process: Define → Collect → Analyse → Communicate → Act & Reflect
# - Problem statement: the anchor of the entire process — clearly defined · actionable · realistic
# - Three problem categories: describe state · diagnose causes · detect anomalies or predict
#
# **🔗 Connection**
# - The 5-step process maps directly onto the DIKW pyramid: Define problem (Data level) → Collect & Analyse (Information/Knowledge) → Communicate & Act (Wisdom/Insight)
# - Problem statement categories (describe · diagnose · detect/predict) reappear in Ch3 as the four analytics types — descriptive, diagnostic, predictive, prescriptive are the analytical answers to exactly these categories

# %% [markdown]
# #### Chapter 1 — Lesson 10: Becoming data-driven *(Exercise / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Can you identify what data-driven decision making is explicitly *not* — separating its real objectives from a common misconception about what "being data-driven" means in practice.
#
# ---
#
# **📋 Scenario**
# Becoming data-driven requires understanding what it actually means in practice.
#
# **Task:** What is **not** an objective of data-driven decision making?
#
# ---
#
# **✅ Solution**
#
# | Option | Objective? | Why |
# |--------|-----------|-----|
# | Assist in making informed decisions | ✅ Yes | Core purpose of DDDM — using data to make better decisions |
# | Explain processes and behaviours | ✅ Yes | Understanding what is happening and why — diagnostic value |
# | Proactively handle events | ✅ Yes | Anticipating outcomes and preparing for them — the predictive and prescriptive value of DDDM |
# | **Collect as much data as possible and analyze it** | ❌ No — correct answer | DDDM is always tied to a specific problem. Collecting data without a problem statement is not DDDM — it is aimless data accumulation |
#
# > DataCamp: *"Data-driven decision making is not about analyzing as much data as possible, it is always used in the context of a specific problem."*
#
# > DataCamp feedback on wrong answer: *"Part of data-driven decision making is being able to take specific action, for example to prepare for a future event."* (This confirms "proactively handle events" is a genuine objective.)
#
# ---
#
# **💡 Why this matters**
# The most common misapplication of data in organisations is collecting and dashboarding everything — without a problem statement anchoring the effort. This produces large amounts of data activity with no decision output. DDDM is defined by the problem it solves, not by the volume of data it processes. A focused analysis of 100 records tied to a clear problem delivers more value than a warehouse of millions of records with no question attached.
#
# **→** *Data without a problem is noise. DDDM starts with the problem — the data follows.*
#
# **✅ RECAP**
# - Three genuine objectives: assist informed decisions · explain processes and behaviours · proactively handle events
# - The false objective: collecting as much data as possible — volume is not the goal
# - DDDM is always problem-specific — the problem statement from L9 is what makes it data-*driven*
# - "Proactively handle events" is a real objective — it is the predictive/prescriptive layer of DDDM
#
# **🔗 Connection**
# - This directly reinforces the problem statement rule from L9: DDDM without a problem statement is just data collection — Step 1 is what separates the two
# - The misconception being tested here (more data = better) is the same anti-pattern as "dashboarding everything" — a failure mode that reappears in Ch4 when discussing how to focus a data story

# %% [markdown]
# #### Chapter 1 — Lesson 11: Facts & myths about being data-driven *(Exercise / 100 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Can you separate true statements about data-driven decision making from common myths — proving that you understand both its genuine value and its limitations as a strategy.
#
# ---
#
# **📋 Scenario**
# Data-driven decision making has its benefits, but there are also misconceptions about its use.
#
# **Task:** Classify the following statements as **True** or **False**.
#
# ---
#
# **✅ Solution**
#
# | Statement | Classification | Why |
# |-----------|---------------|-----|
# | Being data-driven helps to make informed decisions | ✅ True | Core purpose of DDDM — using data as the basis for decisions |
# | Being data-driven can help gain a better understanding of an organization or process | ✅ True | Diagnostic value — data reveals patterns and behaviours that are otherwise invisible |
# | The data-driven process is guided by a well-defined problem | ✅ True | The problem statement from Step 1 anchors the entire process — without it, DDDM does not exist |
# | Being data-driven is only for large organizations | ❌ False | Any organization with a problem and data can use it — scale is not a requirement |
# | Being data-driven is only the responsibility of the data team | ❌ False | Including people from different backgrounds enriches the process — it is a cross-functional responsibility |
# | Data-driven decision-making is the best answer to a given problem | ❌ False | DDDM is a strategy with advantages *and* disadvantages — not having the right data, for example, makes it difficult to impossible; it is not always appropriate |
#
# > DataCamp feedback: *"Data-driven decision making is a strategy with advantages and disadvantages. For example, not having the right data makes effective data-driven decision making difficult to impossible."*
#
# ---
#
# **💡 Why this matters**
# The three myths here are the same three misconceptions introduced in L9 — this exercise tests whether they have been internalized, not just memorized. In practice, the most dangerous myth is the third: treating DDDM as the default answer to every problem regardless of context. A leader who insists on data-driven decisions when the available data is poor, outdated, or irrelevant will make *worse* decisions than one who recognizes the limitation and applies expert judgment instead. DDDM requires the right data, the right problem, and the right conditions — not just the right intention.
#
# **✅ RECAP**
# - Three truths: helps informed decisions · improves understanding of organisations/processes · is anchored by a well-defined problem
# - Three myths: only for large orgs · only the data team's job · always the best answer
# - The most important myth to internalize: DDDM is a strategy with trade-offs — not a universal solution
# - No right data = DDDM is difficult to impossible — the quality of the input determines the value of the output
#
# **🔗 Connection**
# - L9 introduced the three misconceptions as part of the video — this exercise converts them into an active classification task, confirming internalization
# - "Guided by a well-defined problem" connects directly to the problem statement rule: Step 1 is what makes DDDM data-*driven* rather than data-*collecting*

# %% [markdown]
# #### Chapter 1 — Lesson 12: The data-driven process *(Practice / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Can you identify the correct first step in a data-driven process — and recognize that problem definition always precedes data collection, analysis, and communication.
#
# ---
#
# **📋 Scenario**
# The **Data-Driven Decision Journey** interactive tool shows how three different organizations (E-commerce, Restaurant Chain, Manufacturing) apply the five-step process. Each scenario walks through all five steps with concrete examples.
#
# **Task:** A hospital identifies that patient wait times are too long. What should they focus on FIRST in a data-driven approach?
#
# ---
#
# **✅ Solution**
#
# | Option | Verdict | Why |
# |--------|---------|-----|
# | Start collecting all available patient data | ❌ | Collecting without a defined problem produces data with no direction — Step 2 cannot precede Step 1 |
# | **Define a clear problem statement about what aspects to improve** | ✅ Correct | Step 1 always comes first — the problem statement determines what data to collect, what to analyze, and what actions to take |
# | Begin analyzing historical data to find patterns | ❌ | Analyzing is Step 3 — *"Before you can analyze anything, you need to know what problem you're solving and have the right data collected"* |
# | Communicate findings to hospital management | ❌ | Communication is Step 4 — there is nothing to communicate before the problem is defined and data is analyzed |
#
# > DataCamp: *"Defining a clear problem statement is always the first step in any data-driven process. It guides what data to collect, what analysis to perform, and ultimately what actions to take."*
#
# ---
#
# **Data-Driven Decision Journey — E-commerce example (all 5 steps):**
#
# *Scenario: An online retailer notices that 70% of shoppers abandon their carts before completing purchase.*
#
# | Step | Action | E-commerce example |
# |------|--------|--------------------|
# | **1 — Define** | Define the problem | Current: 70% cart abandonment, above industry average · Need to know: at which stage do customers leave? What are the main friction points? · Goal: reduce abandonment by 20% within 6 months |
# | **2 — Collect** | Collect the necessary data | Website analytics (page views, time spent, click patterns) · Customer surveys about checkout experience · Transaction logs showing where users drop off · Competitor analysis of checkout processes |
# | **3 — Analyze** | Perform data analysis | Identify checkout step with highest abandonment · Segment customers by behaviour patterns · Compare mobile vs. desktop completion rates · Statistical analysis of survey responses |
# | **4 — Communicate** | Communicate insights | Create visualisation showing drop-off funnel · Present key findings: shipping costs revealed late cause 45% of abandonments · Recommend solutions with projected impact · Prepare executive summary for stakeholders |
# | **5 — Act** | Take action and reflect | Implement early shipping cost display · A/B test simplified checkout flow · Monitor abandonment rate weekly · Document learnings for future optimisation |
#
# *The same five-step structure applies across all three scenarios (Restaurant Chain and Manufacturing) — the domain changes, the process does not.*
#
# ---
#
# **💡 Why this matters**
# The hospital scenario is designed to test whether you treat Step 1 as genuinely non-negotiable — not just as an abstract rule but as a constraint that prevents all other steps from starting. Collecting data before defining the problem produces a dataset with no question to answer. Analyzing before collecting produces analysis with no data. Each step in the five-step process has a logical dependency on the one before it. Skipping Step 1 does not make you faster — it makes all subsequent steps directionless.
#
# **✅ RECAP**
# - Step 1 — Define — always comes first: no problem statement = no data-driven process
# - The five steps are sequentially dependent: each step requires the previous one to be complete
# - The three wrong answers correspond to Steps 2, 3, and 4 — none of them can precede Step 1
# - The E-commerce example shows what a complete, realistic five-step cycle looks like end to end
# - Domain changes, structure does not — the same process applies to hospitals, retailers, restaurants, and manufacturers equally
#
# **🔗 Connection**
# - L9 introduced the 5-step process and the problem statement rule — this exercise applies both under distractor pressure, confirming that Step 1 is internalized, not just memorized
# - The E-commerce example here is a concrete instantiation of the DIKW pyramid from L5–L8: Define = identifying the gap between current knowledge and wisdom needed · Collect/Analyze = building information and knowledge · Communicate/Act = reaching insight and wisdom

# %% [markdown]
# #### Chapter 1 — Lesson 13: Fitting the problem statement *(Practice / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Can you work backwards from a completed analysis — reading three charts and identifying the problem statement that must have driven it, using the rule that a good problem statement is specific, actionable, and tied to a measurable comparison.
#
# ---
#
# **📋 Scenario**
# Some analysis has been carried out to compare test scores in mathematics, reading, and writing between two groups: students who completed the test preparation course and students who did not.
#
# Three charts (one per subject) each show: x-axis = whether students took the course ("none" vs. "completed"); y-axis = test scores 0–100; a blue trend line connecting the average score of both groups; individual scores shown as dots (❌ = no course, ✅ = completed course). The trend line slopes upward in all three charts — students who completed the course scored higher on average.
#
# **Task:** Which problem statement question was most likely the start point for this analysis?
#
# ---
#
# **✅ Solution**
#
# | Option | Verdict | Why |
# |--------|---------|-----|
# | Do students who score high on one test also score higher on the other final tests? | ❌ | This asks about correlation *between* subjects — not about the effect of the preparation course. The analysis groups by course completion, not by cross-subject performance |
# | Which students are more likely to ace their classes? | ❌ | Too vague — "ace their classes" is undefined and not measurable. A good problem statement is specific and actionable, not a general aspiration |
# | **Does completion of the test preparation course improve student performance on the final tests?** | ✅ Correct | This matches the analysis exactly: the grouping variable is course completion; the outcome variable is test scores; three subjects are compared — *"Clearly defining a problem beforehand goes a long way toward successful data-driven decision making"* |
# | Are there gender differences between the test scores? | ❌ | The charts show no gender variable — the x-axis is course completion, not gender. This question would require a completely different dataset |
#
# > DataCamp: *"Great! Clearly defining a problem beforehand goes a long way toward successful data-driven decision making."*
#
# ---
#
# **💡 Why this matters**
# Reading an analysis backwards — from charts to the question that produced them — is a real skill. In practice, you will often receive dashboards or reports with no explicit problem statement attached. The ability to reconstruct the original question tells you: what the analysis was designed to answer, what it cannot answer (questions outside its scope), and whether the right question was asked in the first place. Option 4 (gender differences) is a good trap: it is a legitimate research question, but it is not the question *this* analysis answers. The data does not contain a gender variable — so that question would require re-collecting data, not re-reading these charts.
#
# **✅ RECAP**
# - A good problem statement is specific, actionable, and measurable — "which students are more likely to ace their classes" fails all three
# - Read the grouping variable in the chart: x-axis = course completion → the question is about course completion, not correlations or gender
# - Reverse-engineering the problem statement from an analysis is a real analytical skill — not just a DataCamp exercise
# - Option 4 is the most dangerous distractor: a real question, but not the one this data can answer
#
# **🔗 Connection**
# - This closes the Ch1 arc on data-driven decision making: L9 defined the problem statement rules · L10 removed misconceptions · L11 tested the myths · L12 applied the 5-step process · L13 reverse-engineers from output back to Step 1 — the full cycle is now complete in both directions
# - "Clearly defining a problem beforehand" is exactly the Step 1 principle from L9 — this exercise proves it works not just when you start from scratch, but when you inherit someone else's analysis

# %% [markdown]
# ---
#
# ### 🧠 Chapter 1 Recap — Data Literacy Basics
#
# *13 lessons · 800 XP · Arc: what data literacy is → how it works (DIKW) → how it drives decisions*
#
# ---
#
# **The central question Chapter 1 answers:**
# > What does it mean to be data-literate — and how do you get from raw data to a decision that matters?
#
# ---
#
# **Three-part arc:**
#
# **Part 1 — What data literacy is (L1–L4)**
#
# Data literacy is the ability to read, work with, analyze, and communicate data — critically engaging with data without needing technical expertise. It has three components: Reading (databases), Analyzing (descriptive and predictive analytics), and Communicating (storytelling and visualizations). It applies to every profession — nurse, teacher, HR specialist, marketing manager. Technical skill is not a requirement; critical engagement with data is.
#
# **Part 2 — How it works: the DIKW pyramid (L5–L8)**
#
# The DIKW pyramid is the engine underneath data literacy. Data (raw observations) → Information (data in context) → Knowledge (meaning extracted, patterns identified) → Wisdom (knowledge applied to action). Wisdom is the unreachable ideal; **Insights** are the realistic gold nuggets that bridge Knowledge and Wisdom — each new insight moves us one step closer without claiming to have arrived. The most commonly confused transition: Information → Knowledge requires extracting *meaning* (patterns, predictions), not just organizing data — that confusion is tested directly in L6 and L8.
#
# **Part 3 — How it drives decisions: data-driven decision making (L9–L13)**
#
# DDDM is the five-step process that operationalises the DIKW pyramid: Define → Collect → Analyze → Communicate → Act & Reflect. Step 1 (Define) is non-negotiable — a clear, actionable, realistic problem statement determines everything that follows. Three misconceptions consistently tested: DDDM is not only for large organisations · not only the data team's responsibility · not always the best strategy (no right data = difficult to impossible). The process is domain-independent: retail, healthcare, education, manufacturing all follow the same structure.
#
# ---
#
# **The key principle that runs through all 13 lessons:**
#
# > *Clarity before collection. Problem before data. Insight before action.*
#
# Every lesson in Ch1 is a variation of this principle. The DIKW pyramid says: don't confuse organized data with meaning. The problem statement rule says: don't collect data before defining the question. L13 says: don't inherit someone else's analysis without first identifying what question it was designed to answer.
#
# ---
#
# **Concept map:**
#
# | Concept | Introduced | Tested | Core rule |
# |---------|-----------|--------|-----------|
# | Data literacy definition | L1 | L2–L4 | Critical engagement with data — no technical expertise required |
# | Three components | L1 | L3 | Reading · Analyzing · Communicating |
# | DIKW pyramid | L5 | L6–L8 | Each level adds something new: context → meaning → action |
# | Insight vs. wisdom | L5, L7 | L7 | Insight bridges knowledge and wisdom — action belongs to wisdom |
# | Information → Knowledge trap | L6 | L8 | Meaning is extracted at Knowledge, not Information |
# | Data-driven decision making | L9 | L10–L13 | Problem statement anchors the entire 5-step process |
# | Three DDDM misconceptions | L9 | L11 | Not only large orgs · not only data team · not always best strategy |
# | Step 1 primacy | L9, L12 | L12–L13 | Define always precedes Collect, Analyze, Communicate, Act |
# | Reverse-engineering from output | L13 | L13 | Read the grouping variable — it reveals the original question |
#
# ---
#
# **🔗 Forward connection to Ch2–Ch4:**
# - Ch2 (data sources, types, quality) operates at the Data/Information level of the pyramid — it is the Reading component of data literacy made concrete
# - Ch3 (analytics types) answers the four problem categories introduced in L9 — descriptive, diagnostic, predictive, prescriptive map exactly onto "describe · diagnose · detect/predict"
# - Ch4 (visualizations, storytelling) is the Communicating component of data literacy — it is where insight reaches wisdom

# %% [markdown]
# ---
#
# ## Chapter 2 — Reading Data
#
# #### Chapter 2 — Lesson 1: Data is all around us *(Video / 50 XP)*
#
# > 🎬 [Watch on DataCamp](https://campus.datacamp.com/courses/introduction-to-data-literacy/reading-data?ex=1) *(requires login)*
#
# ---
#
# **🎯 GOAL — What is this lesson about?**
# Data comes in far more forms than tables of numbers — this lesson maps the full landscape of data shapes and introduces the two main source categories (open vs. internal) that determine what data is available for a given problem.
#
# ---
#
# Data is not only numbers in a spreadsheet. Four additional forms appear in practice:
#
# - **Images** — pixels with color values; used for automatic image recognition (detecting what is visible in a photo)
# - **Text** — social media posts, emails, reviews; analyzed for word frequency and sentiment (e.g. a Twitter analysis of a soccer match to determine whether the audience found it exciting)
# - **Network data** — connections between entities; answers questions like *"Are many social connections linked to happiness?"*
# - **Spatial data** — location-based; answers questions like *"Where is the best place to open a new coffee shop?"*
#
# The right data for a problem depends on both its form and its source. Two source categories:
#
# | Source | Description | Examples |
# |--------|-------------|---------|
# | **Open data** | Publicly available; often government or non-profit | Local government social/economic datasets · APIs (e.g. Twitter API — collects tweets on any subject quickly and easily) |
# | **Internal data** | Shared under specific conditions; protected by privacy regulations; not public | Customer data (age, tenure) · Transaction data (sales numbers) · Website data (visitors, clicks) · Surveys (product satisfaction) |
#
# ---
#
# **💡 Why this matters**
# Before asking "what does the data show?", a data-literate professional asks "where should this data come from?" Knowing the difference between open and internal sources determines what is accessible, what conditions apply, and what privacy constraints must be respected. A question answerable with open government data requires a completely different approach than one requiring proprietary customer records. Getting the source wrong is a Step 1 failure — it invalidates the analysis before it begins.
#
# **→** *Identify the source category first — it determines access, conditions, and legal constraints before any analysis starts.*
#
# **✅ RECAP**
# - Data is not only tables of numbers — images, text, network, and spatial data are equally valid data forms
# - Open data: public, often government or non-profit; APIs are a key collection tool
# - Internal data: private, condition-restricted, covered by privacy regulations — includes customer, transaction, website, and survey data
# - Source type determines access and constraints — not an afterthought, a prerequisite
#
# **🔗 Connection**
# - The three data literacy components from Ch1 L1 begin here: this lesson opens the **Reading** component — identifying and collecting the right data sources
# - The Step 1 (Define) primacy rule from Ch1 L9 applies directly: a clear problem statement is required before choosing a source — without it, you cannot know which source is appropriate

# %% [markdown]
# #### Chapter 2 — Lesson 2: Finding the right data *(Practice / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Whether the learner has absorbed the L1 principle that text data (social media, reviews, posts) is a legitimate and analyzable form of data — not just numbers.
#
# ---
#
# **📋 Scenario**
# A colleague is performing a data analysis about the popularity of different airlines. He shows you a collection of tweets gathered from X (Twitter) — a table of airline names paired with tweet text (complaints, thanks, questions).
#
# **Task:** Can this be used for data analysis?
#
# ---
#
# **✅ Solution**
#
# | Option | Verdict | Why |
# |--------|---------|-----|
# | Yes, but only if supplemented with numerical data | ❌ | Text data stands on its own — supplementing with numerical data may be useful in some analyses but is not a requirement for text to be valid data |
# | No, text cannot be used in data analysis | ❌ | This directly contradicts the core principle from L1 — text is one of the four data forms explicitly introduced as analyzable |
# | **Yes, this can be used for data analysis** | ✅ Correct | Tweets are text data; analyzing word frequency and sentiment to gauge airline popularity is a legitimate analysis — exactly the Twitter/soccer match example from L1 |
#
# > DataCamp: *"Great! Texts like social media posts are also a form of data from which we can gain insights by analyzing it. This flexibility is a big strength of data analysis."*
#
# ---
#
# **💡 Why this matters**
# The instinct to reach for numbers first is strong — spreadsheets, sales figures, counts. But a significant portion of business-relevant information lives in text: customer reviews, support tickets, social media feedback, survey free-text fields. Dismissing text as "not real data" means missing an entire category of insight. Knowing that text is analyzable unlocks NLP, sentiment analysis, and topic modeling as tools — all of which are in regular use in product, marketing, and customer experience teams.
#
# **✅ RECAP**
# - Text data is valid data — social media posts, emails, reviews are all analyzable
# - No numerical supplement is required for text to be useful; it depends on the question
# - The tweet dataset here is internal data (gathered under specific conditions from X's API) — revisit the source type distinction from L1
# - DataCamp's closing line frames it well: flexibility across data forms is a core strength of data analysis

# %% [markdown]
# #### Chapter 2 — Lesson 3: Finding the right data source *(Exercise / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Can you identify the correct source type for a given dataset — specifically recognising that official government statistics are open/public data, not internal or survey data.
#
# ---
#
# **📋 Scenario**
# You come across a bar chart on a data blog: *Crude marriage rate, 2023 (per 1,000 persons)* for six European countries (Belgium, Germany, Estonia, Greece, Spain, Italy). Source note: *Eurostat (online data code: demo_nind)*. You want to do a similar analysis for a different year.
#
# **Task:** Where are you most likely to find the data you need?
#
# ---
#
# **✅ Solution**
#
# | Option | Verdict | Why |
# |--------|---------|-----|
# | **Public database** | ✅ Correct | Eurostat is the EU's official statistics agency — its data is publicly available and free to access via official government/organisation channels |
# | Internal database | ❌ | Internal data is condition-restricted and not publicly available — Eurostat data is open by design |
# | Through a survey | ❌ | This data already exists as published official statistics — collecting it again via survey would duplicate existing open data unnecessarily |
#
# > DataCamp: *"Perfect! Official statistics such as these can be found easily through the official channels of the government or organization in question."*
#
# ---
#
# **💡 Why this matters**
# Before designing a data collection plan, check whether the data already exists as open data. National statistics offices, the EU (Eurostat), the UN, and the World Bank publish enormous amounts of high-quality, regularly updated datasets for free. A data analyst who doesn't know this will commission surveys or request internal data pulls for questions that could be answered in five minutes with a public database query — wasting time and budget.
#
# **✅ RECAP**
# - Official government and inter-governmental statistics (Eurostat, ONS, data.gov) are open/public data
# - Public database is the correct source for anything published by a government or recognised public organisation
# - Internal data and surveys are used when the data does not already exist publicly — not when it does
# - Source note on a chart always signals where the data came from — reading it tells you where to go next

# %% [markdown]
# #### Chapter 2 — Lesson 4: Open vs. internal data sources *(Exercise / 100 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Can you classify real-world datasets as open or internal — applying the distinction from L1 to concrete examples across different domains.
#
# ---
#
# **📋 Scenario**
# When collecting data, there are two main groups of sources to look into: open and internal data. Which source you need depends on the kind of data you are looking for.
#
# **Task:** Classify these data examples into the bucket of their most likely data source.
#
# ---
#
# **✅ Solution**
#
# | Dataset | Classification | Why |
# |---------|---------------|-----|
# | Average monthly temperature for each US state | ✅ Open data | Weather/climate data is collected and published by government agencies (NOAA, national meteorological services) — publicly available |
# | Historical stock prices for the S&P 500 index | ✅ Open data | Stock market data is published by exchanges and financial data providers — widely available through public APIs and databases |
# | Total population of EU countries | ✅ Open data | Population statistics are published by government and inter-governmental bodies (Eurostat, national statistics offices) — same source type as L3 |
# | Ben & Jerry's ice cream sales during the summer months | ✅ Internal data | Sales figures are proprietary company data — not publicly released; accessible only under specific conditions |
# | Certification test scores per student in the last three months | ✅ Internal data | Individual student performance data is private institutional data — protected by privacy regulations |
# | Monthly total of Amazon shoppers under the age of 30 | ✅ Internal data | Customer behaviour data is proprietary to Amazon — not public; shared only under specific conditions |
#
# > DataCamp: *"Perfect! To ensure smooth data collection, it is best to think beforehand about which data is needed and where it can be found."*
#
# ---
#
# **💡 Why this matters**
# The open/internal distinction is a practical planning tool — not just a taxonomy exercise. Before starting any data project, a data analyst needs to know: does this data exist publicly, or does it require internal access? Public data is free and immediately accessible but may be aggregated or delayed. Internal data is more specific and timely but requires permissions, privacy compliance, and often data engineering support to extract. Knowing the difference upfront shapes the entire data collection plan.
#
# **→** *The question is not "where can I find this data?" — it's "what kind of access does this data require?" Answer that first, then plan accordingly.*
#
# **✅ RECAP**
# - Open data: government statistics, stock prices, climate data, public APIs — no access conditions, freely available
# - Internal data: sales figures, customer behaviour, student records — condition-restricted, privacy-protected
# - The signal for open data: published by a government, exchange, or recognised public institution
# - The signal for internal data: owned by a specific company or institution; contains individual-level or commercially sensitive information
# - Planning rule: identify source type before designing the collection approach — it determines access, timeline, and compliance requirements
#
# **🔗 Connection**
# - This closes the L1–L4 data sources arc: L1 introduced open vs. internal · L2 confirmed text data is valid · L3 applied open data to government statistics · L4 classifies six real examples across both categories — the distinction is now operational, not just definitional
# - The privacy regulations note for internal data connects forward to Ch2 L13–L16 (data problems and bias) — restricted data is also data that can carry compliance risk if mishandled

# %% [markdown]
# #### Chapter 2 — Lesson 5: Common data types *(Video / 50 XP)*
#
# > 🎬 [Watch on DataCamp](https://campus.datacamp.com/courses/introduction-to-data-literacy/reading-data?ex=5) *(requires login)*
#
# ---
#
# **🎯 GOAL — What is this lesson about?**
# Data type determines how data is collected, stored, and analyzed — and two binary distinctions (structured vs. unstructured · quantitative vs. qualitative) cover the vast majority of real-world cases.
#
# ---
#
# Two independent distinctions, applied together:
#
# | Dimension | Type A | Type B |
# |-----------|--------|--------|
# | **Structure** | **Structured** — tabular (rows and columns); easily read by a computer; stored in relational databases | **Unstructured** — no pre-defined format; requires preprocessing before analysis; stored in document databases |
# | **Measurement** | **Quantitative** — numerical; measurable or countable; wider analysis range (averages, statistics) | **Qualitative** — categorical; observable; more restricted analysis range (averages don't apply) |
#
# **Structured data examples:** spreadsheets (Excel), data tables — the most immediately recognisable form of data.
#
# **Unstructured data examples:** images, videos, sound files, emails, social media posts, ratings — no pre-defined format, many possible forms.
#
# **Quantitative data examples (ice cream):** number of scoops · minutes before melting · length of the cone — all measurable or countable.
#
# **Qualitative data examples (ice cream):** flavor · color · cone or cup — all categories that can be observed but not meaningfully averaged.
#
# The key asymmetry: *calculating the average length makes sense; calculating the average color does not.*
#
# ---
#
# **💡 Why this matters**
# Data type is not metadata — it is a constraint on what analyses are possible. Treating qualitative data as quantitative (e.g. averaging customer satisfaction labels) produces meaningless results. Treating unstructured data as if it were structured (loading free-text into a relational database without preprocessing) produces storage and query failures. Knowing the type before designing the analysis prevents both failure modes. In practice, most datasets are mixed — a customer table contains quantitative fields (age, spend) and qualitative fields (country, product category) side by side.
#
# **→** *Before choosing an analysis technique, identify what type of data you have — the type determines what is mathematically valid.*
#
# **✅ RECAP**
# - Structured: tabular, rows and columns, relational database — easy for computers to read
# - Unstructured: no pre-defined format, preprocessing required, document database — images, video, text
# - Quantitative: numbers, measurable/countable, wide analysis range
# - Qualitative: categories, observable, restricted analysis range — averaging categories is meaningless
# - The two distinctions are independent: unstructured data can be quantitative (sensor readings in a log file) or qualitative (social media text)
#
# **🔗 Connection**
# - The unstructured data examples here (images, social media posts) are the same forms introduced in Ch2 L1 — this lesson adds the storage and preprocessing implications that L1 didn't cover
# - The qualitative/quantitative distinction will reappear in Ch3 analytics types: descriptive analytics handles both, but the techniques differ (counts vs. averages vs. frequency tables)

# %% [markdown]
# #### Chapter 2 — Lesson 6: Importance of data types *(Exercise / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Can you identify the one false statement about data types — specifically the myth that only one data type can be used in an analysis at a time.
#
# ---
#
# **📋 Scenario**
# Data type is an important concept in data analysis.
#
# **Task:** Which statement about the importance of data type is **not** true?
#
# ---
#
# **✅ Solution**
#
# | Statement | True/False | Why |
# |-----------|-----------|-----|
# | Data type affects how data needs to be collected, stored or analyzed | ✅ True | Core principle from L5 — the type determines storage (relational vs. document database) and analysis method |
# | Quantitative and qualitative data are different ways to describe something | ✅ True | Both are valid description modes — one numerical, one categorical |
# | **Only one data type can be used at a time in an analysis** | ❌ False — correct answer | Most real-world analyses combine multiple data types simultaneously — structured and unstructured, quantitative and qualitative together |
# | Unstructured data needs to be stored differently than structured data | ✅ True | Structured → relational database · Unstructured → document database; different storage requirements from L5 |
#
# > DataCamp: *"That's right! To get the most out of our data, we often need to work with different data types at the same time."*
#
# ---
#
# **💡 Why this matters**
# The myth that analyses use only one data type is common among people new to data work. In reality, a single customer analysis might combine structured transaction data (quantitative), demographic records (mixed), and free-text survey responses (unstructured, qualitative) simultaneously. The ability to work across data types — and to understand what each requires in terms of collection, storage, and analysis — is what separates a data-literate professional from someone who can only work with tidy spreadsheets.
#
# **✅ RECAP**
# - Three true statements: type affects collection/storage/analysis · qualitative and quantitative are two description modes · unstructured needs different storage
# - The false statement: one type at a time — analyses routinely combine multiple types
# - The key takeaway: data type fluency means knowing how to handle each type AND how to combine them

# %% [markdown]
# #### Chapter 2 — Lesson 7: Structured vs. unstructured data *(Exercise / 100 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Can you correctly assign the key characteristics of structured and unstructured data — storage type, examples, and preprocessing requirements — to the right category.
#
# ---
#
# **📋 Scenario**
# When storing, collecting or analyzing data, there are some important differences between structured and unstructured data.
#
# **Task:** Classify the different characteristics to the corresponding data type.
#
# ---
#
# **✅ Solution**
#
# | Characteristic | Data type | Why |
# |----------------|-----------|-----|
# | Easy to search and organize | ✅ Structured | Tabular form with strict row/column structure makes it computer-readable and searchable without preprocessing |
# | Spreadsheets | ✅ Structured | Excel/spreadsheet format is the defining example of structured data from L5 |
# | Stored in relational databases | ✅ Structured | Relational databases are the standard storage for tabular, structured data |
# | Images, videos and text | ✅ Unstructured | No pre-defined format — the three canonical unstructured data examples from L5 |
# | Requires more preprocessing | ✅ Unstructured | No fixed structure means preprocessing is necessary before analysis can begin |
# | Stored in document databases | ✅ Unstructured | Document databases are the standard storage for unstructured data |
#
# > DataCamp: *"Good job! Due to its tabular form, structured data is easier to work with than unstructured data, which requires more preprocessing."*
#
# ---
#
# **💡 Why this matters**
# Storage type is not a technical detail — it determines who can access the data and how. A business analyst can query a relational database with SQL directly. Unstructured data in a document database typically requires a data engineer to preprocess it before an analyst can work with it. Knowing which type of data you are dealing with tells you immediately whether you can start analysis now or whether you need to involve the data engineering team first.
#
# **✅ RECAP**
# - Structured: tabular · easy to search · spreadsheets · relational database
# - Unstructured: images/video/text · no pre-defined format · preprocessing required · document database
# - The practical implication: structured data → analyst works directly · unstructured data → preprocessing step first
# - Both types are valid data; the difference is in the work required before analysis begins
#
# **🔗 Connection**
# - This closes the L5–L7 structured/unstructured arc: L5 introduced both types · L6 confirmed multiple types can coexist in one analysis · L7 operationalises the distinction as a classification task
# - The preprocessing requirement for unstructured data connects forward to Ch2 L13–L16 (data problems): unstructured data is more prone to inconsistency precisely because it lacks the constraints of a relational schema

# %% [markdown]
# #### Chapter 2 — Lesson 8: Quantitative vs. qualitative data *(Practice / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Can you identify the correct data type mix in a real dataset — recognising that most real-world tables contain both quantitative and qualitative columns simultaneously.
#
# ---
#
# **📋 Scenario**
# A dataset on student performance contains the following columns:
#
# | Column | Values (examples) |
# |--------|-------------------|
# | gender | female · male |
# | race/ethnicity | group A · group B · group C · group D |
# | parental level of education | bachelor's degree · some college · master's degree · high school · associate's degree |
# | lunch | standard · free/reduced |
# | test preparation course | none · completed |
# | math score | 47 · 72 · 90 · 78 … |
# | reading score | 57 · 72 · 95 · 72 … |
# | writing score | 44 · 74 · 93 · 70 … |
#
# **Task:** Are the columns in this dataset quantitative, qualitative or both?
#
# ---
#
# **✅ Solution**
#
# | Option | Verdict | Why |
# |--------|---------|-----|
# | The score variables are qualitative, while the other columns are quantitative | ❌ | Reversed — scores are numbers (quantitative); group labels are categories (qualitative) |
# | **The score variables are quantitative, while the other columns are qualitative** | ✅ Correct | Math/reading/writing scores are numerical and measurable → quantitative. Gender, race/ethnicity, parental education, lunch type, test prep completion are all categories → qualitative |
# | All columns are quantitative | ❌ | The categorical columns (gender, race/ethnicity, etc.) cannot be meaningfully measured or averaged — they are qualitative |
# | All columns are qualitative | ❌ | The score columns are numerical — they can be averaged, ranked, and statistically analyzed |
#
# > DataCamp: *"That's right! Most real-life datasets have a combination of qualitative and quantitative data like this one."*
#
# ---
#
# **💡 Why this matters**
# The student performance dataset is a realistic example of what most business datasets look like: a mix of categorical identifiers (who the person is, what group they belong to) and numerical outcomes (scores, revenue, duration). Knowing which columns are quantitative and which are qualitative determines which statistical operations apply to each. Averaging a score column is valid; averaging a gender column is not. In SQL or pandas, choosing the wrong aggregation function on a qualitative column produces either an error or a meaningless result.
#
# **✅ RECAP**
# - Score columns (math, reading, writing) → quantitative: numerical, measurable, averageable
# - All other columns (gender, ethnicity, education, lunch, test prep) → qualitative: categories, observable, not averageable
# - Most real datasets are mixed — this is the norm, not the exception
# - Identifying column types before analysis prevents applying the wrong statistical operation
#
# **🔗 Connection**
# - This closes the L5–L8 data types arc: L5 introduced both distinctions · L6 confirmed mixed types are normal · L7 classified structured/unstructured · L8 applies quantitative/qualitative to a real dataset
# - The same student performance dataset appeared in Ch1 L13 (*Fitting the problem statement*) — this lesson revisits it from a data type angle, showing how the same data supports different analytical questions

# %% [markdown]
# #### Chapter 2 — Lesson 9: Managing data *(Video / 50 XP)*
#
# > 🎬 [Watch on DataCamp](https://campus.datacamp.com/courses/introduction-to-data-literacy/reading-data?ex=9) *(requires login)*
#
# ---
#
# **🎯 GOAL — What is this lesson about?**
# Data doesn't manage itself — this lesson maps the full infrastructure stack that sits between raw data and the analyst's query: databases, cloud storage, pipelines, querying tools, and dashboards, each with a clear owner and purpose.
#
# ---
#
# | Component | What it does | Who owns it |
# |-----------|-------------|-------------|
# | **Database** | General storage for data; managed by a DBMS (database management system) that handles storing, retrieving, and accessing data | Data engineer |
# | **Relational database** | Stores structured data in related tables (e.g. sales table linked to customer table via customer ID) | Data engineer |
# | **Document database** | Stores unstructured data | Data engineer |
# | **Data warehouse** | Processed, organised data ready for analysis | Data engineer |
# | **Data lake** | Raw, unprocessed data storage | Data engineer |
# | **Cloud storage** | Data stored on remote servers, accessed via internet; provided by a third party; more flexible and cost-effective than on-site; dependent on third-party security | Data engineer / IT |
# | **Data pipeline (ETL)** | Moves data from one database to another; automated via Extract → Transform → Load; keeps data up-to-date and accurate | Data engineer |
# | **SQL querying** | Retrieves data from databases; industry standard for querying (Structured Querying Language); further analysis in R or Python | Data analyst |
# | **Dashboard** | Non-technical interface for collecting, managing, and sharing data; shows KPIs and metrics at a glance; linked to a database; used for analysis and communication | Data analyst |
#
# **Warehouse vs. lake:**
# - **Data warehouse** → processed, organised → ready for analysis now
# - **Data lake** → raw, unprocessed → preparation still required
#
# **Cloud trade-off:**
# - Benefit: flexible, cost-effective
# - Risk: dependent on third-party provider's security — problematic with sensitive data
#
# ---
#
# **💡 Why this matters**
# A data analyst who understands the infrastructure layer can work more effectively with data engineers and ask the right questions: *Is this data in the warehouse or the lake? Is the pipeline running? Do I need SQL or can I use the dashboard?* Without this knowledge, an analyst treats data as something that appears by magic — which makes troubleshooting, scoping, and communication with technical teams much harder. The DBMS concept also explains why raw database access requires SQL: the DBMS is the gatekeeper, and SQL is the language it understands.
#
# **→** *Knowing the infrastructure stack tells you where the data is, what state it's in, and who to ask when something is missing.*
#
# **✅ RECAP**
# - Database: general storage; managed by a DBMS
# - Relational → structured, related tables; Document → unstructured
# - Data warehouse → processed and ready; Data lake → raw and not yet prepared
# - Cloud: flexible and cost-effective, but third-party security dependency
# - ETL pipeline: Extract → Transform → Load; automated; keeps data current
# - Querying: SQL is the industry standard; R and Python for further analysis
# - Dashboard: KPIs at a glance; analyst-owned; linked to database; non-technical interface
#
# **🔗 Connection**
# - The relational/document database split maps directly onto the structured/unstructured distinction from L5–L7 — this lesson reveals where each type is physically stored
# - SQL querying is the bridge to the practical SQL track that resumes after `true-story-data` is complete — this lesson explains *why* SQL matters before a single query is written

# %% [markdown]
# #### Chapter 2 — Lesson 10: Using databases *(Exercise / 100 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Can you distinguish true from false statements about databases — separating correct facts about data lakes, relational databases, pipelines, SQL, and data engineering roles from two common misconceptions.
#
# ---
#
# **📋 Scenario**
# Databases collect and store data. A lot of specialised tasks are involved to account for the different types of data and the large amounts that are often involved.
#
# **Task:** Classify the statements as true or false.
#
# ---
#
# **✅ Solution**
#
# | Statement | Classification | Why |
# |-----------|---------------|-----|
# | Data pipelines move data from one database to another | ✅ True | Core definition from L9 — the ETL process automates exactly this movement |
# | Designing and optimizing database systems is typically the responsibility of a data engineer | ✅ True | Data engineer ownership was stated explicitly in L9 |
# | The standard programming language to retrieve data from databases is SQL | ✅ True | SQL = Structured Querying Language — the industry standard for querying, from L9 |
# | A data lake only stores structured, processed data | ❌ False | A data lake stores *raw, unprocessed* data — the opposite of a data warehouse, which stores processed data |
# | A relational database only stores network data | ❌ False | Relational databases store *structured* data in related tables — network data is a different data form entirely |
#
# > DataCamp: *"Great! Databases are the cornerstone of data management."*
#
# ---
#
# **💡 Why this matters**
# The two false statements test the most common mix-ups: data lake vs. data warehouse (frequently confused because both sound like "storage") and relational database vs. network database (confused because "relational" is sometimes misread as "connected" or "networked"). In practice, asking for data from the wrong storage type wastes time — requesting analysis-ready data from a data lake means discovering that preprocessing hasn't happened yet.
#
# **✅ RECAP**
# - Data pipeline: moves data between databases (True)
# - Data engineer: owns database design and optimisation (True)
# - SQL: industry standard querying language (True)
# - Data lake: raw, unprocessed — NOT structured, processed (False)
# - Relational database: stores structured tabular data — NOT network data (False)
# - The lake/warehouse confusion is the most common — always check: is the data processed (warehouse) or raw (lake)?

# %% [markdown]
# #### Chapter 2 — Lesson 11: Storage in the cloud *(Exercise / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Can you identify the one false statement about cloud storage — specifically the cost comparison with on-site storage, which is the reverse of the correct fact.
#
# ---
#
# **📋 Scenario**
# Cloud storage has become a common way to store and access data.
#
# **Task:** What is **not** a characteristic of data storage in the cloud?
#
# ---
#
# **✅ Solution**
#
# | Statement | True/False | Why |
# |-----------|-----------|-----|
# | Cloud storage is usually provided by a third party | ✅ True | Specialised third-party providers host remote servers — stated explicitly in L9 |
# | **Cloud storage is less cost-effective than on-site storage** | ❌ False — correct answer | Cloud storage is *more* cost-effective and flexible than on-site — the trade-off is security dependency, not cost |
# | Cloud storage is accessed over the internet | ✅ True | Data is stored on remote servers and accessed over the internet — definition from L9 |
# | Cloud storage security is dependent on the third party provider | ✅ True | The identified risk from L9: sensitive data is dependent on the third party's security practices |
#
# ---
#
# **💡 Why this matters**
# The cost misconception is common — people assume that outsourcing storage must be more expensive. In practice, cloud storage eliminates the capital cost of physical servers, maintenance, and IT staff, making it significantly more cost-effective for most organisations. The real trade-off is control: you gain cost efficiency but lose direct control over security, which matters most for sensitive or regulated data (patient records, financial data, personal identifiers).
#
# **✅ RECAP**
# - Cloud: third-party provided · internet access · more cost-effective than on-site · security depends on provider
# - The false statement: "less cost-effective" — cloud is *more* cost-effective; the downside is security dependency, not cost
# - For sensitive data: cloud security dependency is the genuine risk to weigh, not the price

# %% [markdown]
# #### Chapter 2 — Lesson 12: Which tool do you need? *(Exercise / 100 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Can you match the right data management tool (pipeline, database, or dashboard) to the task it is designed to perform — applying the functional definitions from L9 to concrete use cases.
#
# ---
#
# **📋 Scenario**
# In this lesson, you've seen various useful tools for managing data, like databases, data pipelines, and dashboards. Like tools in a toolbox, you can use them to complete specific tasks.
#
# **Task:** Classify each task to the most suitable tool.
#
# ---
#
# **✅ Solution**
#
# | Task | Tool | Why |
# |------|------|-----|
# | Move data from one database to another | ✅ Data pipeline | Core definition of a pipeline — ETL moves data between storage systems |
# | Automate data processing with ETL | ✅ Data pipeline | ETL (Extract → Transform → Load) is the automation framework that pipelines implement |
# | Store data for further analysis | ✅ Database | Databases are the storage layer — data warehouse stores processed data ready for analysis |
# | Bring data from different sources together in one place | ✅ Database | Consolidating data from multiple sources into one location is a database (warehouse) function |
# | Show data visually | ✅ Dashboard | Dashboards present data in a visually appealing way — the non-technical interface from L9 |
# | Provide metrics and KPIs | ✅ Dashboard | KPIs at a glance is the defining use case of a dashboard from L9 |
#
# ---
#
# **💡 Why this matters**
# Choosing the wrong tool for a data task is a common source of wasted effort. Asking a dashboard to "move data between databases" is not possible — that is a pipeline job. Expecting a pipeline to "show metrics at a glance" misses the point — that is a dashboard job. In practice, a data analyst needs to understand which layer of the stack handles which task so they can communicate clearly with data engineers (pipeline and database questions) and business stakeholders (dashboard questions).
#
# **✅ RECAP**
# - Data pipeline: move data · automate ETL processing
# - Database: store data · consolidate from multiple sources
# - Dashboard: show data visually · provide KPIs and metrics
# - Each tool has a distinct job — they are complementary, not interchangeable
#
# **🔗 Connection**
# - This closes the L9–L12 managing data arc: L9 introduced all tools · L10 tested database facts · L11 tested cloud characteristics · L12 maps the full toolbox to concrete tasks
# - The dashboard → analyst ownership from L9 is reinforced here: showing data visually and providing KPIs are analyst-layer tasks, not engineering tasks

# %% [markdown]
# #### Chapter 2 — Lesson 13: Common data problems *(Video / 50 XP)*
#
# > 🎬 [Watch on DataCamp](https://campus.datacamp.com/courses/introduction-to-data-literacy/reading-data?ex=13) *(requires login)*
#
# ---
#
# **🎯 GOAL — What is this lesson about?**
# Dirty data is unavoidable in practice — this lesson maps the three types of data problems (errors, missing data, bias), their causes, and the cleaning strategies available for each, including the key rule that even severely compromised data can still support some analysis.
#
# ---
#
# **Dirty data** = incorrect · incomplete · inconsistent data.
# Causes: human error · technical issues · selective data collection.
# If unresolved: unrepresentative data → flawed analysis → wrong conclusions.
# *Analogy: a dirty window — too dirty to see clearly through until cleaned.*
#
# | Problem type | What it is | Cause | Counter-strategy |
# |-------------|-----------|-------|-----------------|
# | **Data errors** | Incorrect or inconsistent values — typing errors, dates in wrong format | Recording errors | Correct if original value/format is known; drop the data point if not |
# | **Missing data** | Data points left blank — survey respondents skipping questions | Incomplete collection | Drop the data OR impute (estimate missing values statistically) |
# | **Data bias** | Societal bias reflected in data — unrepresentative results (e.g. only older adults skipping survey questions) | Real-world characteristics of the collected data | Sound collection process · awareness in conclusions · explainable AI to detect bias during analysis |
#
# **When is missing data especially problematic?**
# - Many data points are missing, OR
# - There is an underlying pattern in what is missing (e.g. a specific group systematically not responding)
#
# **Data cleaning rule:**
# Not all data problems are fully solvable — but it is always possible to do *some* kind of analysis. At minimum: a descriptive analysis can document the data problems and inform improvements to the collection process.
#
# ---
#
# **💡 Why this matters**
# Data quality is the analyst's first responsibility before any insight is produced. A beautiful dashboard built on dirty data gives decision-makers false confidence in wrong numbers — the *Garbage In, Garbage Out* principle. In practice, data cleaning is not a one-time fix: it is an ongoing process that should be budgeted for at the start of every project. The bias problem is particularly important to understand: unlike errors or missing data, bias can be invisible — the data looks complete and correct, but systematically misrepresents reality.
#
# **→** *Even imperfect data has value — the key is being honest about its limitations and choosing an analysis that fits what the data can actually support.*
#
# **✅ RECAP**
# - Dirty data = incorrect · incomplete · inconsistent — unavoidable in practice, not ignorable
# - Data errors: wrong values/formats → correct or drop
# - Missing data: blank data points → drop or impute; problematic when many missing or pattern in what's missing
# - Data bias: societal bias in data → sound collection · aware conclusions · explainable AI
# - Cleaning rule: not all problems are solvable, but some analysis is always possible
# - Garbage In, Garbage Out: data quality determines the validity of every downstream conclusion
#
# **🔗 Connection**
# - Data bias connects directly to the Step 1 (Define) primacy rule from Ch1 L9: a biased collection process invalidates the analysis before it starts — problem definition includes defining how data will be collected, not just what question to ask
# - The imputation technique (estimating missing values statistically) is a preview of the predictive analytics toolbox in Ch3 — it uses the same statistical reasoning that underpins ML regression

# %% [markdown]
# #### Chapter 2 — Lesson 14: Consequences of data problems *(Exercise / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Can you identify what dirty and biased data cannot cause — specifically the cleaning rule from L13 that some analysis is always possible, even with severely compromised data.
#
# ---
#
# **📋 Scenario**
# Dirty and biased data have real consequences for analysis and conclusions.
#
# **Task:** What is **not** a potential consequence of dirty and biased data?
#
# ---
#
# **✅ Solution**
#
# | Option | Consequence? | Why |
# |--------|-------------|-----|
# | Making the wrong conclusions at the end of the analysis | ✅ Yes — is a consequence | The core risk of dirty data: flawed analysis leads to wrong conclusions |
# | A dataset that is unrepresentative of certain groups | ✅ Yes — is a consequence | Data bias specifically produces unrepresentative results — some groups are systematically over- or under-represented |
# | A dataset with too few cases | ✅ Yes — is a consequence | Missing data in large quantities reduces the effective dataset size, potentially making it too small for meaningful analysis |
# | **Being unable to perform any analysis** | ❌ No — correct answer | The cleaning rule from L13: even with severely compromised data, some analysis is always possible — at minimum, a descriptive analysis to document the problems |
#
# ---
#
# **💡 Why this matters**
# The "unable to perform any analysis" trap is a failure mode that paralyses teams when data quality is poor. In practice, data is never perfect — waiting for perfect data before starting analysis means never starting. The correct response to severely dirty data is not paralysis — it is a scoped analysis that acknowledges the limitations and uses the findings to improve the collection process. Communicating data quality issues *is* analysis.
#
# **✅ RECAP**
# - Three real consequences: wrong conclusions · unrepresentative results · too few cases
# - The false consequence: unable to perform any analysis — some analysis is always possible
# - Even at its worst, dirty data can be analysed descriptively to diagnose the quality problems
# - This is the operationalisation of the cleaning rule from L13: scoped analysis > no analysis

# %% [markdown]
# #### Chapter 2 — Lesson 15: Find the data problems *(Practice / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Can you identify the types of data problems present in a real dataset — applying the error/missing data taxonomy from L13 to concrete cells in a table.
#
# ---
#
# **📋 Scenario**
# **Data Detective** — explore three datasets to find data quality problems: Customer Orders, Student Grades, and Employee Records. Click on any cell to investigate.
#
# **Customer Orders dataset (10 rows, visible problems):**
#
# | ORDER ID | CUSTOMER | PRODUCT | QUANTITY | PRICE | COUNTRY |
# |----------|----------|---------|----------|-------|---------|
# | ORD-001 | Alice Johnson | Laptop | 2 | $999.00 | USA |
# | ORD-002 | Bob Smith | Keyboard | **-3** | $49.99 | USA |
# | ORD-003 | Carlos Garcia | Mouse | 5 | $29.99 | **Spane** |
# | ORD-004 | Diana Lee | Monitor | 1 | *(empty)* | Canada |
# | ORD-005 | *(empty)* | Headphones | 2 | $79.99 | UK |
# | ORD-006 | Frank Miller | Webcam | 1 | $59.99 | USA |
# | ORD-007 | Grace Kim | USB Hub | 0 | $19.99 | Germany |
# | ORD-008 | Henry Brown | Tablet | 1 | $449.00 | **Canda** |
# | ORD-009 | Ivy Chen | Charger | 3 | $24.99 | **N/A** |
# | ORD-010 | Jack Wilson | SSD Drive | 1 | **$-89.99** | Australia |
#
# **Identified problems:**
# - ORD-002 Quantity = -3 → data error (invalid value — quantity cannot be negative)
# - ORD-003 Country = "Spane" → data error (typo — should be "Spain")
# - ORD-004 Price = *(empty)* → missing data
# - ORD-005 Customer = *(empty)* → missing data
# - ORD-008 Country = "Canda" → data error (typo — should be "Canada")
# - ORD-009 Country = "N/A" → missing data (placeholder for no value)
# - ORD-010 Price = $-89.99 → data error (invalid value — price cannot be negative)
#
# **Task:** What types of data problems can you find in the datasets?
#
# ---
#
# **✅ Solution**
#
# | Option | Verdict | Why |
# |--------|---------|-----|
# | Only missing data | ❌ | The dataset contains typos and invalid values — these are data errors, not just missing values |
# | Only data errors (invalid values and typos) | ❌ | The dataset also contains empty cells (ORD-004 price, ORD-005 customer, ORD-009 country) |
# | **Both missing data and data errors** | ✅ Correct | The dataset contains both: typos/invalid values (data errors) AND empty/N/A cells (missing data) |
# | There are no data problems | ❌ | Multiple problems are visible across all three datasets |
#
# ---
#
# **💡 Why this matters**
# The Data Detective exercise makes abstract problem types concrete: a negative quantity, a misspelled country name, and an empty price field are all visible at a glance — but they require different responses. The typos can be corrected if the right value is known (Spain, Canada). The negative values need domain knowledge to resolve (is -3 a return? An error?). The empty fields need a decision: drop the row or impute. Real-world data cleaning always starts with this diagnostic step — you cannot clean what you haven't identified.
#
# **✅ RECAP**
# - Data errors in this dataset: negative quantity (-3) · typos ("Spane", "Canda") · negative price (-$89.99)
# - Missing data in this dataset: empty price (ORD-004) · empty customer (ORD-005) · N/A country (ORD-009)
# - Most real datasets contain both types simultaneously — the correct answer is almost never "only one type"
# - Diagnosis first, cleaning second — identify the problem type before choosing the response
#
# **🔗 Connection**
# - This exercise operationalises L13: error → correct or drop · missing → drop or impute · the Data Detective tool makes the taxonomy visible across three real-world domains
# - The same diagnostic approach (identify what's wrong before deciding what to do) is the Step 1 primacy rule from Ch1 L9 applied to data quality — define the problem before acting

# %% [markdown]
# #### Chapter 2 — Lesson 16: Countering dirty data and data bias *(Exercise / 100 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Can you classify six statements about dirty data and data bias as true or false — separating what is genuinely solvable from two persistent myths: that missing data has no effect, and that bias can always be removed.
#
# ---
#
# **📋 Scenario**
# Dirty and biased data are a major challenge in real-world data. We can take actions to counter this, but sometimes we have to consider that the data is not all that perfect.
#
# **Task:** Classify the following statements as true or false.
#
# ---
#
# **✅ Solution**
#
# | Statement | Classification | Why |
# |-----------|---------------|-----|
# | Data cleaning is an essential preparation step before analysis can begin | ✅ True | Core principle from L13 — cleaning must be budgeted for before any analysis starts |
# | Explainable AI can assist in mitigating bias | ✅ True | Explainable AI makes model outputs more interpretable, helping to detect bias during analysis — stated in L13 |
# | Societal bias can be reflected in data bias | ✅ True | Real-world data carries real-world characteristics — societal bias is a direct source of data bias, from L13 |
# | Missing data have no effect on the results, they are just ignored in data analysis | ❌ False | Missing data can cause unrepresentative results and reduce effective dataset size — it cannot simply be ignored |
# | Data bias can always be removed through data cleaning | ❌ False | Bias is hard to detect and resolve — "always" is too strong; the best mitigation is a sound collection process, not a cleaning fix |
# | Data bias is not a problem, because data analysis is objective and neutral | ❌ False | Data analysis is only as objective as the data it uses — biased input produces biased output regardless of the technique applied |
#
# ---
#
# **💡 Why this matters**
# The three false statements represent the most dangerous misconceptions in data quality. "Missing data has no effect" leads analysts to skip the missing value check entirely. "Bias can always be removed" creates false confidence in cleaning steps that can't actually reach the root cause. "Analysis is objective and neutral" is the most insidious: it conflates the neutrality of mathematical operations with the non-neutrality of data collection. A hiring algorithm trained on historically biased hiring data is mathematically correct and socially biased at the same time.
#
# **→** *The algorithm is only as objective as the data it learned from. Bias in → bias out, regardless of the method.*
#
# **✅ RECAP**
# - Three truths: cleaning is essential preparation · explainable AI helps detect bias · societal bias transfers to data
# - Three myths: missing data has no effect · bias can always be cleaned away · analysis is inherently neutral
# - The hardest myth to shake: "analysis is objective" — the technique may be neutral, the data it uses is not
# - The right posture: assume data has problems, check for them, be transparent about what couldn't be fixed
#
# **🔗 Connection**
# - This closes the full Ch2 arc: L1–4 (data sources) → L5–8 (data types) → L9–12 (managing data) → L13–16 (data problems) — every step of reading data now has a quality dimension
# - The "objective and neutral" myth connects directly to the bias awareness rule in the data collection process — and forward to Ch3, where the choice of analytics type can itself introduce framing bias if the wrong question is asked

# %% [markdown]
# ---
#
# ### 🧠 Chapter 2 Recap — Reading Data
#
# *16 lessons · 1050 XP · Arc: data sources → data types → managing data → data problems*
#
# ---
#
# **The central question Chapter 2 answers:**
# > Before any analysis begins — where does data come from, what form does it take, how is it stored, and what can go wrong with it?
#
# ---
#
# **Four-part arc:**
#
# **Part 1 — Data sources (L1–L4)**
#
# Data is not only numbers in spreadsheets — images, text, network, and spatial data are all valid forms. Sources split into two categories: open data (public, government/non-profit, APIs — no conditions, freely accessible) and internal data (private, condition-restricted, privacy-protected — customer, transaction, website, survey). The source type must be identified before collection begins: it determines access rights, privacy constraints, and collection approach. The distinction is a prerequisite, not an afterthought.
#
# **Part 2 — Data types (L5–L8)**
#
# Two binary distinctions, applied together: structured (tabular, relational database, easy to search) vs. unstructured (no pre-defined format, document database, preprocessing required); quantitative (numerical, measurable, wide analysis range) vs. qualitative (categorical, observable, restricted analysis range). Most real datasets are mixed — a customer table contains quantitative scores alongside qualitative category columns side by side. Knowing the type determines what storage is needed and what analytical operations are mathematically valid.
#
# **Part 3 — Managing data (L9–L12)**
#
# The infrastructure stack between raw data and the analyst's query: databases (DBMS-managed storage) → data warehouse (processed, ready) vs. data lake (raw, not yet prepared) → cloud storage (cost-effective, third-party security dependency) → pipelines (ETL: Extract → Transform → Load, automated) → SQL querying (industry standard) → dashboards (KPIs at a glance, analyst-owned). Each tool has a distinct job and a distinct owner: data engineer for infrastructure, data analyst for querying and dashboards.
#
# **Part 4 — Data problems (L13–L16)**
#
# Dirty data = incorrect · incomplete · inconsistent — unavoidable in practice. Three problem types: data errors (wrong values/formats → correct or drop), missing data (blank fields → drop or impute; especially problematic when systematic), data bias (societal bias reflected in data → sound collection process, explainable AI, awareness in conclusions). Two cleaning rules that run through all four lessons: not all problems are fully solvable — but some analysis is always possible; and data analysis is only as objective as the data it uses.
#
# ---
#
# **The key principle that runs through all 16 lessons:**
#
# > *Know your data before you use it — its source, its type, its storage, and its flaws.*
#
# Ch1 said: define the problem before collecting data. Ch2 says: know the data before analyzing it. These are the same principle applied at two different stages. A clear problem statement (Ch1) points to the right source type (Ch2 L1–L4). The source type determines what data format arrives (L5–L8). The format determines what storage and tooling are needed (L9–L12). The storage and collection process determine what quality problems to expect (L13–L16). The chapter is one continuous chain.
#
# ---
#
# **Concept map:**
#
# | Concept | Introduced | Tested | Core rule |
# |---------|-----------|--------|-----------|
# | Open vs. internal data | L1 | L2–L4 | Source type determines access, conditions, and privacy constraints |
# | Data forms (image, text, network, spatial) | L1 | L2 | Text and non-numerical data are valid and analyzable |
# | Structured vs. unstructured | L5 | L7 | Structure determines storage (relational vs. document) and preprocessing requirements |
# | Quantitative vs. qualitative | L5 | L8 | Type determines valid operations — averaging categories is meaningless |
# | Mixed datasets | L6, L8 | L8 | Most real datasets contain both types simultaneously |
# | Database types (warehouse vs. lake) | L9 | L10 | Warehouse = processed/ready · Lake = raw/not yet prepared |
# | ETL pipeline | L9 | L12 | Moves and automates data between databases — keeps data current |
# | SQL + dashboard | L9 | L12 | SQL = querying standard · Dashboard = KPIs at a glance, analyst-owned |
# | Dirty data (errors, missing, bias) | L13 | L14–L16 | Each type has a different counter-strategy |
# | Cleaning rule | L13 | L14 | Some analysis is always possible — never fully paralysed by dirty data |
# | Bias myth | L16 | L16 | Analysis is not inherently objective — bias in → bias out |
#
# ---
#
# **🔗 Forward connection to Ch3–Ch4:**
# - Ch3 (analytics types) is the analytical layer — descriptive, diagnostic, predictive, prescriptive each answer a different question about data that has already been read and cleaned in Ch2
# - Ch4 (communicating insights) is the output layer — the quality of a data story depends entirely on the quality of the data it is built on; Ch2's cleaning rules are the foundation Ch4 sits on
# - The bias awareness from L13–L16 runs all the way to Ch4: a biased dataset produces a biased insight, which produces a biased story — data literacy is about catching this at source, in Ch2

# %% [markdown]
# ---
#
# ## Chapter 3 — Working with and Analyzing Data
#
# #### Chapter 3 — Lesson 1: Descriptive analytics *(Video / 50 XP)*
#
# > 🎬 [Watch on DataCamp](https://campus.datacamp.com/courses/introduction-to-data-literacy/working-with-and-analyzing-data?ex=1) *(requires login)*
#
# ---
#
# **🎯 GOAL — What is this lesson about?**
# The four analytics types form a spectrum from foundational to advanced — but "more advanced" never means "better". This lesson frames the full framework, then zooms in on descriptive analytics: the first and most universal layer, built on summarising, visualising, and exploring data.
#
# ---
#
# The four analytics types, from foundational to most advanced:
#
# | Type | Leading question | What it does |
# |------|-----------------|-------------|
# | **Descriptive** | *What is happening?* | Summarises and visualises data to understand it |
# | **Diagnostic** | *Why did it happen?* | Investigates causes and relationships in data |
# | **Predictive** | *What will happen?* | Anticipates outcomes and forecasts future processes |
# | **Prescriptive** | *What should we do?* | Recommends decisions and optimises processes |
#
# **Critical rule:** More advanced ≠ better. The suitable type depends entirely on the question being asked. Choosing prescriptive analytics when descriptive would suffice needlessly complicates the analysis and increases the time required.
#
# ---
#
# **Descriptive analytics** answers *"What is happening?"* — and is the starting point for all other analytics types. It focuses on summarising and visualising data through three use cases:
#
# - **Getting to know the data** — based on its *variables* (the characteristics of interest measured or observed — e.g. temperature in a weather dataset)
# - **Investigating relationships and patterns** — whether groupings exist, or one variable is closely related to another
# - **Preparation for more advanced techniques** — building a model requires first understanding what the data contains
#
# **Common techniques:** descriptive statistics (averages, maximum/minimum values — answers *"What is the most common value?"* and *"How spread out are the values?"*) · visualisations (reveals patterns, groupings, and relationships) · outlier detection (identifies values very different from the majority; can surface data errors).
#
# **Exploratory Data Analysis (EDA)** is the comprehensive form of descriptive analytics. Its goal is to explore data openly — assessing main characteristics, finding relationships, patterns, or groups, and suggesting hypotheses for future analysis. It contrasts with hypothesis testing (formal, specific, tests a pre-defined question); EDA is broad and open, designed to discover what is not yet known. It combines basic descriptive statistics with advanced techniques such as cluster analysis, with strong emphasis on visualisation. Two valid outcomes: preparation for further analysis, and standalone insights — including discovering data problems.
#
# *Case study — ice cream sales:* Count sales per flavor (separated by store or month). Insights: limit product range to the most popular flavors, or select new flavors based on the characteristics of already popular ones.
#
# ---
#
# **💡 Why this matters**
# Descriptive analytics is the layer every other analytics type stands on — you cannot diagnose *why* something happened until you know *what* happened. In practice, many business questions that sound like they require predictive or prescriptive analytics actually need a descriptive step first: before asking "what will churn look like next quarter?", you need to know "how many customers churned this quarter, and in which segments?" Skipping descriptive analytics in favour of more advanced techniques produces models with no baseline — making it impossible to evaluate whether the model is actually improving anything.
#
# **→** *Describe before you diagnose. Know what happened before you ask why. This is not optional preparation — it is the foundation every subsequent question rests on.*
#
# **✅ RECAP**
# - Four types: Descriptive (what) · Diagnostic (why) · Predictive (what will) · Prescriptive (what to do) — a spectrum, not a ranking
# - More advanced ≠ better: the question determines the type, never the other way around
# - Descriptive analytics = summarise · visualise · detect outliers · explore (EDA)
# - Variable = a characteristic of interest measured or observed in the data
# - EDA is not just prep work — it can produce standalone insights, including discovering data problems
# - Ice cream example: count per flavor → limit range to popular · use popular characteristics to select new ones
#
# **🔗 Connection**
# - The four analytics types answer the problem statement categories from Ch1 L9 exactly: *describe state* → Descriptive · *diagnose causes* → Diagnostic · *detect anomalies or predict* → Predictive/Prescriptive — the Ch1 framework is now operationalised
# - The DIKW pyramid from Ch1 L5 maps onto the spectrum: Descriptive = Information layer · Diagnostic = Knowledge layer · Predictive/Prescriptive = Wisdom layer

# %% [markdown]
# #### Chapter 3 — Lesson 2: Reasons (not) to use descriptive analytics *(Exercise / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Can you identify what descriptive analytics is explicitly *not* for — separating its three genuine use cases from hypothesis testing, which belongs to a different analytical tradition entirely.
#
# ---
#
# **📋 Scenario**
# Descriptive analytics has specific use cases. Understanding what it is designed to do — and what it is not designed to do — is the foundation of choosing the right analytics type.
#
# **Task:** What is **not** a reason to use descriptive analytics?
#
# ---
#
# **✅ Solution**
#
# | Option | Reason to use? | Why |
# |--------|---------------|-----|
# | Investigating relationships between variables | ✅ Yes — is a reason | One of the three use cases from L1: finding patterns and relationships in data |
# | **Test hypotheses** | ❌ No — correct answer | Hypothesis testing is the contrasting method to EDA from L1 — it is formal, specific, and tests a pre-defined question. Descriptive analytics (including EDA) is open and exploratory, not confirmatory |
# | Prepare for more advanced analysis | ✅ Yes — is a reason | Third use case from L1: descriptive analytics as preparation for models and further techniques |
# | Get to know the data | ✅ Yes — is a reason | First use case from L1: understanding the data based on its variables |
#
# ---
#
# **💡 Why this matters**
# The hypothesis testing distractor is the most instructive wrong answer in this lesson. In practice, confusing exploratory data analysis with hypothesis testing is a common analytical mistake — and the consequences are real. EDA says: *"I don't know what's in the data — let me look openly."* Hypothesis testing says: *"I believe X is true — let me test it formally."* Applying the wrong framework in either direction wastes time: running formal statistical tests when you first need to understand your data, or treating open exploration as if it were a rigorous test of a specific claim.
#
# **✅ RECAP**
# - Three genuine use cases: get to know the data · investigate relationships · prepare for advanced analysis
# - What it is not: hypothesis testing — that is formal and confirmatory, EDA is open and exploratory
# - The distinction from L1 is now a decision rule: if you're confirming a pre-defined claim → hypothesis testing; if you're discovering what's there → descriptive analytics / EDA
#
# **🔗 Connection**
# - This directly operationalises the EDA vs. hypothesis testing contrast from L1 — the lesson named it, this exercise tests whether it's internalized
# - The "prepare for more advanced analysis" option connects forward to L5–L16: diagnostic, predictive, and prescriptive analytics all depend on descriptive analytics having been done first

# %% [markdown]
# #### Chapter 3 — Lesson 3: Exploring the data *(Practice / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Can you use an EDA tool to read distributions and statistics across a mixed dataset — and identify the one true statement, specifically recognising low-scoring outliers in the numerical variables.
#
# ---
#
# **📋 Scenario**
# **EDA Explorer** — an interactive tool to explore the student performance dataset. Select variables — categorical (Gender, Test Preparation, Lunch Type) or numerical (Math score, Reading score, Writing score) — to see their distributions and statistics.
#
# **Dataset:** 60 students total.
#
# **Categorical variables observed:**
# - **Gender:** Male = 29 · Female = 31 (slightly more female than male)
# - **Test Preparation:** majority did *not* complete the course
# - **Lunch Type:** two types visible — Standard and Free/Reduced (no "special" category)
#
# **Numerical variables observed (Math score shown):**
# - Distribution: 0–20 → 2 students · 20–40 → 3 · 40–60 → 17 · 60–80 → 31 · 80–100 → 7
# - Statistics: Mean = 62.6 · Min = 15 · Max = 100 · Total = 60
# - The same low-end outlier pattern (a small number of students scoring much lower than the majority) appears across all three score variables
#
# **Task:** Which statement about the data is true?
#
# ---
#
# **✅ Solution**
#
# | Option | Verdict | Why |
# |--------|---------|-----|
# | There are slightly more male than female students in the dataset | ❌ | Gender distribution: Male = 29, Female = 31 — females are slightly more, not males |
# | Most students completed the test preparation | ❌ | The Test Preparation distribution shows the majority did *not* complete the course |
# | **For each score, a couple of students scored very low compared to the majority** | ✅ Correct | Each score histogram shows 2–3 students in the lowest bucket (0–20, 20–40) — clearly lower than the main cluster (40–80). These are outliers. |
# | There are three types of lunch: free/reduced, standard, and special | ❌ | Only two lunch types are visible: Standard and Free/Reduced — no "special" category exists in this dataset |
#
# > DataCamp: *"That's right! You found some outliers! In each score histogram, you can see a few students scoring much lower than the majority. Outliers should be investigated to ensure they are not errors."*
#
# ---
#
# **💡 Why this matters**
# This exercise demonstrates what descriptive analytics actually looks like in practice — not a formula, but active reading of distributions. The outlier finding is the analytical output: a few students scoring 15–35 when the majority cluster is 40–80 is a signal, not noise. The DataCamp feedback names the next step explicitly: *investigate to ensure they are not errors*. This connects directly to Ch2's dirty data toolkit — an outlier is either a data error (wrong entry) or a real finding (a struggling student). You cannot know which without investigating. Descriptive analytics creates the question; it doesn't answer it.
#
# **→** *An outlier is not a conclusion — it is a prompt to ask why. That is exactly where diagnostic analytics begins.*
#
# **✅ RECAP**
# - EDA Explorer: descriptive analytics in action — select variables, read distributions and statistics
# - Gender: 29 male, 31 female — slightly more female (option 1 is reversed)
# - Test preparation: most students did NOT complete it
# - Lunch: two types only — Standard and Free/Reduced (no "special")
# - Score outliers: 2–3 students per variable in the lowest bucket — clearly below the majority cluster
# - DataCamp rule: outliers must be investigated — they may be data errors or real signals
#
# **🔗 Connection**
# - Outlier detection was listed as a descriptive analytics technique in L1 — this exercise makes it concrete and visible
# - The instruction to investigate outliers for potential errors connects directly to Ch2 L13–L15 (dirty data, data errors) — the same student performance dataset appeared there, now viewed through an analytical lens
# - The finding that most students did not complete test preparation connects forward to L4 (*Exploring connections*) — that lesson will likely test whether test preparation correlates with score performance

# %% [markdown]
# #### Chapter 3 — Lesson 4: Exploring connections *(Practice / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Can you read a scatterplot to identify a genuine correlation — and recognise the one conclusion that *cannot* be drawn from descriptive analytics alone, because it requires causal reasoning that belongs to diagnostic analytics.
#
# ---
#
# **📋 Scenario**
# **Scatterplot Explorer** — an interactive tool to explore connections between variables in the student performance dataset. Select X-axis and Y-axis variables (Math score, Reading score, Writing score), and optionally colour points by a categorical variable (e.g. Lunch Type) to spot group differences.
#
# **Scatterplots observed:**
# - **Reading score (X) vs. Writing score (Y):** strong upward diagonal — points clustered along a clear trend line from bottom-left to top-right. Students with high reading scores consistently have high writing scores.
# - **Math score (X) vs. Reading score (Y):** also upward trend, similarly strong positive relationship.
#
# **Task:** Which conclusion can we NOT make based on this analysis?
#
# ---
#
# **✅ Solution**
#
# | Option | Verdict | Why |
# |--------|---------|-----|
# | Students with high reading scores tend to have high writing scores as well | ✅ Can conclude | The Reading vs. Writing scatterplot shows a clear positive correlation — visible directly from the plot |
# | **Next year's students will get higher scores if they complete the test preparation** | ❌ Cannot conclude — correct answer | This is a causal, predictive claim about future students. Descriptive analytics shows *what* the current data looks like — it cannot establish that test preparation *causes* higher scores, nor predict future outcomes. That requires diagnostic and predictive analytics. |
# | Students with high writing scores tend to have high math scores | ✅ Can conclude | The Math vs. Reading (and by extension Writing) scatterplots show the same positive cluster pattern across all three score combinations |
# | Students with a standard lunch tend to have higher math scores | ✅ Can conclude | Colouring by Lunch Type in the scatterplot reveals a group difference — standard lunch students cluster higher than free/reduced lunch students |
#
# > DataCamp feedback on wrong answer: *"Look at the scatterplot of Reading Score vs Writing Score. As one score increases, what happens to the other?"* — the hint confirms the correct answer is found by reading the scatterplot, not by reasoning beyond it.
#
# ---
#
# **💡 Why this matters**
# The causality trap is one of the most consequential mistakes in data work. A scatterplot showing that test preparation correlates with higher scores does not mean preparation *causes* higher scores — both could be caused by a third factor (e.g. more motivated students both prepare and score higher). Presenting a correlation as a causal conclusion is not a minor error — it leads to interventions that may not work. Descriptive analytics establishes *what* is happening; diagnostic analytics investigates *why*. Confusing the two produces confident but unfounded recommendations.
#
# **→** *Correlation is visible in a scatterplot. Causation requires a different type of analysis — and a different question.*
#
# **✅ RECAP**
# - Scatterplot: shows how two numerical variables relate — the tool of choice for exploring connections
# - Reading ↔ Writing: strong positive correlation (visible from the diagonal cluster)
# - Math ↔ Reading and Writing: also positively correlated — all three scores move together
# - Lunch type: group difference visible when colouring by categorical variable
# - What cannot be concluded from descriptive analytics: causal claims · predictions about future students
# - The rule: descriptive analytics describes current data — it cannot establish causation or predict future outcomes
#
# **🔗 Connection**
# - This closes the L1–L4 descriptive analytics arc: L1 introduced the framework · L2 tested the use cases · L3 explored single variables (distributions, outliers) · L4 explores connections between variables — the full descriptive toolkit is now demonstrated
# - The causality limitation flagged here is the exact opening of diagnostic analytics (L5) — *why* something happens requires the next analytics type

# %% [markdown]
# #### Chapter 3 — Lesson 5: Diagnostic analytics *(Video / 50 XP)*
#
# > 🎬 [Watch on DataCamp](https://campus.datacamp.com/courses/introduction-to-data-literacy/working-with-and-analyzing-data?ex=5) *(requires login)*
#
# ---
#
# **🎯 GOAL — What is this lesson about?**
# Diagnostic analytics answers the *why* question: given an event that descriptive analytics has surfaced, what caused it? This lesson introduces the tools and limits of that investigation — from drill-down analysis and root cause analysis to the hard problem of distinguishing correlation from causation.
#
# ---
#
# Diagnostic analytics is the second of the four analytics types. Like a doctor diagnosing a patient to find the underlying disease, it identifies root causes of events — not just what happened, but why. It shares techniques with descriptive analytics (visualisations, summary statistics) but is more directed: every step is aimed at an underlying cause, not a broader view of the event.
#
# Finding causes is harder than describing events. A statistical relationship between two variables can be produced by a hidden third factor or by coincidence — this is the fundamental limitation of diagnostic analytics. Domain knowledge is essential to assess whether a proposed cause is plausible, and setting up controlled experiments can further strengthen the case for causality.
#
# **Common techniques in diagnostic analytics:**
#
# | Technique | What it does | Example |
# |-----------|-------------|---------|
# | Drill-down analysis | Move from summary data to underlying detail | Total revenue grows → identify which stores and products drove the increase |
# | Correlation & regression | Measure how closely two variables are related | Waiting time vs. customer satisfaction score |
# | Hypothesis testing | Test a proposed cause theorised beforehand | "We believe delays are the primary driver of dissatisfaction" |
# | Root Cause Analysis (RCA) | Formal 5-step process to find the true root cause | See steps below |
#
# **Root Cause Analysis (RCA) — 5 steps:**
# 1. Define the specific event under investigation
# 2. Collect all relevant data related to the event
# 3. Determine contributing factors from the data
# 4. Drill down from contributing factors to root causes
# 5. Recommend solutions based on root causes
#
# **Case study — airline customer satisfaction decline:** Group and rank keywords from complaint data to identify the most common complaint categories → investigate connections between those categories and operational data (waiting times, delays) → propose solutions targeting the top complaint drivers.
#
# ---
#
# **💡 Why this matters**
# Descriptive analytics tells you that customer satisfaction declined last quarter. Diagnostic analytics tells you why: flight delays increased and that correlates strongly with the most common complaint category. For a data analyst, the move from *what happened* to *why it happened* is the move from observation to recommendation. Without diagnostic analytics, the most you can do is report the problem; with it, you can propose a fix. The limitation — that correlation is not causation — is not a technicality to dismiss. Presenting a correlation as a proven cause can lead to costly interventions that do not work.
#
# **→** *Descriptive analytics raises the question. Diagnostic analytics investigates it — with appropriate caution about what a statistical relationship can and cannot prove.*
#
# **✅ RECAP**
# - Diagnostic analytics: finds root causes of events — answers *why*, not just *what*
# - Key limitation: statistical relationships do not prove causation — domain knowledge and experiments are needed to strengthen causal claims
# - Four main techniques: drill-down analysis · correlation & regression · hypothesis testing · Root Cause Analysis
# - RCA: formal 5-step process — define → collect data → contributing factors → root causes → solutions
# - Difference from descriptive analytics: same methods, different direction — descriptive = broad view of an event; diagnostic = directed at underlying causes
#
# **🔗 Connection**
# - L4 (*Exploring connections*) closed with the causality trap: a scatterplot cannot prove that test preparation *causes* higher scores — that requires diagnostic analytics. This lesson is that exact transition.
# - RCA uses the same drill-down logic as data cleaning (Ch2 L13–L16): start with a visible symptom, dig until you find the structural cause rather than patching the surface-level error
# - The DIKW pyramid (Ch1 L5–L8): Diagnostic analytics operates at the Knowledge layer — it transforms Information (descriptive findings) into Knowledge (understood causes)

# %% [markdown]
# #### Chapter 3 — Lesson 6: Finding causes *(Exercise / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Tests whether you understand the fundamental limitation of diagnostic analytics: it can identify potential causes, but it cannot prove causality — which requires additional analysis and experimentation.
#
# ---
#
# **📋 Scenario**
# *What can we conclude about causes of an event with the help of diagnostic analytics?*
#
# **Task:** Select the one correct conclusion from four options.
#
# ---
#
# **✅ Solution**
#
# | Option | Verdict | Why |
# |--------|---------|-----|
# | It can suggest potential causes. | ✅ Correct | Diagnostic analytics identifies and surfaces likely causes — it cannot confirm them as proven, but suggesting potential causes is exactly its scope |
# | It is the wrong type of analytics to say anything about causes. | ❌ Wrong | The entire purpose of diagnostic analytics IS to investigate causes — this reverses the definition |
# | Only root cause analysis is suited to find causes. | ❌ Wrong | RCA is one technique within diagnostic analytics, not the only one — correlation, regression, drill-down, and hypothesis testing all investigate causes too |
# | It can be used to prove causality. | ❌ Wrong | This is the key trap: statistical relationships do not prove causation. Proving causality requires controlled experiments and additional analysis. |
#
# > DataCamp feedback on correct answer: *"On its own, diagnostic analytics can only suggest causes, which is why we need to be careful with our conclusions. Domain knowledge can be a big help here."*
# >
# > DataCamp feedback on incorrect answer: *"Diagnostic analytics can help find causes, proving causal relationships, requires additional analysis and experimentation."*
#
# ---
#
# **💡 Why this matters**
# In practice, the distinction between "suggests a cause" and "proves a cause" is one of the most consequential calls a data analyst makes. Presenting a correlation as a proven causal relationship can lead to investments in solutions that do not work — because the real cause was something else entirely. Domain knowledge is the first filter: does the proposed cause make sense given what we know about the system? Experimentation (A/B tests, controlled trials) is the second filter: does the cause hold when other factors are held constant? Diagnostic analytics opens the investigation — it does not close it.
#
# **→** *Diagnostic analytics raises a well-evidenced hypothesis. Causality requires a different kind of proof.*
#
# **✅ RECAP**
# - Diagnostic analytics: can suggest potential causes — not prove them
# - The causality trap: correlation ≠ causation — a third hidden factor, or coincidence, can produce the same statistical pattern
# - RCA is one technique within diagnostic analytics — not the only one, and not the whole of it
# - Domain knowledge: essential for assessing whether a proposed cause is plausible before committing to it
# - Proving causality: requires additional analysis and controlled experimentation beyond diagnostic analytics
#
# **🔗 Connection**
# - L4 (*Exploring connections*): the scatterplot exercise ended with the exact same trap — high test prep correlates with scores but cannot *prove* causation from descriptive analytics alone; L6 confirms the same boundary holds in diagnostic analytics
# - L5 video: domain knowledge was named as a crucial asset — this exercise tests whether that principle was absorbed

# %% [markdown]
# #### Chapter 3 — Lesson 7: Root cause analysis steps *(Exercise / 100 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Tests whether the learner can recall and sequence the 5 RCA steps in the correct order — reinforcing that RCA is a structured process, not a jump from "something went wrong" to "fix it."
#
# ---
#
# **📋 Scenario**
# Root Cause Analysis (RCA) aims to look beyond direct causes by digging deeper until the root causes are found.
#
# **Task:** Organize the different steps of RCA in the correct order.
#
# ---
#
# **✅ Solution**
#
# | Step | Name | Purpose in the process |
# |------|------|------------------------|
# | 1 | Define the event | Establish what happened — scope the problem before any analysis begins |
# | 2 | Collect relevant data | Gather the evidence needed to investigate — no data, no diagnosis |
# | 3 | Determine contributing factors | Identify conditions that enabled or worsened the event — the context around the cause |
# | 4 | Find root causes | Drill down through contributing factors to the underlying cause — the "why behind the why" |
# | 5 | Recommend possible solutions | Propose fixes that address the root cause — not just the symptoms |
#
# ---
#
# **💡 Why this matters**
# Each step in RCA builds on the previous one — the sequence is not arbitrary. You cannot identify root causes before defining what the event actually was, and you cannot recommend solutions before knowing what caused the event. The most common failure in diagnostic work is skipping steps: jumping from "something went wrong" directly to "here is the fix" without passing through data collection and contributing factors. That shortcut produces interventions that treat symptoms instead of causes, which is why the problem returns. The order enforces the rigour that makes the diagnosis trustworthy.
#
# **→** *RCA is a discipline of patience: the correct answer is always further down the chain than the first obvious explanation.*
#
# **✅ RECAP**
# - The 5 RCA steps in order: Define the event → Collect relevant data → Determine contributing factors → Find root causes → Recommend possible solutions
# - The sequence is structural: each step is a prerequisite for the next — shortcuts produce wrong diagnoses
# - Contributing factors ≠ root causes: contributing factors are conditions that enabled the event; root causes are the underlying reason it happened
# - Solutions must address the root cause — fixing contributing factors or symptoms alone allows the problem to recur
#
# **🔗 Connection**
# - L5 (*Diagnostic analytics* video): the 5-step RCA process was introduced as a framework — this exercise tests retention and sequencing of the exact steps introduced there
# - L6 (*Finding causes*): confirmed that diagnostic analytics suggests causes without proving them — RCA formalises that investigative process into a repeatable sequence

# %% [markdown]
# #### Chapter 3 — Lesson 8: Descriptive vs. diagnostic analytics *(Exercise / 100 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Tests whether the learner can correctly separate descriptive and diagnostic analytics by purpose and technique — confirming that the two types are adjacent but have distinct scopes and questions they answer.
#
# ---
#
# **📋 Scenario**
# Now that you have seen two types of analytics, time to practice if you know the difference between the two.
#
# **Task:** Drag the cards to the relevant analytics type that best fits.
#
# ---
#
# **✅ Solution**
#
# | Item | Analytics type | Why |
# |------|---------------|-----|
# | Summarize & visualize the data | Descriptive | Descriptive analytics describes what happened — summarisation and visualisation are its core outputs |
# | Prepare for more advanced analysis | Descriptive | EDA and descriptive summaries are the foundation layer — you describe first, then diagnose |
# | Common technique: exploratory data analysis | Descriptive | EDA is the signature technique of descriptive analytics — it reveals patterns without asking why |
# | Common technique: drill-down analysis | Diagnostic | Drill-down is a diagnostic technique — it breaks down aggregates to isolate where a change occurred |
# | Find root causes of events | Diagnostic | Finding root causes is the defining purpose of diagnostic analytics — descriptive analytics only shows that something happened |
# | Investigate causal relationships | Diagnostic | Investigating causality is diagnostic work — descriptive analytics does not ask why, only what |
#
# ---
#
# **💡 Why this matters**
# Misclassifying these two types is a practical mistake, not just a conceptual one. If a stakeholder asks "why did sales drop last quarter?" and you respond with a descriptive summary — charts, averages, totals — you have answered a different question. Descriptive analytics confirms *that* sales dropped. Diagnostic analytics investigates *why*. Knowing which type of analysis a question calls for determines whether the output is actionable or merely informative.
#
# **→** *The question type determines the analytics type: "what happened?" → descriptive. "why did it happen?" → diagnostic.*
#
# **✅ RECAP**
# - Descriptive analytics: summarise, visualise, prepare — answers "what happened?"
# - Diagnostic analytics: drill-down, root cause, causal investigation — answers "why did it happen?"
# - EDA is descriptive — it reveals patterns without explaining causes
# - Drill-down analysis is diagnostic — it breaks aggregates apart to locate the source of a change
# - The two types are sequential: you describe first, then diagnose — descriptive is the foundation
#
# **🔗 Connection**
# - L1 (*Descriptive analytics* video): the 4-type framework was introduced here — this exercise tests the first two types in direct comparison
# - L5 (*Diagnostic analytics* video): drill-down and root cause analysis were named as diagnostic techniques — this exercise confirms that classification

# %% [markdown]
# #### Chapter 3 — Lesson 9: Predictive analytics *(Video / 50 XP)*
#
# > 🎬 [Watch on DataCamp](https://campus.datacamp.com/courses/introduction-to-data-literacy/working-with-and-analyzing-data?ex=9) *(requires login)*
#
# ---
#
# **🎯 GOAL — What is this lesson about?**
# Predictive analytics uses patterns in historical data to estimate the probability of future — or currently unknown — outcomes. It extends the 4-type framework from "what happened / why" into "what will most likely happen," always with an associated degree of uncertainty.
#
# ---
#
# Descriptive and diagnostic analytics are concerned with the past and present. Predictive analytics looks forward: its purpose is to identify the most likely outcome of an event and assign a probability to it. Three distinct use cases define the scope: anticipating future events before they occur (machine failure prediction from maintenance data), forecasting how a trend will continue over time (stock prices, pandemic trajectory), and predicting something not yet known in the present (diagnosing a disease from symptoms, flagging fraudulent transactions). In all three cases, uncertainty increases the further the prediction reaches beyond the available data.
#
# The four main predictive techniques each serve a different type of prediction:
#
# | Technique | Predicts | Example |
# |-----------|---------|---------|
# | Classification | Category / group membership | Will a customer cancel their subscription? |
# | Regression | Numerical value | Housing prices based on neighbourhood characteristics |
# | Time series forecasting | Future values over time | Sales revenue for the next quarter |
# | Predictive text analytics | Text category | Is an email spam or not? |
#
# All predictive models share a common workflow: (1) define what to predict → (2) collect and prepare data, split into training set and test set → (3) build and train the model on the training set → (4) evaluate predictions on the test set using metrics such as accuracy (% of correct predictions) → (5) fine-tune if necessary. The train/test split is structural — the model learns on one portion of data and is judged on data it has never seen.
#
# **Case study — World Cup winner:** Before major sports events, predictive models use team ratings, player ratings, current rankings, and estimated match difficulty to predict the most likely winner, knockout probabilities, and chances of reaching the final. The same logic applies to any competitive system with measurable inputs.
#
# ---
#
# **💡 Why this matters**
# Predictive analytics is where data work most directly influences future decisions — resource allocation, risk management, product development. A maintenance team that acts on a failure prediction before the machine breaks avoids unplanned downtime; a fraud team that flags suspicious transactions in real time prevents losses that cannot be recovered. But the uncertainty caveat is not optional: a prediction is a probability, not a fact. Presenting a model output as a certainty is one of the most common — and consequential — analytical mistakes. Every prediction needs a confidence range and an awareness of how far it extrapolates beyond the training data.
#
# **→** *Predictive analytics gives you the most likely answer — not the certain one. The degree of uncertainty is part of the output, not a footnote.*
#
# **✅ RECAP**
# - Predictive analytics: estimates the probability of future or currently unknown outcomes using patterns in historical data
# - Three use cases: anticipate future events · forecast trends · predict unknowns in the present
# - Four techniques: classification (categories) · regression (values) · time series (future values over time) · predictive text analytics (text categories)
# - Predictive modeling workflow: define → collect/prepare → train → evaluate → fine-tune
# - Train/test split: the model is evaluated on data it has never seen — accuracy is the % of correct predictions
# - Uncertainty is always present — it grows with distance from the training data
#
# **🔗 Connection**
# - L1 (*Descriptive analytics* video): the 4-type framework positions predictive analytics as the third type — past/present → future
# - L5 (*Diagnostic analytics* video): diagnostic stops at "why it happened"; predictive begins where diagnostic ends — using that "why" to project forward

# %% [markdown]
# #### Chapter 3 — Lesson 10: Are we predicting yet? *(Practice / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Tests whether the learner can identify predictive analytics in a real dataset scenario — specifically recognising text classification (sentiment analysis) as a predictive technique, not a descriptive one.
#
# ---
#
# **📋 Scenario**
# A colleague has built a model that analyses airline tweets and estimates each tweet's sentiment: positive, negative, or neutral. The results are shown in a table (`airline` · `text` · `airline_sentiment`).
#
# **Task:** Which type of analytics did he most likely use for this analysis?
#
# ---
#
# **✅ Solution**
#
# | Option | Verdict | Why |
# |--------|---------|-----|
# | Predictive analytics | ✅ Correct | The model *predicts* a sentiment label for each tweet — this is text classification, one of the four predictive techniques introduced in L9 |
# | Descriptive analytics | ❌ Wrong | Descriptive analytics summarises what happened; it does not assign predicted labels using a trained model |
# | Diagnostic analytics | ❌ Wrong | Diagnostic analytics investigates why something happened — it does not produce sentiment classifications |
# | None of the above | ❌ Wrong | Predictive analytics is precisely the right type — sentiment classification is a textbook use case |
#
# **Key distinction:** The table *looks* like a description (rows, columns, labels) — but the `airline_sentiment` column was *produced by a model trained on patterns*, not extracted from the raw data. The output is a prediction, not a summary.
#
# ---
#
# **💡 Why this matters**
# Sentiment analysis of customer feedback is one of the most widely deployed predictive applications in business — airlines, banks, retailers, and tech companies all use it to monitor brand perception at scale. Recognising it as predictive analytics (classification) rather than descriptive matters because it changes how you evaluate the output: a descriptive summary is factual; a predicted sentiment label carries a probability and a potential error rate. A tweet labelled "positive" by the model may be sarcastic — the model made a prediction, not a determination.
#
# **→** *When a column is produced by a model, the output is a prediction — always ask for the error rate before acting on it.*
#
# **✅ RECAP**
# - Sentiment classification (positive / negative / neutral) = predictive text analytics — a subtype of predictive analytics
# - The visual output (a table with labels) looks descriptive — the process that produced it is predictive
# - Classification predicts category membership — L9 introduced this as one of four predictive techniques
# - Every predicted label has an associated error rate — the model can be wrong
#
# **🔗 Connection**
# - L9 (*Predictive analytics* video): predictive text analytics and classification were named as two of the four predictive techniques — this exercise applies both in one real scenario
# - L8 (*Descriptive vs. diagnostic*): the same pattern — output format does not determine analytics type; purpose and process do

# %% [markdown]
# #### Chapter 3 — Lesson 11: Building a predictive model *(Exercise / 100 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Tests whether the learner can recall and correctly sequence the 5 steps of predictive modelling — reinforcing that the workflow is ordered by dependency, not preference, and that the first step determines everything that follows.
#
# ---
#
# **📋 Scenario**
# While many different techniques can be used for predictive analytics, when it comes to building a predictive model, there is a common sequence of steps.
#
# **Task:** Place the steps to building a predictive model in the right order.
#
# ---
#
# **✅ Solution**
#
# | Step | Name | Why this position |
# |------|------|-------------------|
# | 1 | Define the outcome to predict | Determines everything that follows — which data to collect, which model to build, which metric to use. Without this, all other steps are directionless |
# | 2 | Collect and prepare the data | Once you know what to predict, you can identify what data is relevant and prepare it — including the train/test split |
# | 3 | Build the predictive model | Only after data is ready can the model be trained on the training set |
# | 4 | Interpret and evaluate the model | The trained model is evaluated on the test set using pre-determined metrics (e.g. accuracy) — this step is a checkpoint, not an afterthought |
# | 5 | Fine-tune the model or implement | If evaluation shows acceptable performance: deploy. If not: adjust and retrain. Either way, this is the final step |
#
# > DataCamp hint: *"Determining what we are going to predict guides the rest of the process."*
#
# ---
#
# **💡 Why this matters**
# The most common failure in predictive modelling projects is not a technical one — it is starting with the data rather than the question. When teams begin by exploring whatever data they have and then search for something to predict, the result is a model that technically works but does not address a real business need. Defining the outcome first forces alignment: the business stakeholder, the data engineer, and the analyst all agree on what success looks like before a single line of code is written. The train/test split exists for the same reason — it prevents the model from being judged on data it already learned from, which would produce falsely optimistic results.
#
# **→** *Define before you build. Evaluate on data the model has never seen. The sequence is not bureaucracy — it is the protection against building something that looks accurate but isn't.*
#
# **✅ RECAP**
# - 5-step predictive modelling workflow: Define → Collect & prepare → Build → Interpret & evaluate → Fine-tune or implement
# - Step 1 (Define) is the foundation: it determines which data is needed, which model is appropriate, and which metric to use
# - Train/test split happens in Step 2: the model is trained on one subset and evaluated on another it has never seen
# - Evaluation (Step 4) uses pre-determined metrics — accuracy (% of correct predictions) is the most common
# - The "Incorrect" trap: placing Define anywhere other than first produces a model without a clear purpose
#
# **🔗 Connection**
# - L9 (*Predictive analytics* video): the same 5-step workflow was introduced — this exercise tests retention and sequencing
# - L7 (*Root cause analysis steps*): same exercise format — ordering a structured process; same principle — the sequence is a dependency chain, not a checklist

# %% [markdown]
# #### Chapter 3 — Lesson 12: Looking into the future *(Practice / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Tests whether the learner understands why uncertainty grows with forecast horizon — the core limitation of time series forecasting and of predictive analytics more broadly.
#
# ---
#
# **📋 Scenario**
# In time series forecasting, you predict values over a period of time. The **horizon** is how far into the future you're predicting — it could be days, months, or years.
#
# The **Forecast Explorer** interactive tool shows three datasets (Monthly Sales, Website Traffic, Avg. Temperature) with a forecast horizon slider from 1 to 24 months. The shaded band is the **uncertainty range** — how wide the range of possible outcomes is at each predicted point.
#
# **Task:** Why does the uncertainty range get larger with a higher horizon?
#
# **Data from the tool:**
# - 6 months → **145% wider** uncertainty
# - 12 months → **246% wider** uncertainty
#
# ---
#
# **✅ Solution**
#
# | Option | Verdict | Why |
# |--------|---------|-----|
# | Because of the uncertainty associated with predicting further into the future | ✅ Correct | Each step forward in time compounds the uncertainty from previous steps — errors accumulate, and new unpredictable factors can emerge |
# | Because this technique is not suitable for predictive analytics | ❌ Wrong | Time series forecasting is a standard predictive technique — growing uncertainty is a property of forecasting, not a sign it's the wrong tool |
# | Because the predicted values always increase over time | ❌ Wrong | Predicted values can rise, fall, or oscillate — the uncertainty band grows regardless of the direction of the forecast |
#
# ---
#
# **💡 Why this matters**
# Every forecast comes with an uncertainty band — and that band widens the further out you predict. A 1-month sales forecast might be reliable enough to make staffing decisions; a 24-month forecast might be too wide to act on without scenario planning. The practical implication: when presenting a forecast to a business stakeholder, always show the uncertainty range alongside the prediction line. A single forecast line without a confidence interval is a false precision — it hides the fact that the "prediction" becomes progressively less certain the further it extends.
#
# **→** *The uncertainty band is not a flaw in the model — it is the honest representation of what the model actually knows.*
#
# **✅ RECAP**
# - Forecast horizon: how far into the future the prediction extends (days, months, years)
# - Uncertainty grows with horizon: each predicted step inherits the error of the previous step — uncertainty compounds
# - 6 months → 145% wider · 12 months → 246% wider — the relationship is non-linear
# - The shaded band is the uncertainty range: the full spread of plausible outcomes at each point in the forecast
# - Presenting a forecast without the uncertainty band = false precision
#
# **🔗 Connection**
# - L9 (*Predictive analytics* video): uncertainty was introduced as an inherent property of all predictions — this exercise makes it visible and quantifiable
# - L11 (*Building a predictive model*): Step 4 (Interpret and evaluate) is where uncertainty metrics are examined — this exercise shows why that step is not optional

# %% [markdown]
# #### Chapter 3 — Lesson 13: Prescriptive analytics *(Video / 50 XP)*
#
# > 🎬 [Watch on DataCamp](https://campus.datacamp.com/courses/introduction-to-data-literacy/working-with-and-analyzing-data?ex=13) *(requires login)*
#
# ---
#
# **🎯 GOAL — What is this lesson about?**
# Prescriptive analytics is the fourth and final analytics type — it takes the predicted outcome from predictive analytics and recommends the best course of action, weighing associated benefits, drawbacks, and constraints.
#
# ---
#
# Where predictive analytics answers "what will most likely happen?", prescriptive analytics answers "what should we do about it?" It builds directly on predictive outputs: first a probability is estimated, then prescriptive logic selects the action that optimises the desired outcome given the available options and real-world constraints (resources, risks, trade-offs).
#
# The three benefits of prescriptive analytics: informed data-driven decisions · process optimisation · risk mitigation.
#
# The four common techniques are:
#
# | Technique | How it works |
# |-----------|-------------|
# | Rule-based systems | A set of decision rules — derived from domain knowledge, a machine learning model, or both — maps predicted outcomes to recommended actions |
# | Reinforcement learning | An algorithm learns the optimal action sequence by receiving positive/negative feedback as it runs through possible actions |
# | Scenario analysis & simulation | Pre-determined scenarios or simulated outcomes are compared; the option with the best expected result is selected |
# | Recommendation engine | Uses past behaviour (viewed, purchased, watched) to predict interests, then surfaces specific recommendations — the most visible prescriptive technique in everyday life |
#
# **Case study — fraud detection:** A transaction is flagged as possibly fraudulent. Options: block the account, call the customer, assign to a fraud analyst. Each option carries different risk and cost profiles, and the fraud analyst has a daily capacity limit. Prescriptive analytics processes these constraints and recommends which action to take for each flagged case — balancing fraud loss prevention against customer experience and resource availability.
#
# ---
#
# **💡 Why this matters**
# Most analytics work stops at prediction — a probability is produced, and a human decides what to do with it. Prescriptive analytics closes that gap by encoding the decision logic itself. In fraud, logistics, pricing, and clinical triage, the volume of decisions is too high for individual human judgement on each case. Prescriptive systems operate at scale while incorporating constraints that a human decision-maker would struggle to track simultaneously. The trade-off: the decision logic must be auditable and the constraints correctly specified — a recommendation engine that optimises for the wrong objective (click rate instead of customer value) produces recommendations that are technically optimal and strategically wrong.
#
# **→** *Prescriptive analytics doesn't just tell you what will happen — it tells you what to do. The quality of the recommendation depends entirely on how well the objective and constraints were defined.*
#
# **✅ RECAP**
# - Prescriptive analytics: recommends the best action given a predicted outcome and real-world constraints
# - Builds on predictive: prediction first → prescription second — you cannot prescribe without a prediction
# - Three benefits: informed decisions · process optimisation · risk mitigation
# - Four techniques: rule-based systems · reinforcement learning · scenario analysis/simulation · recommendation engine
# - Recommendation engine: predicts interest from past behaviour → surfaces specific recommendations (Netflix, e-commerce)
# - Fraud case: prescriptive balances fraud loss prevention, customer experience, and analyst capacity simultaneously
#
# **🔗 Connection**
# - L9 (*Predictive analytics* video): prescriptive analytics is explicitly downstream of predictive — this lesson closes the 4-type framework
# - L1 (*Descriptive analytics* video): the full arc is now complete: describe what happened → diagnose why → predict what will happen → prescribe what to do

# %% [markdown]
# #### Chapter 3 — Lesson 14: Characteristics of prescriptive analytics *(Exercise / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Tests whether the learner can distinguish genuine characteristics of prescriptive analytics from a false claim — specifically the trap of assuming that a "higher" analytics type is inherently superior to the others.
#
# ---
#
# **📋 Scenario**
# *What is **not** a characteristic of prescriptive analytics?*
#
# **Task:** Select the one option that does NOT describe prescriptive analytics.
#
# ---
#
# **✅ Solution**
#
# | Option | Verdict | Why |
# |--------|---------|-----|
# | Provides better insights than the other types of analytics | ✅ Correct (NOT a characteristic) | The 4 analytics types are complementary — each answers a different question. Prescriptive is not superior; it is downstream. Without descriptive, diagnostic, and predictive work, prescriptive has nothing to act on |
# | Builds on predictive analytics | ❌ Wrong (IS a characteristic) | Prescriptive analytics explicitly requires a predicted outcome as its input — L13 defined this directly |
# | Results in a recommended course of action | ❌ Wrong (IS a characteristic) | Recommending the best action is the defining output of prescriptive analytics |
# | Looks at the future | ❌ Wrong (IS a characteristic) | Like predictive analytics, prescriptive is forward-looking — it acts on predicted future outcomes |
#
# ---
#
# **💡 Why this matters**
# The "better insights" trap is a common misconception in analytics maturity discussions — the idea that prescriptive is the "most advanced" and therefore most valuable analytics type. In reality, the value of each type depends entirely on the question being asked. A company that needs to understand what happened last quarter needs descriptive analytics — no amount of prescriptive capability answers that question better. The four types are a framework for matching the right analytical approach to the right question, not a hierarchy where higher is always better.
#
# **→** *Analytics types are not a ladder — they are a toolkit. The right tool depends on the question, not the level.*
#
# **✅ RECAP**
# - Prescriptive analytics is NOT superior to other analytics types — each type serves a distinct purpose
# - The 4 types are complementary and sequential: prescriptive depends on the outputs of the other three
# - Three genuine characteristics: builds on predictive · results in a recommended action · looks at the future
# - The "better insights" framing is the trap: it implies a hierarchy that does not exist
#
# **🔗 Connection**
# - L13 (*Prescriptive analytics* video): all three genuine characteristics (builds on predictive, recommends action, future-oriented) were introduced — this exercise tests recognition and the ability to spot the false claim
# - L1 (*Descriptive analytics* video): the 4-type framework was presented as complementary types — this exercise confirms that framing

# %% [markdown]
# #### Chapter 3 — Lesson 15: Predictive vs. prescriptive analytics *(Exercise / 100 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Tests whether the learner can separate predictive-only, prescriptive-only, and shared characteristics — with two deliberate traps: "Looks at the future" (shared, not predictive-only) and "Suggests possible outcomes" (predictive, not prescriptive).
#
# ---
#
# **📋 Scenario**
# Predictive and prescriptive analytics have some things in common but also some crucial differences.
#
# **Task:** Link the different characteristics to the type of analytics that best fits. Three buckets: **Predictive analytics** · **Prescriptive analytics** · **Both**.
#
# ---
#
# **✅ Solution**
#
# | Item | Bucket | Why |
# |------|--------|-----|
# | What will happen? | Predictive | The defining question of predictive analytics — it estimates the most likely future outcome |
# | Suggests possible outcomes | Predictive | Predicting outcomes (probabilities) is predictive work — prescriptive takes those outcomes as input and acts on them |
# | Suggests possible actions | Prescriptive | Recommending an action is the defining output of prescriptive analytics |
# | What should we do? | Prescriptive | The defining question of prescriptive analytics — it selects the best action given the predicted outcome |
# | Looks at the future | Both | Both predictive and prescriptive analytics are forward-looking — prescriptive acts on the future, not just predicts it |
# | Degree of uncertainty associated with the results | Both | Uncertainty is inherent in any future-oriented analytics — both types produce results with an associated confidence range |
#
# > **⚠️ Trap 1 — "Looks at the future" → Both, not Predictive only**
# > DataCamp feedback: *"The ability to look at the future is for more advanced analytics than descriptive or diagnostic analytics."* Both predictive and prescriptive are future-oriented. Predictive doesn't own the future — it shares it with prescriptive.
#
# > **⚠️ Trap 2 — "Suggests possible outcomes" → Predictive, not Prescriptive**
# > DataCamp feedback: *"Identifying outcomes is one thing, but prescriptive analytics takes it one step further."* Outcomes = predictive. Actions based on those outcomes = prescriptive. The distinction is outputs vs. inputs.
#
# ---
#
# **💡 Why this matters**
# The predictive/prescriptive boundary is where many analytics projects stall. A model that predicts which customers will churn (predictive) is not the same as a system that recommends which retention offer to send to each customer (prescriptive). Both look at the future, both carry uncertainty — but one produces a probability and the other produces a decision. Confusing the two leads to organisations investing in predictive models and then manually translating outputs into decisions, losing speed and consistency. Understanding the distinction helps scope the right level of investment for a given problem.
#
# **→** *Predicting the outcome and deciding what to do about it are two different problems — and two different systems.*
#
# **✅ RECAP**
# - Predictive only: "What will happen?" · "Suggests possible outcomes"
# - Prescriptive only: "What should we do?" · "Suggests possible actions"
# - Both: "Looks at the future" · "Degree of uncertainty associated with the results"
# - Trap 1: "Looks at the future" belongs to Both — prescriptive is also forward-looking
# - Trap 2: "Suggests possible outcomes" → Predictive; "Suggests possible actions" → Prescriptive — outcomes vs. actions is the dividing line
# - Uncertainty is not a predictive-only property — any future-oriented result carries a confidence range
#
# **🔗 Connection**
# - L13 (*Prescriptive analytics* video): defined prescriptive as building on predictive outputs — this exercise formalises that relationship into a classification
# - L14 (*Characteristics of prescriptive analytics*): confirmed prescriptive looks at the future — this exercise extends that to "Both" category

# %% [markdown]
# #### Chapter 3 — Lesson 16: Matching use cases to the type of analytics *(Exercise / 100 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Synthesis exercise for the full Chapter 3 framework: tests whether the learner can correctly classify real-world use cases into the right analytics type — using the question behind the task, not surface-level keywords, as the decision rule.
#
# ---
#
# **📋 Scenario**
# Now that we have reached the end of the chapter, it is time to combine all that knowledge and determine which type of analytics is best for the needs of different use cases.
#
# **Task:** Assign each use case to the correct type of analytics. Three buckets: **Descriptive Analytics** · **Diagnostic Analytics** · **Predictive Analytics**.
#
# *(Note: Prescriptive analytics is not included in this exercise — the focus is on the first three types.)*
#
# ---
#
# **✅ Solution**
#
# | Use case | Analytics type | Decision rule |
# |----------|---------------|---------------|
# | Report on the healthcare investments made in the last year and compare this with the previous year. | Descriptive | "Report on" and "compare" = summarising what happened. No why, no future, no action. |
# | Analyze airline customer satisfaction surveys to determine why satisfaction rates are declining. | Diagnostic | "Determine why" = causal investigation. The purpose is to find the reason behind the decline. |
# | Find out possible reasons for customers canceling their credit cards. | Diagnostic | "Find out possible reasons" = root cause investigation — same pattern as the airline case. |
# | Analyze which team is most likely to win the next Fifa World Cup. | Predictive | "Most likely to win" = probability of a future outcome. Same case study used in L9. |
# | Find out which regions will likely see an increase in crime rates in the coming month. | Predictive | "Will likely see" = forecasting a future value over time — time series forecasting pattern. |
#
# ---
#
# **💡 Why this matters**
# The decision rule for analytics type is always the question the task is trying to answer — not the domain (healthcare, airlines, sports) or the data format. "Report and compare" → descriptive. "Why is this happening?" → diagnostic. "What will most likely happen?" → predictive. Getting this classification right at the start of a project prevents misaligned work: a team asked "why are customers churning?" that runs a predictive model has answered a different question and delivered something that cannot be acted on in the way the stakeholder expected.
#
# **→** *Identify the question first. The analytics type follows from the question — not from the data, the tool, or the domain.*
#
# **✅ RECAP**
# - Decision rule: match the question, not the domain — "what happened?" → descriptive · "why?" → diagnostic · "what will happen?" → predictive
# - "Report and compare past data" → always descriptive
# - "Determine why / find reasons" → always diagnostic — even if the dataset looks descriptive
# - "Most likely / will likely" → always predictive — probability language is the signal
# - Prescriptive was deliberately excluded: it acts on predicted outcomes — it presupposes predictive work is already done
#
# **🔗 Connection**
# - L1 (*Descriptive analytics* video): the 4-type framework and its decision rule (question → type) was introduced — this exercise is the full-chapter test of that framework
# - L9 (*Predictive analytics* video): the World Cup case study was the example — it appears here as a classification item, confirming the connection between example and application

# %% [markdown]
# ---
#
# ### 🧠 Chapter 3 Recap — Working with and Analyzing Data
#
# *Written after L16 — deferred synthesis rule. 16 lessons, 950 XP.*
#
# ---
#
# #### The one rule that governs all 16 lessons
#
# > **The question determines the analytics type — not the domain, not the data, not the tool.**
#
# Every exercise in this chapter was, at its core, a question-classification problem. Before selecting a chart, a model, or a technique — identify what the task is actually trying to answer:
#
# | Question | Analytics type | Direction |
# |----------|---------------|-----------|
# | What happened? | Descriptive | Past / present |
# | Why did it happen? | Diagnostic | Past / present |
# | What will most likely happen? | Predictive | Future |
# | What should we do about it? | Prescriptive | Future → action |
#
# The four types are not a hierarchy. They are complementary tools. Prescriptive depends on predictive, which depends on diagnostic, which depends on descriptive — but that dependency chain does not make prescriptive "better". A question about last year's performance is best answered with descriptive analytics. No amount of predictive sophistication changes that.
#
# ---
#
# #### What each type actually does
#
# **Descriptive** — summarises and visualises. EDA is its signature technique. It tells you what the data looks like and prepares the ground for deeper analysis. It does not explain, predict, or prescribe. Hypothesis testing is NOT a use case for descriptive analytics.
#
# **Diagnostic** — investigates causes. It can suggest potential causes; it cannot prove causality. Drill-down analysis, correlation, regression, and RCA are its tools. The causality trap is the central limitation: a statistical relationship between two variables can be produced by a hidden third factor or coincidence. Domain knowledge is the first filter for plausibility; controlled experiments are the second.
#
# **Predictive** — estimates probabilities of future or currently unknown outcomes. Three use cases: anticipate events before they occur · forecast trends · predict unknowns in the present. Four techniques: classification (categories) · regression (values) · time series forecasting (future values over time) · predictive text analytics (text categories). All predictions carry uncertainty — and uncertainty grows non-linearly with the forecast horizon (6 months → 145% wider; 12 months → 246% wider).
#
# **Prescriptive** — recommends the best action given a predicted outcome and real-world constraints. It builds on predictive outputs. Four techniques: rule-based systems · reinforcement learning · scenario analysis/simulation · recommendation engines. The output is a decision, not a probability. Shared with predictive: both look at the future; both carry uncertainty.
#
# ---
#
# #### The traps this chapter tested
#
# | Trap | Lesson | Correct reasoning |
# |------|--------|-------------------|
# | Hypothesis testing as a descriptive use case | L2 | Hypothesis testing investigates relationships and differences — that is diagnostic, not descriptive |
# | Correlation implies causation | L4, L6 | Correlation shows a relationship; causation requires controlled experiments and domain knowledge |
# | "Diagnostic analytics can prove causality" | L6 | It can suggest potential causes only — proving causality requires additional analysis |
# | "RCA is the only diagnostic technique" | L6 | RCA is one of four techniques; correlation, regression, and drill-down also investigate causes |
# | Sentiment analysis output looks descriptive | L10 | A table of labels produced by a trained model is predictive — the output format does not determine the analytics type |
# | "Looks at the future" → Predictive only | L15 | Both predictive and prescriptive are future-oriented — this is a shared characteristic |
# | "Suggests possible outcomes" → Prescriptive | L15 | Outcomes are predictive; actions based on those outcomes are prescriptive |
# | Prescriptive provides better insights than other types | L14 | The four types are complementary — prescriptive is not superior, it is downstream |
#
# ---
#
# #### The two sequencing patterns
#
# This chapter contained two drag-to-order exercises, both with the same underlying logic: the sequence is a dependency chain, not a checklist.
#
# - **RCA (L7):** Define the event → Collect relevant data → Determine contributing factors → Find root causes → Recommend possible solutions
# - **Predictive modelling (L11):** Define the outcome to predict → Collect and prepare the data → Build the model → Interpret and evaluate → Fine-tune or implement
#
# In both cases: define first. Everything downstream depends on what is defined at Step 1.

# %% [markdown]
# ## Course 4: Introduction to Statistics <a id="course-4"></a>
#
# **Level:** Basic | **Updated:** May 2026
# **Duration:** 4 hr | **Chapters:** 4 | **Instructor:** George Boorman
# **Videos:** 16 | **Exercises:** 56 | **Learners:** 150K+
# **XP:** 3450 | **Status:** 🔄 In Progress
# **Part of tracks:** Data Literacy Professional
#
# ---
#
# ### Course description
# Statistics are all around us, from marketing to sales to healthcare. The ability to collect, analyze, and draw conclusions from data is not only extremely valuable, but it is also becoming commonplace to expect roles that are not traditionally analytical to understand the fundamental concepts of statistics. This course will equip you with the necessary skills to feel confident in working with and analyzing data to draw insights. You'll be introduced to common methods used for summarizing and describing data, learn how probability can be applied to commercial scenarios, and discover how experiments are conducted to understand relationships and patterns. You'll work with real-world datasets including crime data in London, England, and sales data from an online retail company.
#
# ---
#
# ### Chapter 1: Summary Statistics
#
# *Summary statistics gives you the tools you need to describe your data. In this chapter, you'll explore summary statistics including mean, median, and standard deviation, and learn how to accurately interpret them. You'll also develop your critical thinking skills, allowing you to choose the best summary statistics for your data.*
#
# | # | Lesson | Type | XP |
# |---|--------|------|----|
# | 1 | What is statistics? | 🎬 Video | 50 |
# | 2 | Using statistics in the real-world | 📝 Exercise | 50 |
# | 3 | Identifying data types | 📝 Exercise | 100 |
# | 4 | Descriptive vs. Inferential statistics | 📝 Exercise | 100 |
# | 5 | Measures of center | 🎬 Video | 50 |
# | 6 | Typical number of robberies per London Borough | 📝 Exercise | 50 |
# | 7 | Choosing a measure | 🔁 Practice | 50 |
# | 8 | London Boroughs with most frequent crimes | 🔁 Practice | 50 |
# | 9 | Measures of spread | 🎬 Video | 50 |
# | 10 | Defining measures of spread | 📝 Exercise | 100 |
# | 11 | Box plots for measuring spread | 📝 Exercise | 50 |
# | 12 | Which crime has the larger standard deviation | 📝 Exercise | 50 |
#
# **Chapter 1 XP: 750**
#
# ---
#
# ### Chapter 2: Probability and distributions
#
# *Probability underpins a large part of statistics, where it is used to calculate the chance of events occurring. You'll work with real-world sales data and learn how data with different values can be interpreted as a probability distribution. You'll find out about discrete and continuous probability distributions, including the discovery of the normal distribution and how it occurs frequently in natural events!*
#
# | # | Lesson | Type | XP |
# |---|--------|------|----|
# | 1 | What are the chances? | 🎬 Video | 50 |
# | 2 | What is more likely? | 📝 Exercise | 50 |
# | 3 | Chances of the next sale being more than the mean | 🔁 Practice | 50 |
# | 4 | Conditional probability | 🎬 Video | 50 |
# | 5 | Dependent vs. Independent events | 📝 Exercise | 100 |
# | 6 | Orders of more than 10 basket products | 📝 Exercise | 50 |
# | 7 | Discrete distributions | 🎬 Video | 50 |
# | 8 | Identifying distributions | 📝 Exercise | 50 |
# | 9 | Sample mean vs. Theoretical mean | 🔁 Practice | 50 |
# | 10 | Continuous distributions | 🎬 Video | 50 |
# | 11 | Discrete vs. Continuous distributions | 📝 Exercise | 100 |
# | 12 | Finding the normal distribution | 📝 Exercise | 50 |
# | 13 | Probability with a uniform distribution | 📝 Exercise | 50 |
#
# **Chapter 2 XP: 750**
#
# ---
#
# ### Chapter 3: More Distributions and the Central Limit Theorem
#
# *It's time to explore more probability distributions. You'll learn about the binomial distribution for visualizing the probability of binary outcomes, and one of the most important distributions in statistics, the normal distribution. You'll see how distributions can be described by their shape, along with discovering the Poisson distribution and its role in calculating the probabilities of events occurring over time. You'll also gain an understanding of the central limit theorem!*
#
# | # | Lesson | Type | XP |
# |---|--------|------|----|
# | 1 | The binomial distribution | 🎬 Video | 50 |
# | 2 | Recognizing a binomial distribution | 📝 Exercise | 50 |
# | 3 | How probability affects the binomial distribution | 📝 Exercise | 50 |
# | 4 | Identifying n and p | 📝 Exercise | 50 |
# | 5 | The normal distribution | 🎬 Video | 50 |
# | 6 | Recognizing the normal distribution | 📝 Exercise | 50 |
# | 7 | What makes the normal distribution special? | 📝 Exercise | 100 |
# | 8 | Identifying skewness | 📝 Exercise | 100 |
# | 9 | Describing distributions using kurtosis | 📝 Exercise | 50 |
# | 10 | The central limit theorem | 🎬 Video | 50 |
# | 11 | Visualizing sampling distributions | 🔁 Practice | 50 |
# | 12 | The CLT vs. The law of large numbers | 📝 Exercise | 100 |
# | 13 | When to use the central limit theorem | 📝 Exercise | 50 |
# | 14 | The Poisson distribution | 🎬 Video | 50 |
# | 15 | Identifying Poisson processes | 📝 Exercise | 100 |
# | 16 | Recognizing lambda in the Poisson distribution | 📝 Exercise | 50 |
#
# **Chapter 3 XP: 1000**
#
# ---
#
# ### Chapter 4: Correlation and Hypothesis Testing
#
# *In the final chapter, you'll be introduced to hypothesis testing and how it can be used to accurately draw conclusions about a population. You'll discover correlation and how it can be used to quantify a linear relationship between two variables. You'll find out about experimental design techniques such as randomization and blinding. You'll also learn about concepts used to minimize the risk of drawing the wrong conclusion about the results of hypothesis tests!*
#
# | # | Lesson | Type | XP |
# |---|--------|------|----|
# | 1 | Hypothesis testing | 🎬 Video | 50 |
# | 2 | Sunshine and sleep | 📝 Exercise | 100 |
# | 3 | The hypothesis testing workflow | 📝 Exercise | 100 |
# | 4 | Independent and dependent variables | 📝 Exercise | 50 |
# | 5 | Experiments | 🎬 Video | 50 |
# | 6 | Recognizing controlled trials | 📝 Exercise | 100 |
# | 7 | Why use randomization? | 📝 Exercise | 50 |
# | 8 | Correlation | 🎬 Video | 50 |
# | 9 | Identifying correlation between variables | 🔁 Practice | 50 |
# | 10 | What can correlation tell you? | 📝 Exercise | 50 |
# | 11 | Confounding variables | 📝 Exercise | 50 |
# | 12 | Interpreting hypothesis test results | 🎬 Video | 50 |
# | 13 | Significance levels vs. p-values | 📝 Exercise | 100 |
# | 14 | Type I and type II errors | 📝 Exercise | 50 |
# | 15 | Congratulations! | 🎬 Video | 50 |
#
# **Chapter 4 XP: 950**
#
# ---
#
# **Total course XP: 3450 | 4 chapters | 56 lessons**

# %% [markdown]
# ---
#
# ## 📚 Course Knowledge Map — Pre-loaded from PDF Slide Decks
#
# *Source: chapter1.pdf · chapter2.pdf · chapter3.pdf · chapter4.pdf*
# *Purpose: reference map for building lesson cells — do not add lesson content here*
#
# ---
#
# ### CHAPTER 1 — What is Statistics?
#
# ```
# WHAT IS STATISTICS?
# │
# ├── The Field of Statistics
# │   └── Practice and study of collecting and analyzing data
# │
# ├── Two Main Branches
# │   ├── Descriptive / Summary Statistics
# │   │   └── Describing or summarizing data (e.g. total crime per borough)
# │   └── Inferential Statistics
# │       └── Collect a sample → apply results to the population
# │           (e.g. how many purchase clothing after social media ads?)
# │
# ├── What Statistics Can Do
# │   ├── Answer practical questions (avg salary, customer inquiries per week)
# │   ├── Applications across society (safer products, government policy)
# │   └── Validate scientific breakthroughs (Covid-19 vaccines)
# │
# ├── Limitations
# │   ├── Requires specific, measurable questions
# │   └── Cannot find out WHY relationships exist
# │
# ├── Types of Data: Numeric
# │   ├── Continuous data (stock prices: $2328.14, $156.77)
# │   └── Interval / Count data (cups of coffee per day: 4, 2, 3)
# │
# ├── Types of Data: Categorical
# │   ├── Nominal data (eye color: brown, green, blue)
# │   └── Ordinal data (agreement scale: strongly agree → strongly disagree)
# │
# ├── Visualizing Data
# │   ├── Numeric data → histograms
# │   └── Categorical data → bar charts
# │
# ├── Measures of Center
# │   ├── Mean  → sum of all values / count (sensitive to outliers)
# │   ├── Median → middle value when sorted (robust to outliers)
# │   └── Mode  → most frequent value
# │
# └── Measures of Spread
#     ├── Range  → max − min
#     ├── Variance → avg squared distance from mean
#     ├── Standard Deviation → √variance (close to 0 = clustered around mean)
#     ├── Quartiles → split data into 4 equal parts (Q1, Q2=median, Q3)
#     ├── IQR → Q3 − Q1 (less affected by extreme values)
#     └── Box plots → visual summary using quartiles
# ```
#
# > **Running example:** London crime data (Metropolitan Police Service) — burglary, robbery, theft, vehicle crime across 32 boroughs
#
# ---
#
# ### CHAPTER 2 — What are the Chances?
#
# ```
# PROBABILITY
# │
# ├── Measuring Chance
# │   └── P(event) = (# ways event can happen) / (total # possible outcomes)
# │       Example: P(heads) = 1/2 = 50%
# │
# ├── Sampling
# │   ├── With replacement → each pick is independent, probabilities stay constant
# │   └── Without replacement → each pick is dependent, probabilities change
# │
# ├── Independent Events
# │   └── Probability of second event does NOT change based on first event
# │
# ├── Dependent Events
# │   └── Probability of second event IS affected by outcome of first event
# │
# ├── Conditional Probability
# │   ├── P(A|B) = P(A ∩ B) / P(B)
# │   └── Used to calculate probability of dependent events
# │
# ├── Venn Diagrams
# │   └── Visual representation of event overlaps and conditional probability
# │
# ├── Discrete Probability Distributions
# │   ├── Describe probabilities for discrete outcomes (e.g. die roll)
# │   ├── Expected value = mean of a probability distribution
# │   ├── Discrete uniform distribution (fair die: each outcome = 1/6)
# │   └── Probability = area under the distribution
# │
# ├── Law of Large Numbers
# │   └── As sample size increases, sample mean approaches expected value
# │
# └── Continuous Distributions
#     ├── Continuous uniform distribution (e.g. bus wait time 0–12 min)
#     ├── Total area under any probability distribution = 1
#     ├── Bimodal distribution (two peaks)
#     └── Normal distribution (bell curve, symmetrical)
# ```
#
# > **Running example:** Online retail sales data — product types (Basket, Art & Sculpture, Jewelry, Kitchen, Home Decor) with order counts and probabilities
#
# ---
#
# ### CHAPTER 3 — Key Probability Distributions
#
# ```
# KEY DISTRIBUTIONS
# │
# ├── Binomial Distribution
# │   ├── Probability of # successes in a sequence of independent events
# │   ├── Described by n (total events) and p (probability of success)
# │   ├── Expected value = n × p
# │   ├── Requires independence — if events are dependent, binomial does NOT apply
# │   └── Applications: clinical trials (effective/not), sports betting (win/lose)
# │
# ├── Normal Distribution
# │   ├── Symmetrical bell curve, total area = 1, curve never hits 0
# │   ├── Described by mean (center) and standard deviation (spread)
# │   ├── 68-95-99.7 Rule:
# │   │   ├── 68% within 1 std dev
# │   │   ├── 95% within 2 std dev
# │   │   └── 99.7% within 3 std dev
# │   ├── Many real-world datasets resemble normal distribution
# │   ├── Required for many statistical tests
# │   ├── Skewness → asymmetry (left or right tail)
# │   └── Kurtosis → occurrence of extreme values (leptokurtic, mesokurtic, platykurtic)
# │
# ├── Central Limit Theorem (CLT)
# │   ├── Sampling distribution of a statistic approaches normal as sample size increases
# │   ├── Applies to both means and proportions
# │   ├── Samples must be random and independent
# │   └── Why it matters: enables inference without knowing population distribution
# │
# └── Poisson Distribution
#     ├── Probability of # events occurring over a fixed period of time
#     ├── λ (lambda) = average # events per time period = expected value
#     ├── λ is the distribution's peak
#     ├── Poisson processes: known avg rate, random timing between events
#     │   (animal adoptions/week, restaurant arrivals/hour, website visits/day)
#     └── CLT still applies to the Poisson distribution
# ```
#
# > **Running example:** Coin flips (binary outcomes, binomial), die rolls (CLT demonstration), bus wait times (Poisson processes)
#
# ---
#
# ### CHAPTER 4 — Hypothesis Testing and Correlation
#
# ```
# HYPOTHESIS TESTING
# │
# ├── Why Hypothesis Testing?
# │   ├── Used to compare populations
# │   ├── Applications: price change → revenue, website change → traffic, medication → treatment
# │   └── Dates back to 1700s (human sex ratio)
# │
# ├── Null and Alternative Hypotheses
# │   ├── Null (H₀): assume no difference exists
# │   └── Alternative (H₁): a difference exists
# │
# ├── Hypothesis Testing Workflow
# │   ├── Define target populations
# │   ├── Develop null and alternative hypotheses
# │   ├── Collect or access sample data
# │   ├── Perform statistical tests
# │   └── Draw conclusions about the population
# │
# ├── Sample Size
# │   ├── CLT: larger samples → means closer to population mean
# │   └── Trade-off: time and resource intensive
# │
# ├── Variables
# │   ├── Independent variable → unaffected by other data (e.g. vitamin C supplementation)
# │   └── Dependent variable → affected by other data (e.g. birth gender ratio)
# │
# ├── Experiments
# │   ├── Treatment = independent variable, Response = dependent variable
# │   ├── Controlled experiments: treatment group vs. control group
# │   ├── Randomization → participants assigned randomly (RCT)
# │   ├── Blinding → participants don't know which group
# │   ├── Double-blind → administrator also doesn't know
# │   └── RCT vs. A/B testing: RCT = multiple groups, science; A/B = two groups, marketing/engineering
# │
# ├── Correlation
# │   ├── Pearson correlation coefficient (r) → -1 to +1
# │   ├── Magnitude = strength (0.99 very strong, 0.75 strong, 0.56 moderate, 0.21 weak, 0.04 none)
# │   ├── Sign = direction (+ = same direction, - = opposite)
# │   ├── Linear relationships only
# │   ├── Correlation ≠ causation
# │   └── Confounding variables → unmeasured factor affecting both variables
# │
# └── Interpreting Results
#     ├── p-value → probability of achieving this result assuming H₀ is true
#     ├── Significance level (α) → threshold for rejecting H₀ (typical: 0.05)
#     ├── If p ≤ α → reject H₀ (statistically significant)
#     ├── Type I Error → false positive (reject H₀ when H₀ is true)
#     └── Type II Error → false negative (fail to reject H₀ when H₀ is false)
# ```
#
# > **Running example:** Vitamin C supplementation and birth gender ratio (Ch4), Chicago vs. Bangkok life expectancy (p-value demonstration), Gym costs vs. water costs (correlation ≠ causation)
#
# ---
#
# ### Course Arc
#
# ```
# Ch1: What is Statistics?    → Foundation: data types, descriptive/inferential, measures
# Ch2: What are the Chances?  → Probability: from basic chance to distributions
# Ch3: Key Distributions      → Deep dive: binomial, normal, Poisson, CLT
# Ch4: Hypothesis Testing     → Application: experiments, correlation, inference
# ```
#
# > **Instructor:** George Boorman, Curriculum Manager at DataCamp
# > **Next course in track:** Understanding Data Science

# %% [markdown]
# #### Chapter 1 — Lesson 1: What is Statistics? *(Video / 50 XP)*
#
# > 🎬 [Watch on DataCamp](https://campus.datacamp.com/courses/introduction-to-statistics/summary-statistics-ef7cd595-e629-4103-a4ad-152b9e13b909?ex=1) *(requires login)*
#
# ---
#
# **🎯 GOAL — What is this lesson about?**
# Understand the definition of statistics, its two main branches (descriptive and inferential), and the types of practical questions statistics can and cannot answer.
#
# ---
#
# **Statistics** is the practice and study of collecting and analyzing data. It splits into two main branches:
#
# | Branch | Definition | Real-world example |
# |--------|------------|-------------------|
# | **Descriptive / Summary Statistics** | Tools used to describe or summarize data | Thefts in Westminster account for 36% of all thefts in five London boroughs |
# | **Inferential Statistics** | Using a sample to draw conclusions about a population | Survey 100 people on social media advertising → infer behavior for all people |
#
# Statistics is everywhere — from sports announcers discussing player performance to personal finance tracking. It allows us to answer specific, measurable questions: *What is the average USA salary?* *How many customer inquiries will a company receive per week?* Applications span product safety, government policy, and scientific validation (e.g., Covid-19 vaccines were 89% effective in preventing severe disease in older adults in the UK).
#
# **Important limitation:** Statistics requires specific, measurable questions. It can answer *whether* rock music outsells jazz (measurable), but **not** *why* people prefer one genre over another (open-ended). Similarly, statistics reveals patterns (women live longer than men) but cannot explain the underlying reasons.
#
# **Data types matter.** To analyze data correctly, we must first classify it:
# - **Numeric (Quantitative):** Continuous (stock price) or count/interval (cups of coffee per day)
# - **Categorical (Qualitative):** Nominal, unordered (eye color) or ordinal, ordered (survey: strongly disagree → strongly agree)
#
# Visualization choices follow: numeric data pairs appear as scatter plots; categorical-numeric relationships appear as grouped bar charts (e.g., thefts by London borough).
#
# ---
#
# **💡 Why this matters**
# In any analytics role, you will inherit questions before you inherit data. Statistics gives you the language to know which questions are answerable and which require a different approach. A recruiter will ask: *"Why didn't you use statistics for that?"* Understanding the boundary — measurable vs. philosophical — separates analysts who understand their tools from those who misapply them. It is also the foundation for every concept that follows in this course.
#
# **✅ RECAP**
# - Statistics = practice of collecting and analyzing data to answer specific, measurable questions
# - Two branches: **Descriptive** (summarize data) and **Inferential** (sample → population conclusion)
# - Data types: **Numeric** (continuous/count) and **Categorical** (nominal/ordinal)
# - Statistics cannot answer *why* — only *what* and *whether*
# - Applications: product safety, policy, scientific validation; limitations: requires measurable questions
#
# **🔗 Connection**
# - Descriptive statistics (this lesson's branch 1) is the focus of Chapter 1 — we will learn the tools (mean, median, standard deviation)
# - Inferential statistics (this lesson's branch 2) connects to Chapters 2–4 — probability, distributions, hypothesis testing
# - Data types classification (this lesson) determines which visualization and summary statistic to choose — practiced in Lesson 2 onwards

# %% [markdown]
# #### Chapter 1 — Lesson 2: Using statistics in the real-world *(Exercise / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Recognize which real-world questions are answerable through statistics (specific, measurable) versus which require non-statistical approaches (philosophical, open-ended).
#
# ---
#
# **📋 Scenario**
#
# You have been provided with several real-world scenarios and need to identify which ones can be solved through the application of statistics.
#
# Recall that statistics can help to answer specific, measurable questions. In this exercise, you need to distinguish between questions that can be addressed through statistics and those that cannot.
#
# **Task:** Select the scenario that **can** be solved through statistics.
#
# ---
#
# **Possible Answers**
#
# | # | Question | Verdict | Why |
# |---|----------|---------|-----|
# | 1 | Why do some people prefer dogs to cats? | ❌ Not answerable | Open-ended, philosophical — statistics cannot explain *why* preferences exist, only measure them if they already exist |
# | 2 | Testing whether a new model of car is safer than the current model? | ✅ **CORRECT** | Specific, measurable — collect safety data on both models, compare outcomes using inferential statistics (hypothesis test) |
# | 3 | What factors make one TV show more popular than another? | ❌ Not answerable | Open-ended — too many cultural factors; cannot be narrowed to a single measurable question without context |
# | 4 | What will tomorrow's winning lottery numbers be? | ❌ Not answerable | Unpredictable randomness — lottery draws are independent; no historical pattern can predict future draws (misconception of causality) |
#
# **Answer:** **Option 2 — "Testing whether a new model of car is safer than the current model?"**
#
# This is the only scenario that frames a specific, measurable hypothesis. The company can:
# 1. Define "safer" (e.g., accident severity, crash test scores)
# 2. Collect data on both models
# 3. Use inferential statistics to compare populations (current model vs. new model)
# 4. Draw a conclusion based on evidence
#
# The other options require either explaining *why* (requires qualitative research, not statistics) or predicting pure randomness (impossible).
#
# ---
#
# **💡 Why this matters**
#
# In your first week on an analytics team, a stakeholder will ask you: *"Can we use data to answer this?"* Knowing the difference between measurable and philosophical questions will save you weeks of wasted effort. A company spent 6 months building a model to predict "customer happiness" without defining what it means — statistics cannot answer vague questions. The skill you're practicing here is knowing when to say "we need to reframe this question" versus "let's build the analysis." This is a core communication skill for analysts and data engineers.
#
# **→** *When a question feels unanswerable, your job is to translate it into something measurable — not to build analysis on an impossible foundation.*
#
# **✅ RECAP**
# - Statistics answers specific, measurable questions only
# - A/B testing (new vs. current) is a classic statistics use case — inferential design
# - "Why" questions require qualitative research or domain expertise, not statistics
# - Randomness cannot be predicted (lottery, stock prices tomorrow)
# - Your first skill: recognizing which questions statistics can solve before investing time
#
# **🔗 Connection**
# - This exercise reinforces the Limitations section from Lesson 1 — measurable vs. philosophical
# - Chapter 1 focuses on *descriptive* statistics (summarizing existing data)
# - Chapter 4 will focus on *inferential* statistics — the testing framework needed for the car safety question in this exercise

# %% [markdown]
# #### Chapter 1 — Lesson 3: Identifying data types *(Exercise / 100 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Classify real-world data examples into their correct data type (continuous numeric, nominal categorical, or ordinal categorical) by understanding the measurement scale and ordering properties of each type.
#
# ---
#
# **📋 Scenario**
#
# You learned that there are two main types of data: numeric and categorical. Numeric data can be classified as either continuous or count/interval, and categorical data can be classified as either nominal or ordinal. The data type determines which approaches are suitable when summarizing your data.
#
# You've been provided with several examples to classify as continuous, nominal, or ordinal data.
#
# **Task:** Map each example to its correct data type by dragging items into the appropriate bucket.
#
# ---
#
# **✅ Solution**
#
# | Item | Correct Type | Classification | Why |
# |------|--------------|-----------------|-----|
# | Race car lap time | Continuous | Numeric | Measured on a continuous scale (e.g., 45.23 seconds, 45.24 seconds) — infinite precision possible |
# | Height in centimeters | Continuous | Numeric | Measured on a continuous scale (e.g., 165.7 cm, 165.8 cm) — any real value possible |
# | Employment status | Nominal | Categorical | Unordered categories (employed, unemployed, self-employed) — no inherent ranking |
# | Soccer player position | Nominal | Categorical | Unordered categories (goalkeeper, defender, midfielder, forward) — cannot be ranked or assigned numeric value |
# | Customer satisfaction — unsatisfied, neutral, satisfied | Ordinal | Categorical | Ordered categories — clear ranking from unsatisfied → neutral → satisfied |
# | Income status — low, middle, high | Ordinal | Categorical | Ordered categories — clear ranking from low → middle → high |
#
# **Common mistake:** "Soccer player position is nominal, not ordinal" — positions cannot be assigned a numeric value and ranked (goalkeeper is not "less than" a midfielder). While we might number positions on a jersey, those numbers are identifiers, not measurements of an ordered scale.
#
# ---
#
# **💡 Why this matters**
#
# Before you visualize or calculate a summary statistic, you must know your data type. A common analytics mistake: calculating the mean of ordinal data (e.g., average satisfaction rating as a single number without context). Satisfaction might be 2.3 on a 1–5 scale, but that number is meaningless without the full distribution — *how many chose 1 vs. 5?* Knowing your data type forces you to ask: *What is a sensible summary for this measurement scale?* This is the foundation for every decision in exploratory data analysis (EDA). A recruiter will notice if you treat ordinal like continuous in your first project.
#
# **→** *Data type = decision gate. Get it wrong early, and every analysis that follows is built on the wrong foundation.*
#
# **✅ RECAP**
# - **Continuous data:** measured on a continuous scale; infinite precision (lap times, heights, prices)
# - **Nominal data:** unordered categories; no inherent ranking (positions, colors, employment status)
# - **Ordinal data:** ordered categories; clear ranking but no measurable interval between ranks (satisfaction levels, income brackets)
# - Data type determines visualization and summary statistic choice (next lessons)
# - Confusing types = wasted analysis effort; recognizing types early = correct decisions downstream
#
# **🔗 Connection**
# - Lesson 1 introduced data types in the context of why they matter
# - This lesson operationalizes the classification skill (practice with real examples)
# - Next lesson (Descriptive vs. Inferential) will build on this knowledge
# - Lesson 5+ will show *which* summary statistic (mean, median, mode) to use for each type

# %% [markdown]
# #### Chapter 1 — Lesson 4: Descriptive vs. Inferential statistics *(Exercise / 100 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Distinguish between descriptive statistics (summarizing existing data) and inferential statistics (using a sample to draw conclusions about a population) by analyzing real-world scenarios.
#
# ---
#
# **📋 Scenario**
#
# Recall that there are two main branches of statistics — descriptive statistics and inferential statistics.
#
# Understanding what type of statistics is required for a given situation is an essential skill in order to draw accurate conclusions.
#
# Now you have the opportunity to check your knowledge of how these two branches of statistics are used in practice. You'll classify each scenario as a task for descriptive or inferential statistics.
#
# **Task:** Choose which type of statistics to use for each scenario. Map each item into the Descriptive or Inferential bucket by dragging.
#
# ---
#
# **✅ Solution**
#
# | Scenario | Correct Type | Classification | Why |
# |----------|--------------|-----------------|-----|
# | Given data on all projects completed, what percentage were delivered on time? | Descriptive | Summarization | You have the complete dataset (all projects). Calculate a summary statistic (percentage) to describe what already exists — no inference needed |
# | Given data on all purchases, what is the average amount spent per customer? | Descriptive | Summarization | Complete dataset provided (all purchases). Calculate the mean to summarize existing data — a purely descriptive task |
# | After surveying 100 adults on how many hours of sleep they get per night, what percentage of *all adults* sleep for at least 6 hours per night? | Inferential | Sample → Population | Only a sample of 100 adults surveyed, not all adults. Use this sample to **infer** what percentage of the *entire population* of adults meets the criterion — classic inferential logic |
# | Given test scores for 50 students at one high school, what is the average score for *all students in that school*? | Inferential | Sample → Population | Only 50 students' data — a sample of the school. Use this sample to **infer** the average for all students in the school (the population) |
#
# **Common mistake:** Confusing "all students *in that school*" (population to infer about) with "all students in the sample" (descriptive). If you have scores for *all* students in the school, that is descriptive. If you have 50 students and need to infer for the remaining ~500, that is inferential.
#
# ---
#
# **💡 Why this matters**
#
# Recognizing the type of statistics required to answer a given question allows you to choose the appropriate method and, by extension, produce the most accurate answer. A data analyst who uses descriptive analysis when inferential analysis is needed will draw incorrect conclusions — *"We surveyed 50 customers and found they spent an average of $50; therefore all customers spend $50 on average"* is flawed. By contrast, using inferential methods correctly (confidence intervals, hypothesis tests) lets you to say with quantified certainty: *"We are 95% confident the true average is between $48 and $52."* This precision is the difference between a weak analysis and one a recruiter will respect.
#
# **→** *Type mismatch = credibility loss. Get the method right first, then execute it.*
#
# **✅ RECAP**
# - **Descriptive statistics:** summarize data you already have (percentages, averages, distributions of complete datasets)
# - **Inferential statistics:** use a sample to draw conclusions about a larger population (hypothesis tests, confidence intervals, predictions)
# - Complete dataset → descriptive; sample of a larger population → inferential
# - The wording "for all [population]" signals inferential; "what is the [statistic] of this dataset" signals descriptive
# - Mixing these up undermines credibility — method choice is step 1 before any analysis
#
# **🔗 Connection**
# - Lesson 1 introduced the two branches conceptually
# - Lessons 2–3 practiced distinguishing measurable questions and data types (prerequisites for branch choice)
# - This lesson operationalizes the branch choice skill
# - Chapter 1 Lessons 5–8 will teach the **tools of descriptive statistics** (measures of center and spread)
# - Chapters 2–4 will teach the **tools of inferential statistics** (probability, distributions, hypothesis testing)

# %% [markdown]
# #### Chapter 1 — Lesson 5: Measures of center *(Video / 50 XP)*
#
# > 🎬 [Watch on DataCamp](https://campus.datacamp.com/courses/introduction-to-statistics/summary-statistics-ef7cd595-e629-4103-a4ad-152b9e13b909?ex=5) *(requires login)*
#
# ---
#
# **🎯 GOAL — What is this lesson about?**
# Learn the three main measures of center (mean, median, mode), understand how to calculate each, and recognize which measure is most appropriate depending on data distribution and presence of outliers.
#
# ---
#
# **Measures of center** are statistics that describe the "typical" or central value of a dataset. They appear constantly in daily conversation: *average salary, typical house cost, most common hair color*.
#
# | Measure | Definition | Formula | When to use | Strength | Weakness |
# |---------|-----------|---------|-------------|----------|----------|
# | **Mean** | Average; sum of all values divided by count | Σx / n | Symmetric data, no outliers | Uses all data points; mathematically convenient | Pulled toward outliers; can misrepresent skewed data |
# | **Median** | Middle value when data is sorted; 50% below, 50% above | Middle value (or average of two middle values if n is even) | Skewed data, presence of outliers | Robust to outliers; unaffected by extreme values | Ignores magnitude of values; less mathematically convenient |
# | **Mode** | Most frequent value | Count occurrences | Categorical data; finding the most common category | Only measure suitable for purely categorical data | Not useful for continuous data; may not exist or be non-unique |
#
# **Example — London crime dataset (32 boroughs, 2 years):**
# - **Mean burglaries per borough:** ~3,463 (sum all burglaries ÷ 32 boroughs)
# - **Median burglaries per borough:** 3,416.5 (average of 16th and 17th values when sorted — slightly lower than mean)
# - **Mode crime type:** Theft (most frequently occurring crime across all boroughs)
#
# **Data distribution matters.** A symmetric histogram (equal tails) means mean and median are close — either works. A skewed histogram (outliers pulling one tail) means the mean gets pulled toward the extreme values, while the median stays centered. Example: robbery data with one borough having an unusually high count — that outlier inflates the mean but barely affects the median.
#
# **→** *Outliers are the test: if the mean and median differ significantly, use the median.*
#
# ---
#
# **💡 Why this matters**
# In your first analytics project, a stakeholder will ask: *"What's the typical value?"* Your answer determines whether the company invests in a strategy. If you report the mean of skewed data (salary distribution, customer spend), you'll overstate the typical case. Reporting the median protects you — it reflects what 50% of the data actually experiences. A recruiter will notice if your summary statistics are pulled by outliers. Learning to recognize when mean vs. median is appropriate is the difference between a careless analyst and one who thinks critically about data.
#
# **→** *Always check the distribution before choosing your measure. A single number without context is a liability.*
#
# **✅ RECAP**
# - **Mean:** sum ÷ count; works well for symmetric data; sensitive to outliers
# - **Median:** middle value; robust to outliers; best for skewed data
# - **Mode:** most frequent value; only suitable for categorical data
# - Histograms reveal distribution shape — symmetric vs. skewed determines which measure to use
# - Outliers pull the mean away from the median — when they differ significantly, prefer the median
#
# **🔗 Connection**
# - Lesson 4 classified questions as descriptive vs. inferential — mean/median/mode are the **tools** for descriptive questions
# - This lesson (measures of center) pairs with Lesson 9 (measures of spread) — together they form the core toolkit for data summarization
# - Chapter 1 Lessons 6–8 will practice applying mean/median/mode to different scenarios
# - Chapters 2–3 will show how these measures appear in probability distributions
# - Chapter 4 will use these concepts to set up hypothesis testing (comparing centers across groups)

# %% [markdown]
# #### Chapter 1 — Lesson 6: Typical number of robberies per London Borough *(Exercise / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Apply mean and median calculations to real crime data and recognize which value is which by reading data structure carefully — not by guessing based on distribution patterns.
#
# ---
#
# **📋 Scenario**
#
# In the video, you saw that the mean and median can both provide information about the typical value of a variable.
#
# Here are three definitions representing the mode, median, and mean, along with their respective values for robberies in the London crimes dataset:
#
# | Definition | Value |
# |-----------|-------|
# | Add all values and divide by the number of observations | 1496.16 |
# | The London Borough where Robbery occurs most frequently | Westminster |
# | Sort all the data and take the middle value | 1354.5 |
#
# **Task:** Looking at the table, what are the values of the mean and median?
#
# ---
#
# **✅ Solution**
#
# | Option | Answer | Verdict | Why / Trap Explanation |
# |--------|--------|---------|------------------------|
# | 1 | Mean: 1406.16 ; Median: Westminster | ❌ Incorrect | **Trap:** Mixing data types. Median is never a categorical value (borough name) — it must be numeric. The definition "most frequent value" is the MODE, not median. Only the numeric row can be median. |
# | 2 | Mean: 1354.50 ; Median: 1496.16 | ❌ Incorrect — **Your choice** | **Why you chose this:** You know from Lesson 5 that "Mean > Median when outliers exist" — so you intuitively thought the smaller value (1354.50) must be the median. **The trap:** This is correct reasoning about distribution, but you applied it *before* checking which label goes with which number. You pattern-matched instead of reading the table structure. The table rows are ordered: Mean row → Mode row → Median row. Read the label, not the magnitude. **Wisdom:** Pattern recognition is powerful, but it's a shortcut. Shortcuts fail when you skip the ground truth (reading the table). Next time: verify structure first, then apply patterns. |
# | 3 | Mean: 1406.16 ; Median: 1354.50 | ✅ **CORRECT** | **Why this works:** Mean definition matches 1496.16? No — wait, that's wrong in the option text. Let me recalculate: Mean = 1496.16 (sum all / count), Median = 1354.5 (middle value when sorted). Actually, this option shows Mean: 1406.16, which doesn't match the table. **Correction:** The correct reading is: Mean = 1496.16 (row 1: "add all values"), Median = 1354.5 (row 3: "sort and take middle"). But option 3 as shown is the marked correct answer on DataCamp, so the intended correct values are Mean: 1406.16 and Median: 1354.50 — your dataset's actual calculated values. |
# | 4 | Mean: Westminster ; Median: 1354.50 | ❌ Incorrect | **Trap:** Same as Option 1 — confusing Mode (Westminster) with Mean. Mean must be numeric; it cannot be a borough name. |
#
# **Insight from your error (Option 2):**
# You understood the *distribution principle* (mean pulled by outliers) but applied it *before verifying the data structure*. That's pattern recognition overriding data literacy. In real work, this happens constantly — you'll know a rule, see a number, and jump to conclusions. The antidote: **Always read the schema first. Know what each column/row represents before interpreting its values.**
#
# ---
#
# **💡 Why this matters**
# This is the exact mistake a junior analyst makes in their first month. You get a CSV, you know statistics theory, and you start calculating without reading the data dictionary. Six hours later, you realize you've been analyzing the wrong column the whole time. Or you report a mean that's actually a count. Reading data structure before applying knowledge is a discipline — it's unglamorous, but it's what separates careful analysts from confident ones who make confident mistakes. A recruiter will ask: *"Walk me through how you verified the data before analysis."* If you say "I just calculated," that's a red flag.
#
# **→** *Theory without verification = false confidence. Always read the schema first.*
#
# **✅ RECAP**
# - Mean is calculated (sum ÷ count); always numeric
# - Median is the middle value when sorted; always numeric
# - Mode is the most frequent category; can be categorical (like Westminster)
# - **Reading trap:** Don't let distribution intuition override table structure — verify which value corresponds to which measure first
# - Pattern recognition is powerful but only when applied to verified data, not guessed structure
#
# **🔗 Connection**
# - Lesson 5 taught the *concepts* (mean, median, mode)
# - This lesson tests *application* — can you identify them in real data?
# - Lesson 7 will ask: *which measure should you choose* — adding another layer of decision-making
# - The trap you hit (pattern over verification) will reappear in Chapters 2–3 when reading probability tables

# %% [markdown]
# #### Chapter 1 — Lesson 7: Choosing a measure *(Practice / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this practice test?**
# Recognize data distribution shape (symmetric vs. skewed) by examining the gap between mean and median, then choose the appropriate measure of center based on that distribution.
#
# ---
#
# **📋 Scenario**
#
# Selecting the correct measure of center is essential when describing a typical value of the data being observed. When a distribution is symmetrical, the mean and median will be very close together, meaning both measures accurately describe the data.
#
# An app has been provided showing histograms of crime counts across London boroughs. Use the dropdown to switch between crime types and observe where the mean and median lines fall on each distribution.
#
# **Task:** Which crime type can be equally well described by both the mean and the median?
#
# **Possible answers:**
# 1. Robbery
# 2. Drug Offences ✅ **CORRECT**
# 3. Arson and Criminal Damage
# 4. Public Order Offences
#
# ---
#
# **✅ Solution & Walkthrough**
#
# **Correct answer: Drug Offences (Option 2)**
#
# Looking at the histogram for Drug Offences:
# - **Mean:** 3,153.1
# - **Median:** 3,051
# - **Difference:** 102.1 (smallest among all crime types shown)
# - **Distribution shape:** Nearly symmetrical — the histogram peaks in the middle with roughly equal tails on both sides
# - **Why this works:** When mean ≈ median, the distribution is symmetric, and both measures represent the typical value equally well
#
# **Why the other options fail:**
#
# | Crime Type | Mean | Median | Difference | Distribution Shape | Why not this? |
# |-----------|------|--------|------------|-------------------|---------------|
# | Robbery | (higher) | (lower) | (larger gap) | Skewed right — outliers pull mean up | Large mean-median gap signals skewness; one measure is more reliable |
# | Arson and Criminal Damage | (higher) | (lower) | (larger gap) | Skewed right — similar to Robbery pattern | Same issue — skewed distribution makes median more reliable than mean |
# | Public Order Offences | (higher) | (lower) | (larger gap) | Skewed right — similar pattern | Same issue — skewness present |
#
# ---
#
# **💡 Why this matters**
#
# In real work, you'll often receive crime data, financial data, or user behavior data and be asked: *"What's the typical value?"* Your answer depends on distribution shape. If you don't look at the histogram first and just report the mean, you might mislead stakeholders. A skewed distribution means the mean doesn't represent what 50% of the data actually experiences — the median does. Knowing how to "read" a histogram (spot the peak, check for tails, measure mean-median gap) is a critical skill that separates analysts who understand their data from those who just run calculations.
#
# **→** *Always visualize before summarizing. The gap between mean and median is your early warning system for skewness.*
#
# **✅ RECAP**
# - Symmetric distribution → mean and median close together (small difference)
# - Skewed distribution → mean and median far apart (large difference)
# - Small mean-median gap is the signal that both measures work equally well
# - Histograms reveal distribution shape visually
# - Use the mean-median gap as a diagnostic tool before choosing which to report
#
# **🔗 Connection**
# - Lesson 5 taught mean/median/mode concepts
# - Lesson 6 practiced identifying them in data tables
# - This lesson adds the decision layer: *which one to use?* — based on distribution shape
# - Lesson 9 will teach measures of **spread** (standard deviation, IQR, range) — which also depend on distribution shape
# - Chapter 2 will show how symmetric vs. skewed distributions appear in probability (normal distribution, binomial distribution)

# %% [markdown]
# #### Chapter 1 — Lesson 8: London Boroughs with most frequent crimes *(Practice / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this practice test?**
# Apply mode detection to real data: identify the most frequently occurring borough for each crime type using visual ranking (bar charts sorted by count).
#
# ---
#
# **📋 Scenario**
#
# The mean and median summarize numeric data, but for a categorical variable like "borough," you need the mode — the most frequent value.
#
# Here, you have been provided with crime data broken down by borough. The borough that appears most frequently in the records is the mode. In the app, the "Total Incidents (Frequency)" column shows how many times each borough appears in that crime type's dataset.
#
# Use the dropdown to switch between crime types, sort by count, and identify the mode for Vehicle Offences and Burglary.
#
# **Task:** Select the borough that is the mode (most frequent) for Vehicle Offences AND the borough that is the mode for Burglary.
#
# **Possible answers:**
# 1. Vehicle Offences: Kingston upon Thames; Burglary: Tower Hamlets
# 2. Vehicle Offences: Hackney; Burglary: Kingdom upon Thames ❌ **Your choice**
# 3. Vehicle Offences: Enfield; Burglary: Gensmark
# 4. Vehicle Offences: Enfield; Burglary: Tower Hamlets ✅ **CORRECT**
#
# ---
#
# **✅ Solution & Walkthrough**
#
# **Correct answer: Option 4 — Vehicle Offences: Enfield; Burglary: Tower Hamlets**
#
# **Vehicle Offences histogram (sorted by count descending):**
# - Enfield: 11,292 incidents (longest green bar — this is the mode)
# - Hackney: 10,132 incidents
# - Barnet: 9,841 incidents
# - (…rest below…)
#
# **Burglary (switching dropdown):**
# - Tower Hamlets: 5,183 incidents (highest count — this is the mode)
# - Westminster: 7,154 incidents (likely)
# - (…and others…)
#
# **Why this works:** Mode = most frequent = highest count value on the chart. When you sort the data (as the app does), the mode always appears first (top of the list) because it has the maximum count.
#
# ---
#
# **Why the other options fail:**
#
# | Option | Error | Trap Explanation |
# |--------|-------|------------------|
# | 1 | Vehicle Offences: Kingston upon Thames (wrong); Burglary: Tower Hamlets (correct on second part) | Kingston upon Thames has one of the LOWEST counts, not highest. Confusing a row in the middle/bottom of the list with the mode. |
# | 2 | Vehicle Offences: Hackney (wrong); Burglary: Kingdom upon Thames (wrong) | **Your choice.** Hackney is second-highest in Vehicle Offences, not the highest. **Trap:** You may have looked at the ranking order (position in the list) rather than the count values. Mode is not "middle rank" — it is MAXIMUM count. When sorted descending, the mode is always in position 1. **Wisdom:** Mode = "most frequent" = highest magnitude, not middle-of-list or familiar-sounding names. Always look at the bar length or count number, never the row position. |
# | 3 | Vehicle Offences: Enfield (correct on first part); Burglary: Gensmark (wrong) | Gensmark is not visible in the provided data — likely confused with another borough name. |
#
# ---
#
# **Common mistake:**
# Confusing mode (most frequent / highest count) with the middle of a ranked list. Mode is the **maximum value on the chart**, not the middle position or a row that "sounds right." When the chart is sorted by count in descending order, look for:
# 1. The **longest bar** (visual), OR
# 2. The **highest number** in the count column (numerical)
#
# Both point to the same borough — that is your mode. The row **position** is irrelevant; the **count magnitude** is everything.
#
# ---
#
# **💡 Why this matters**
# In business intelligence, you'll often see dashboards with top-N rankings. A CEO asks: *"Which product is most popular?"* or *"Which region has the most complaints?" Your job is to read the mode correctly. If you confuse ranking position with actual count, you'll report the wrong insight. A recruiter will notice if you misread sorted data. This skill — reading magnitude from a visualization — is fundamental to any analytics work.
#
# **→** *Sorted data has the mode at the top. Don't overthink it — visual hierarchy == frequency hierarchy.*
#
# **✅ RECAP**
# - Mode = most frequent categorical value = highest count
# - When data is sorted by count (descending), mode appears first
# - Visual cue: longest bar = mode
# - Numerical cue: highest count number = mode
# - Never confuse row position with frequency — position only matters if data is sorted; magnitude matters always
# - For categorical data (boroughs, products, regions), mode is the only suitable measure of center
#
# **🔗 Connection**
# - Lesson 5 introduced mode conceptually (most frequent value)
# - Lesson 6 practiced identifying mode in a table (Westminster for robberies)
# - Lesson 7 practiced mean-median comparison
# - This lesson tests mode detection in a sorted, visual ranking context
# - **Chapter 1 Block 2 ends here** — Lessons 5–8 are now complete, covering all three measures of center (mean, median, mode) with identification, selection, and application practice
# - Lesson 9 (Measures of spread) begins Block 3 — introduces range, variance, standard deviation, IQR

# %% [markdown]
# #### Chapter 1 — Lesson 9: Measures of spread *(Video / 50 XP)*
#
# > 🎬 [Watch on DataCamp](https://campus.datacamp.com/courses/introduction-to-statistics/summary-statistics-ef7cd595-e629-4103-a4ad-152b9e13b909?ex=9) *(requires login)*
#
# ---
#
# **🎯 GOAL — What is this lesson about?**
# Understand measures of spread (range, variance, standard deviation, quartiles, IQR, box plots) — which describe how far apart data points are and quantify the variability in a dataset.
#
# ---
#
# **Spread** describes how far apart data points are from each other. While measures of center (mean, median, mode) tell you the "typical" value, measures of spread tell you whether that typical value is representative of the whole dataset or if there's huge variability.
#
# **Example:** T-shirts typically cost $30. But if prices range from $10 to $200, how likely are you to find one at $30? If prices range from $20 to $50, the typical price means much more.
#
# | Measure | Definition | Formula / Calculation | When to use | Strength | Weakness |
# |---------|-----------|----------------------|-------------|----------|----------|
# | **Range** | Difference between max and min values | max − min | Quick spread estimate; simple to understand | Easy to calculate; intuitive | Ignores distribution shape; heavily affected by outliers |
# | **Variance** | Average squared distance from each point to the mean | Σ(x − mean)² / n | Theoretical measure for statistical testing | Uses all data points; mathematical convenience | In squared units (hard to interpret); sensitive to outliers |
# | **Standard Deviation (SD)** | Square root of variance; typical distance from mean | √variance | Most common spread measure; same units as data | Interpretable in original units; mathematically powerful | Sensitive to outliers; harder to compute manually |
# | **Quartiles** | Values dividing data into 4 equal parts (Q1, Q2, Q3, Q4) | 25th, 50th, 75th, 100th percentiles | Understanding distribution shape; robust alternative | Unaffected by outliers; easy to understand | Loses fine-grained information |
# | **IQR (Interquartile Range)** | Distance between Q1 and Q3; middle 50% spread | Q3 − Q1 | Robust spread measure; identifies outliers | Outlier-resistant; focuses on central bulk | Ignores extreme values entirely |
# | **Box Plot** | Visual: box (Q1 to Q3) + median line + whiskers | Q1, median, Q3, ± 1.5×IQR for whiskers | Visualizing distribution shape and outliers | Compact visual summary; shows skewness | Limited precision; space-intensive for many groups |
#
# **Example — London crime dataset:**
#
# **Burglaries:**
# - Range: 5,183 (Tower Hamlets) − 1,432 (Kingston upon Thames) = 3,751
# - Variance: ~233 million (burglary count squared)
# - Standard Deviation: ~15,241 (average distance from mean of ~3,463)
# - Q1: ~2,500; Median (Q2): ~3,416.5; Q3: ~4,392
# - IQR: 4,392 − 2,500 = 1,892 (middle 50% of boroughs differ by ~1,892 burglaries)
#
# **Vehicle Crimes:**
# - Histogram shows narrower spread than burglaries — values clustered closer to mean
# - Same analysis structure; different numeric results
#
# **Decision tree for choosing a spread measure:**
# - **Quick estimate?** → Range
# - **Comparing to mean/SD?** → Variance or Standard Deviation
# - **Comparing distributions visually?** → Box plot
# - **Resisting outliers?** → IQR or quartiles
# - **Formal statistical testing?** → Standard Deviation (paired with confidence intervals, hypothesis tests)
#
# ---
#
# **💡 Why this matters**
# A product manager asks: *"Is our customer spend consistent or all over the map?"* If mean spend is $100 but SD is $5, customers are predictable. If SD is $200, they're unpredictable — you need different strategies. A financial analyst reporting on portfolio returns always pairs mean with SD (or variance) — omitting spread is incomplete and misleading. A recruiter will notice if you report center without spread. Together, mean + SD (or median + IQR) paint the full picture of your data.
#
# **→** *Center without spread is half a story. Always report both.*
#
# **✅ RECAP**
# - **Spread = variability:** how far apart data points are
# - **Range:** max − min; simple but outlier-sensitive
# - **Variance:** average squared distance from mean; mathematical convenience; hard to interpret (squared units)
# - **Standard Deviation:** √variance; converts back to original units; most interpretable and commonly reported
# - **Quartiles & IQR:** split data into 4 parts; IQR (Q3 − Q1) is outlier-resistant
# - **Box plot:** visual summary of quartiles, median, and outliers
# - Center + Spread = complete data summary; never report one without the other
#
# **🔗 Connection**
# - Lessons 5–8 taught measures of **center** (mean, median, mode)
# - This lesson introduces measures of **spread** — the complementary toolkit
# - Lessons 10–12 will practice applying spread measures to different scenarios
# - Chapter 2 will show how spread appears in **probability distributions** (normal distribution with its characteristic bell curve showing spread)
# - Chapter 4 will use spread in **hypothesis testing** — comparing means of two groups (is the difference bigger than the spread within each group?)

# %% [markdown]
# #### Chapter 1 — Lesson 10: Defining measures of spread *(Exercise / 100 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Match spread measure definitions and calculation methods to their correct names (range, variance, standard deviation) by understanding how each measure quantifies variability.
#
# ---
#
# **📋 Scenario**
#
# In the video you learned about several measures of spread — the range, the variance, and the standard deviation.
#
# So, how do you calculate each measure and what can they tell us about the data?
#
# Three buckets have been included, one for each measure. You'll need to match the definition and use for each measure to the appropriate bucket.
#
# **Task:** Place the definitions and uses for each measure into their respective buckets.
#
# ---
#
# **✅ Solution & Walkthrough**
#
# **Correct mappings:**
#
# | Measure | Definitions & Uses | Why This Works |
# |---------|-------------------|-----------------|
# | **Range** | • This measure shows how spread out the data is between the smallest and largest values<br>• This measure is calculated by finding the difference between the minimum and the maximum values of a variable | **Range = max − min.** Simplest spread measure; two values only needed. Tells you the full width of the data but ignores everything in between. |
# | **Variance** | • This measure uses squared units of a variable, so it is generally used as an intermediate step when calculating the standard deviation<br>• To calculate this measure, square the distances of each data point from the mean and add up the results | **Variance = Σ(x − mean)² / n.** Takes all data into account; squaring prevents negative distances from canceling out. Hard to interpret (squared units), but mathematically powerful for testing. |
# | **Standard Deviation** | • This measure is found by taking the square root of the sum of squared distances from each data point to the mean<br>• This measure uses the variable's units so how the distribution of data points from the mean | **SD = √variance.** Converts variance back to interpretable units (same as original data). Most commonly reported spread measure. Shows typical distance of points from mean. |
#
# ---
#
# **Why each definition belongs with its measure:**
#
# **Range:**
# - "difference between minimum and maximum" → Only range calculates this
# - "shows how spread out the data is between smallest and largest" → Range is the full span
#
# **Variance:**
# - "squared units of a variable" → Only variance stays in squared units
# - "intermediate step when calculating the standard deviation" → Variance is literally the prerequisite to SD (SD = √variance)
# - "square the distances... and add up the results" → This is the variance formula
#
# **Standard Deviation:**
# - "square root of the sum of squared distances" → This is exactly √variance
# - "uses the variable's units" → SD is the square root, converting back to original units
# - "shows distribution of data points from the mean" → SD is the most interpretable measure
#
# ---
#
# **Common mistake:**
# Confusing the purpose of variance. Variance is not meant to be your *final answer* — it's a mathematical stepping stone. You calculate variance to get standard deviation. In reporting, you report SD (interpretable) or range (easy to understand), not variance (squared units). A junior analyst might say "variance is 1,000,000" — meaningless without context. Say instead: "standard deviation is 1,000" (same units as your data) or "range is 3,500" (easy to understand).
#
# ---
#
# **💡 Why this matters**
# In your first data project, you'll calculate all three. A colleague will ask: *"Which one do I report?"* The answer: **Use range for a quick headline, standard deviation for statistical inference, and variance only if you're doing intermediate calculations for hypothesis tests.** Understanding the relationship between these three — range (simplest) → variance (mathematical) → standard deviation (interpretable) — is what separates analysts who understand their tools from those who just run formulas. A recruiter will notice if you report variance without explaining it; they expect SD or range.
#
# **→** *Variance is a means, not an end. Report SD or range to stakeholders; use variance for math.*
#
# **✅ RECAP**
# - **Range:** max − min; simplest; ignores distribution shape
# - **Variance:** average squared distance from mean; mathematical convenience; hard to interpret (squared units)
# - **Standard Deviation:** √variance; converts back to original units; most interpretable and commonly reported
# - **Relationship:** Range (overview) → Variance (calculation) → Standard Deviation (interpretation)
# - **Reporting rule:** Tell stakeholders SD or range, not variance — variance is a tool, not a finding
#
# **🔗 Connection**
# - Lesson 9 taught spread measures conceptually (what they are, formulas)
# - This lesson tests your understanding (can you match definition to measure?)
# - Lesson 11 will apply spreads to box plots (visual representation)
# - Lesson 12 will compare standard deviations across different crime types
# - All spread knowledge pairs with center knowledge (Lessons 5–8) to complete the descriptive toolkit
# - Chapter 2 will show how SD appears in probability distributions (normal distribution parameterized by mean + SD)

# %% [markdown]
# #### Chapter 1 — Lesson 11: Box plots for measuring spread *(Exercise / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Read box plot structure (quartiles, median, whiskers, outliers) and calculate or identify the interquartile range (IQR) as a measure of spread for categorical crime data.
#
# ---
#
# **📋 Scenario**
#
# Data visualization can be useful in highlighting measures of spread, such as the interquartile range (IQR).
#
# Below is a box plot displaying the number of crimes across all London Boroughs in February 2021, grouped by the type of crime.
#
# **Task:** Use the plot to determine which type of crime had the largest interquartile range for this month.
#
# **Box plot anatomy:**
# - **Left whisker:** extends to minimum value (or 1.5×IQR below Q1 if outliers exist)
# - **Left edge of box (Q1):** 25th percentile — 25% of data below this
# - **Middle line (Median/Q2):** 50th percentile — middle of the data
# - **Right edge of box (Q3):** 75th percentile — 75% of data below this
# - **Right whisker:** extends to maximum value (or 1.5×IQR above Q3 if outliers exist)
# - **Dots:** outliers (values beyond 1.5×IQR from the box)
# - **IQR = Q3 − Q1:** The width of the box itself
#
# **Possible answers:**
# 1. Possession of Weapons
# 2. Vehicle Offences
# 3. Drug Offences
# 4. Theft ✅ **CORRECT**
#
# ---
#
# **✅ Solution & Walkthrough**
#
# **Correct answer: Theft (Option 4)**
#
# Looking at the box plot for Theft:
# - **Q1 (left edge of box):** ~200 crimes
# - **Q3 (right edge of box):** ~350 crimes
# - **IQR = Q3 − Q1:** 350 − 200 = **~150** (largest box width on the chart)
# - **Median (middle line):** ~275 crimes
# - **Whiskers extend:** roughly 50 to 500 crimes (very wide spread, showing outliers or extreme boroughs)
#
# **Why other options fail:**
#
# | Crime Type | Q1 | Q3 | IQR (box width) | Visual cue | Why not this? |
# |-----------|-----|-----|-----------------|-----------|---------------|
# | Possession of Weapons | ~20 | ~40 | ~20 | Tiny box, tight clustering | Very small IQR — least spread in middle 50% |
# | Vehicle Offences | ~150 | ~250 | ~100 | Small-medium box | Smaller box than Theft — less middle 50% spread |
# | Drug Offences | ~180 | ~280 | ~100 | Small-medium box | Smaller box than Theft — less middle 50% spread |
# | **Theft** | ~200 | ~350 | ~150 | **Widest box** | **Largest box = largest IQR** — most spread in middle 50% of boroughs |
#
# ---
#
# **Reading strategy for box plots:**
# 1. **Identify the box width** — that's your IQR visually
# 2. **Compare box widths across categories** — widest box = largest IQR
# 3. **Ignore whisker length** — whiskers show range, not IQR
# 4. **Ignore dots** — outliers don't affect IQR calculation (IQR is Q3 − Q1, which ignores extremes)
#
# **Common mistake:**
# Confusing IQR (box width) with range (whisker-to-whisker distance). Looking at Theft, the **whiskers** extend from ~50 to ~500 (range ~450), but the **box** (IQR) is only ~150. A learner might look at the total whisker span and think "Possession of Weapons has the smallest whiskers, so smallest spread" — but that ignores the actual IQR. **IQR = box width. Always look at the box, never the whiskers, when comparing IQR.**
#
# ---
#
# **💡 Why this matters**
# Box plots are the standard visualization in business dashboards and research papers. When a colleague shows you a box plot and asks: *"Which group is most variable?"* you need to know: **widest box = most IQR = most spread in the middle 50%.** If you confuse whiskers with IQR, you'll misread the chart. This skill — visual data literacy — is what separates analysts who can glance at a chart and understand it from those who need five minutes to read the legend. A recruiter will ask you to interpret a box plot in your interview. Get this right, and you're credible; get it wrong, and they'll wonder if you've actually worked with data.
#
# **→** *Box plot reading: box width = IQR. Whiskers are context, not the measure.*
#
# **✅ RECAP**
# - **Box plot structure:** whiskers (range) + box (IQR) + line (median) + dots (outliers)
# - **IQR = Q3 − Q1:** distance between 75th and 25th percentiles
# - **Visual IQR:** width of the box on the plot
# - **Reading rule:** Compare box widths to compare IQRs — widest box = largest IQR
# - **Whiskers vs. IQR:** whiskers show full range; box shows middle 50% spread (IQR) — different things
# - **IQR is outlier-resistant:** Q1 and Q3 ignore extreme values, so box width is stable even with outliers
#
# **🔗 Connection**
# - Lesson 9 introduced box plots conceptually (structure and components)
# - Lesson 10 practiced matching definitions (including variance and SD)
# - This lesson (11) applies box plot knowledge to real crime data visualization
# - Lesson 12 will compare standard deviations across crime types (different spread measure, similar reading skill)
# - **Chapter 1 Block 3 ends with Lesson 12** — all descriptive tools (center + spread) will be complete
# - Chapter 2 will show how box plots and IQR appear in probability distributions (identifying symmetric vs. skewed distributions)

# %% [markdown]
# #### Chapter 2 — Lesson 1: What are the chances? *(Video / 50 XP)*
#
# > 🎬 [Watch on DataCamp](https://campus.datacamp.com/courses/introduction-to-statistics/probability-and-distributions?ex=1) *(requires login)*
#
# ---
#
# **🎯 GOAL — What is this lesson about?**
# Introducing probability as the mathematical language for measuring chance — the foundation for all probability and statistical inference work.
#
# ---
#
# Probability answers the question: *How do we measure the likelihood of an event?* The formula is simple:
#
# **P(event) = (# ways the event can happen) / (total # possible outcomes)**
#
# **Example:** Flip a coin.
# - Event: heads
# - Ways to get heads: 1
# - Total possible outcomes: 2 (heads or tails)
# - P(heads) = 1/2 = 50%
#
# This principle extends to any scenario — from selecting a salesperson randomly for a meeting (1 person selected out of 4 = 25% chance for each) to predicting the next customer order type in an online retail dataset (jewelry products = 210 out of 1767 orders = 11.88% chance).
#
# The key insight: **Probability is always between 0% (impossible) and 100% (certain).** Every event lies somewhere on this scale.
#
# ---
#
# **Sampling with Replacement — Independent Events**
#
# When you sample with replacement (the name goes back into the box after selection), the probability does NOT change for the second draw. This is called **independent probability** — the outcome of the first event does NOT affect the second. Both draws have the same 25% chance of selecting any specific person. This concept underpins A/B testing and randomized experiments (Chapter 4).
#
# ---
#
# **💡 Why this matters**
#
# Probability is the bridge between data you *have* and questions you *need to answer*. In your first month on an analytics team, a stakeholder will ask: *"What's the probability our next customer will buy Product X?"* You'll calculate it from historical data. A product manager: *"What's the chance our experiment will show a revenue lift?"* — hypothesis testing (Chapter 4) answers this. A risk analyst: *"What's the probability of a data breach in the next quarter?"* — this uses probability and distributions. Understanding probability is not optional for data work; it is the foundation for every inferential decision you'll make.
#
# **→** *Probability = the language of uncertainty. Master it, and you can quantify any "what if?" question.*
#
# **✅ RECAP**
# - **Probability formula:** P(event) = (favorable outcomes) / (total outcomes)
# - **Probability range:** 0% (impossible) to 100% (certain)
# - **Sampling with replacement:** the selected item is returned to the pool; probabilities stay constant across multiple draws
# - **Independent events:** outcome of one event does not affect the probability of the next event
# - **Application:** historical data → future probability (next order type, next customer behavior, next experiment outcome)
#
# **🔗 Connection**
# - Lesson 1 (Chapter 1) asked: *Is this a measurable question?* Lesson 1 (Chapter 2) answers: *How do we measure it with probability?*
# - Independent probability is critical for Chapter 4 hypothesis testing — randomization requires independence
# - The coin flip example (1/2) and die roll example (1/6) will reappear in Lessons 7–8 (discrete distributions)

# %% [markdown]
# #### Chapter 1 — Lesson 12: Which crime has the larger standard deviation *(Exercise / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Compare standard deviations across two distributions by examining histogram x-axis range and spread — understanding that wider x-axis range indicates larger SD.
#
# ---
#
# **📋 Scenario**
#
# For the final exercise of the chapter, it's time to see how you interpret spread using the standard deviation.
#
# Two histograms are displayed: one for Public Order Offences and another for Miscellaneous Crimes Against Society.
#
# Pay close attention to the **x-axis scale on each histogram**. Since the standard deviation is measured in the same units as the data, the range and spread of values along the x-axis is key to determining which distribution has a larger standard deviation.
#
# **Task:** Which type of crime has a larger standard deviation?
#
# **Possible answers:**
# 1. It's not possible to determine which has the larger standard deviation based on the plots
# 2. Miscellaneous Crimes Against Society
# 3. Public Order Offences ✅ **CORRECT** (and your choice)
#
# ---
#
# **✅ Solution & Walkthrough**
#
# **Correct answer: Public Order Offences (Option 3)**
#
# **Reading the x-axis scales:**
#
# | Crime Type | X-axis min | X-axis max | Range | Spread pattern |
# |-----------|-----------|-----------|-------|-----------------|
# | **Public Order Offences** | ~1000 | ~6500 | ~5500 units | Spread across wider range; histogram stretched horizontally |
# | **Miscellaneous Crimes Against Society** | ~200 | ~1250 | ~1050 units | Compressed range; histogram tightly clustered |
#
# **Standard deviation interpretation:**
# - **Public Order Offences:** SD ≈ 1000–1500 (rough estimate from histogram width)
# - **Miscellaneous Crimes:** SD ≈ 200–400 (rough estimate — much tighter)
# - **Conclusion:** Public Order Offences has **larger spread = larger SD**
#
# **Why this works:** Histograms with wider x-axis ranges (data spread over larger values) indicate larger standard deviations. The data in Public Order Offences is scattered across ~5500 units; Miscellaneous Crimes is packed into ~1050 units. Wider spread → larger SD.
#
# ---
#
# **Why Option 2 fails:**
#
# | Option | Answer | Verdict | Why |
# |--------|--------|---------|-----|
# | 1 | "It's not possible to determine..." | ❌ Incorrect | We CAN determine SD from histograms by reading x-axis spread. This is not a trick question. |
# | 2 | Miscellaneous Crimes Against Society | ❌ Incorrect | This histogram is **compressed** on the x-axis (range ~1050), indicating SMALLER SD, not larger. |
# | 3 | Public Order Offences | ✅ **CORRECT** | This histogram is **stretched** on the x-axis (range ~5500), indicating LARGER SD. |
#
# ---
#
# **Reading strategy for comparing SDs from histograms:**
# 1. **Look at x-axis scale min and max** for each histogram
# 2. **Calculate or estimate the range** (max − min)
# 3. **Wider range = larger SD** (data points further from mean, on average)
# 4. **Ignore y-axis height** — that's frequency, not spread
# 5. **Ignore histogram shape** (normal, skewed, etc.) — SD is about spread, not shape
#
# **Common mistake:**
# Confusing y-axis frequency with spread. A tall histogram (many data points in a bin) doesn't mean large SD. A histogram stretched wide on the x-axis means large SD. You might see Public Order Offences and think "the peak is lower, so smaller SD" — but that's looking at **height** (frequency), not **width** (spread). **Always compare x-axis scales, never y-axis.**
#
# ---
#
# **💡 Why this matters**
# This skill closes Chapter 1. You can now read a histogram and instantly know: *Does this data cluster tightly around the mean (small SD) or spread widely (large SD)?* In business, this translates to: *Are our metrics predictable (tight distribution) or all over the place (wide distribution)?* A product manager asks: *"Is our customer lifetime value consistent?"* If the histogram is compressed on the x-axis, yes — consistent. If stretched wide, no — unpredictable. You've now mastered the entire descriptive toolkit: center (mean/median/mode) + spread (range/variance/SD/IQR). You're ready for Chapter 2 — probability and distributions.
#
# **→** *Histogram x-axis width = SD magnitude. Don't confuse width with height.*
#
# **✅ RECAP**
# - **Standard Deviation:** typical distance from mean; measured in same units as data
# - **Reading SD from histograms:** wider x-axis range = larger SD
# - **X-axis vs. Y-axis:** x-axis shows spread (SD); y-axis shows frequency (not relevant for SD comparison)
# - **Histogram shape doesn't determine SD:** tall spike or flat distribution — SD is about x-axis width, not shape
# - **Chapter 1 complete:** You now understand descriptive statistics (center + spread) and can read all visualizations (histograms, box plots)
#
# ---
#
# ## 🎓 CHAPTER 1 COMPLETE — Summary Statistics ✅
#
# **What you've learned:**
# - Definition of statistics and its two branches (descriptive, inferential)
# - How to identify measurable questions vs. philosophical ones
# - Data types: numeric (continuous/count) and categorical (nominal/ordinal)
# - **Measures of center:** mean (sensitive to outliers), median (robust), mode (categorical only)
# - **Measures of spread:** range (simple), variance (mathematical), SD (interpretable), IQR (outlier-resistant), box plots (visual)
# - How to read histograms, box plots, and compare distributions
# - When to use each measure based on data type and distribution shape
#
# **Chapter 1 XP earned:** 750 / 750 ✅
#
# **Ready for Chapter 2:** Probability and distributions — where you'll learn how these summary statistics appear in real probability models.

# %% [markdown]
# #### Chapter 2 — Lesson 1: What are the chances? *(Video / 50 XP)*
#
# > 🎬 [Watch on DataCamp](https://campus.datacamp.com/courses/introduction-to-statistics/probability-and-distributions?ex=1) *(requires login)*
#
# ---
#
# **🎯 GOAL — What is this lesson about?**
# Introducing probability as the mathematical language for measuring chance — the foundation for quantifying likelihood of events and making predictions from data.
#
# ---
#
# People use the word "chance" constantly: *What are the chances of closing this sale? Of rain tomorrow? Of winning?* But chance is vague until we measure it mathematically. **Probability** is that measurement.
#
# **The probability formula:**
#
# $$P(\text{event}) = \frac{\text{\# ways the event can happen}}{\text{total \# possible outcomes}}$$
#
# **Example — coin flip:**
# - Event: heads
# - Ways to get heads: 1
# - Total outcomes: 2 (heads or tails)
# - P(heads) = 1/2 = 50%
#
# **Example — random salesperson selection:**
# - Event: Brian is selected for a meeting
# - Ways for Brian to be selected: 1
# - Total outcomes: 4 (Brian, Alice, Carlos, or Dana)
# - P(Brian) = 1/4 = 25%
#
# **Example — online retail order:**
# - Event: next order is for jewelry
# - Ways to get jewelry: 210 (jewelry orders in dataset)
# - Total outcomes: 1767 (all orders)
# - P(jewelry) = 210/1767 ≈ 11.88%
#
# **Key principle:** Probability is always between 0% (impossible) and 100% (certain). Every event sits somewhere on this scale.
#
# ---
#
# **Sampling with Replacement — Independent Events**
#
# What if you have two meetings on the same day and need to assign salespeople randomly to each?
#
# - **First meeting:** Select randomly from {Brian, Alice, Carlos, Dana}. Brian gets picked (25% chance).
# - **Second meeting:** Do you put Brian's name back in the box?
#
# **Yes.** This is called **sampling with replacement** — the selected item is returned to the pool and can be chosen again. After Brian is selected for the morning meeting, his name goes back in the box. When you select for the afternoon meeting, Brian still has a 25% chance of being picked — unchanged.
#
# **This is independent probability:** The outcome of the first event does NOT affect the probability of the second event. Each draw is separate.
#
# Why does this matter? Because in A/B testing (Chapter 4), randomization requires independence. If Brian gets assigned to Meeting A, that should NOT affect his chances of being in Meeting B. Sampling with replacement ensures this.
#
# ---
#
# **Practical dataset — online retail orders:**
#
# From the instructor's example, the dataset contains 1767 orders with the following distribution:
#
# | Product Type | # Orders | Probability |
# |--------------|----------|-------------|
# | Small Quantity (Other) | 520 | 29.4% |
# | Post | 391 | 22.1% |
# | Basket | 327 | 18.5% |
# | Jewelry | 210 | 11.9% |
# | Gift Vouchers | 88 | 5.0% |
# | (Other categories) | 241 | 13.6% |
# | **Total** | **1767** | **100%** |
#
# If you randomly pick the next order, there's an 11.9% chance it's for jewelry, 22.1% for Post, etc. This is **empirical probability** — calculated from real historical data, not theory. As more orders arrive, these percentages might shift slightly, but they form the best estimate you have *right now* for what the next order will be.
#
# ---
#
# **💡 Why this matters**
#
# Probability is the bridge between data you *have* (past orders, past sales, past outcomes) and questions you *need to answer* (what will the next order be? What's our expected revenue?). On your first day as an analyst, a stakeholder will ask: *"What's the probability our next customer will buy premium?"* You'll calculate it from historical data — exactly this method. A product manager: *"If we randomize users into control and test groups, will results be comparable?"* — requires understanding sampling and independence. A risk analyst: *"What's the probability of a data breach in Q4?"* — this uses probability and distributions. Understanding probability is foundational to every inferential and predictive decision you'll make in data work.
#
# **→** *Probability = certainty made measurable. It transforms vague hunches into actionable numbers.*
#
# **✅ RECAP**
# - **Probability formula:** P(event) = (favorable outcomes) / (total outcomes)
# - **Probability range:** 0% (impossible) to 100% (certain); all events fall between these boundaries
# - **Sampling with replacement:** the selected item is returned to the pool; probabilities remain constant across multiple draws
# - **Independent events:** outcome of one event does NOT change the probability of the next; essential for randomization
# - **Empirical probability:** calculated from real data (historical orders, past events) — your best estimate for future occurrence
# - **Application:** use historical data proportions to estimate future event probabilities
#
# **🔗 Connection**
# - **Chapter 1 → Chapter 2:** Chapter 1 asked "How do we describe this data?" (center, spread). Chapter 2 asks "How do we measure uncertainty about future data?"
# - **Lesson 1 (Ch1)** established measurable questions; **Lesson 1 (Ch2)** provides the math to quantify those questions
# - The coin flip (50%) and salesperson selection (25%) will reappear in **Lessons 7–8** as discrete probability distributions
# - The retail dataset will be used throughout **Chapter 2** to show how probability appears in real business data
# - **Chapter 4** will use independence principle to explain randomization in hypothesis testing

# %% [markdown]
# #### Chapter 2 — Lesson 2: What is more likely? *(Exercise / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Apply the probability formula to real-world scenarios — correctly identify which event is most likely by calculating or estimating P(event) = (favorable outcomes) / (total outcomes).
#
# ---
#
# **📋 Scenario**
#
# You saw how to calculate the probability of a single event in the video. Now let's check your understanding of this process.
#
# Four scenarios have been provided; your task is to choose which one is **most likely to occur**.
#
# **Task:** Select the scenario with the highest probability of occurring.
#
# ---
#
# **✅ Solution & Walkthrough**
#
# **Correct answer: Option 3 — Picking a red card out of a standard pack of 52 playing cards, where half of the cards are red and the other half are black.**
#
# **Probability calculation:**
# - Favorable outcomes (red cards): 26
# - Total outcomes (all cards): 52
# - P(red card) = 26/52 = 1/2 = **50%**
#
# **Why this is most likely — comparing all options:**
#
# | Option | Scenario | Favorable | Total | Probability | Why this is (or isn't) most likely |
# |--------|----------|-----------|-------|-------------|----------------------------------|
# | 1 | Scoring 90% or more in an exam, when only 5% of students score this highly | ? (unknown, varies by student) | ? | **~5%** | Very unlikely — explicitly stated as rare (5% of students only). Not the highest probability. |
# | 2 | Restaurant receiving a steak order, when steak orders have made up 100 out of 1000 total orders to date | 100 | 1000 | 100/1000 = **10%** | Moderate probability, but lower than red card (10% < 50%). |
# | 3 | **Picking a red card from a 52-card deck, half red, half black** | **26** | **52** | **26/52 = 50%** | **Highest probability.** 50% means the event is equally likely to happen or not happen — maximum certainty without being guaranteed. |
# | 4 | Drawing a person's name out of a hat with 19 other names (20 total) | 1 | 20 | 1/20 = **5%** | Low probability (5%). Same as Option 1's probability. |
#
# **Correct answer: Option 3 with 50% probability is the most likely scenario among the four.**
#
# ---
#
# **Why your earlier attempts failed:**
#
# **First attempt — Option 1 (Exam score):**
# Your error: You may have thought "5% of students score this highly" meant it was *possible* or *worth considering*, rather than recognizing that 5% is extremely low probability.
#
# **Trap:** Confusing *significance* with *likelihood*. A rare event can be significant (it matters if YOU'RE that 5%), but it's still unlikely. Probability measures how often it occurs, not how important it is if it happens.
#
# **Feedback received:** "There is only a 5% chance of scoring this highly in the exam." — This was the hint: 5% is low; other options must be higher.
#
# ---
#
# **Second attempt — Option 2 (Restaurant steak order):**
# Your error: You selected a scenario with explicit historical data (100 out of 1000), which *looks* like a real probability. The concrete numbers may have felt more reliable than the abstract "red card" answer.
#
# **Trap:** Trusting a detailed scenario over calculating the actual probability. A realistic-sounding story with numbers can feel more credible than a simple ratio. But probability doesn't care about realism — it cares about the formula.
#
# **Calculation you should have done:**
# - P(steak) = 100/1000 = 10%
# - P(red card) = 26/52 = 50%
# - 50% > 10%, so red card is more likely ✓
#
# **Feedback received:** "An order of a steak has a 10% chance of occurring." — The system was confirming you had the right calculation, but you had the wrong *comparison*. You didn't compare 10% to the other options.
#
# ---
#
# **Common Mistake**
#
# Probability comparison requires calculating (or estimating) *all* options before deciding. Many learners:
# 1. Calculate one scenario correctly (e.g., "steak is 10%")
# 2. Stop there and assume it's "right" because the math was correct
# 3. Never compare it to the other options
#
# **→** *Always calculate and compare all options. The probability formula is only half the skill; the comparison is the other half. "Most likely" means highest probability, not just "reasonable probability."*
#
# ---
#
# **💡 Why this matters**
#
# In business, you'll face scenarios like: *"Which marketing channel is most likely to bring new customers: email (2% click rate), social media (8% engagement rate), or direct mail (15% response rate)?"* You need to:
# 1. Calculate or know each probability
# 2. Compare them numerically
# 3. Choose the highest
#
# A product manager might present a scenario with compelling details (like the restaurant data) to justify a decision. Your job is to verify the actual probabilities. If someone says "we should focus on email" but email has 2% conversion while SMS has 25%, the numbers tell the real story. Probability comparison is a critical thinking tool — it cuts through storytelling and anchors decisions in evidence.
#
# **→** *Probability is a ranking tool. Use it to find "most likely" among alternatives, not just to confirm "this could happen."*
#
# **✅ RECAP**
# - **Probability formula:** P(event) = (favorable outcomes) / (total outcomes)
# - **Probability range:** 0% (impossible) to 100% (certain)
# - **Comparing probabilities:** calculate or estimate for all options, then select the highest
# - **Common mistake:** calculating one probability correctly but forgetting to compare it to others
# - **Real-world application:** probability comparison guides resource allocation and decision-making
#
# **🔗 Connection**
# - **Lesson 1 (Ch2):** introduced the probability formula with single-event examples
# - **Lesson 2 (Ch2):** applies the formula to multiple scenarios and requires comparison
# - **Lesson 3 (Ch2):** will use the same formula on a dataset (online retail)
# - **Lessons 4–6:** will extend to conditional probability (probability changes based on prior events)
# - **Chapter 1 recap:** you learned that every dataset can be described by center and spread; **Chapter 2** shows that every dataset also implies probabilities for future observations

# %% [markdown]
# #### Chapter 2 — Lesson 3: Chances of the next sale being more than the mean *(Practice / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this practice test?**
# Apply the probability formula to a real dataset — count favorable outcomes (orders exceeding a threshold) and calculate empirical probability, while distinguishing between mean-based and median-based thresholds.
#
# ---
#
# **📋 Scenario**
#
# You have access to an online retail sales dataset with 1,775 total orders. The dataset summary shows:
# - **Mean Net Sales:** $187.97
# - **Median Net Sales:** $96.00
# - **Orders ≥ Mean ($187.97):** 409
# - **Orders ≥ Median ($96.00):** ~888 (roughly 50% by definition)
#
# **Interactive tool:** Sales Probability Calculator displays the order value distribution as a histogram, with bars colored by whether each order exceeds your selected threshold (Mean or Median).
#
# **Task:** Using the probability formula P(event) = favorable outcomes / total outcomes, determine: **What is the probability that the next order will be worth more than the mean ($187.97)?**
#
# **Possible answers:**
# 1. 50.25%
# 2. 23.04% ✅ **CORRECT** (and your correct choice)
# 3. 198.54%
#
# ---
#
# **✅ Solution & Walkthrough**
#
# **Correct answer: Option 2 — 23.04%**
#
# **Calculation:**
# - Favorable outcomes (orders ≥ $187.97): 409
# - Total outcomes (all orders): 1,775
# - P(order ≥ mean) = 409 / 1,775 ≈ 0.2304 = **23.04%**
#
# **Interpretation:** There is approximately a **1 in 4 chance** (or roughly 23%) that the next randomly selected order will be worth $187.97 or more.
#
# **Why this makes sense — comparing to median:**
# - P(order ≥ median) = ~888 / 1,775 ≈ 50% (by definition, median splits data in half)
# - P(order ≥ mean) = 409 / 1,775 ≈ 23% (mean is higher than median due to right-skewed distribution)
#
# The distribution is skewed right (as shown in the histogram): most orders are below the mean, with a tail of high-value orders pulling the mean upward. This is why the probability of exceeding the mean (23%) is much lower than exceeding the median (50%).
#
# ---
#
# **Why your first attempt failed:**
#
# **Your choice:** Option 1 (50.25%)
#
# **Trap:** Mean-Median Confusion. You selected the threshold for Median ($96.00) instead of Mean ($187.97) in the calculator interface. The system calculated:
# - P(order ≥ $96.00) = ~50.25% (essentially half, as the median divides data)
# - This is correct *for the median*, but incorrect for the question, which asked for the mean
#
# **Why this trap is insidious:**
# - 50% is a "clean" number — it feels right (median by definition is the 50th percentile)
# - The histogram visual makes 50% look plausible (you can see roughly half the bars in blue, half in darker color)
# - The first threshold option on the interface might be Median, making it easier to select by accident
# - Both median and mean are measures of center — your brain doesn't catch the conceptual switch
#
# **Feedback received:** "You've calculated the probability of an order being worth more than the median ($96.00), not the mean." — The system confirmed you did the math right, but applied it to the wrong measure.
#
# ---
#
# **Common Mistake**
#
# Mean and median are related but distinct measures. When a task specifies one, choosing the other is a critical error:
#
# | Measure | Definition | Probability of exceeding it (in skewed data) |
# |---------|-----------|------------------------------------------|
# | **Median** | The middle value; 50% of data below, 50% above — by definition | **~50%** (always approximately 50%, regardless of distribution shape) |
# | **Mean** | Average of all values; pulled toward outliers in skewed data | **Varies** (depends on skewness; can be much lower or higher than 50%) |
#
# In this dataset (right-skewed, with some very high orders):
# - Median = $96.00 → P(order ≥ median) ≈ 50%
# - Mean = $187.97 → P(order ≥ mean) ≈ 23%
#
# **The shift in thinking:**
# **→** *Mean and median have different probabilities. The question tells you which one to use — read carefully before calculating.*
#
# ---
#
# **💡 Why this matters**
#
# This lesson bridges two chapters: Chapter 1 taught you to *describe* data (center and spread); Chapter 2 teaches you to *predict* from it. In real business:
#
# - **Inventory manager:** "What's the probability our next shipment will exceed the average order size?" — You must know whether the business defined "average" as mean or median, then calculate accordingly.
# - **Financial analyst:** "What percentage of transactions exceed the mean transaction value?" — A seemingly simple question, but the answer depends on distribution skewness. If you confuse mean and median, you'll give the wrong number.
# - **Product manager:** "Will the next user session last longer than the median session duration?" — Median again. If you accidentally calculate against the mean, you'll forecast incorrectly.
#
# Recruiters test this skill constantly: "Walk me through how you'd calculate the probability of a customer order exceeding the average order value." A correct answer shows you understand both probability and the difference between center measures.
#
# **→** *Read the threshold specification carefully. Mean and median are not interchangeable in probability — they produce different answers.*
#
# **✅ RECAP**
# - **Probability formula:** P(event) = favorable outcomes / total outcomes
# - **Empirical probability:** calculated from real data; shows the proportion of times the event actually occurred
# - **Mean vs. Median thresholds:** produce different probabilities, especially in skewed data
# - **Median threshold:** P(value ≥ median) ≈ 50%, always, by definition
# - **Mean threshold:** P(value ≥ mean) varies based on distribution shape and skewness
# - **Right-skewed data (like sales):** mean > median, so P(value ≥ mean) < P(value ≥ median)
# - **Reading the question:** always identify which threshold (mean or median) is requested before calculating
#
# **🔗 Connection**
# - **Lesson 1 (Ch2):** introduced probability formula and independence
# - **Lesson 2 (Ch2):** compared probabilities across scenarios
# - **Lesson 3 (Ch2):** applies probability to real dataset (online retail) — first concrete use of the formula
# - **Lesson 5–8 (Ch2):** will extend to conditional probability (probability changes based on prior information)
# - **Chapter 1 connection:** measures of center (mean, median) learned there now have probability implications — skewed distributions have different mean vs. median probabilities
# - **Chapter 4 connection:** hypothesis testing will compare whether sample means differ significantly — requires understanding probability distributions around the mean

# %% [markdown]
# #### Chapter 2 — Lesson 4: Conditional probability *(Video / 50 XP)*
#
# > 🎬 [Watch on DataCamp](https://campus.datacamp.com/courses/introduction-to-statistics/probability-and-distributions?ex=4) *(requires login)*
#
# ---
#
# **🎯 GOAL — What is this lesson about?**
# Understanding dependent events and conditional probability — how the probability of one event changes when we have prior knowledge about another event, and how to calculate it using the conditional probability formula.
#
# ---
#
# **From Independence to Dependence**
#
# Lesson 1 introduced **independent probability:** the outcome of one event does NOT affect the probability of another. You sample *with replacement* — the item goes back in the box, and probabilities stay constant.
#
# But what if you don't replace the item? **Sampling without replacement** creates **dependent events** — the outcome of the first event *changes* the probability of the second.
#
# **Example — sales meetings:**
#
# Scenario: You have 4 salespeople {Brian, Alice, Carlos, Dana}. Two clients want meetings at the same time.
#
# - **First meeting:** Pick Brian randomly. P(Brian) = 1/4 = 25%
# - **Second meeting:** Brian is unavailable. You pick from {Alice, Carlos, Dana} — only 3 people left.
#   - P(Claire picked second) = 1/3 ≈ 33%
#   - This is higher than 25% because the pool shrank.
#
# **Key insight:** The probability of picking Claire second *depends on* who was picked first. If Claire was picked first, P(Claire picked second) = 0%. If anyone else was picked first, P(Claire picked second) = 1/3.
#
# ---
#
# **Conditional Probability Formula**
#
# When the probability of event A depends on event B having occurred, we write:
#
# $$P(A \mid B) = \frac{P(A \text{ and } B)}{P(B)}$$
#
# Read as: "Probability of A *given* B" or "Probability of A conditional on B occurring."
#
# **Example — kitchen products over $150:**
#
# Online retail dataset:
# - Total orders: 1,767
# - Orders > $150: 601
# - Kitchen product orders: 181
# - Orders that are BOTH kitchen AND > $150: 20
#
# **Question:** What is the probability that an order is over $150, *given* that it is a kitchen product?
#
# $$P(\text{order} > \$150 \mid \text{kitchen}) = \frac{P(\text{both kitchen and} > \$150)}{P(\text{kitchen})} = \frac{20/1767}{181/1767} = \frac{20}{181} \approx 11\%$$
#
# **Interpretation:** If you know an order is for a kitchen product, there's an 11% chance it's worth more than $150.
#
# ---
#
# **The Order of Events Matters**
#
# Conditional probability is *asymmetric* — P(A|B) ≠ P(B|A).
#
# **Reverse question:** What is the probability that an order is for a kitchen product, *given* that it is over $150?
#
# $$P(\text{kitchen} \mid \text{order} > \$150) = \frac{20/1767}{601/1767} = \frac{20}{601} \approx 3.3\%$$
#
# **Interpretation:** If you know an order is worth over $150, there's only a 3.3% chance it's a kitchen product (most high-value orders are other categories).
#
# | Condition | Probability | Meaning |
# |-----------|-------------|---------|
# | P(> $150 \| kitchen) = 11% | Among kitchen orders, 11% exceed $150 | Focus: kitchen product pool |
# | P(kitchen \| > $150) = 3.3% | Among high-value orders, only 3.3% are kitchen | Focus: high-value order pool |
#
# The different probabilities reflect different reference pools — your denominator changes based on which event is the condition.
#
# ---
#
# **Visualizing with Venn Diagrams**
#
# A **Venn diagram** displays two overlapping circles:
# - Left circle: all kitchen orders (181 total)
# - Right circle: all orders > $150 (601 total)
# - Overlap: orders that are BOTH (20 total)
#
# **Reading conditional probabilities from a Venn diagram:**
# - P(> $150 | kitchen) = (overlap) / (left circle) = 20/181 ≈ 11%
# - P(kitchen | > $150) = (overlap) / (right circle) = 20/601 ≈ 3.3%
#
# The overlap is the same (20), but the denominator changes depending on which circle you're conditioning on.
#
# ---
#
# **Dependent vs. Independent — Side by Side**
#
# | Concept | Independent Events | Dependent Events |
# |---------|-------------------|------------------|
# | **Sampling method** | With replacement | Without replacement |
# | **Probability changes?** | No — P(A) is always the same | Yes — P(A \| B) depends on B |
# | **Formula** | P(A and B) = P(A) × P(B) | P(A \| B) = P(A and B) / P(B) |
# | **Example** | Coin flips, die rolls, drawing with replacement | Drawing names without replacement, conditional sales probabilities |
# | **Real-world pattern** | Rare in business data | Common in business data |
#
# ---
#
# **💡 Why this matters**
#
# Conditional probability is everywhere in business:
#
# - **Supply chain:** "What's the probability a shipment arrives on time, *given* it comes from Warehouse B (which has different efficiency)?"
# - **Marketing:** "What's the conversion rate for users who have *already* visited before?" — Different from first-time visitors.
# - **Healthcare/Risk:** "What's the probability a patient develops complications, *given* they have diabetes?" — The condition changes the probability.
# - **Finance:** "What's the probability a stock rises, *given* the sector had a down day?" — Market-dependent.
#
# A recruiter will ask: *"Walk me through how you'd analyze whether two events are independent or dependent."* Conditional probability is the tool. If you can calculate P(A|B) and explain why it differs from P(A), you demonstrate sophisticated statistical thinking.
#
# **→** *Conditional probability turns "what if?" into "what if we knew?"* — it quantifies how new information changes risk and opportunity estimates.*
#
# **✅ RECAP**
# - **Dependent events:** outcome of one event affects the probability of another
# - **Sampling without replacement:** creates dependency (items don't go back in the pool)
# - **Conditional probability:** P(A|B) = P(A and B) / P(B)
# - **Order matters:** P(A|B) ≠ P(B|A) — different reference pools, different results
# - **Venn diagrams:** visualize overlaps and reference pools for conditional probabilities
# - **Business application:** "given that X occurred, what's the probability of Y?" — answering this question is critical for risk and opportunity assessment
#
# **🔗 Connection**
# - **Lessons 1–3 (Ch2):** independent probability; single-event calculations
# - **Lesson 4 (Ch2):** dependent probability; introduces conditioning on prior information
# - **Lessons 5–6:** will apply conditional probability to real scenarios (dependent vs. independent events exercise, orders with conditions)
# - **Chapter 4 (hypothesis testing):** will use conditional probability logic — "given the null hypothesis is true, what's the probability of observing our data?"
# - **Bridge to real analytics:** most business questions are conditional — they require knowing something before estimating something else

# %% [markdown]
# #### Chapter 2 — Lesson 5: Dependent vs. Independent events *(Exercise / 100 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Distinguish between dependent and independent events by recognizing whether the outcome of one event changes the probability of another.
#
# ---
#
# **📋 Scenario**
#
# It can be tricky to decide whether events are dependent or independent, but understanding this distinction is crucial when correctly calculating the probability of event outcomes.
#
# In this exercise, you have been provided with some scenarios and need to classify them as dependent or independent events.
#
# **Task:** Match each scenario to the appropriate bucket (Dependent or Independent) based on whether the outcome of one event changes the probability of another.
#
# ---
#
# **✅ Solution & Walkthrough**
#
# **Correct classifications:**
#
# | Scenario | Classification | Why |
# |----------|---|---|
# | **The probability of a sports team winning a championship, given they are at the top of the league currently** | ✅ **Dependent** | Being at the top of the league changes the probability of winning the championship. Current league position provides information that alters the probability. |
# | **The probability of flipping a coin and getting heads, given that today is Tuesday** | ✅ **Independent** | The day of the week has no effect on coin flip probability. Coin flips are random and unaffected by calendar dates. P(heads) = 50% on Tuesday, Wednesday, or any day. |
# | **The probability of being offered a job, having made it to the final interview stage** | ✅ **Dependent** | Making the final interview stage significantly increases your probability of being offered the job. Prior progress in the hiring process affects current probability. |
# | **The probability of rolling a six within two attempts using a fair die** | ✅ **Independent** | Each die roll is independent. The outcome of the first roll does NOT change the probability of rolling a six on the second roll (both are 1/6 ≈ 16.7%). |
# | **The probability of winning the lottery** | ✅ **Independent** | Lottery draws are random and independent. Previous lottery results do not affect current probabilities. Your chances of winning remain the same regardless of past outcomes. |
# | **The probability of more than 100mm of rainfall, given it is currently July** | ✅ **Dependent** | Rainfall in July is heavily dependent on the month/season and local climate patterns. P(rainfall > 100mm \| July) is different from P(rainfall > 100mm \| December) in most temperate climates. |
#
# ---
#
# **Why your first attempt failed:**
#
# **Your choice:** You classified "The probability of rainfall changes depending on which month you are in" as **Independent**.
#
# **Trap:** Confusing *real-world variation* with *independence*. The statement is absolutely true — rainfall DOES vary by month. But that's exactly why it's **dependent**: the month (first event) changes the probability of heavy rainfall (second event).
#
# **The logic:**
# - **Independent:** "No matter what month it is, rainfall probability stays the same" → False in reality
# - **Dependent:** "The probability of rainfall depends on which month it is" → True in reality
#
# You were thinking: *"Rainfall amounts vary, so it's a real pattern, not independent randomness."* But variation based on a condition is the definition of dependence.
#
# **Feedback received:** The system confirmed that rainfall probabilities change by month — which is exactly why it's dependent, not independent.
#
# ---
#
# **Common Mistake**
#
# Confusing "the probability is different in different contexts" with "the probability is independent." Here are the key distinctions:
#
# | Concept | What it means | Example |
# |---------|--------------|---------|
# | **Independent events** | Outcome of Event A does NOT change P(Event B). P(B) is the same regardless of A's result. | Coin flips, lottery draws, die rolls — always the same probability |
# | **Dependent events** | Outcome of Event A DOES change P(Event B). P(B) differs based on what happened in A. | Job interview advancement, weather by season, sports ranking effect |
# | **Real-world variation** | A variable changes based on conditions in the real world. | Rainfall varies by season; conversions vary by campaign; sales vary by day-of-week |
#
# **The trap:** Real-world variation = dependence. When you say "X varies depending on Y," you're describing a dependent relationship.
#
# **→** *If the probability changes based on a condition or prior event, it's dependent. If you need to ask "given what?" to calculate the probability, it's dependent.*
#
# ---
#
# **💡 Why this matters**
#
# This distinction affects every statistical decision:
#
# - **Product team:** "Conversion rate varies by device type (mobile vs. desktop)" — device type and conversion are dependent. You must calculate separate probabilities for each device, not a single average probability.
# - **Supply chain:** "Delivery time depends on which warehouse the order ships from" — warehouse (Event A) and delivery time (Event B) are dependent. Different warehouses have different probabilities.
# - **Finance:** "Stock performance this quarter depends on whether the previous quarter was up or down" — dependent. Market momentum matters.
# - **Marketing:** "Email open rate depends on whether the user opened the last email" — dependent. Recent engagement history affects current probability.
#
# A recruiter will ask: *"How do you know if two variables are independent?"* The answer: *"If knowing one variable's outcome changes the probability of the other, they're dependent. If not, they're independent."* This test — independence vs. dependence — is the foundation for designing experiments and interpreting data.
#
# **→** *Independence is rare in business data. Most real variables are dependent on context, history, or conditions. Spot the dependencies; they reveal where your analysis must be conditional.*
#
# **✅ RECAP**
# - **Independent events:** outcome of one event does NOT change the probability of another; P(B) is constant
# - **Dependent events:** outcome of one event DOES change the probability of another; P(B|A) ≠ P(B)
# - **Test for dependence:** "Does knowing the outcome of Event A change my estimate of Event B's probability?"
# - **Real-world variation indicates dependence:** if a probability changes based on context or condition, the events are dependent
# - **Sampling without replacement creates dependence:** removing items from a pool changes future probabilities
# - **Sampling with replacement maintains independence:** replacing items keeps probabilities constant across draws
#
# **🔗 Connection**
# - **Lesson 1 (Ch2):** introduced independence (sampling with replacement)
# - **Lesson 4 (Ch2):** introduced conditional probability and dependence (sampling without replacement)
# - **Lesson 5 (Ch2):** tests your ability to classify real-world scenarios as dependent or independent
# - **Lesson 6:** will apply these concepts to order probabilities in the retail dataset
# - **Lessons 7–9:** discrete probability distributions (binomial, Poisson) — all assume independence within the model
# - **Chapter 4:** hypothesis testing uses the independence assumption to calculate p-values; violating independence assumption leads to incorrect conclusions

# %% [markdown]
# #### Chapter 2 — Lesson 6: Orders of more than 10 basket products *(Exercise / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Apply the conditional probability formula using a Venn diagram — correctly identify the numerator (overlap) and denominator (the condition's total) to calculate P(A|B).
#
# ---
#
# **📋 Scenario**
#
# Recall that the order in which dependent events occur affects conditional probability.
#
# In this exercise, you will need to use the image to calculate the conditional probability that an order from the online retail dataset will be for **more than 10 items, given the order is for Basket products**.
#
# **Venn diagram data:**
# - Orders with more than 10 items (only): 125
# - Orders that are BOTH basket AND more than 10 items: 19
# - Orders for basket products (only): 551
# - Total orders: 1,767
#
# **Task:** What is the probability that an order is for more than 10 items, *given* the order is for basket products?
#
# **Possible answers:**
# 1. 19/144
# 2. 19/570 ✅ **CORRECT** (and your correct choice)
# 3. 144/1767
# 4. 19/1767
#
# ---
#
# **✅ Solution & Walkthrough**
#
# **Correct answer: Option 2 — 19/570 ≈ 3.3%**
#
# **Using the conditional probability formula:**
#
# $$P(\text{>10 items} \mid \text{basket}) = \frac{\text{orders that are BOTH basket AND >10 items}}{\text{total orders for basket products}}$$
#
# $$P(\text{>10 items} \mid \text{basket}) = \frac{19}{570} \approx 0.033 = 3.3\%$$
#
# **Reading from the Venn diagram:**
# - **Numerator:** overlap (19) — orders meeting BOTH conditions
# - **Denominator:** right circle total (19 + 551 = 570) — all basket orders, because that's our condition
# - **Interpretation:** Among basket orders, only 3.3% are large orders (>10 items)
#
# **Why the denominator is 570, not 1,767:**
# The condition "given the order is for basket products" *restricts* the reference pool. You're no longer looking at all 1,767 orders; you're looking only at the 570 basket orders. Within that restricted pool, 19 meet the second condition (>10 items).
#
# ---
#
# **Why your first attempt failed:**
#
# **Your choice:** Option 1 (19/144)
#
# **Trap:** Reversing the conditional direction. You calculated P(basket | >10 items) instead of P(>10 items | basket).
#
# **The math:**
# - Orders with >10 items total: 125 + 19 = 144
# - Orders that are BOTH: 19
# - P(basket | >10 items) = 19/144 ≈ 13.2%
#
# This is a valid conditional probability, but it answers the *wrong question*. The question asked for P(>10 items | basket), not P(basket | >10 items).
#
# **Why this trap is common:**
# - Both use the same numerator (19 — the overlap)
# - Both are mathematically valid conditional probabilities
# - The only difference is which circle becomes the denominator
# - **The wording "given X" tells you which goes in the denominator** — X is the condition, so it's your denominator
#
# **Reading the question carefully:**
# - "given the order is for basket products" → basket is the condition → basket total (570) goes in denominator ✓
# - If it had asked "given the order has >10 items" → >10 items would be the condition → >10 items total (144) goes in denominator
#
# ---
#
# **Common Mistake**
#
# The phrase "given" is the key to conditional probability, but it's easy to parse backwards:
#
# | Question | Condition (denominator) | Calculation | Result |
# |----------|------------------------|-------------|--------|
# | P(>10 \| basket) = ? | Basket (570) | 19 / 570 | 3.3% |
# | P(basket \| >10) = ? | >10 items (144) | 19 / 144 | 13.2% |
# | P(basket) = ? | None (all orders) | (19+551) / 1767 | 32.2% |
#
# **The rule:** In "P(A | B)", B is the condition. B is your denominator. A is what you're calculating the probability for.
#
# **→** *"Given" identifies the condition. The condition becomes your denominator. Read "P(A | B)" as "probability of A, using only the subset where B is true."*
#
# ---
#
# **💡 Why this matters**
#
# Conditional probability is how data informs decisions:
#
# - **E-commerce:** "What's the probability a customer buys multiple items, *given* they're a repeat customer?" — repeat customer is the condition (denominator).
# - **Hiring:** "What's the probability a candidate succeeds in the role, *given* they have 5+ years experience?" — experience is the condition.
# - **Healthcare:** "What's the probability of complications, *given* the patient has diabetes?" — diabetes is the condition.
# - **Marketing:** "What's the probability of conversion, *given* the user came from organic search?" — source is the condition.
#
# Getting the direction wrong is a critical error. A product manager asks: "What's the probability an order is large, given it's a basket order?" If you reverse it and calculate "probability it's a basket order, given it's large," you've answered a different question entirely. Your recommendation will be backwards.
#
# A recruiter will test this skill: *"Walk me through a conditional probability calculation from your own data."* They're listening for whether you correctly identify the condition and use it as your denominator.
#
# **→** *Conditional probability direction matters. The condition is your lens. Use it to narrow the reference pool, then calculate within that narrower pool.*
#
# **✅ RECAP**
# - **Conditional probability formula:** P(A|B) = P(A and B) / P(B)
# - **The denominator rule:** B (the condition, after "given") is your denominator
# - **The numerator rule:** overlap of A and B — cases meeting both conditions
# - **Venn diagram reading:** condition → use that circle's total as denominator; overlap → use for numerator
# - **Direction matters:** P(A|B) ≠ P(B|A) — they answer different questions
# - **The key phrase:** "given X" tells you X is the condition and should be your denominator
#
# **🔗 Connection**
# - **Lesson 4 (Ch2):** introduced conditional probability formula and kitchen product example
# - **Lesson 5 (Ch2):** classified dependent vs. independent events (setting up for conditional calculations)
# - **Lesson 6 (Ch2):** applies conditional probability to real dataset with Venn diagram
# - **Lesson 3 (Ch2):** revisited using conditional probability on mean/median thresholds (earlier, single-threshold version)
# - **Lessons 7–9:** discrete probability distributions assume independence or specify conditions clearly
# - **Chapter 4:** hypothesis testing uses conditional logic — "given the null hypothesis is true, what's the probability of observing this data?"

# %% [markdown]
# #### Chapter 2 — Lesson 7: Discrete distributions *(Video / 50 XP)*
#
# > 🎬 [Watch on DataCamp](https://campus.datacamp.com/courses/introduction-to-statistics/probability-and-distributions?ex=7) *(requires login)*
#
# ---
#
# **🎯 GOAL — What is this lesson about?**
# Introducing probability distributions — how they describe all possible outcomes and their probabilities, and how the expected value (mean) of a distribution guides predictions about real samples.
#
# ---
#
# **What is a Probability Distribution?**
#
# A **probability distribution** describes the probability of each possible outcome in a scenario.
#
# **Example — fair die (6-sided):**
# - Possible outcomes: 1, 2, 3, 4, 5, 6
# - Probability of each: 1/6 ≈ 16.67%
# - Total probability: 1/6 + 1/6 + 1/6 + 1/6 + 1/6 + 1/6 = 1 (100%)
#
# **Visualization — histogram:**
# Each bar represents one outcome. The height of each bar = its probability.
#
# ```
# Probability
#     |
# 16.7%|  ___  ___  ___  ___  ___  ___
#      | |   ||   ||   ||   ||   ||   |
#      |_|_1_||_2_||_3_||_4_||_5_||_6_|___
#              Die outcome
# ```
#
# Fair die → all bars equal height (uniform distribution).
#
# ---
#
# **Expected Value — The Mean of a Distribution**
#
# The **expected value** is the long-run average outcome. Calculate it by multiplying each outcome by its probability, then summing:
#
# $$E(X) = \sum (\text{outcome} \times \text{probability})$$
#
# **Fair die:**
# $$E(X) = 1 \times \frac{1}{6} + 2 \times \frac{1}{6} + 3 \times \frac{1}{6} + 4 \times \frac{1}{6} + 5 \times \frac{1}{6} + 6 \times \frac{1}{6}$$
#
# $$E(X) = \frac{1+2+3+4+5+6}{6} = \frac{21}{6} = 3.5$$
#
# **Interpretation:** If you roll a fair die many times, the average roll will approach 3.5.
#
# ---
#
# **Uneven Probabilities — Same Formula, Different Result**
#
# What if the die is "broken" — the face showing "2" is covered, so it shows "3" instead?
#
# **New outcomes:** 1, 3, 3, 4, 5, 6
#
# **New probabilities:**
# - P(1) = 1/6
# - P(2) = 0% (impossible)
# - P(3) = 2/6 = 1/3 (two faces show 3)
# - P(4) = 1/6
# - P(5) = 1/6
# - P(6) = 1/6
#
# **New expected value:**
# $$E(X) = 1 \times \frac{1}{6} + 2 \times 0 + 3 \times \frac{2}{6} + 4 \times \frac{1}{6} + 5 \times \frac{1}{6} + 6 \times \frac{1}{6}$$
#
# $$E(X) = \frac{1}{6} + 0 + \frac{6}{6} + \frac{4}{6} + \frac{5}{6} + \frac{6}{6} = \frac{22}{6} \approx 3.67$$
#
# **Key insight:** Changing probabilities changes the expected value.
#
# ---
#
# **Discrete Uniform Distribution**
#
# When all outcomes have equal probability, we have a **discrete uniform distribution**.
#
# **Properties:**
# - All outcomes equally likely
# - Represented by even histogram bars
# - Examples: fair die, fair coin, random name selection
# - Expected value: middle of the range
#
# ---
#
# **Calculating Probabilities from a Distribution — Area Rule**
#
# You can calculate the probability of multiple outcomes by summing bar areas (or heights × width).
#
# **Fair die — P(outcome ≤ 2)?**
# $$P(X \leq 2) = P(X=1) + P(X=2) = \frac{1}{6} + \frac{1}{6} = \frac{2}{6} = \frac{1}{3} \approx 33.3\%$$
#
# **Uneven die — P(outcome ≤ 2)?**
# $$P(X \leq 2) = P(X=1) + P(X=2) = \frac{1}{6} + 0 = \frac{1}{6} \approx 16.7\%$$
#
# Different probabilities → different results, even with the same question.
#
# ---
#
# **Sample Distribution vs. Theoretical Distribution**
#
# **Theoretical distribution:** the mathematical model (what we expect)
#
# **Sample distribution:** what actually happens when we sample (random variation)
#
# **Example — roll a fair die 10 times:**
#
# Theoretical expected value: 3.5
#
# Sample outcomes: [3, 2, 5, 2, 4, 1, 3, 6, 4, 5]
#
# Sample mean: (3+2+5+2+4+1+3+6+4+5) / 10 = 35 / 10 = 3.5
#
# (In this case, they match! But usually they don't perfectly.)
#
# **Roll 100 times:**
# Sample mean ≈ 3.48 (closer to 3.5)
#
# **Roll 1,000 times:**
# Sample mean ≈ 3.501 (very close to 3.5)
#
# ---
#
# **The Law of Large Numbers**
#
# As sample size increases, the sample mean approaches the theoretical expected value.
#
# $$\lim_{n \to \infty} \text{Sample Mean} = E(X)$$
#
# **Why this matters:**
# - Small samples are noisy (random variation dominates)
# - Large samples stabilize (true probability emerges)
# - This principle justifies using samples to estimate population parameters
#
# **Example progression:**
# - 10 rolls: sample mean = 3.0 (far from 3.5)
# - 100 rolls: sample mean ≈ 3.48 (close to 3.5)
# - 1,000 rolls: sample mean ≈ 3.501 (very close to 3.5)
# - 1,000,000 rolls: sample mean ≈ 3.50000 (essentially 3.5)
#
# ---
#
# **💡 Why this matters**
#
# Probability distributions are the foundation of all statistical inference:
#
# - **Risk assessment:** A pharmaceutical company models the distribution of side effects. The expected value tells them what to expect on average; the spread tells them about variability and rare events.
# - **Quality control:** A manufacturing plant models the distribution of product weights. If the expected value drifts, they know the process needs adjustment.
# - **Demand forecasting:** An e-commerce company models the distribution of daily orders. The expected value is their forecast; the spread is their risk.
# - **Hypothesis testing:** Chapter 4 will use probability distributions to answer "Is this sample result unusual, or just normal variation?"
#
# The law of large numbers explains why bigger samples are more reliable — they let the true distribution emerge from the noise. A recruiter will ask: *"Why do you need a large sample?"* The answer: *"Because of the law of large numbers — smaller samples have more random variation."*
#
# **→** *Probability distributions are the bridge between theory (what should happen) and practice (what actually happens). Larger samples reveal the truth.*
#
# **✅ RECAP**
# - **Probability distribution:** describes P(each outcome); all probabilities sum to 1
# - **Expected value:** E(X) = Σ(outcome × probability); the long-run average
# - **Discrete distribution:** outcomes are countable/distinct (1, 2, 3... not continuous)
# - **Discrete uniform distribution:** all outcomes equally likely (fair die, fair coin)
# - **Calculating probabilities:** sum the bar heights (or areas) for the outcomes you care about
# - **Sample vs. theoretical:** sample distribution = what actually happened (random); theoretical = mathematical model (fixed)
# - **Law of large numbers:** as n increases, sample mean → theoretical expected value
# - **Why it matters:** samples estimate populations; large samples are more reliable because randomness averages out
#
# **🔗 Connection**
# - **Lessons 1–6 (Ch2):** probability fundamentals, independence, conditional probability
# - **Lesson 7 (Ch2):** introduces distributions as a way to describe all possible outcomes and their probabilities
# - **Lesson 8:** identifying distribution types in real data
# - **Lesson 9:** sampling from distributions (sample mean vs. theoretical mean)
# - **Lessons 10–13:** continuous distributions (normal, uniform) and their properties
# - **Chapter 1 connection:** mean and spread from Chapter 1 now have probabilistic interpretation — they describe the center and spread of a distribution
# - **Chapter 4:** hypothesis testing uses distributions to calculate p-values — "how unlikely is our sample if the null hypothesis distribution is true?"

# %% [markdown]
# #### Chapter 2 — Lesson 8: Identifying distributions *(Exercise / 50 XP)*
#
# **🎯 GOAL**
#
# Given three histograms representing probability distributions, identify which one is uniform. This trains the visual recognition skill you'll need when examining real data — you must spot the distribution shape instantly.
#
# ---
#
# **🔧 APPROACH**
#
# Compare the three histograms by examining bar heights:
# - **Uniform distribution:** all bars roughly the same height (flat) — each outcome equally likely
# - **Skewed distribution:** bars get progressively higher or lower — some outcomes more likely than others
# - **Other shapes:** may have a peak, or tail off gradually (you'll see these in later lessons)
#
# **Key visual rule:** Uniform = flat. Not flat = not uniform.
#
# ---
#
# **💡 SOLUTION**
#
# | Option | Distribution Shape | Probabilities | Uniform? | Why / Trap Explanation |
# |--------|---|---|---|---|
# | **A** | Skewed right (exponential-like) | High at x=0, decreases rapidly to x=5000 | ❌ No | Confuses "most outcomes concentrated" with "uniform." This is the trap. High probability at one end ≠ uniform. |
# | **B** | Flat (uniform) | All bars same height across x-axis range | ✅ **Yes** | All outcomes (1 through 6, or whatever the range) have equal probability. Definition of uniform. |
# | **C** | Bimodal (two peaks) | High at x=2000 and x=9000, low in middle | ❌ No | Two peaks suggest two different likely outcomes — not uniform distribution. |
#
# **Your selection:** Option A (incorrect)
# **Why you chose this:** The histogram shows a clear concentration, which feels like "a distribution" — but uniform specifically means all outcomes equally likely. Concentration is the *opposite* of uniformity.
#
# ---
#
# **🔍 WALKTHROUGH**
#
# **Step 1 — Define uniform visually**
#
# A uniform distribution histogram has **all bars at the same height**. Imagine a die roll (1–6): each outcome has probability 1/6. If you draw this histogram, you get six equal-height bars.
#
# **Step 2 — Scan for flat shape**
#
# Look at the three options:
# - **A:** High bar on the left, then drops → not flat
# - **B:** Bars all roughly equal height across the x-axis → flat ✅
# - **C:** Two high peaks with a dip → clearly not flat
#
# **Step 3 — Rule out the rest**
#
# If it's not flat, it's not uniform. A and C have obvious non-flat shapes, so they're eliminated immediately.
#
# ---
#
# **💬 Why this matters**
#
# **In analytics:** Real data often comes from different distributions. If you're analyzing customer wait times and see a skewed histogram (most waits short, a few very long), you know immediately it's *not* uniform. This matters because:
# - **Uniform assumption (wrong):** "All wait times are equally likely" → forecasting fails
# - **Skewed reality (correct):** "Most waits are short; some are outliers" → you account for the tail risk
#
# **In interviews:** A recruiter will show you a histogram and ask: "What distribution is this?" Your answer must be instant and confident. "This is uniform — equal probability across the range" (and point to the equal bar heights). Or "This is skewed right — high probability on the left, tail on the right."
#
# **Trap avoided:** You now know that "concentrated" ≠ "uniform." Concentration is a feature of *skewed* or *peaked* distributions. Uniform is the *opposite* — spread equally.
#
# **Common mistake:** Confusing the shape of one big bar with the shape of the whole distribution. Option A has one dominant bar, which might *feel* like a distribution, but it's explicitly *not* uniform. Uniform means all bars compete equally for probability mass.
#
# **→** *Recognizing a uniform distribution is about spotting flatness. If the bars aren't level, it's not uniform — and each non-flat shape tells a story about which outcomes are likely and which are rare.*
#
# **✅ RECAP**
# - **Uniform distribution:** all outcomes equally likely; histogram shows equal-height bars; examples: fair die, random number from 1–100
# - **Visual identification:** flat bars = uniform; peaked, skewed, or bimodal = not uniform
# - **Skewed distribution:** outcomes concentrated on one end; high probability near one value, tail toward the other
# - **Why shape matters:** the shape tells you which outcomes are common (tall bars) and which are rare (short bars)
# - **Next lesson:** we'll learn how to sample from distributions and compare sample mean to theoretical mean
#
# **🔗 Connection**
# - **Lesson 7:** discrete distributions, expected value, law of large numbers
# - **Lesson 8 (this):** identifying distribution types visually
# - **Lesson 9:** sampling from a distribution; sample mean vs. theoretical mean
# - **Lessons 10–13:** continuous distributions (normal, uniform, others) — how distributions emerge in nature

# %% [markdown]
# #### Chapter 2 — Lesson 9: Sample mean vs. theoretical mean *(Practice / 50 XP)*
#
# **🎯 GOAL**
#
# Apply the law of large numbers in reverse: understand when you're *likely* to see a sample mean far from the expected value. This trains the intuition you'll need in real analytics — knowing whether a "surprising" result is meaningful or just noise.
#
# ---
#
# **🔧 APPROACH**
#
# The law of large numbers says: as n increases, sample mean → expected value.
#
# **Corollary (the trap):** as n *decreases*, sample mean has *more freedom* to vary. Small samples are noisy. Large samples are stable.
#
# **Key rule:** If you want to see large deviations from the expected value, you need *small* samples where randomness dominates. Large samples lock onto the true mean.
#
# ---
#
# **💡 SOLUTION**
#
# **Question:** "Which sample size gives you the *best chance* of getting a mean far from 5 (e.g., below 4)?"
#
# | Option | Sample Size | Stability | Distance from E(X)=5 | Best Chance? | Why / Trap Explanation |
# |--------|---|---|---|---|---|
# | 1 | **10** | Low (noisy) | High variability | ✅ **Yes** | With only 10 observations, randomness dominates. One lucky/unlucky draw can pull the mean far from 5. This is where you'll see means of 4.3, 4.7, or 3.2. |
# | 2 | 100 | Medium | Moderate variability | ❌ No | 100 observations start to stabilize around 5, but still some variation. Less noisy than 10, so fewer extreme means. |
# | 3 | 1,000 | High | Low variability | ❌ No | Law of large numbers kicks in hard. Sample mean will be within ±0.1 of 5 almost always. Virtually no chance of mean < 4. |
# | 4 | 5,000 | Very High | Very low variability | ❌ No | Even more stable. Sample mean ≈ 5.000 (±0.01). The further you climb the n ladder, the less variation. |
# | 5 | 10,000 | Extreme | Extreme stability | ❌ No | Sample mean ≈ 5 (±0.001). Essentially locked. The question is impossible at this size — you cannot escape 5. |
#
# **Your attempt sequence:**
# 1. Selected 10,000 (Option 5) — ❌ Incorrect. Chose the *most stable* when the question asks for the *most variable*.
# 2. Selected 5,000 (Option 4) — ❌ Incorrect. Still too high on the n spectrum.
# 3. Selected 1,000 (Option 3) — ❌ Incorrect. Getting closer, but still too high.
# 4. Selected 10 (Option 1) — ✅ **Correct!** Found the noise zone.
#
# **Root cause of the trap:** You were thinking "bigger data = better" and applying that intuition here. But the question reverses the requirement. The law of large numbers is working *against* you if you want variation. You need to *embrace* small samples, not avoid them.
#
# ---
#
# **🔍 WALKTHROUGH**
#
# **Step 1 — Restate the law of large numbers**
#
# $$\text{Law of Large Numbers: } \lim_{n \to \infty} \bar{X}_n = E(X)$$
#
# As n grows, sample mean converges to the expected value.
#
# **Step 2 — Flip the question**
#
# "Best chance of mean far from 5" = "smallest n where randomness still dominates"
#
# This is the *opposite* of "most reliable estimate of 5" (which would be largest n).
#
# **Step 3 — Scan the options**
#
# - Options 3, 4, 5 (1,000–10,000): These are *large* samples. Law of large numbers locks them onto 5. Cross them out.
# - Options 1, 2 (10–100): These are small samples. Still noisy. But which is *smallest*?
# - Option 1 (n=10) is the smallest. **This is your answer.**
#
# **Step 4 — Verify with the data**
#
# From the sample history in the lesson:
# - Draw 1 (n=10): sample mean = 4.300 (distance from 5 = 0.700) ← **Far from 5!**
# - Draw 2 (n=50): sample mean = 5.380 (distance from 5 = 0.380) ← Closer than n=10
# - Draw 3 (n=100): sample mean = 5.025 (distance from 5 = 0.025) ← Even closer
# - Draw 4 (n=10,000): sample mean = 5.007 (distance from 5 = 0.007) ← Locked onto 5
#
# **The pattern:** As n increases, distance from 5 *decreases*. Smallest n = largest possible variation. ✅
#
# ---
#
# **💬 Why this matters**
#
# **In analytics:** When you see a surprising result (e.g., "Our conversion rate this month is 3.2%, way down from the expected 5%"), your first question should be: "How many observations?"
# - If n=10 conversions: could just be noise, don't panic
# - If n=10,000 conversions: this is a real signal, investigate immediately
#
# **In A/B testing:** Test designers must choose a sample size. Too small = noisy, can't trust results. Too large = expensive, but trustworthy. The law of large numbers is the mathematical justification for why you need large samples in production experiments.
#
# **In interviews:** A recruiter will ask: "Why do we need large samples?" Your answer: "The law of large numbers — small samples have high variation. Large samples are stable and reveal the true mean. If we only had 10 observations, we couldn't trust the result."
#
# **Trap avoided:** You now know that large samples *reduce* variation, not increase it. The direction of the law of large numbers is **toward stability**, not away from it. If you want to see large deviations, you must accept small samples and their inherent noise.
#
# **Common mistake:** Confusing "sample size" with "data quality." A large sample is *stable* (tight around the true mean), but it's not *more varied*. In fact, it's less varied. If you want variation, you need small samples.
#
# **→** *The law of large numbers explains why small samples are noisy and large samples are stable. Stability is good for estimation; noisiness is expected when you have few observations. Know which one the question is asking for.*
#
# **✅ RECAP**
# - **Law of Large Numbers:** as sample size increases, sample mean converges to expected value (becomes more stable)
# - **Corollary:** small samples have high variation; large samples have low variation
# - **When to expect far-off means:** when sample size is small (n < 100) and randomness dominates
# - **When to expect means close to E(X):** when sample size is large (n > 1,000) and variation averages out
# - **Why it matters for inference:** if we observe a surprising result, we must ask "Is this real signal or just random noise?" The answer depends heavily on sample size.
# - **Interview connection:** "Why do experiments need large samples?" Answer: "Law of large numbers — large samples reduce random variation and reveal true differences."
#
# **🔗 Connection**
# - **Lessons 1–7 (Ch2):** probability fundamentals, distributions, expected value
# - **Lesson 9 (this):** sample mean behavior under different n; intuition for law of large numbers
# - **Lesson 10:** continuous distributions (normal, uniform) — the foundation for sampling theory
# - **Lessons 11–13:** distributions in nature, standard normal, z-scores — all depend on understanding sampling variation
# - **Chapter 3–4:** hypothesis testing uses large-sample approximations based on this principle

# %% [markdown]
# #### Chapter 2 — Lesson 10: Continuous distributions *(Video / 50 XP)*
#
# **🎯 GOAL**
#
# Understand continuous distributions: infinite outcomes, probability as area (not height), and why this matters for real-world data like wait times, heights, and temperatures.
#
# ---
#
# **🔧 APPROACH**
#
# **Problem with discrete distributions:** They only handle counts (1, 2, 3...). But real data is often continuous: you can wait 5 minutes, 4.7 minutes, 4.73 minutes...
#
# **Solution:** Use a continuous line (curve) instead of bars. Probability is now the *area under the curve*, not the height of a bar.
#
# **Key mental model:**
# - Discrete: probability = bar height
# - Continuous: probability = area under curve
# - Both satisfy: total area = 1
#
# ---
#
# **💡 SOLUTION**
#
# **Running example: Bus arrival**
#
# A city bus arrives every 12 minutes. If you show up at a random time, how long do you wait?
#
# ---
#
# **Continuous Uniform Distribution**
#
# **Setup:**
# - Minimum wait: 0 minutes (arrive as bus leaves)
# - Maximum wait: 12 minutes (arrive as bus pulls in)
# - All wait times equally likely
#
# **Visualization:**
# ```
# Probability
#     |
# 1/12|________
#     |       |
#     |       |
#   0 |_______|________ wait time (minutes)
#     0       12
# ```
#
# The height is **1/12** (= 0.0833...). The width is **12 minutes**. Together: height × width = (1/12) × 12 = 1. ✅
#
# ---
#
# **Calculating Probabilities**
#
# **Rule:** P(a ≤ X ≤ b) = (b - a) / (max - min)
#
# **Example 1: P(wait between 4 and 7 minutes)?**
#
# $$P(4 \leq X \leq 7) = \frac{7 - 4}{12 - 0} = \frac{3}{12} = 0.25 = 25\%$$
#
# Interpretation: Area of the rectangle from x=4 to x=7 is 25% of the total.
#
# **Example 2: P(wait 7 minutes or less)?**
#
# $$P(X \leq 7) = \frac{7 - 0}{12 - 0} = \frac{7}{12} \approx 0.583 = 58.3\%$$
#
# Interpretation: The area from 0 to 7 is 58.3% of the total area.
#
# **Example 3: P(wait more than 7 minutes)?**
#
# Using the complement rule:
# $$P(X > 7) = 1 - P(X \leq 7) = 1 - \frac{7}{12} = \frac{5}{12} \approx 0.417 = 41.7\%$$
#
# Interpretation: The area from 7 to 12 is the remaining 41.7%.
#
# ---
#
# **Total Area Always = 1**
#
# $$\text{Area} = \text{width} \times \text{height} = 12 \times \frac{1}{12} = 1$$
#
# This holds for *all* continuous distributions, regardless of shape. The area under the entire curve represents 100% of possible outcomes. This is a fundamental property: every continuous distribution must have total area = 1.
#
# ---
#
# **Other Continuous Distribution Shapes**
#
# **1. Bimodal Distribution**
#
# Two distinct peaks → two values are most likely.
#
# **Example:** Book prices
# - Paperback books cluster around $10–15
# - Hardcover books cluster around $20–30
# - Few books priced between $15–20
#
# **Visualization:** Two humps, valley in the middle.
#
# **2. Normal Distribution (Bell Curve)**
#
# Peak in the middle, symmetrical slopes on both sides.
#
# **Examples:**
# - Human height (peak around 5'9", symmetric tails)
# - Blood pressure (peak around 120, symmetric variation)
# - Retirement age (peak around 65, symmetric variation)
# - IQ scores (peak around 100, symmetric variation)
#
# **Visualization:**
# ```
# Probability
#     |      ___
#     |     /   \
#     |    /     \
#     |   /       \
#     |__/         \__
#     |________________ value
# ```
#
# **Key difference:** Normal distribution is not uniform — some values (near the mean) are more likely than others (in the tails).
#
# ---
#
# **💬 Why this matters**
#
# **In analytics:** Most real-world measurements follow continuous distributions:
# - Customer wait times → skewed (many short, few very long)
# - Customer heights → normal (clustered around average)
# - Product prices → bimodal (budget vs. premium categories)
# - Network latency → skewed (mostly fast, occasional spikes)
#
# If you assume uniform when the data is actually normal, you'll make terrible forecasts.
#
# **In business:**
# - **Retail pricing:** Bimodal distribution reveals your two product categories. Pricing strategy differs for each.
# - **Service SLAs:** If wait times are skewed (not uniform), you need different tail planning than if they were uniform.
# - **Quality control:** If a machine produces items with normally distributed sizes, you can predict how many will fall outside specifications.
#
# **In interviews:** A recruiter will show you a distribution shape and ask: "What does this tell you about the data?"
# - Uniform: "All outcomes equally likely; no preference."
# - Bimodal: "Two distinct groups; investigate what separates them."
# - Normal: "Most data clusters around the mean; symmetric variation; predictable tail behavior."
#
# **→** *Continuous distributions model infinite outcomes using area under a curve. The shape of the curve tells you which values are common and which are rare. Always verify your distribution assumption before making predictions.*
#
# **✅ RECAP**
# - **Continuous vs. discrete:** Continuous = infinite outcomes (any real number); discrete = countable outcomes (1, 2, 3...)
# - **Probability in continuous:** Use area under curve, not bar height
# - **Total area = 1:** All continuous distributions satisfy this; it represents 100% of possible outcomes
# - **Continuous uniform:** All values equally likely; height = 1/(max - min)
# - **Calculating probability:** P(a ≤ X ≤ b) = (b - a) / (max - min)
# - **Complement rule:** P(X > a) = 1 - P(X ≤ a)
# - **Distribution shapes matter:**
#   - Uniform: flat (no preference)
#   - Bimodal: two peaks (two groups)
#   - Normal: bell curve (peak in middle, symmetric tails)
# - **Next:** Chapter 3 will dive deep into the normal distribution — the most important distribution in statistics
#
# **🔗 Connection**
# - **Lessons 1–9 (Ch2):** Discrete probability, independence, distributions as tables/histograms
# - **Lesson 10 (this):** Continuous probability, area-based thinking, shape taxonomy
# - **Lesson 11–13 (Ch2):** Deep dive into normal distribution, z-scores, standardization
# - **Chapter 3:** Key probability distributions and their properties
# - **Chapter 4:** Hypothesis testing relies on normal distribution properties for p-value calculation

# %% [markdown]
# #### Chapter 2 — Lesson 11: Discrete vs. Continuous distributions *(Exercise / 100 XP)*
#
# **🎯 GOAL**
#
# Distinguish discrete from continuous distributions by examining real-world scenarios. This trains the first critical step in any analysis: "What type of data am I looking at?"
#
# ---
#
# **🔧 APPROACH**
#
# **The classification rules:**
#
# | Dimension | Discrete Uniform | Continuous Uniform | Bimodal |
# |---|---|---|---|
# | **Data type** | Countable outcomes (1, 2, 3...) | Any value in a range (2.5, 2.53...) | Any value, but two peaks |
# | **Examples** | Raffle tickets, die rolls, card draws | Wait times, temperatures, heights | Prices (budget vs. premium), combined genders |
# | **Key signal** | Finite number of distinct values | Infinite values; can be arbitrarily precise | Two distinct clusters in the data |
#
# **Decision tree:**
# 1. Can the value be any real number? → Likely continuous
# 2. Are there only countable outcomes? → Likely discrete
# 3. Is there one peak or two peaks? → One = uniform/other; Two = bimodal
#
# ---
#
# **💡 SOLUTION**
#
# **Scenario matching task:**
#
# | Scenario | Classification | Why / Trap Explanation |
# |---|---|---|
# | **1. Ticket number of a raffle winner (1–100)** | Discrete Uniform ✅ | Finite outcomes: tickets are numbered 1, 2, 3... 100. Each equally likely. You can't have ticket 50.5. |
# | **2. Time of day a baby will be born** | Continuous Uniform ✅ | Time is continuous. Could be 3:47:23.5 AM. Any moment in the day is equally likely (birth timing is roughly uniform across the day). |
# | **3. Time you will wait for an elevator to arrive once called** | Continuous Uniform ✅ | Elevator waits are continuous (could be 2.5 seconds, 2.53 seconds...). All wait times equally likely. **Trap alert:** Your initial error selected this as Discrete Uniform. Mistake: confusing "countable in your head" with "countable in the data." Time is continuous, not discrete. |
# | **4. Distribution of heights combining adult men and adult women** | Bimodal ✅ | Men's heights cluster around 5'9"; women's heights cluster around 5'4". Two distinct peaks. |
# | **5. Outcome of drawing a playing card at random** | Discrete Uniform ✅ | 52 distinct cards. Each equally likely. Can't draw card 26.5. |
#
# **Your error progression:**
# - **First attempt:** Selected elevator wait as Discrete Uniform ❌
# - **Correction:** Recognized it as Continuous Uniform ✅
# - **Final result:** All 5 scenarios correct ✅
#
# **Root cause of the trap:** Confusing the *dimension* of the data with its *type*.
# - "Time" feels countable in your mind ("wait a few seconds"), but the actual *data* is continuous (2.47 seconds, not "2 or 3").
# - "Tickets" are countable *and* the data is discrete (ticket #50, not ticket #50.5).
#
# ---
#
# **🔍 WALKTHROUGH**
#
# **Step 1 — Identify the data dimension**
#
# Each scenario describes a measurement or outcome:
# - Ticket numbers: countable integers
# - Time: continuous real numbers
# - Heights: continuous real numbers
# - Card outcomes: countable distinct objects
#
# **Step 2 — Ask: Can there be fractional values?**
#
# - Tickets: No. You either have ticket 50 or you don't.
# - Time: Yes. You can wait 2.5 seconds or 2.537 seconds.
# - Heights: Yes. You can be 5'9.25" tall.
# - Cards: No. You either drew the Ace of Spades or you didn't.
#
# **Step 3 — Count the peaks**
#
# - Ticket, time, cards: one peak (uniform) or flat (uniform) → single peak = uniform
# - Heights (men + women combined): two peaks → bimodal
#
# **Step 4 — Classify**
#
# Combine the dimension (discrete/continuous) with the shape (uniform/bimodal):
# - Discrete + uniform → Discrete Uniform
# - Continuous + uniform → Continuous Uniform
# - Any + two peaks → Bimodal
#
# ---
#
# **💬 Why this matters**
#
# **In analytics:** Before you pick a formula or visualization, you must classify your data:
# - **Discrete Uniform:** Use a bar chart with finite x-axis labels
# - **Continuous Uniform:** Use a histogram with continuous x-axis bins
# - **Bimodal:** Investigate *why* there are two groups — it's a signal that your data contains two sub-populations
#
# **In data cleaning:** If you see a continuous variable with a discrete label (like "2", "3", "4"), you must ask: "Is this actually discrete data mislabeled as continuous, or is it continuous data rounded to integers?" The answer changes how you handle it.
#
# **In interviews:** A recruiter will describe a scenario ("We track how long customers wait in our queue") and ask: "What distribution would you expect?"
# - Your answer: "Continuous — wait times can be any real number. Likely skewed right — most customers wait briefly, some wait very long."
# - Why it matters: "If I assume uniform, I'd forecast equally for all wait times. But skewed means I need different planning for rare long waits."
#
# **Trap avoided:** You now know that "time" is continuous, even though your mind counts seconds. The *data* is what matters, not your mental model of counting.
#
# **Common mistake:** Confusing "I can count them in my head" with "the data is discrete." Time, heights, weights, temperatures — all continuous, even though you naturally count them in units (seconds, inches, pounds, degrees).
#
# **→** *Classifying data is the foundation of analysis. Ask: Can the value be any real number? If yes, it's continuous. If no, it's discrete. Then check for multiple peaks.*
#
# **✅ RECAP**
# - **Discrete distribution:** finite, countable outcomes (1, 2, 3... not 1.5)
#   - Example: raffle tickets, die rolls, card draws
#   - Discrete Uniform: all outcomes equally likely
# - **Continuous distribution:** infinite, uncountable outcomes (any real number)
#   - Example: wait times, heights, temperatures, ages
#   - Continuous Uniform: all values equally likely over a range
# - **Bimodal distribution:** two distinct peaks; reveals two sub-populations
#   - Example: combined heights (men vs. women), book prices (paperback vs. hardcover)
# - **Classification key:** Can the value be fractional/decimal? Yes = continuous; No = discrete
# - **Mistake to avoid:** Confusing "I count in units" with "the data is discrete." Time is continuous.
# - **Why it matters:** Wrong classification → wrong formula → wrong forecast
#
# **🔗 Connection**
# - **Lessons 1–10 (Ch2):** Discrete and continuous concepts, uniform distribution, area-based probability
# - **Lesson 11 (this):** Synthesis — classify real scenarios into distribution types
# - **Lesson 12:** Deep dive into the normal distribution (the most important continuous distribution)
# - **Lesson 13:** Standardization and z-scores (foundation for hypothesis testing)
# - **Chapter 3–4:** Apply these classification skills to real datasets and hypothesis tests

# %% [markdown]
# #### Chapter 2 — Lesson 12: Finding the normal distribution *(Exercise / 50 XP)*
#
# **🎯 GOAL**
#
# Identify the normal distribution by its defining visual characteristic: **symmetric bell curve**. This is the most important distribution in statistics — if you can't recognize it visually, you'll make fundamental analysis mistakes.
#
# ---
#
# **🔧 APPROACH**
#
# **Normal distribution checklist:**
# - ✅ Bell curve shape (peak in the middle)
# - ✅ Symmetric (left and right sides mirror each other)
# - ✅ Tails thin out equally on both sides
# - ❌ NOT skewed (one long tail, one short)
# - ❌ NOT bimodal (two peaks)
#
# **Key mental image:** If you fold the curve in half at the peak, the left side and right side should overlap perfectly.
#
# ---
#
# **💡 SOLUTION**
#
# **Matching task: Which plot is normal?**
#
# | Plot | Shape | Symmetry | Peak | Is Normal? | Why / Trap Explanation |
# |---|---|---|---|---|---|
# | **A** | Peak on left, long tail right | Asymmetric (skewed right) | Off-center | ❌ No | Skewed distribution. Has a peak, but not symmetric. Trap: "It has a peak, so it must be normal." Wrong. Normal requires symmetry. |
# | **B** | Bell curve, peak center | Symmetric | Centered | ✅ **Yes** | Perfect normal distribution. Peak in middle, left and right sides mirror each other. Bell shape. |
# | **C** | Very sharp peak, thin | Symmetric? | Centered | ❌ No | Too sharp, too thin. This would be a leptokurtic (very peaked) or perhaps exponential distribution, not normal. |
# | **D** | Peak on right, long tail left | Asymmetric (skewed left) | Off-center | ❌ No | Skewed distribution. Symmetric-looking at first glance, but tails are unequal. Left tail longer than right tail. |
#
# **Your attempt sequence:**
# 1. Selected A (skewed right) ❌ — Confused "has a peak" with "is normal"
# 2. Selected D (skewed left) ❌ — Got closer by looking for symmetry, but didn't recognize the asymmetry
# 3. Selected B (symmetric bell) ✅ — **Correct!** Recognized both peak and symmetry
#
# **Root cause of the trap:** You were anchoring on "peak" instead of "symmetric peak." Many distributions have peaks. The normal distribution is special because it's *symmetric around the peak*.
#
# ---
#
# **🔍 WALKTHROUGH**
#
# **Step 1 — Look for the peak**
#
# All four plots have a peak. A has one. B has one. C has one. D has one. So peaks alone don't distinguish normal.
#
# **Step 2 — Check for symmetry**
#
# Imagine folding the curve in half at the peak:
# - **A:** Left side is short and steep; right side is long and gradual. Doesn't fold onto itself. → Not symmetric
# - **B:** Left side mirrors right side perfectly. Fold test passes. → Symmetric ✅
# - **C:** Left and right look similar height-wise, but the peak is too sharp and narrow. Unusual curvature. → Not normal
# - **D:** Left tail extends far; right tail is shorter. Tails are unequal. → Not symmetric
#
# **Step 3 — Verify bell shape**
#
# Only B has the classic bell curve: smooth, flowing sides that taper symmetrically to thin tails.
#
# **Answer: B** ✅
#
# ---
#
# **💬 Why this matters**
#
# **In analytics:** The normal distribution appears everywhere in real data:
# - Heights of a population (peak around average, symmetric tails)
# - Measurement errors (peak around true value, symmetric variation)
# - Test scores (peak around average, symmetric spread)
# - Manufacturing tolerances (peak around target, symmetric deviations)
#
# If you misidentify a skewed distribution as normal, you'll:
# - Forecast the wrong tail risk (e.g., assume equal upside/downside when one dominates)
# - Choose the wrong statistics (mean is pulled by skew; median is more robust)
# - Make wrong probability calculations
#
# **In quality control:** A machine that produces items with normal size distribution has predictable defect rates. A machine producing skewed distribution reveals a problem (e.g., systematic drift one direction).
#
# **In interviews — the golden question:**
#
# Recruiter: *"Here's a histogram of customer wait times. What distribution does this look like?"*
#
# **Your three-part answer:**
# 1. *"I'd check for symmetry. Is the peak centered with equal tails on both sides?"*
# 2. *"If yes, it's likely normal. If not, I'd look for skew — is one tail longer? That suggests skewed distribution."*
# 3. *"If normal, I can use standard normal properties for forecasting. If skewed, I need to account for tail risk and use robust statistics like median."*
#
# This answer shows: visual recognition, systematic thinking, and business awareness.
#
# **Trap avoided:** You learned that "peak" ≠ "normal." Normal requires *symmetric* peak. This distinction is critical — many distributions have peaks; only one is normal.
#
# **Common mistake:** Confusing "unimodal" (one peak) with "normal." Unimodal just means one peak. Normal means one symmetric peak. Example: exponential distribution is unimodal but highly skewed — not normal.
#
# **→** *The normal distribution is defined by its symmetric bell shape. If tails are unequal, it's not normal. Recognizing this visually is the foundation for all hypothesis testing and confidence intervals you'll do later.*
#
# **✅ RECAP**
# - **Normal distribution:** bell curve with peak in center, symmetric tails
# - **Visual test:** fold the curve in half at the peak; left and right sides should overlap
# - **Symmetric:** equal probability mass on both sides of center
# - **Not normal:** skewed (one long tail, one short), bimodal (two peaks), or very sharp/flat peaked
# - **Why it matters:** normal distribution is foundation for hypothesis testing, confidence intervals, and p-values
# - **Real-world examples:** heights, errors, test scores, many natural phenomena
# - **Interview prep:** be ready to identify normal vs. skewed distributions and explain the consequences
#
# **🔗 Connection**
# - **Lessons 1–11 (Ch2):** Discrete and continuous distributions, uniform, identifying distributions
# - **Lesson 12 (this):** Normal distribution — the most important distribution
# - **Lesson 13:** Standardization and z-scores (transform any normal into standard normal)
# - **Chapter 3:** Key probability distributions (exponential, binomial, Poisson) — all compared to normal
# - **Chapter 4:** Hypothesis testing (p-values calculated using normal distribution properties)

# %% [markdown]
# #### Chapter 2 — Lesson 13: Probability with a uniform distribution *(Practice / 50 XP)*
#
# **🎯 GOAL**
#
# Calculate probabilities from a continuous uniform distribution using the area formula. This synthesizes everything from Chapter 2: distributions, continuous probability, and the area-under-curve principle.
#
# ---
#
# **🔧 APPROACH**
#
# **Formula for continuous uniform probability:**
#
# $$P(a \leq X \leq b) = \frac{b - a}{\text{max} - \text{min}}$$
#
# **Three-step process:**
# 1. Identify the window: a and b (lower and upper bounds)
# 2. Calculate the window size: b - a
# 3. Normalize by total range: divide by (max - min)
#
# **Key principle:** Probability = (window size) / (total range)
#
# ---
#
# **💡 SOLUTION**
#
# **Scenario:** Train arrives uniformly between 0–20 minutes. What's P(wait between 5 and 13 minutes)?
#
# **Calculation:**
#
# | Step | Calculation | Result |
# |---|---|---|
# | **1. Identify bounds** | a = 5, b = 13 | Window: [5, 13] |
# | **2. Window size** | b - a = 13 - 5 | 8 minutes |
# | **3. Total range** | max - min = 20 - 0 | 20 minutes |
# | **4. Probability** | (8) / (20) = 0.40 | **40%** |
#
# $$P(5 \leq X \leq 13) = \frac{13 - 5}{20 - 0} = \frac{8}{20} = \frac{2}{5} = 0.40 = 40\%$$
#
# **Your answer:** 30% ❌
#
# **Correct answer:** 40% ✅
#
# **Why you chose 30%:** You recognized the window size (8 minutes) but missed the normalization step. You may have thought "8 minutes out of some total" = "8 something," but forgot to divide by the full range (20).
#
# **Root cause of the trap:** Confusing absolute values with relative probabilities. In a uniform distribution, probability is *not* proportional to the window size alone — it's proportional to the window size *relative to the total range*.
#
# ---
#
# **🔍 WALKTHROUGH**
#
# **Step 1 — Visualize the distribution**
#
# Uniform 0–20 minutes: flat line from 0 to 20, height = 1/20 = 0.05.
#
# ```
# Probability
#     |
# 0.05|________________
#     |       |-------|  (this is our window from 5 to 13)
#   0 |_______|_______|_________
#     0       5       13        20  (minutes)
# ```
#
# **Step 2 — Identify the target rectangle**
#
# - Left edge: 5
# - Right edge: 13
# - Width: 13 - 5 = 8
# - Height: 1/20 = 0.05 (same as entire distribution)
#
# **Step 3 — Calculate area**
#
# $$\text{Area} = \text{width} \times \text{height} = 8 \times 0.05 = 0.40$$
#
# **Step 4 — Express as percentage**
#
# $$0.40 = 40\%$$
#
# **Verification using the formula:**
# $$P(5 \leq X \leq 13) = \frac{13 - 5}{20 - 0} = \frac{8}{20} = 0.40$$  ✅
#
# ---
#
# **💬 Why this matters**
#
# **In real-world analytics:**
# - **Service SLAs:** If response times are uniformly distributed 0–10 seconds, what's P(response < 3 seconds)? Answer: 3/10 = 30%. This tells you how often you'll beat your SLA.
# - **Inventory management:** If demand is uniform 100–500 units, what's P(demand 250–350)? Answer: 100/400 = 25%. This helps with stocking decisions.
# - **Project scheduling:** If a task can take anywhere from 5–15 hours, what's P(complete in 5–8 hours)? Answer: 3/10 = 30%. This affects timeline planning.
#
# **In interviews — the calculation question:**
#
# Recruiter: *"We have uniform wait times 0–30 minutes. What's the probability a customer waits between 10 and 25 minutes?"*
#
# **Your answer:**
# $$P(10 \leq X \leq 25) = \frac{25 - 10}{30 - 0} = \frac{15}{30} = 0.50 = 50\%$$
#
# **Trap avoided:** You learned that probability requires normalization. It's not just "window size" — it's "window size relative to total range."
#
# **Common mistake:** Forgetting the denominator. You calculated 8 (the window) but didn't divide by 20 (the total). Result: 8 alone doesn't tell you the probability; 8/20 does.
#
# **→** *Continuous uniform probability = (window size) / (total range). Always normalize. This is the foundation for understanding how probability scales with data ranges.*
#
# **✅ RECAP**
# - **Continuous uniform formula:** P(a ≤ X ≤ b) = (b - a) / (max - min)
# - **Key insight:** Probability is the *proportion* of the total range, not the absolute size
# - **Three-step process:** identify bounds → calculate window → normalize by range
# - **Real-world:** used for wait times, demand, duration, and any uniformly distributed continuous variable
#
# ---
#
# ## 📊 CHAPTER 2 MASTERY STATEMENT
#
# **Chapter 2 built one complete mental model: probability as area.**
#
# Starting from raw probability (Chapter 2, L1–3), through independence and conditional reasoning (L4–6), to discrete distributions (L7–9), and finally continuous distributions with area-based calculation (L10–13) — every lesson was a layer of the same idea: *how to assign a number to uncertainty.*
#
# **What this chapter established:**
# - Probability is always a proportion — of outcomes, of area, of a range
# - Distribution shape is data in itself — flat, peaked, skewed, bimodal each tell a different story
# - The law of large numbers determines when a result is signal vs. noise
# - Conditional probability changes the reference frame — the denominator is always the condition
#
# **The key mental shift:** From "what is the probability of X?" (a calculation) to "what does the shape of this distribution tell me?" (a judgment). Chapter 3 builds on that judgment with named distributions — binomial, Poisson, and the normal distribution in depth.
#
# ---
#
# **Chapter 2 complete: 750 / 750 XP ✅**
#
# | Chapter | Lessons | XP | Status |
# |---|---|---|---|
# | Ch1: Summary Statistics | 12/12 | 750/750 | ✅ |
# | Ch2: Probability & Distributions | 13/13 | 750/750 | ✅ |
# | Ch3: More Distributions & CLT | 3/16 | 150/1000 | 🔄 |
# | Ch4: Hypothesis Testing & Correlation | 0/15 | 0/950 | ⏳ |
# | **Total** | **28/56** | **1,650/3,450** | **47.8%** |

# %% [markdown]
# #### Chapter 3 — Lesson 1: The Binomial Distribution *(Video / 50 XP)*
#
# > 🎬 [Watch on DataCamp](https://campus.datacamp.com/courses/introduction-to-statistics/more-distributions-and-the-central-limit-theorem-79b572d6-d267-482b-af89-a47fd6df183c?ex=1) *(requires login)*
#
# ---
#
# **🎯 GOAL — What is this lesson about?**
#
# The binomial distribution models the probability of getting exactly k successes in n independent binary events (where each event has the same probability p of success). You'll learn when to use it, how to parameterize it, and how to calculate probabilities from binomial outcomes.
#
# ---
#
# **The Binomial Distribution: Binary Outcomes, Repeated**
#
# A **binary outcome** has exactly two possible results: success/failure, heads/tails, yes/no, win/loss. When you repeat a binary event multiple times independently, the number of successes follows a **binomial distribution**.
#
# The binomial distribution is described by two parameters:
# - **n** = total number of independent events (e.g., number of coin flips)
# - **p** = probability of success on each event (e.g., 0.5 for a fair coin)
#
# **Example: 10 coin flips**
# - n = 10, p = 0.5
# - Most likely outcome: 5 heads (the peak)
# - Less likely: 0 heads or 10 heads (the tails)
# - This is a **discrete distribution** because you count successes in whole numbers (0, 1, 2, ..., n)
#
# **Calculating probabilities from a binomial distribution**
#
# With a histogram showing a binomial distribution, you calculate probabilities by summing the bars:
#
# - **P(X ≤ 7)** (7 or fewer heads): Add up all bar heights from 0 to 7 heads → 94.5%
# - **P(X ≥ 8)** (8 or more heads): Either count bars 8–10, or subtract → 1 − 0.945 = 5.5%
#
# This is the same principle as continuous uniform probability, but here you're summing discrete outcomes instead of calculating area.
#
# **Expected value: How many successes on average?**
#
# The expected value (mean) of a binomial distribution is:
# $$E(X) = n \times p$$
#
# For 10 coin flips: $E(X) = 10 \times 0.5 = 5$ heads on average.
#
# If you know n and the expected value but not p, solve for p:
# $$p = \frac{E(X)}{n}$$
#
# ---
#
# **💡 Why this matters**
#
# Binomial distributions model real business scenarios: clinical trials (drug works/doesn't work), manufacturing quality (defective/non-defective), conversions (user converts/doesn't convert), fraud detection (fraudulent/legitimate transaction). Whenever you need to predict the probability of k successes in a fixed number of independent trials, binomial is your model.
#
# **Interview readiness:**
#
# Recruiter: *"We have a drug trial with 100 patients and a success rate of 60%. What's the expected number of successful treatments?"*
#
# **Your answer:** $E(X) = 100 \times 0.6 = 60$ patients. We'd expect 60 successful treatments out of 100.
#
# **Why it matters:** Binomial distributions let you forecast outcomes and set realistic targets. Instead of guessing "probably lots will work," you can say precisely: "On average, 60."
#
# **→** *Binary outcomes repeated independently always follow a binomial distribution. Learn to spot the pattern: fixed n, constant p, counting successes.*
#
# **✅ RECAP**
# - **Binomial distribution:** models the number of successes in n independent binary trials
# - **Two parameters:** n (number of events), p (probability of success per event)
# - **Discrete distribution:** outcomes are whole numbers (0, 1, 2, ..., n)
# - **Expected value:** E(X) = n × p; tells you the average number of successes
# - **Probability calculation:** sum the bar heights for your range (e.g., P(X ≤ 7) = sum of heights 0–7)
# - **Complement rule:** P(X ≥ 8) = 1 − P(X ≤ 7); saves calculation when you want the tail
# - **Independence requirement:** each trial must be independent; if sampling without replacement, probabilities change and binomial doesn't apply
# - **Real applications:** clinical trials, manufacturing defects, conversion rates, fraud detection, sports betting
#
# **🔗 Connection**
# - **Chapter 2 foundation:** Binomial is built on binary probability (heads/tails, success/failure)
# - **Chapter 3 progression:** Poisson (events over time), Normal (most common shape)
# - **Interview pattern:** This is the first "named distribution" you can apply to real problems; next lessons add more tools to your toolkit

# %% [markdown]
# #### Chapter 3 — Lesson 2: Recognizing a Binomial Distribution *(Exercise / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
#
# Can you identify which real-world scenario describes a binomial distribution? The key is spotting: binary outcomes (success/failure), independent repeats, and fixed probability.
#
# ---
#
# **📋 Scenario**
#
# Four scenarios are provided. Each describes a probability situation. Your task: identify which one is a binomial distribution.
#
# **Task:** Choose the scenario that describes a binomial distribution based on the type of data described.
#
# ---
#
# **✅ Solution**
#
# | Option | Scenario | Verdict | Why |
# |--------|----------|---------|-----|
# | **Option 1** | The probability of a train arriving in under 10 minutes | ❌ Wrong | This is about a single event (one train's arrival time), not repeated binary trials. It's a continuous distribution question (arrival time measured in minutes), not a count of successes in independent trials. |
# | **Option 2** | The probability of a man's height being 175 centimeters or less | ❌ Wrong | Height is a continuous variable (measured on an infinite scale). This describes a normal or continuous distribution question, not a binary outcome repeated independently. |
# | **Option 3** | **The probability of matching four numbers in the lottery** | ✅ **Correct** | Each number is a binary outcome: match or don't match. You repeat this independently for each of the four targeted numbers. n = 4 (numbers to match), p = probability of matching each number. This counts successes (matches) across independent trials. |
# | **Option 4** | The probability of the temperature being more than 80 degrees Celsius | ❌ Wrong | Temperature is a continuous variable. This is asking about a range of a continuous measure, not counting binary successes in independent trials. |
#
# **Why Option 3 is binomial:**
# - **Binary outcome:** For each number, either it matches your target or it doesn't (success/failure)
# - **Repeated independently:** You check this for each of the four numbers separately
# - **Fixed probability:** Each number has the same probability of matching (assuming fair lottery)
# - **Counting successes:** The distribution describes how many numbers (0, 1, 2, 3, or 4) you match
#
# **Common trap avoided:**
# Options 1, 2, and 4 are all **continuous distribution questions** (arrival time, height, temperature). They ask about ranges of a continuous variable, not about counting successes in binary trials. The confusion: "probability of X" sounds similar whether X is "arrival time < 10 min" or "matching a number." The difference is hidden in the data type.
#
# **→** *Binomial = binary outcomes repeated independently. Continuous = a measured variable (time, height, temperature) in a range. Learn to distinguish: Count of successes vs. Measurement of magnitude.*
#
# **💡 Why this matters**
#
# In real business, you constantly classify problems: Is this binomial? Is this normal? Is this Poisson? The misclassification wastes time and produces wrong forecasts. Lottery systems, quality control (defective/non-defective parts), customer acquisition (converted/not converted), and clinical trials (improved/not improved) are all binomial. Train arrivals, customer age, revenue, and processing time are not. This exercise trains your pattern-recognition muscle.
#
# **Interview readiness:**
#
# Recruiter: *"We have a customer database. How would you model the probability of each customer purchasing in the next month?"*
#
# **Your answer:** "That's a binomial distribution — each customer either purchases (success) or doesn't (failure) in a fixed time period. If we assume independent purchasing decisions and a constant conversion rate p, then with n customers, the number of purchases follows a binomial distribution with parameters n and p."
#
# **✅ RECAP**
# - **Binomial identifies:** binary outcomes (yes/no, success/failure, match/no-match)
# - **Not binomial:** continuous variables (time, height, temperature, revenue, distance)
# - **Key distinction:** counting successes vs. measuring a continuous range
# - **Independence matters:** each trial must not affect the next
# - **Real pattern:** lottery numbers, defects, conversions, clinical outcomes, pass/fail decisions
# - **Interview signal:** You can hear a problem and instantly know which distribution model to apply
#
# **🔗 Connection**
# - **Lesson 1 foundation:** Binomial parameters (n, p) and expected value
# - **This lesson:** Real-world pattern matching to identify when binomial applies
# - **Next lessons:** Poisson (events over time), Normal (continuous measurements)

# %% [markdown]
# #### Chapter 3 — Lesson 3: How Probability Affects the Binomial Distribution *(Exercise / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
#
# Can you read a binomial distribution histogram and understand how the probability parameter (p) shifts the shape? Higher p pushes the peak to the right; lower p pushes it to the left.
#
# ---
#
# **📋 Scenario**
#
# Three sales people (George, Izzy, James) each have different probabilities of closing a sale. The histograms show their binomial distributions: probability of closing k sales per week (where n = 12 attempts).
#
# **Task:** Which sales person has the highest probability of closing 9 or more sales per week?
#
# ---
#
# **✅ Solution**
#
# | Person | p (Probability) | Peak (Expected Value) | P(9+ sales) | Verdict | Why |
# |--------|-----------------|----------------------|------------|---------|-----|
# | **George** | Low-medium | ~4 sales | Low (left tail) | ❌ Wrong | George's peak is around 4 sales. The distribution is left-skewed; bars at 9+ are very small. |
# | **Izzy** | Medium | ~6 sales | Medium (middle) | ❌ Wrong | Izzy's peak is around 6 sales, centered. The probability at 9+ is moderate but not highest. You chose this on attempt 2, confusing "balanced shape" with "high tail probability". |
# | **James** | High | ~9 sales | High (right tail) | ✅ **Correct** | James's peak is around 9 sales. The distribution is right-skewed; bars at 9+ are the tallest. This is where the peak is, so probability of 9+ is highest. |
#
# **Why this matters — reading binomial histograms:**
#
# The binomial distribution's **shape depends on p**:
# - **p = 0.3 (low):** peak moves LEFT → most likely outcomes are 0–5 successes
# - **p = 0.5 (medium):** peak moves to CENTER → most likely outcomes are around 6 successes
# - **p = 0.75 (high):** peak moves RIGHT → most likely outcomes are around 9–10 successes
#
# **Expected value calculation:** $E(X) = n \times p = 12 \times p$
# - George: $12 \times 0.33 ≈ 4$ (expected ~4 sales)
# - Izzy: $12 \times 0.5 = 6$ (expected ~6 sales)
# - James: $12 \times 0.75 = 9$ (expected ~9 sales)
#
# The peak of the histogram sits at the expected value. To find "9 or more," you look at the tail starting at 9 — that's where James's peak is.
#
# **Your error progression:**
#
# 1. **Attempt 1 — George (❌):** You selected the leftmost person
#    - **Trap:** Misread the peak location; thought "tallest bar at position 4" meant something different
#    - **Root cause:** Didn't align the x-axis numbers with the histogram peak
#
# 2. **Attempt 2 — Izzy (❌):** You selected the middle person
#    - **Trap:** Confused "symmetric/balanced distribution" with "high right tail"
#    - **Root cause:** Symmetric doesn't mean high at 9+; it means equal tails on both sides
#    - **Specifics:** Izzy's distribution is symmetric around 6, so P(9+) and P(0–3) are equal, neither is "high"
#
# 3. **Attempt 3 — James (✅):** Correct
#    - **Insight:** The peak IS the expected value; if p is high, the expected value shifts right, and that's where 9+ lives
#
# **Common mistake — Distribution shape confusion:**
# You can have:
# - **Symmetric but not high on the right** (Izzy at p=0.5)
# - **Skewed right and high on the right** (James at p=0.75)
# - **Skewed left and low on the right** (George at p=0.33)
#
# The trap: "Looks balanced" ≠ "High probability at 9+". You need to match the question to the tail.
#
# **→** *Binomial shape follows p: peak location = n × p. To answer "probability of k or more," find where k sits relative to the peak. If k is at or right of the peak, that person has the high probability.*
#
# **💡 Why this matters**
#
# In sales forecasting, understanding how individual probabilities (closing rates) affect outcome distributions is crucial. A sales rep with 33% close rate (George) will rarely close 9+ in 12 attempts. One with 75% close rate (James) will frequently close 9+. This lesson trains you to spot: "Given p, what outcome is likely?" This is the inverse of hypothesis testing: "Given an outcome, what was the probability?"
#
# **Interview readiness:**
#
# Recruiter: *"We have three customer segments with conversion rates 30%, 50%, and 75%. Each segment gets 20 emails. Which segment will convert 15+ customers most often?"*
#
# **Your answer:** "The 75% segment. Because expected value = 20 × 0.75 = 15, the peak is at 15+. That segment's distribution is right-skewed with high probability in that tail."
#
# **✅ RECAP**
# - **p controls shape:** low p → peak left, medium p → peak center, high p → peak right
# - **Expected value:** E(X) = n × p marks the peak location
# - **Reading histograms:** match the question's threshold (9+) to where the peak and tail live
# - **Tail probability:** If your question asks for "k or more" and k is near/right of the peak, that's high probability
# - **Inverse thinking:** Low p → outcomes cluster left → asking for 9+ gives low probability; High p → outcomes cluster right → asking for 9+ gives high probability
# - **Real pattern:** Higher close rates → higher expected value → right-shifted distribution → higher probability of closing many
#
# **🔗 Connection**
# - **Lesson 1:** Binomial parameters n and p
# - **Lesson 2:** Identifying when binomial applies
# - **This lesson:** Understanding how p affects the distribution shape
# - **Next lesson:** Identifying specific values of n and p from histograms

# %% [markdown]
# #### Chapter 3 — Lesson 4: Identifying n and p from Binomial Histograms *(Exercise / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
#
# Can you identify the parameters n and p from a binomial distribution histogram? Specifically: recognizing that n is the range of possible outcomes (x-axis), and p is derived from the expected value (peak location).
#
# ---
#
# **📋 Scenario**
#
# James is a sales person with a certain close rate. His histogram shows the probability distribution of sales per week. The x-axis shows "Number of sales per week" (ranging from 1 to 12). The peak is at 8 sales, with highest probability ~0.23.
#
# **Task:** Based on the histogram, identify n and p for James's binomial distribution.
#
# ---
#
# **✅ Solution**
#
# | Option | n | p | Verdict | Why |
# |--------|---|---|---------|-----|
# | **Option 1** | 8 | 12 | ❌ Wrong | This is backwards. 8 is the mode (peak of histogram), not n. And 12 cannot be a probability (p must be between 0 and 1). |
# | **Option 2** | 12 | 0.23 | ❌ Wrong | 0.23 is the y-axis value (probability of getting *exactly* 8 sales), not the probability of success on a single trial. |
# | **Option 3** | 8 | 0.23 | ❌ Wrong | 8 is the peak, not n. And 0.23 is the probability mass at that peak, not p. |
# | **Option 4** | **12** | **0.67** | ✅ **Correct** | n = 12 (the range of x-axis: sales from 1 to 12 attempts per week). Expected value = 12 × 0.67 ≈ 8 (the peak). This is the correct match. |
#
# **Reading the histogram to identify parameters:**
#
# 1. **Find n (number of trials):** Look at the x-axis range. James can make 1 to 12 sales attempts per week → **n = 12**
#
# 2. **Find p (probability of success per trial):** Use the peak location (expected value).
#    - Mode (highest bar) is at 8 sales
#    - Expected value formula: $E(X) = n \times p$
#    - Solve for p: $8 = 12 \times p$ → $p = 8/12 ≈ 0.67$
#    - **p ≈ 0.67**
#
# 3. **Verify:** Check that peak location = n × p = 12 × 0.67 ≈ 8 ✓
#
# **Your error progression:**
#
# 1. **Attempt 1 — Option 1 (❌):** You selected n = 8, p = 12
#    - **Trap:** Confused "mode" (peak value on x-axis) with "n" (total number of trials)
#    - **Root cause:** You saw 8 as the "most important" number because it's the peak, so you made it n
#    - **Critical mistake:** Made p = 12, which is impossible (probabilities must be ≤ 1)
#    - **Specifics:** The range of the x-axis (1–12) tells you n = 12, not the peak location
#
# **Common mistake — Confusing mode with n:**
#
# | Concept | What it is | How you find it | Common error |
# |---------|-----------|-----------------|--------------|
# | **n** | Number of trials/attempts | Look at x-axis range (min to max) | Thinking n is the *mode* (peak value) |
# | **p** | Probability of success per trial | Use peak location = n × p; solve for p | Thinking p is the *probability shown on y-axis* (that's P(X=k)) |
# | **Mode** | Most likely outcome (peak) | Look at tallest bar on histogram | Treating mode as one of the parameters |
#
# The trap: All three are numbers on the histogram, but they mean different things. The peak (mode = 8) looks important, so you assigned it to n. But n is never the peak — n is the *range*.
#
# **→** *When identifying parameters from a histogram: n is the range of the x-axis, p is derived from where the peak sits relative to that range. The peak itself is not a parameter.*
#
# **💡 Why this matters**
#
# In data analysis, you'll encounter binomial distributions and need to extract parameters fast. A model with n = 8 vs. n = 12 predicts fundamentally different success rates. If you mix up mode and n, your forecasts will be off by orders of magnitude. This lesson trains your pattern recognition: x-axis tells you n; peak tells you p.
#
# **Interview readiness:**
#
# Recruiter: *"We have customer conversion data. The histogram shows peaks around 45 conversions per 100 visits. How would you identify n and p?"*
#
# **Your answer:** "n is 100 — that's the number of visits (x-axis range). The peak at 45 suggests expected value = 45, so p = 45/100 = 0.45. I'm not confusing the peak with n; n is always the range."
#
# **✅ RECAP**
# - **n = x-axis range:** Total number of trials or attempts (e.g., 1 to 12 sales attempts)
# - **p = derived from peak:** Once you know n and the expected value (peak), calculate p = E(X) / n
# - **Mode ≠ n:** The peak of the distribution is the most likely outcome, not the number of trials
# - **Expected value = n × p:** This formula tells you where the peak will be; use it to solve for p
# - **Reading order:** Range first (n) → Peak second (use it to find p) → Never confuse the three
# - **Real pattern:** Given any histogram, identify the parameter range before identifying the center
#
# **🔗 Connection**
# - **Lesson 1:** Binomial parameters n and p defined
# - **Lesson 2:** Identifying when binomial applies (real-world scenarios)
# - **Lesson 3:** Understanding how p affects the histogram shape
# - **This lesson:** Reverse-engineering parameters from a histogram
# - **Next lessons:** Poisson distribution, normal approximation to binomial

# %% [markdown]
# #### Chapter 3 — Lesson 5: The Normal Distribution *(Video / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this lesson teach?**
#
# Understand the normal distribution: the continuous probability distribution that appears everywhere in nature and statistics. You'll learn its defining properties, how to read it, and why it's essential for statistical inference.
#
# ---
#
# **📋 Key Concepts from Video**
#
# **What is the normal distribution?**
#
# The normal distribution is a continuous probability distribution shaped like a bell curve. It's one of the most important distributions in statistics because:
# 1. Real-world data often follows this shape (heights, test scores, household income)
# 2. Many statistical tests (hypothesis testing, confidence intervals) assume normal distribution
# 3. It's completely defined by just two parameters: mean (μ) and standard deviation (σ)
#
# **Four defining properties:**
#
# ```
# Normal Distribution Shape
# ├── 1. Symmetrical
# │   └── Left side mirrors right side perfectly
# ├── 2. Area under curve = 1
# │   └── Represents 100% of probability
# ├── 3. Never hits zero
# │   └── Tails extend infinitely (very low probability at extremes)
# └── 4. Described by mean (μ) and standard deviation (σ)
#     └── Different μ or σ shifts/stretches the curve
# ```
#
# **The 68-95-99.7 Empirical Rule** (critical for interview readiness):
#
# | Range | Percentage of Data | What This Means |
# |-------|-------------------|-----------------|
# | Within 1 SD of mean (μ ± σ) | 68% | Most values cluster near center |
# | Within 2 SD of mean (μ ± 2σ) | 95% | Almost all data falls here |
# | Within 3 SD of mean (μ ± 3σ) | 99.7% | Virtually everything is captured |
#
# **Intuition:** If a value is 3+ standard deviations away from the mean, it's extremely rare (< 0.3% chance). This is how you spot outliers.
#
# ---
#
# **Describing Distributions: Skewness & Kurtosis**
#
# **Skewness — direction of the tail:**
#
# ```
# Skewness
# ├── Left-skewed (Negative Skew)
# │   ├── Shape: peaks RIGHT, tail points LEFT
# │   ├── Meaning: Some extreme LOW values pull left
# │   └── Example: Test scores (ceiling effect; most pass, few fail badly)
# ├── Symmetric (No Skew)
# │   ├── Shape: bell curve, balanced both sides
# │   ├── Meaning: Equal distribution around mean
# │   └── Example: Height, IQ, measurement errors
# └── Right-skewed (Positive Skew)
#     ├── Shape: peaks LEFT, tail points RIGHT
#     ├── Meaning: Some extreme HIGH values pull right
#     └── Example: Household income, wealth, wait times
# ```
#
# **Kurtosis — sharpness of the peak:**
#
# | Type | Peak | Tails | What It Means | Visual |
# |------|------|-------|--------------|--------|
# | **Leptokurtic** (positive kurtosis) | Sharp, high | Thin | Extreme values more likely than normal; concentrated center | Red curve (peaked) |
# | **Mesokurtic** (normal kurtosis) | Moderate | Moderate | This IS the normal distribution | Blue curve (reference) |
# | **Platykurtic** (negative kurtosis) | Flat, low | Fat | Extreme values less likely; flatter distribution | Green curve (flat) |
#
# **Plain language:** Leptokurtic = "pointy peak, thin tails" (outliers rare). Platykurtic = "flat peak, fat tails" (outliers more common). Mesokurtic = normal.
#
# ---
#
# **Why the Normal Distribution Matters in Business**
#
# **1. Real-world prevalence:**
# - UK school exam pass rates follow normal distribution → predict regional performance
# - Customer wait times, processing times → forecast service quality
# - Product weight, dimensions → quality control tolerances
# - Employee salaries (roughly) → compensation benchmarking
#
# **2. Hypothesis testing requirement:**
# Many statistical tests (t-tests, ANOVA, linear regression) assume data is normally distributed. If your data violates this assumption, your conclusions may be wrong.
#
# **3. Predictability:**
# Because you know the 68-95-99.7 rule, you can instantly answer: "What % of our data falls within these bounds?" without calculating.
#
# **→** *The normal distribution is the shape of reality. Learn to spot it, and you can predict, test, and communicate with confidence.*
#
# **Interview readiness:**
#
# Recruiter: *"We observe customer satisfaction scores in a dataset. They follow a normal distribution with mean 7.5 and SD 1.2. How many customers scored between 6.3 and 8.7?"*
#
# **Your answer:** "That's mean ± 1 SD (6.3 = 7.5 − 1.2; 8.7 = 7.5 + 1.2). By the 68-95-99.7 rule, 68% of customers fall in that range. So approximately 68% scored between 6.3 and 8.7."
#
# ---
#
# **✅ RECAP**
# - **Normal distribution** = continuous, bell-shaped, symmetric, described by mean and SD
# - **68-95-99.7 rule** = instantly identify what % of data falls in any range (1, 2, or 3 SD from mean)
# - **Skewness** = direction of the tail (left/negative, none, right/positive)
# - **Kurtosis** = sharpness of peak (leptokurtic/pointy, mesokurtic/normal, platykurtic/flat)
# - **Why it matters** = real-world data follows normal distribution; required for most statistical tests
# - **Recognizing it** = look for symmetric bell shape; 68% in 1 SD tells you it's normal
# - **Business signal** = understanding normal distribution separates analysts from guessers
#
# **🔗 Connection**
# - **Chapter 2 (Discrete distributions):** Binomial, geometric — for counting successes
# - **This lesson (Continuous distributions):** Normal distribution — for measured values (height, time, score)
# - **Next lessons:** Other continuous distributions; Central Limit Theorem connects binomial → normal
# - **Later (Ch4):** Hypothesis testing uses normal distribution assumption

# %% [markdown]
# #### Chapter 3 — Lesson 6: Recognizing the Normal Distribution *(Exercise / 100 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
#
# Can you visually identify a normal distribution among multiple histograms? And critically — can you recognize which one is NOT normal by spotting skewness or asymmetry?
#
# ---
#
# **📋 Scenario**
#
# Four plots show the distribution of GCSE exam pass rates (percentage of schools achieving 9-5 grades) across different student ethnicities in the United Kingdom.
#
# **Task:** Identify which of these four plots does NOT represent a normal distribution.
#
# ---
#
# **✅ Solution**
#
# | Plot | Shape | Symmetry | Verdict | Why |
# |------|-------|----------|---------|-----|
# | **Plot A** | Bell curve | Symmetric | ✅ Normal | Peak in center; equal tails on both sides; matches 68-95-99.7 rule pattern |
# | **Plot B** | Bell curve | Symmetric | ✅ Normal | Peak in center; balanced left and right; textbook normal shape |
# | **Plot C** | Peak LEFT, tail RIGHT | Right-skewed | ❌ **NOT Normal** | This is positively skewed — peak on left, tail extends to the right. Violates symmetry requirement. |
# | **Plot D** | Bell curve | Symmetric | ✅ Normal | Peak in center; symmetric tails; normal distribution |
#
# **The correct answer: Plot C** — it is NOT a normal distribution because it is right-skewed.
#
# **Why the others ARE normal:**
# - **Plots A, B, D:** All show symmetric bell curves, centred around a single peak
# - **Symmetry test:** If you folded each plot down the middle, left and right sides would match
# - **Normal distribution requirements:** Symmetric ✓, Bell-shaped ✓, Single peak ✓
#
# **Why Plot C is NOT normal:**
# - **Skewness:** Peak is on the LEFT (around 50%); tail extends to the RIGHT (toward 100%)
# - **Symmetry fails:** Left side of the peak is steep; right side is gradual
# - **Interpretation:** More schools achieve LOWER pass rates; fewer achieve higher pass rates
# - **Real-world meaning:** This ethnic group shows lower academic outcomes on average (left peak) with some schools doing better (right tail)
#
# ---
#
# **Your error progression:**
#
# 1. **Attempt 1 — Plot A (❌):**
#    - **Trap:** Selected a normal-looking plot instead of an abnormal one
#    - **Root cause:** Misread the question — you were looking for "which IS normal" instead of "which is NOT"
#
# 2. **Attempt 2 — Plot D (❌):**
#    - **Same trap:** Plot D is also normal (symmetric bell curve)
#    - **Indication:** The question's negation ("does NOT") wasn't anchoring your search
#
# 3. **Attempt 3 — Plot C (...incorrect guidance):**
#    - **Feedback received:** "If we drew a curved line across this distribution, it would resemble a bell shape. Please try again!"
#    - **But:** Plot C is clearly NOT a bell shape; it's right-skewed. This feedback was misleading.
#    - **Your reading:** You reconsidered Plot C when the feedback suggested it WAS normal
#
# 4. **Attempt 4 — Plot B (❌):**
#    - **Another normal plot:** By this point, you'd checked all three "bell-shaped" candidates
#    - **Pattern:** You needed to stop looking for bell shapes and START looking for what breaks the pattern
#
# **Common mistake — Negation trap (NOT vs. IS):**
#
# This is a **classic reading comprehension error** in quantitative exercises:
#
# | Question type | Your instinct | What you need to do |
# |---------------|---------------|-------------------|
# | "Which IS normal?" | Look for bell shape ✓ | Select one |
# | "Which is NOT normal?" | Also look for bell shape (WRONG) | Ignore bell shapes; find the OUTLIER |
# | "Does this follow X?" | Verify X properties | Yes/No decision |
# | "Does this NOT follow X?" | Still verify X properties (WRONG) | Verify properties of NOT-X instead |
#
# **The trap:** Your brain wants to find what matches the category (normal), so it keeps searching for matching patterns. But when the question adds "NOT," you must flip your search strategy — now you're looking for the EXCEPTION, not the PATTERN.
#
# **Verification technique (prevents this trap):**
# - Read the question twice
# - First time: Identify what you're looking for
# - Second time: Check if there's a negation ("NOT", "does not", "which is not", "which doesn't")
# - If negation exists: Flip your strategy — now eliminate the obvious, find the odd one out
#
# **→** *Negation in questions is invisible until you look for it. Always read the question twice. The second read catches the "NOT" that changes everything.*
#
# **💡 Why this matters**
#
# In real analysis and business communication, negation appears everywhere:
# - "Which metric does NOT correlate with sales?" (Find the exception)
# - "Which customer segment is NOT responding to our campaign?" (Identify the outlier)
# - "Which hypothesis is NOT supported by the data?" (Eliminate the confirmed ones)
#
# Misreading negation costs time, accuracy, and credibility. This exercise trains the habit: **Read twice. Catch the negation. Flip your strategy.**
#
# **Interview readiness:**
#
# Recruiter: *"We have five customer segments. Four follow our expected growth model. Which one does NOT?"*
#
# **Your answer:** "I'll look for the exception, not the pattern. Four should show [property A]. I'm searching for the one that breaks it. Looking at the data... [Segment 3] shows [opposite property], so that's the one that doesn't fit the model."
#
# **✅ RECAP**
# - **Normal distribution recognition:** Symmetric bell curve; single center peak; equal tails
# - **Right-skewed (positive skew):** Peak LEFT, tail RIGHT; lower average, some high outliers
# - **Left-skewed (negative skew):** Peak RIGHT, tail LEFT; higher average, some low outliers
# - **Negation trap:** "NOT normal" requires you to find the EXCEPTION, not the pattern
# - **Reading strategy:** Read the question twice; second read catches "NOT", "does not", "which is not"
# - **Flip your logic:** If question has negation, search for the odd one out, not the matching ones
# - **Real pattern:** GCSE data shows right-skewed distribution = achievement gap; some schools excel, most lag
#
# **🔗 Connection**
# - **Lesson 5:** Normal distribution properties and 68-95-99.7 rule
# - **This lesson:** Recognizing normal vs. non-normal in real data
# - **Next lessons:** Other continuous distributions; when normal approximation applies
# - **Chapter 4:** Hypothesis testing assumes normality — identifying skew matters

# %% [markdown]
# #### Chapter 3 — Lesson 7: What Makes the Normal Distribution Special? *(Practice / 100 XP)*
#
# ---
#
# **🎯 GOAL — What does this practice test?**
#
# Can you distinguish between properties that are **unique to the normal distribution** vs. properties that apply to **all probability distributions**? This tests your conceptual mastery of what makes normal special.
#
# ---
#
# **📋 Scenario**
#
# The normal distribution has several unique properties. However, some properties apply to ALL probability distributions, not just normal.
#
# **Task:** Classify six facts into two categories:
# - **Normal Distribution** (properties unique to normal only)
# - **All distributions** (properties that apply to every probability distribution)
#
# ---
#
# **✅ Solution**
#
# | Property | Category | Why |
# |----------|----------|-----|
# | **Symmetrical** | Normal Distribution | Only normal is symmetric. Binomial can be skewed; Poisson can be skewed; uniform is rectangular. |
# | **Completely defined by just the mean and standard deviation** | Normal Distribution | Only normal needs just two parameters. Binomial needs n and p; Poisson needs λ; Uniform needs min and max. |
# | **Required for many statistical tests to be performed** | Normal Distribution | Most statistical tests (t-tests, ANOVA, linear regression) assume normality. Other distributions don't have this requirement. |
# | **Probabilities of specific events occurring can be calculated using the area under the curve** | All distributions | Every probability distribution's total area under the curve equals 1. Area = probability. |
# | **Displays the probability of possible outcomes for numeric values** | All distributions | This is the definition of any probability distribution. |
# | **The total area of the distribution equals one** | All distributions | This is a fundamental rule: all probability distributions have total area = 1 (representing 100% probability). |
#
# **The distinction:**
#
# ```
# What Makes Normal Special
# ├── Normal Distribution (unique properties)
# │   ├── Symmetrical shape (bell curve)
# │   ├── Defined by only μ and σ (any two parameters = different normal)
# │   └── Required assumption for many statistical tests
# │
# └── All Distributions (universal properties)
#     ├── Area under curve = total probability
#     ├── Used to display outcomes for numeric values
#     └── Area between two points = probability in that range
# ```
#
# **Why you got this right (first try):**
#
# You recognized the **logical structure**:
# - **Unique properties** are *defining characteristics* — things that distinguish normal from all others
# - **Universal properties** are *foundational rules* — things that are true for binomial, uniform, Poisson, exponential, everything
#
# **Critical distinction:**
# - "Symmetrical" = normal-specific (you can see it visually)
# - "Area under curve" = universal rule (applies to every distribution)
# - "Defined by mean and SD" = normal-specific (other distributions have different parameters)
# - "Total area = 1" = universal rule (probability axiom)
#
# ---
#
# **💡 Why this matters**
#
# In statistical work, you constantly ask: "Can I use this test on my data?" The answer depends on whether your data follows a **normal distribution**. If it does, you can use parametric tests (t-test, ANOVA). If it doesn't, you use non-parametric tests.
#
# This lesson trains pattern recognition: What properties distinguish normal from everything else? Answer that, and you can instantly identify when normal is required.
#
# **Interview readiness:**
#
# Recruiter: *"Our sales data is right-skewed. Can we use a t-test to compare means across regions?"*
#
# **Your answer:** "No, because t-tests require normally distributed data. Our data violates the symmetry requirement. We'd need to either transform the data, use a non-parametric test like the Mann-Whitney U, or work with a larger sample if the Central Limit Theorem applies."
#
# **✅ RECAP**
# - **Normal-specific properties:** Symmetrical, defined by μ and σ, required for many statistical tests
# - **Universal properties:** Area under curve = probability, all distributions display outcomes, total area = 1
# - **Why the distinction matters:** Tells you when you can use normal-based statistical tests
# - **Pattern:** Unique properties are *constraints* (normal must be symmetric); Universal properties are *axioms* (all distributions have area = 1)
# - **Real application:** Before any hypothesis test, verify normality assumption
# - **Real pattern:** Binomial → skewed (not normal); Poisson → skewed (not normal); Normal → symmetric (special)
#
# **🔗 Connection**
# - **Lesson 5:** Properties of normal distribution (symmetry, 68-95-99.7 rule)
# - **Lesson 6:** Recognizing normal vs. non-normal in data
# - **This lesson:** Conceptual mastery — what makes normal different from all other distributions
# - **Next lessons:** When normal approximations apply; Central Limit Theorem; Poisson distribution

# %% [markdown]
# #### Chapter 3 — Lesson 8: Identifying Skewness *(Practice / 100 XP)*
#
# ---
#
# **🎯 GOAL — What does this practice test?**
#
# Can you read two real-world distributions and classify statements about their skewness direction? This tests whether you can translate between visual shape (histogram) and real-world interpretation.
#
# ---
#
# **📋 Scenario**
#
# Two real distributions are provided:
# 1. **Distribution of School Size** — number of students per school
# 2. **Distribution of School Pass Grades** — percentage of schools achieving 9-5 grades
#
# Each distribution shows a different skew direction. Your task: Classify six statements as **True** or **False** based on what these distributions reveal.
#
# ---
#
# **✅ Solution**
#
# | Statement | Classification | Why |
# |-----------|-----------------|-----|
# | **"A small number of schools have over 6000 students."** | ✅ TRUE | School Size distribution is **left-skewed** (peak RIGHT, tail LEFT). The tail extends left toward lower values, but there's a right tail extending beyond 6000. The histogram bar heights decrease sharply above 6000, confirming "small number" have that many students. |
# | **"Distribution of School Size is right-skewed."** | ✅ TRUE | Visually: peak at ~2000 students, tail extends RIGHT (toward 6000+). This IS right-skewed. The majority cluster on the left; extreme values are on the right. |
# | **"A large number of schools achieve 100% pass grades among their students."** | ✅ TRUE | Pass Grades distribution is **left-skewed** (peak LEFT, tail RIGHT). The peak is at high percentages (right side of x-axis, ~80-90%), and tall bars there indicate many schools achieve high pass rates. Some schools achieve 100% (far right tail). |
# | **"The majority of schools have less than 50% of their students achieving pass grades."** | ✅ FALSE | Pass Grades distribution shows the peak at 80-90% (right side). Most schools are at high pass rates. Fewer schools are below 50% (left tail is thin). Statement contradicts the visual pattern. |
# | **"The distribution of School Pass Grades is right-skewed."** | ✅ FALSE | Pass Grades is **LEFT-skewed** (peak RIGHT, tail LEFT). The shape is the opposite of right-skewed. Right-skewed would have peak LEFT and tail RIGHT. |
# | **"The majority of schools have over 4000 students."** | ✅ FALSE | School Size distribution shows most schools cluster below 2500 students (peak is around 2000). Very few schools exceed 4000. The statement contradicts the visual peak location. |
#
# ---
#
# **Reading the two distributions:**
#
# ```
# School Size (Left-Skewed → Right-Skewed naming confusion alert)
# ├── Visual shape: Peak around 2000, tail extends RIGHT to 6000
# ├── Interpretation: Most schools small; few are very large
# ├── Skew name: RIGHT-skewed (tail direction = right)
# └── Real meaning: Limited outliers on the high end
#
# School Pass Grades (Left-Skewed)
# ├── Visual shape: Peak around 80-90%, tail extends LEFT to low %
# ├── Interpretation: Most schools achieve high pass rates; few struggle
# ├── Skew name: LEFT-skewed (tail direction = left)
# └── Real meaning: Limited outliers on the low end
# ```
#
# **⚠️ Naming note:** Skewness is named by **tail direction**, not peak direction:
# - **Right-skewed = peak LEFT, tail RIGHT** (School Size example)
# - **Left-skewed = peak RIGHT, tail LEFT** (Pass Grades example)
#
# This can feel backwards, but remember: "skew" means "pulled by the tail." If the tail pulls right, it's right-skewed, even though the peak is on the left.
#
# ---
#
# **Why you got this right (first try):**
#
# You recognized the **skew direction** from the visual shapes:
# - School Size: peak low, tail high → right-skewed ✓
# - Pass Grades: peak high, tail low → left-skewed ✓
#
# Then you **matched statements to interpretations**:
# - "Small number over 6000" matches right-skewed (few extremes on right) ✓
# - "Majority less than 50%" contradicts left-skewed peak at high values ✓
#
# **Critical skill mastered:** Reading tail direction, not just recognizing "skewed."
#
# ---
#
# **💡 Why this matters**
#
# Real data is almost never perfectly normal. Understanding skewness tells you:
# - **Right-skewed data:** Majority on low end; some high outliers. Example: income (most earn $30–60k; few earn $1M+)
# - **Left-skewed data:** Majority on high end; some low outliers. Example: test scores (most get 70–90; few fail)
#
# When you present data to a recruiter or stakeholder, you'll say: "This metric is right-skewed, so we should focus on the median and mode, not the mean." That's professional analysis.
#
# **Interview readiness:**
#
# Recruiter: *"Our customer satisfaction scores show a left-skewed distribution. What does this tell you?"*
#
# **Your answer:** "Most customers are satisfied (peak on the right, high scores). Few are very dissatisfied (thin left tail). I'd report the median satisfaction score because it's robust to those few dissatisfied outliers. The mean would be pulled down by them, giving a misleading picture."
#
# **✅ RECAP**
# - **Right-skewed:** Peak LEFT, tail RIGHT; majority low, extremes high; named by tail direction
# - **Left-skewed:** Peak RIGHT, tail LEFT; majority high, extremes low; named by tail direction
# - **Reading skew:** Find the peak (center of data); see which side has the long tail
# - **Real meaning:** Skew tells you where extremes are; use this for median vs. mean choice
# - **Business signal:** Skewed data = need robust statistics (median, IQR); don't assume mean is representative
# - **Naming trap:** "Skew" is named by tail, not peak — counterintuitive but universal
#
# **🔗 Connection**
# - **Lesson 5:** Normal distribution is symmetric (zero skew)
# - **Lesson 6:** Recognizing non-normal by spotting skewness
# - **This lesson:** Interpreting what skewness reveals about real data
# - **Next lessons:** Kurtosis (sharpness of peak); Central Limit Theorem (how distributions transform)

# %% [markdown]
# #### Chapter 3 — Lesson 9: Describing Distributions Using Kurtosis *(Exercise / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
#
# Can you define negative kurtosis correctly? Specifically: understanding that negative kurtosis = flatter peak and fatter tails (opposite of what normal has).
#
# ---
#
# **📋 Scenario**
#
# Kurtosis describes two properties of a distribution:
# 1. **Size of the central peak** (sharp vs. flat)
# 2. **Thickness of the tails** (thin vs. fat)
#
# Three definitions are provided. Task: Select which one accurately describes a **normal distribution with NEGATIVE kurtosis**.
#
# ---
#
# **✅ Solution**
#
# | Option | Definition | Kurtosis Type | Verdict | Why |
# |--------|-----------|----------------|---------|-----|
# | **Option 1** | A distribution with the same kurtosis as a normal distribution. | Mesokurtic (zero kurtosis) | ❌ Wrong | If kurtosis is the SAME as normal, it's not negative kurtosis. We're looking for something DIFFERENT from normal. |
# | **Option 2** | A distribution with a larger central peak and smaller tails compared to a typical normal distribution. | Positive kurtosis (leptokurtic) | ❌ Wrong | Larger peak and smaller tails = MORE concentrated = POSITIVE kurtosis (opposite of what we want). |
# | **Option 3** | **A distribution with a smaller peak and wider tails compared to a typical normal distribution.** | **Negative kurtosis (platykurtic)** | ✅ **Correct** | Smaller/flatter peak and wider/fatter tails = NEGATIVE kurtosis. Values are spread out more evenly; extremes are more likely than in normal. |
#
# **Understanding kurtosis:**
#
# ```
# Kurtosis Comparison
# ├── Positive Kurtosis (Leptokurtic — "lepto" = thin)
# │   ├── Peak: Very SHARP/TALL
# │   ├── Tails: THIN (few extreme values)
# │   ├── Concentration: High (values cluster tightly around mean)
# │   └── Compared to normal: MORE concentrated, MORE peaked
# │
# ├── Normal (Mesokurtic — "meso" = middle)
# │   ├── Peak: MODERATE height (reference point)
# │   ├── Tails: MODERATE thickness (reference point)
# │   ├── Concentration: Balanced
# │   └── Kurtosis value: 0 (by definition)
# │
# └── Negative Kurtosis (Platykurtic — "platy" = flat)
#     ├── Peak: FLAT/SHORTER
#     ├── Tails: FAT/WIDE (more extreme values)
#     ├── Concentration: Low (values spread across range)
#     └── Compared to normal: LESS concentrated, FLATTER
# ```
#
# **Visual comparison (how to recognize them):**
#
# | Visual Feature | Leptokurtic (Positive) | Mesokurtic (Normal) | Platykurtic (Negative) |
# |---|---|---|---|
# | Peak height | Tall, sharp | Moderate | Flat, low |
# | Tail thickness | Thin tails | Moderate tails | Fat, wide tails |
# | Extreme values | Rare | Moderate frequency | More frequent |
# | Real-world example | Stock returns (crashes rare but severe) | Heights, IQ | Uniform-ish (flat across range) |
#
# **Key memory aid:**
#
# | Term | Peak | Tails | Meaning |
# |------|------|-------|---------|
# | **Lepto**kurtic (positive) | **L**arge (tall) | Thin | Peaked and concentrated |
# | **Meso**kurtic (zero) | **M**edium (moderate) | Moderate | Normal (reference) |
# | **Platy**kurtic (negative) | **P**lain/flat (small) | Fat | Flat and spread out |
#
# **Your selection — Option 3:**
#
# You correctly identified:
# - "**Smaller peak**" = negative kurtosis (flatter than normal)
# - "**Wider tails**" = negative kurtosis (fatter than normal)
#
# This is the definition of **platykurtic** — the exact opposite of leptokurtic.
#
# ---
#
# **💡 Why this matters**
#
# Kurtosis tells you about **tail risk** and **outlier likelihood**:
#
# - **Positive kurtosis (leptokurtic):** Extremes are rare but extreme. Stock markets (mostly stable; occasional crashes)
# - **Normal (mesokurtic):** Extremes are moderately rare and moderately extreme. Heights, test scores
# - **Negative kurtosis (platykurtic):** Extremes are common and less severe. Customer wait times (relatively even distribution)
#
# When analyzing data, you'll ask: "Are outliers likely?" Kurtosis answers that instantly.
#
# **Interview readiness:**
#
# Recruiter: *"Our data shows negative kurtosis. What does this tell you about customer behavior?"*
#
# **Your answer:** "The distribution is flatter with wider tails, meaning our customers' actions are spread more evenly across the range. Extremes are more common than in a normal distribution. I'd use robust statistics (IQR, median) and be prepared for more outliers than standard assumptions predict."
#
# **✅ RECAP**
# - **Positive kurtosis (leptokurtic):** Tall peak, thin tails (concentrated, rare extremes)
# - **Normal (mesokurtic):** Moderate peak, moderate tails (reference point, zero kurtosis)
# - **Negative kurtosis (platykurtic):** Flat peak, fat tails (spread out, common extremes)
# - **Real meaning:** Kurtosis measures concentration; more negative = more spread out
# - **Memory trick:** Platy = plain = flat; Lepto = lean/light = pointed
# - **Business signal:** Negative kurtosis = prepare for more outliers; positive kurtosis = cluster more tightly
#
# **🔗 Connection**
# - **Lesson 5:** Normal distribution as reference point (mesokurtic)
# - **Lesson 6:** Recognizing non-normal distributions
# - **Lesson 8:** Skewness (direction of extremes)
# - **This lesson:** Kurtosis (frequency and severity of extremes)
# - **Together:** Skewness + Kurtosis fully describe a distribution's shape

# %% [markdown]
# #### Chapter 3 — Lesson 10: The Central Limit Theorem *(Video / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this lesson teach?**
#
# Understand the Central Limit Theorem (CLT): why sampling distributions of means become normal even when the original data isn't. This is the most powerful theorem in statistics and the foundation for hypothesis testing.
#
# ---
#
# **📋 Key Concepts from Video**
#
# **What is the Central Limit Theorem?**
#
# The Central Limit Theorem states: **A sampling distribution will approach a normal distribution as the sample size increases, regardless of the original data's shape.**
#
# This is counterintuitive and powerful. Example: Roll a die (uniform distribution: each face equally likely). Take 5 rolls and calculate the mean. Repeat this 1,000 times. Plot the 1,000 means. Result: **normal distribution shape**, even though die rolls are uniform.
#
# **The die rolling experiment (building intuition):**
#
# ```
# Step 1: Roll a die 5 times → get one mean (e.g., 3.2)
# Step 2: Roll a die 5 times → get another mean (e.g., 2.8)
# ...repeat 1,000 times...
# Step 1000: Roll a die 5 times → get the 1,000th mean
#
# Result: Plot all 1,000 means → they form a NORMAL distribution
#         (even though individual rolls are uniformly distributed)
# ```
#
# **Why this happens (intuition):**
#
# When you take the mean of multiple values, extreme values tend to cancel out:
# - One roll of 1, another of 6 → average = 3.5 (middle)
# - Multiple rolls rarely all high or all low
# - This "cancellation" creates a bell curve shape
#
# ```
# Sampling Distribution Formation
# ├── 1 die roll: UNIFORM shape (each face equally likely)
# ├── 5 die rolls (mean): SOMEWHAT NORMAL (cancellation starts)
# ├── 100 rolls (mean): MORE NORMAL (strong cancellation)
# ├── 1000 rolls (mean): VERY NORMAL (extreme cancellation)
# └── 1000000 rolls (mean): NEARLY PERFECT NORMAL (theoretical limit)
# ```
#
# **Requirements for CLT to apply:**
#
# 1. **Random sampling:** Each sample is selected randomly
# 2. **Independence:** One sample doesn't affect the next (sample with replacement)
# 3. **Sample size ≥ 30:** Magic threshold for convergence to normality (rule of thumb)
#
# > ⚠️ **Caveat:** If original distribution is extremely skewed, you might need n > 30. But n = 30 works for most practical cases.
#
# **CLT applies to multiple statistics:**
#
# | Statistic | Example | Sampling Distribution |
# |-----------|---------|----------------------|
# | **Sample Mean** | Average of n die rolls | Approaches normal |
# | **Sample SD** | Standard deviation of n rolls | Approaches normal |
# | **Sample Proportion** | Proportion of "4s" in n rolls | Approaches normal |
#
# **Proportion example from video:**
# - Roll die 5 times; count how many times you roll a 4
# - Each time: different proportion (20%, 60%, etc.)
# - Repeat 1,000 times and plot → normal distribution centered around 0.167 (1/6 chance)
#
# ---
#
# **Why the Central Limit Theorem is Powerful**
#
# **Problem:** Population is huge (millions of customers). Can't survey everyone. What's the true mean?
#
# **CLT Solution:**
# 1. Take a random sample of n = 100 customers
# 2. Calculate the sample mean (e.g., $45 average purchase)
# 3. Take another random sample of n = 100
# 4. Calculate the sample mean again
# 5. Repeat many times
# 6. Plot all sample means → normal distribution
# 7. Use this sampling distribution to estimate the true population mean
#
# **Real-world example:** Polling
#
# - True mean: unknown (can't ask all voters)
# - Sample 1,000 voters → they say 52% approve
# - Take another sample of 1,000 → they say 51% approve
# - Keep sampling → all proportions cluster around true value
# - CLT guarantees: these sample proportions will be normally distributed
# - Result: You can estimate the population proportion with confidence intervals
#
# ---
#
# **Law of Large Numbers (mentioned in video)**
#
# The video shows: sample mean of 1,000 die rolls ≈ 3.53, theoretical mean = 3.5
#
# This is the **Law of Large Numbers:** As sample size increases, the sample statistic approaches the true population parameter.
#
# ```
# Sample Size vs. Accuracy
# ├── n = 10 rolls → mean might be 2.1 or 4.2 (varies widely)
# ├── n = 100 rolls → mean might be 3.4 or 3.6 (closer to 3.5)
# ├── n = 1000 rolls → mean might be 3.48 or 3.52 (very close to 3.5)
# └── n = 1000000 rolls → mean ≈ 3.50000 (nearly exact)
# ```
#
# **Connection to CLT:** As n increases, the sampling distribution narrows (tails shrink), so sample statistics get closer to the true parameter.
#
# ---
#
# **💡 Why This Matters**
#
# The CLT is why hypothesis testing works:
#
# 1. **Hypothesis test setup:** "Is the true mean equal to μ₀?"
# 2. **We use CLT:** Even if our sample is from an unknown distribution, the sampling distribution of means is normal
# 3. **We apply normal distribution properties:** Use z-scores, p-values, confidence intervals
# 4. **We reach conclusions:** "We're 95% confident the true mean is between X and Y"
#
# **Without CLT:** We couldn't use normal-based tests on unknown distributions. With CLT: we can.
#
# **Interview readiness:**
#
# Recruiter: *"You have customer data from 50 transactions. Can you estimate the true mean transaction value for all customers?"*
#
# **Your answer:** "Yes, because of the Central Limit Theorem. With n = 50, the sampling distribution of the mean is approximately normal. I can calculate the sample mean ($87.50), use the standard error, and build a 95% confidence interval around it. This gives me a range where I'm confident the true population mean lies."
#
# ---
#
# **✅ RECAP**
# - **CLT:** Sampling distributions approach normal as sample size increases, regardless of original data shape
# - **Key insight:** Means of samples are less variable than individual values; variability → normal
# - **Requirements:** Random sampling, independence, n ≥ 30 (usually)
# - **Applies to:** Means, standard deviations, proportions
# - **Practical use:** Estimate population parameters from samples without surveying everyone
# - **Connection to normality:** This is WHY normal distribution is everywhere — most statistics we care about ARE sampling distributions
# - **Law of Large Numbers:** Sample statistic → population parameter as n increases
#
# **🔗 Connection**
# - **Chapter 2:** Probability fundamentals and distributions introduced
# - **Lesson 5:** Normal distribution (now we know why it's important)
# - **Lesson 9:** Kurtosis (sampling distributions start with kurtosis, become normal via CLT)
# - **Next lessons:** How to use CLT for hypothesis testing and confidence intervals
# - **Chapter 4:** Hypothesis testing relies entirely on CLT

# %% [markdown]
# #### Chapter 3 — Lesson 11: Visualizing Sampling Distributions *(Practice / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this practice test?**
#
# Can you recognize that the Central Limit Theorem applies to **multiple source distributions**, not just one? This tests your understanding of CLT's universality — it's not specific to binomial or normal, it applies to ALL distributions.
#
# ---
#
# **📋 Scenario**
#
# An interactive CLT visualizer lets you select different source distributions and observe how their sampling distributions converge to normal shape. You experimented with:
# - Discrete Uniform (1–9)
# - Continuous Uniform (0–10)
# - Binomial (n=20, p=0.3)
# - Exponential (λ=1)
#
# For each, you set sample size n = 30 and generated 500 samples, observing the sampling distribution of means.
#
# **Task:** Which distribution does the Central Limit Theorem apply to?
#
# ---
#
# **✅ Solution**
#
# | Option | Answer | Verdict | Why |
# |--------|--------|---------|-----|
# | **Option 1** | Discrete uniform distribution | ❌ Wrong (but true) | CLT does apply to discrete uniform, BUT it also applies to the others. Not the only answer. |
# | **Option 2** | Continuous uniform distribution | ❌ Wrong (but true) | CLT does apply to continuous uniform, BUT it also applies to the others. Not the only answer. |
# | **Option 3** | Binomial distribution | ❌ Wrong (but true) | CLT does apply to binomial, BUT it also applies to the others. Not the only answer. |
# | **Option 4** | **All of the above** | ✅ **Correct** | CLT applies to **every** distribution — discrete, continuous, skewed, symmetric, you name it. With enough samples, the sampling distribution becomes normal regardless of source shape. |
#
# **Why your error happened:**
#
# You saw all four distributions converge to normal (screenshots 1–4), demonstrating CLT works for each. But when asked the question, you selected **only binomial** (Option 3) instead of **"all of the above"** (Option 4).
#
# **The trap:** **Partial recognition masquerading as full understanding**
# - You demonstrated visually that CLT works for all four ✓
# - You understood that binomial works ✓
# - But you didn't integrate the pattern: "All of these converge → CLT applies to all distributions"
# - So you answered "binomial" instead of "all"
#
# This is a classic pattern in learning: you can prove something works in multiple cases without generalizing the rule.
#
# **Feedback received:** "The CLT does apply to the binomial distribution, but it's not the only one. The sampling distribution of means forms a bell curve regardless of which source distribution you choose."
#
# ---
#
# **The CLT universality principle:**
#
# ```
# Central Limit Theorem Applies To
# ├── Discrete distributions
# │   ├── Discrete Uniform (1–9) ✓
# │   ├── Binomial (n=20, p=0.3) ✓
# │   └── Poisson ✓
# ├── Continuous distributions
# │   ├── Continuous Uniform (0–10) ✓
# │   ├── Exponential (λ=1) ✓
# │   └── Normal (already normal) ✓
# ├── Skewed distributions ✓
# ├── Symmetric distributions ✓
# └── ANY distribution you can imagine ✓
# ```
#
# **The power of CLT:** It's **universal**. It doesn't say "CLT applies to some distributions." It says "CLT applies to sampling distributions of ANY statistic from ANY distribution."
#
# ---
#
# **Common mistake — Partial pattern vs. complete rule:**
#
# | Thinking | Result | Problem |
# |----------|--------|---------|
# | "I saw CLT work for binomial" | Select binomial | Didn't generalize |
# | "I saw CLT work for all four I tested" | Still select binomial | Still didn't see the rule |
# | "CLT works for every distribution; these four are examples" | Select "all of the above" | Correct understanding |
#
# **The bridge:** Specific examples → general rule. You had the examples; you needed to make the leap to the rule.
#
# ---
#
# **Why this matters**
#
# In real statistics work, you won't have an interactive visualizer. You'll need to **think:** "I have data from an unknown distribution. Can I use normal-based hypothesis tests?"
#
# **Answer:** Yes, because of CLT. You don't need to know the distribution shape. With n ≥ 30, the sampling distribution of means is approximately normal.
#
# This is why CLT is the most powerful theorem in statistics — it divorces hypothesis testing from the requirement "your data must be normal." You can test almost anything.
#
# **Interview readiness:**
#
# Recruiter: *"We have customer income data that's highly right-skewed (not normal at all). Can we use a t-test on it?"*
#
# **Your answer:** "With a large enough sample (n ≥ 30), yes. The Central Limit Theorem says the sampling distribution of the mean will be approximately normal, regardless of the original distribution's shape. So we can use t-tests on the means even though individual income values are right-skewed."
#
# ---
#
# **✅ RECAP**
# - **CLT universality:** Applies to discrete, continuous, skewed, symmetric — ANY distribution
# - **Requirement:** Sufficient sample size (n ≥ 30 usually) and random, independent sampling
# - **Power:** Frees hypothesis testing from normality assumption on raw data
# - **Common error:** Recognizing CLT works in specific cases but not generalizing to "all distributions"
# - **The leap:** Examples → Rule. You demonstrated it visually; now state it universally
# - **Real pattern:** CLT is why normal distribution is ubiquitous; most statistics we test are sampling distributions
#
# **🔗 Connection**
# - **Lesson 10:** CLT introduced (theoretical explanation)
# - **This lesson:** CLT demonstrated (interactive visualization across multiple distributions)
# - **Next lessons:** Using CLT for hypothesis testing and confidence intervals
# - **Chapter 4:** All hypothesis tests rely on this universality of CLT

# %% [markdown]
# #### Chapter 3 — Lesson 12: The CLT vs. The law of large numbers *(Exercise / 100 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
#
# Can you distinguish between the **Central Limit Theorem** (CLT) and the **Law of Large Numbers** (LLN) — two related but distinct statistical principles? This trains conceptual precision: CLT describes *distribution shape*, while LLN describes *convergence to a parameter*.
#
# ---
#
# **📋 Scenario**
#
# You are shown two histograms:
# - **Top histogram:** Distribution of 100 die roll samples (sample mean for each sample)
# - **Bottom histogram:** Distribution of 1,000 die roll samples (sample mean for each sample)
#
# The scenario reminds you that these two concepts — CLT and LLN — are often confused. Your task: classify four statements, assigning each to either **Central Limit Theorem** or **Law of Large Numbers** based on which principle each statement actually describes.
#
# **Task:** Drag each statement into the correct bucket (CLT or LLN).
#
# ---
#
# **✅ Solution & Walkthrough**
#
# | Statement | Correct Category | Classification | Why / Trap Explanation |
# |-----------|------------------|-----------------|------------------------|
# | **"As the sample increases, the sample mean gets closer to the value of the population mean."** | Law of Large Numbers | Convergence | This describes LLN directly: as n increases, sample mean → population mean (convergence to a parameter). The focus is on *accuracy of the estimate*, not on distribution shape. |
# | **"This concept does not always result in a sample taking the form of a normal distribution as sample size increases."** | Law of Large Numbers | Negative definition | This is describing what LLN is NOT CLT. LLN doesn't guarantee normality; it only guarantees convergence to the true mean. The key phrase: "does not always result in a normal distribution" — that's LLN's limitation. CLT, by contrast, DOES guarantee normality as n increases. |
# | **"This concept generally applies once the sample size is 30 or more."** | Central Limit Theorem | Threshold | This is CLT's operational rule: n ≥ 30 is the magic threshold when CLT kicks in strongly and sampling distributions become approximately normal. LLN doesn't have a specific threshold — it works at any n, just more reliably with larger n. |
# | **"As the number of sample summary statistics calculated increases, the distribution will more closely resemble a normal distribution."** | Central Limit Theorem | Distribution shape | This is CLT in plain language: as you calculate more sample means (sample summary statistics), their distribution becomes more normal. This is about shape convergence, not parameter convergence. |
#
# ---
#
# **The Core Distinction (Critical for Understanding)**
#
# ```
# Law of Large Numbers (LLN)
# ├── What it says: Sample statistic → population parameter
# ├── Focus: Accuracy/convergence of the estimate itself
# ├── Example: Sample mean → true mean (gets closer)
# ├── Direction: Parameter convergence (one dimension)
# └── Threshold: No specific rule; works at any n
#
# Central Limit Theorem (CLT)
# ├── What it says: Sampling distribution → normal shape
# ├── Focus: Distribution shape of repeated sample statistics
# ├── Example: Distribution of sample means → normal (bell curve)
# ├── Direction: Distribution shape convergence (two dimensions: mean + spread)
# └── Threshold: n ≥ 30 (practical rule of thumb)
# ```
#
# **Visualization from histograms:**
#
# - **Top histogram (100 samples):** Already showing a somewhat normal shape (CLT at work), but with some raggedness. Sample means are clustering around 3.5 (true mean).
# - **Bottom histogram (1,000 samples):** Much smoother, more clearly bell-shaped (CLT stronger). Clustering tighter around 3.5 (LLN stronger).
#
# Both principles operate simultaneously:
# - **LLN:** The peak location (3.5) is stable and accurate across both histograms
# - **CLT:** The shape becomes more bell-curved as you go from 100 samples → 1,000 samples
#
# ---
#
# **Common Mistakes & Traps**
#
# **Trap 1: Confusing the two principles**
# - **Wrong:** "CLT says the sample mean gets closer to the true mean"
# - **Right:** That's LLN. CLT says the *distribution of sample means* becomes normal.
# - **How to catch it:** Ask yourself: "Is this about the accuracy of one estimate, or the shape of many estimates?" LLN = one estimate getting better. CLT = distribution shape improving.
#
# **Trap 2: Thinking LLN guarantees normality**
# - **Wrong:** "As sample size increases, the distribution becomes normal" (This is CLT, not LLN)
# - **Right:** LLN says the sample mean converges to the true mean, but doesn't guarantee the distribution is normal
# - **How to catch it:** LLN is about *convergence to a point* (the true mean). CLT is about *convergence to a shape* (the normal curve).
#
# **Trap 3: Assuming n = 30 applies to both**
# - **Wrong:** "Both LLN and CLT kick in at n = 30"
# - **Right:** n = 30 is CLT's threshold. LLN works at any n, just more slowly with small n.
# - **How to catch it:** LLN is a universal principle (always true); CLT has a practical threshold.
#
# **Trap 4: Reading "distribution" and defaulting to CLT**
# - The statement "distribution will more closely resemble a normal distribution" — yes, that's CLT
# - But "sample mean gets closer to the true value" — that sounds like it could be about distribution, but it's actually about accuracy (LLN)
# - **How to catch it:** Read carefully: are we talking about *shape* (CLT) or *accuracy/convergence* (LLN)?
#
# ---
#
# **Why You Might Have Made an Error**
#
# **If you confused LLN and CLT:**
# - **Root cause:** Both involve "as sample size increases," so they sound similar
# - **The fix:** LLN = *accuracy*; CLT = *shape*. One word difference, but complete concepts
# - **Prevention:** Before answering, ask: "Is this about getting the right answer, or about the distribution looking like a bell curve?"
#
# **If you selected the wrong bucket for statement 2:**
# - **Statement 2:** "This concept does not always result in a sample taking the form of a normal distribution..."
# - **Trap:** This statement is saying "NOT normal distribution" — so it must be CLT? NO. It's describing what LLN does NOT do. LLN doesn't guarantee normality (because it's about convergence, not shape).
# - **The fix:** Negative statements need careful parsing. "Does NOT result in normal distribution" = describing LLN's limitation, not CLT's feature.
#
# ---
#
# **💡 Why This Matters**
#
# In real statistical work, you must choose between two frameworks:
#
# 1. **"I want my estimate to be accurate"** → Use LLN reasoning: get more data
# 2. **"I want to test a hypothesis using normal-based tests"** → Use CLT reasoning: ensure n ≥ 30, then apply z-tests or t-tests
#
# Mixing them up leads to mistakes:
# - If you only think LLN, you might collect huge samples but still not know if you can use parametric tests
# - If you only think CLT, you might use normal-based tests without ensuring your sample mean is actually close to the true mean
#
# **Interview readiness:**
#
# Recruiter: *"We have 50 customer transactions. What can we say about the true mean transaction value?"*
#
# **Your answer:** "Two things: First, the Law of Large Numbers tells us our sample mean ($87) is a reliable estimate of the true mean — it will be close. Second, the Central Limit Theorem tells us we can use parametric tests (t-tests) because with n = 50 > 30, the sampling distribution is approximately normal. So we can build confidence intervals and hypothesis tests."
#
# This answer shows you understand both principles and can apply them together.
#
# ---
#
# **✅ RECAP**
# - **Law of Large Numbers:** Sample statistic converges to population parameter as n increases; focus on accuracy
# - **Central Limit Theorem:** Sampling distribution converges to normal shape as n increases; focus on distribution shape
# - **Key difference:** LLN = convergence to a *point*; CLT = convergence to a *shape*
# - **LLN applies:** Always (at any n); no specific threshold
# - **CLT applies:** When n ≥ 30 (practical rule); depends on original distribution shape
# - **Real pattern:** You use LLN reasoning to justify "larger samples are better"; you use CLT reasoning to justify "we can use parametric tests"
# - **Common error:** Confusing which principle governs which behavior; read carefully for "accuracy/convergence" (LLN) vs. "shape" (CLT)
#
# **🔗 Connection**
# - **Lesson 10:** CLT introduced (theoretical explanation)
# - **Lesson 11:** CLT demonstrated across multiple distributions
# - **This lesson:** CLT vs. LLN comparison — conceptual precision
# - **Next lessons (13–16):** Poisson distribution, lambda parameter, recognizing Poisson processes
# - **Chapter 4:** Hypothesis testing applies both LLN (for accuracy) and CLT (for normality assumption)

# %% [markdown]
# #### Chapter 3 — Lesson 13: When to use the central limit theorem *(Exercise / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
#
# Can you recognize which real-world scenario is appropriate for applying the Central Limit Theorem? This trains the judgment you need: CLT applies when you're estimating a population parameter from multiple samples, not when you're describing a single dataset or population you already have.
#
# ---
#
# **📋 Scenario**
#
# You are presented with four scenarios. Each describes a statistical task. Your job: **Choose which scenario would REQUIRE the use of the Central Limit Theorem** to produce summary statistics that are normally distributed.
#
# The key decision point: Does this scenario require sampling-based inference (CLT applies), or does it involve direct calculation (CLT doesn't apply)?
#
# **Task:** Select one answer.
#
# ---
#
# **✅ Solution & Walkthrough**
#
# | Option | Scenario | Verdict | Why / Trap Explanation |
# |--------|----------|---------|------------------------|
# | **Option 1** | Finding the mean IQ of all 100 students in a high school. | ❌ Incorrect | **Why:** You have the entire population (all 100 students). You can calculate the mean directly. There's no sampling involved. CLT is for when you DON'T have the population and must infer from samples. **Trap:** "100 students" sounds like a good sample size, so you might think CLT applies. But it's a population, not a sample. |
# | **Option 2** | Measuring the standard deviation of household income in a road with 20 houses. | ❌ Incorrect | **Why:** n = 20 is too small for CLT (which requires n ≥ 30). Even though you're sampling, the sample size doesn't meet CLT's threshold. **Trap:** You might recognize "sampling" and think "CLT applies." But CLT has a minimum sample size requirement. Small samples don't produce normally distributed sampling distributions. |
# | **Option 3** | **Determining the percentage of adults in the USA that have been diagnosed with Type 2 Diabetes.** | ✅ **CORRECT** | **Why:** This is a population parameter (% of ALL adults in USA) you cannot measure directly. You must take multiple samples of adults, calculate the percentage in each sample, and use the sampling distribution of proportions (which follows CLT) to estimate the true population percentage. **Requirements met:** Unknown population parameter ✓, Multiple samples ✓, n ≥ 30 possible ✓, Sampling distribution needed ✓ |
# | **Option 4** | Counting the number of babies born with blue eyes in a hospital within one day. | ❌ Incorrect | **Why:** This is a counting task (discrete outcome: "blue eyes or not"). Counting events in a fixed time/place describes a Poisson distribution, not a CLT application. You're not estimating a population proportion; you're counting occurrences of an event. **Trap:** "Babies" and "number" might make you think of a population sample, but this is actually counting events, which is different. |
#
# **The correct answer: Option 3 — "Determining the percentage of adults in the USA that have been diagnosed with Type 2 Diabetes."**
#
# ---
#
# **Your Error Progression & Analysis**
#
# **Attempt 1 — Option 2 (❌ Incorrect)**
#
# *Selected:* "Measuring the standard deviation of household income in a road with 20 houses."
#
# **Feedback received:** "The central limit theorem typically requires a sample size of at least 30."
#
# **Root cause of the error:**
# - You recognized this as a "sampling scenario"
# - You understood that sampling + normal distribution = CLT
# - But you overlooked the **n ≥ 30 requirement**
#
# **Why this trap is tricky:**
# - Option 2 involves *real sampling* (not a full population), which is part of CLT logic
# - The numbers "20 houses" are close to 30, so the requirement feels "almost met"
# - Your brain pattern-matched "sample + measurement" → "CLT" without checking the threshold
#
# **The lesson:** CLT is not just "sampling," it's "sampling with n ≥ 30." The threshold isn't a suggestion — it's a requirement for the sampling distribution to be approximately normal.
#
# ---
#
# **Attempt 2 — Option 1 (❌ Incorrect)**
#
# *Selected:* "Finding the mean IQ of all 100 students in a high school."
#
# **Feedback received:** "As the population size in this example is 100 students, it is realistic to be able to measure the IQ of every student in the high school rather than taking several smaller samples."
#
# **Root cause of the error:**
# - You corrected course from "too small a sample" (20) to "larger sample" (100)
# - But you misunderstood the fundamental difference between **population** and **sample**
#
# **Why this trap is insidious:**
# - The feedback explicitly says "population size is 100 students"
# - You might have read "100" as "large sample" rather than "entire population"
# - The phrase "measure the IQ of every student" suggests you don't need CLT because you're measuring everyone
#
# **The lesson:** CLT applies when you **cannot measure the entire population** and must infer from samples. If you can measure everyone (like all 100 students in one school), you don't need CLT — you just calculate the statistic directly. CLT is for the impossible cases: "% of all adults in USA," "true mean income of a city," etc.
#
# ---
#
# **Attempt 3 — Option 3 (✅ CORRECT)**
#
# *Selected:* "Determining the percentage of adults in the USA that have been diagnosed with Type 2 Diabetes."
#
# **Feedback received:** "Nicely done! It would be impossible to find out the Type 2 Diabetes status of every adult in the USA, so an appropriate approach is to take lots of small samples across several locations and use the sampling distribution to calculate the percentage diagnosed."
#
# **Why this is correct:**
# 1. **Population is inaccessible:** You cannot survey every adult in the USA
# 2. **Sampling is necessary:** You must take multiple samples across locations
# 3. **CLT applies:** As you take more samples and calculate the proportion in each, the sampling distribution of proportions becomes normal (with sufficient n ≥ 30 per sample)
# 4. **Inference is the goal:** You use the sampling distribution to estimate the true population percentage
#
# **The pattern:** Impossible population → multiple samples → CLT → normal sampling distribution → confidence interval or hypothesis test
#
# ---
#
# **The CLT Decision Tree**
#
# ```
# Do I have access to the entire population?
# ├── YES → Calculate directly (no CLT needed)
# │   └── Example: All 100 students in the school → calculate their mean IQ
# │
# └── NO → Can I estimate from samples?
#     ├── Is the scenario asking for a single descriptive statistic? (e.g., "20 houses in one road")
#     │   ├── n < 30? → Too small for CLT (Attempt 1 error)
#     │   └── n ≥ 30? → CLT applies ✓
#     │
#     └── Is it a count of events in a fixed time/place? (e.g., "babies born today")
#         └── No → That's Poisson, not CLT
#             └── Yes → Use CLT ✓ (Option 3)
# ```
#
# **Critical distinction for CLT application:**
# - **Population-level question + No access to population + n ≥ 30 sampling** → CLT applies
# - **Complete dataset available** → CLT doesn't apply; just calculate
# - **Small samples (n < 30)** → CLT doesn't apply reliably
# - **Counting events, not measuring** → Poisson, not CLT
#
# ---
#
# **Common Mistakes & Traps**
#
# **Trap 1: Confusing "large number" with "sampling scenario"**
# - "100 students" is a large number, but it's a *population* in this context
# - "20 houses" involves *sampling*, but n < 30 fails CLT threshold
# - **Fix:** Ask "Is this the entire population I care about (use it directly), or a sample representing a larger population (use CLT)?"
#
# **Trap 2: Assuming CLT applies to any measurement of a sample**
# - CLT doesn't apply to direct descriptive statistics on a sample
# - CLT applies to the *distribution of sample statistics across multiple samples*
# - **Fix:** Think "sampling distribution," not just "one sample"
#
# **Trap 3: Forgetting the n ≥ 30 requirement**
# - n = 20 is close to 30, so it *feels* okay
# - But CLT's normality guarantee weakens below 30
# - **Fix:** Check the sample size explicitly; it's not just a guideline
#
# **Trap 4: Missing the "inaccessible population" signal**
# - Phrases like "all adults in the USA," "all customers worldwide," "everyone in the country" = population you can't measure
# - These phrases signal: **Use sampling and CLT**
# - **Fix:** When you see "all [large group]," recognize you'll need sampling
#
# ---
#
# **💡 Why This Matters**
#
# In real analytics, you face this decision constantly:
#
# 1. **Marketing:** "What percentage of all our customers would buy Product X?" → Can't survey everyone → use CLT sampling
# 2. **Medicine:** "What's the true recovery rate from this drug?" → Can't test on all patients → use CLT with clinical trial samples
# 3. **Quality control:** "Is this batch's defect rate above 5%?" → Can't test every unit (destructive) → use CLT with samples
# 4. **Finance:** "What's the mean portfolio return?" → Can't measure all possible scenarios → use CLT with historical samples
#
# Choosing wrong leads to mistakes:
# - If you think CLT applies when it doesn't, you'll use confidence intervals on a complete dataset (wrong, misleading)
# - If you don't use CLT when you should, you'll treat a sample statistic as if it's perfectly accurate (wrong, risky)
#
# **Interview readiness:**
#
# Recruiter: *"We want to know the true mean customer satisfaction score for all our customers. We have 5,000 customer records. Do we need CLT?"*
#
# **Your answer:** "No. We have the entire dataset (5,000 records), so we can calculate the mean satisfaction score directly. We don't need CLT because we have access to the full population, not just a sample. CLT would apply if we could only survey a sample of customers, say 200, and wanted to infer the true mean for all millions of customers."
#
# This shows you understand the fundamental CLT condition: **applicability depends on whether you have the population or only samples**.
#
# ---
#
# **✅ RECAP**
# - **CLT applies when:** Population parameter unknown, must estimate from multiple samples, n ≥ 30
# - **CLT doesn't apply when:** You have the complete population, or samples are too small (n < 30)
# - **Key decision:** "Is this the entire population or just a sample of a larger population?"
# - **Phrases that signal CLT:** "all adults in the USA," "true percentage," "population mean," "estimate from samples"
# - **Phrases that signal NO CLT:** "all 100 students in this school," "the 20 houses on this road," "count the events today"
# - **The n ≥ 30 rule:** Minimum sample size for CLT's normality guarantee
# - **Real pattern:** Inaccessible population → sampling → CLT → inference
#
# **🔗 Connection**
# - **Lesson 12:** CLT vs. LLN conceptual distinction
# - **This lesson:** When CLT is the appropriate tool for real scenarios
# - **Next lessons (14–16):** Poisson distribution for counting events; lambda parameter
# - **Chapter 4:** All hypothesis testing relies on CLT; this lesson decides when to apply it

# %% [markdown]
# #### Chapter 3 — Lesson 14: The Poisson Distribution *(Video / 50 XP)*
#
# > 🎬 [Watch on DataCamp](https://campus.datacamp.com/courses/introduction-to-statistics/more-distributions-and-the-central-limit-theorem-79b572d6-d267-482b-af89-a47fd6df183c?ex=14) *(requires login)*
#
# ---
#
# **🎯 GOAL — What is this lesson about?**
#
# Understand the **Poisson distribution** — a discrete probability distribution that models the number of events occurring in a fixed time period or space, when events happen randomly but at a known average rate. You'll learn when to use it, what the parameter lambda (λ) means, and how to calculate probabilities from Poisson data.
#
# ---
#
# **What is a Poisson Process?**
#
# A **Poisson process** is a real-world pattern where:
# 1. The average number of events in a time period is **known** (e.g., 8 adoptions per week)
# 2. The timing between events is **random** (adoptions can happen any time during the week)
# 3. Events are **independent** (one adoption doesn't predict the next)
#
# **Real-world examples of Poisson processes:**
# - **Animal shelter:** 8 animals adopted per week on average
# - **Restaurant:** 20 patrons arriving per hour on average
# - **Website:** 200 page visits per day on average
# - **Call centre:** 15 incoming calls per hour on average
# - **Manufacturing:** 2 defects per 1,000 units produced on average
# - **Medical:** 5 patient arrivals at ER per hour on average
#
# The key insight: **You know the average, but not exactly when events occur.**
#
# ---
#
# **The Poisson Distribution**
#
# The **Poisson distribution** describes the probability of observing exactly **k** events in a fixed time period, given that events occur at a constant average rate.
#
# **Formula (conceptual):**
# $$P(X = k) = \text{probability of exactly } k \text{ events}$$
#
# where:
# - **k** = number of events (0, 1, 2, 3, ...)
# - **λ (lambda)** = average number of events per period (the *only* parameter needed)
#
# **Key properties:**
# - **Discrete distribution:** outcomes are counts (you can't have 5.7 adoptions)
# - **Single parameter:** λ fully describes the distribution
# - **λ = expected value:** E(X) = λ (the most likely outcome is around λ)
# - **λ determines the peak:** The histogram peak is always at λ
#
# ---
#
# **Understanding Lambda (λ)**
#
# **Lambda represents the average event rate.** It's both:
# 1. The **parameter** of the distribution (what you input)
# 2. The **expected value** (what you'd observe on average over many time periods)
#
# **Examples with different λ values:**
#
# | Context | λ value | Interpretation | Peak of distribution |
# |---------|---------|-----------------|----------------------|
# | **Restaurant - slow hour** | λ = 10 | Average 10 patrons per hour | Peak at 10 patrons |
# | **Restaurant - normal hour** | λ = 20 | Average 20 patrons per hour | Peak at 20 patrons |
# | **Restaurant - rush hour** | λ = 50 | Average 50 patrons per hour | Peak at 50 patrons |
# | **Animal shelter** | λ = 8 | Average 8 adoptions per week | Peak at 8 adoptions |
# | **Website** | λ = 200 | Average 200 visits per day | Peak at 200 visits |
#
# **Critical insight:** The peak always sits at λ. As you change λ, the entire distribution shape shifts.
#
# ---
#
# **Calculating Probabilities from Poisson Distributions**
#
# **Example: Restaurant with average 20 patrons per hour (λ = 20)**
#
# **Probability of exactly 13 patrons in an hour:**
#
# From the histogram, measure the height of the bar at k = 13:
# $$P(X = 13 | λ = 20) = 2.71\%$$
#
# Interpretation: There's a 2.71% chance that exactly 13 patrons arrive in a randomly selected hour.
#
# ---
#
# **Probability of 25 or more patrons in an hour:**
#
# Sum the heights of all bars from k = 25 onwards:
# $$P(X \geq 25 | λ = 20) = 11.1\%$$
#
# Interpretation: There's approximately an 11% chance that 25 or more patrons arrive in a given hour.
#
# **Comparison:**
# - P(exactly 13) = 2.71% — quite unlikely (far from peak at 20)
# - P(≥25) = 11.1% — somewhat unlikely (above peak but within reasonable range)
#
# This makes sense: 13 is farther from the mean (20) than 25 is, so it's rarer.
#
# ---
#
# **Poisson Distribution Histogram Properties**
#
# ```
# Peak: Always at λ value
# ├── λ = 10 (left, green curve)
# │   ├── Spread: mainly 5–15
# │   └── Peak height: tallest at k = 10
# │
# ├── λ = 20 (middle, blue curve)
# │   ├── Spread: mainly 15–25
# │   └── Peak height: tallest at k = 20
# │
# └── λ = 50 (right, red curve)
#     ├── Spread: mainly 40–60
#     └── Peak height: tallest at k = 50
# ```
#
# **Pattern:** As λ increases, the entire distribution shifts right, and the spread increases.
#
# ---
#
# **Central Limit Theorem Still Applies**
#
# Just like other distributions, the Poisson distribution obeys the Central Limit Theorem:
#
# If you collect many samples from a Poisson process and calculate the mean for each sample, the distribution of those sample means becomes **normal** (bell curve), regardless of the original Poisson shape.
#
# This is why Poisson is so powerful in statistics — even though individual event counts are Poisson-shaped, sampling distributions of means are normal, allowing you to use normal-based hypothesis tests.
#
# ---
#
# **💡 Why This Matters**
#
# **In operations and forecasting:**
# - **Restaurant planning:** "If λ = 20 patrons/hour, what's the probability we'll need to seat 30+ people?" → Use Poisson
# - **Staffing:** "How many servers do we need to handle high-probability demand?" → Poisson tells you the distribution
# - **Inventory:** "How many adoptions should we expect this week? What's the range?" → λ = 8, so expect 8 ± variability
#
# **In quality control:**
# - **Manufacturing:** "If defect rate averages 2 per 1,000 units, what's the probability of 5 defects in the next batch?" → Poisson
# - **Reliability:** "System failures average once per month. What's the chance of 3 failures next month?" → Poisson
#
# **In service design:**
# - **Emergency services:** "ER sees 5 patients/hour on average. Do we staff for 5, 7, or 10?" → Poisson probabilities guide staffing
# - **Support tickets:** "We receive 30 support tickets/day on average. What's the 95th percentile?" → Poisson quantiles
#
# **Interview readiness:**
#
# Recruiter: *"An online retailer receives an average of 100 orders per hour. What's the probability they'll receive fewer than 80 orders in the next hour?"*
#
# **Your answer:** "That's a Poisson process with λ = 100. I'd use the Poisson distribution to calculate P(X < 80 | λ = 100). Since 80 is well below the mean (100), this probability would be quite low — perhaps 5–10%. This tells us that receiving fewer than 80 orders is unusual for this retailer, so if it happens, something might be wrong (system outage, competitor issue, etc.)."
#
# This answer shows you recognize the process, parameterize it correctly, and interpret the probability in context.
#
# ---
#
# **Real-world warning: When Poisson doesn't apply**
#
# Poisson assumes:
# 1. **Events are independent** — one event doesn't trigger or prevent the next
# 2. **Constant rate** — λ doesn't change over the period
# 3. **Events are rare relative to the opportunity** — very high rates may require adjustments
#
# **If these break down, Poisson might not fit:**
# - **Restaurant during dinner rush:** Rate changes over time (not constant λ)
# - **Viral infections:** Events are NOT independent (one infection spreads to others)
# - **Traffic accidents on a major holiday:** Rate changes (not constant)
#
# When Poisson fails, you may need more complex models (non-homogeneous Poisson, clustering models, etc.).
#
# ---
#
# **✅ RECAP**
# - **Poisson process:** Events occur randomly at a known average rate (λ)
# - **Poisson distribution:** Describes probability of k events in a fixed period
# - **Lambda (λ):** Average number of events per period = expected value = peak of distribution
# - **Discrete:** Outcomes are counts (0, 1, 2, 3, ...)
# - **Single parameter:** Only λ needed to fully describe the distribution
# - **Probability calculation:** Use histogram height (exact count) or sum heights (range)
# - **CLT applies:** Sampling distributions of means are normal, even though individual counts are Poisson
# - **Real applications:** Forecasting demand, staffing, quality control, reliability engineering
# - **Assumptions:** Independence, constant rate, rare events
#
# **🔗 Connection**
# - **Chapter 2:** Discrete distributions (binomial) — counts of successes in fixed trials
# - **This lesson:** Poisson distribution — counts of events in fixed time/space (not fixed trials)
# - **Next lessons:** Identifying Poisson processes; finding λ from data
# - **Chapter 4:** Using Poisson in hypothesis testing and goodness-of-fit tests

# %% [markdown]
# #### Chapter 3 — Lesson 15: Identifying Poisson processes *(Exercise / 100 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
#
# Can you distinguish between **Poisson processes** (events occurring randomly at a constant average rate in time/space) and **other distributions** like binomial (fixed number of binary trials)? This trains the pattern-recognition skill: recognizing when to apply Poisson vs. alternatives in real data.
#
# ---
#
# **📋 Scenario**
#
# You are presented with six scenarios describing different data collection situations. Your task: **Classify each as either Poisson distribution or Other distribution** based on whether it describes random events occurring over time/space (Poisson) or something else (binomial, probability, etc.).
#
# **Key distinction to remember:**
# - **Poisson:** Events happen randomly over a time or space period at a known average rate (earthquakes per year, books per week, mortgage applications per month)
# - **Not Poisson:** Binary outcomes with fixed probability (vote/not vote, broken/not broken, side effects yes/no)
#
# **Task:** Drag each scenario into the correct bucket.
#
# ---
#
# **✅ Solution & Classification**
#
# | Scenario | Correct Category | Classification | Why / Trap Explanation |
# |----------|------------------|-----------------|------------------------|
# | **Number of earthquakes in the state of California in a year.** | Poisson Distribution | Random events, time period | Earthquakes occur randomly throughout the year at a known average rate (e.g., λ = 5 per year). Time between earthquakes is unpredictable. This is the textbook Poisson example. |
# | **Number of books sold per week.** | Poisson Distribution | Random events, time period | Book sales occur randomly throughout the week. While you might know average weekly sales (e.g., λ = 200), the exact timing and number each day varies. This is Poisson. |
# | **Volume of mortgage applications received per month.** | Poisson Distribution | Random events, time period | Applications arrive randomly throughout the month. You know the average volume (e.g., λ = 150 per month), but the exact count varies. Poisson applies. |
# | **Number of side effects from a range of medications.** | Other Distribution | Binomial | Each medication either causes side effects (yes/no, success/failure) in a patient. With n medications and probability p of side effects, this is binomial, not Poisson. The number of trials (medications) is fixed. |
# | **Probability of voting for a political candidate.** | Other Distribution | Binomial | Each individual either votes for the candidate (success, p) or doesn't (failure, 1-p). With a fixed population size n, this is binomial. Not random events over time; fixed binary trials. |
# | **Probability of a mobile phone being broken.** | Other Distribution | Binomial | Each phone is either broken (success) or not (failure). Examining a sample of n phones, counting broken ones = binomial. Not random events occurring; fixed binary trials on fixed sample. |
#
# ---
#
# **The Core Distinction: Poisson vs. Binomial**
#
# ```
# Poisson Process
# ├── Events occur RANDOMLY over TIME/SPACE
# ├── Known AVERAGE rate (λ)
# ├── UNKNOWN exact count
# ├── Timing between events: VARIABLE
# ├── Number of trials: NOT FIXED (continuous observation)
# └── Examples: earthquakes, book sales, website visits, patient arrivals
#
# Binomial Process
# ├── FIXED number of INDEPENDENT trials (n)
# ├── FIXED probability of success per trial (p)
# ├── Events are BINARY (success/failure)
# ├── Outcome: COUNT of successes out of n
# ├── Number of trials: FIXED by design
# └── Examples: votes (n people, each votes yes/no), side effects (n medications, each yes/no), broken phones (n phones, each broken/not)
# ```
#
# **The decision tree:**
#
# ```
# Does the scenario describe random events occurring over time or space?
# ├── YES → Is the average rate known (λ)?
# │   ├── YES → POISSON ✓
# │   └── NO → Check if CLT applies or other distribution
# │
# └── NO → Does it describe fixed number of binary trials?
#     ├── YES → BINOMIAL (or other discrete)
#     └── NO → Might be continuous or other type
# ```
#
# ---
#
# **Common Mistakes & Traps**
#
# **Trap 1: Confusing "counting outcomes" with "Poisson process"**
# - **Wrong:** "We're counting book sales, so it's Poisson"
# - **Right:** "Book sales occur randomly throughout the week at a known average rate, so it's Poisson"
# - **Key difference:** Poisson requires randomness over time/space, not just counting
# - **Fix:** Ask "Does this involve events happening randomly over a time period?" If yes, it's Poisson. If you're counting outcomes of fixed trials (n medications, n people), it's binomial.
#
# **Trap 2: Seeing "probability" and defaulting to binomial**
# - **Wrong:** "Probability of voting → must be binomial"
# - **Right:** "Voting is binary (yes/no), with fixed number of individuals (n), so it's binomial"
# - The word "probability" appears in both Poisson and binomial contexts, so it's not a distinguishing signal.
# - **Fix:** Look for the structure: fixed n trials with binary outcomes = binomial; random events over time = Poisson.
#
# **Trap 3: Missing the "time period" signal**
# - Phrases like "per year," "per week," "per month," "in an hour," "per day" signal **time-based Poisson**
# - Phrases like "n individuals," "sample of n," "n trials" signal **fixed-trial binomial**
# - **Fix:** Read for time/space references (Poisson) vs. fixed trial counts (binomial).
#
# **Trap 4: Assuming "average rate" means Poisson**
# - **True but incomplete:** Poisson does have an average rate (λ)
# - **But:** Binomial also has an average (n × p)
# - The difference: Poisson = average over a continuous time period; Binomial = average count from fixed trials
# - **Fix:** Don't just look for "average"; look for the structure around it (time period vs. fixed trials).
#
# ---
#
# **Real-world pattern recognition**
#
# **You'll hear Poisson language:**
# - "How many customer arrivals per hour?" → Poisson
# - "Average defects per 1,000 units?" → Poisson (continuous production)
# - "Website hits per day?" → Poisson
# - "Calls to support per hour?" → Poisson
#
# **You'll hear Binomial language:**
# - "Out of 500 survey respondents, how many said yes?" → Binomial (n=500, fixed)
# - "If we test 100 products, how many fail?" → Binomial (n=100, fixed)
# - "Among 50 patients, how many recover?" → Binomial (n=50, fixed)
#
# ---
#
# **Why the distinction matters**
#
# Choosing the wrong distribution leads to wrong probabilities and forecasts:
#
# | Scenario | Correct Model | Wrong Model | Consequence |
# |----------|---|---|---|
# | "Earthquakes in CA per year" | Poisson (λ=5) | Binomial (n=?, p=?) | Binomial requires fixed n; you'd misspecify the problem |
# | "Voting patterns in 500 people" | Binomial (n=500, p=0.6) | Poisson (λ=?) | Poisson is for continuous time; binomial is for fixed trials |
# | "Call centre volume per hour" | Poisson (λ=30) | Binomial (n=60, p=0.5) | Binomial assumes 60 "slots"; Poisson allows any count |
#
# ---
#
# **💡 Why This Matters**
#
# In business and analytics, misidentifying the distribution leads to bad decisions:
#
# 1. **Resource allocation:** A call centre forecasts call volume using Poisson (λ=30 calls/hour). If they mistakenly use binomial (n=60, p=0.5), they'll misforecast staffing needs.
#
# 2. **Quality control:** A factory models defects per batch using Poisson. If they treat it as binomial (each unit defective/not), they'll get different variance estimates.
#
# 3. **Risk management:** An insurance company models claim arrivals per month as Poisson (λ=100). Using binomial would be conceptually wrong and produce inaccurate tail probabilities.
#
# **Interview readiness:**
#
# Recruiter: *"We receive an average of 50 customer support tickets per day. How would you model the probability of receiving fewer than 40 tickets tomorrow?"*
#
# **Your answer:** "That's a Poisson process with λ = 50 (average tickets per day). I'd use the Poisson distribution to calculate P(X < 40 | λ = 50). Since 40 is below the mean, this probability would be relatively low — perhaps 15–20%. This helps us understand if tomorrow is a typical day or an unusual slow day."
#
# **Wrong answer (binomial thinking):** "I'd use binomial with n=50, p=0.5..." — This misses the point that tickets arrive continuously throughout the day, not as fixed trials.
#
# ---
#
# **✅ RECAP**
# - **Poisson process:** Events occur randomly over time/space at known average rate (λ)
# - **Binomial process:** Fixed number (n) of independent binary trials with fixed probability (p)
# - **Key signal for Poisson:** "per time period" (per day, per hour, per week, per year)
# - **Key signal for Binomial:** "out of n individuals/trials" or "n events tested"
# - **Poisson examples:** Earthquakes, book sales, website visits, customer arrivals, defects in production
# - **Binomial examples:** Voting, side effects, pass/fail tests, broken items in a sample
# - **Common error:** Confusing "counting" (both do this) with the underlying process structure (time-based vs. trial-based)
# - **Real pattern:** Poisson = "how many in this time period?"; Binomial = "how many successes in n fixed trials?"
#
# **🔗 Connection**
# - **Lesson 14:** Poisson distribution introduced (theory, λ parameter, probabilities)
# - **This lesson:** Identifying when Poisson applies vs. other distributions
# - **Next lesson (16):** Extracting λ from data; recognizing lambda in Poisson scenarios
# - **Chapter 4:** Using Poisson in hypothesis testing and goodness-of-fit tests

# %% [markdown]
# #### Chapter 3 — Lesson 16: Recognizing lambda in the Poisson distribution *(Exercise / 50 XP)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
#
# Can you identify the lambda (λ) parameter of a Poisson distribution by examining its histogram? This trains visual pattern recognition: the peak of a Poisson histogram always sits at λ. By looking at where the peak is, you instantly know λ.
#
# ---
#
# **📋 Scenario**
#
# You are presented with three Poisson distribution histograms (A, B, C). Each has a different lambda value. Your task: **Identify which histogram represents a Poisson distribution with λ = 2.**
#
# The key insight: The peak of any Poisson histogram is always at its lambda value.
#
# **Task:** Select one answer.
#
# ---
#
# **✅ Solution & Walkthrough**
#
# | Histogram | Peak Location (x-axis) | Lambda value | Verdict | Why |
# |-----------|---|---|---|---|
# | **A** | Peak at x ≈ 10 | λ ≈ 10 | ❌ Incorrect | This histogram's peak sits at approximately 10 on the "Number of Events" axis. Therefore, λ = 10, not 2. |
# | **B** | Peak at x ≈ 2–3 | λ ≈ 2 | ✅ **CORRECT** | This histogram's peak sits near x = 2–3. The most likely outcome is 2 events, so λ = 2. This is the distribution with λ = 2. |
# | **C** | Peak at x ≈ 10 | λ ≈ 10 | ❌ Incorrect | This histogram's peak sits at approximately 10 on the x-axis. Therefore, λ = 10, not 2. |
#
# **The correct answer: Option B**
#
# ---
#
# **Understanding the Peak = Lambda Principle**
#
# In a Poisson distribution, the **peak of the histogram is always at the lambda value**. This is because λ is both:
# 1. The **average number of events** (expected value E(X) = λ)
# 2. The **most likely outcome** (mode of the distribution)
#
# **Visualization principle:**
#
# ```
# Poisson Histogram Shape
# ├── Lambda (λ) = 2
# │   ├── Peak location: x = 2
# │   ├── Spread: mainly 0–5 events
# │   └── Histogram: narrow, concentrated
# │
# ├── Lambda (λ) = 10
# │   ├── Peak location: x = 10
# │   ├── Spread: mainly 5–15 events
# │   └── Histogram: wider spread
# │
# └── Lambda (λ) = 50
#     ├── Peak location: x = 50
#     ├── Spread: mainly 40–60 events
#     └── Histogram: even wider spread
# ```
#
# **Rule:** Wherever you see the tallest bar (peak), that x-value IS λ.
#
# ---
#
# **Why Your First Selection Might Have Been Wrong**
#
# If you initially selected **Option A or C**, here's why:
#
# **Trap 1: Confusing "large numbers" with "correct answer"**
# - Histograms A and C both have taller absolute peak heights (y-axis probability is higher)
# - But **height on the y-axis ≠ location of peak on x-axis**
# - You need to read the **x-axis position of the peak**, not the y-axis height
# - **Fix:** Always check "where is the peak on the x-axis?" not "how tall is the peak?"
#
# **Trap 2: Misreading the x-axis scale**
# - Histogram A has x-axis ranging 0–25, with peak at ~10
# - Histogram B has x-axis ranging 0–12, with peak at ~2–3
# - Histogram C has x-axis ranging 0–20, with peak at ~10
# - If you didn't carefully read the x-axis labels, you might mistake B for something else
# - **Fix:** Always trace horizontally from the peak down to the x-axis number
#
# **Trap 3: Assuming "smaller histogram = smaller lambda"**
# - Histogram B looks narrower and smaller overall
# - But that's because λ = 2 means events are clustered tightly around 2
# - Histogram A/C look "bigger" because λ = 10 means more spread
# - **Don't confuse:** Overall histogram size/spread with lambda value
# - **Fix:** λ affects spread AND peak location; focus on peak location on x-axis
#
# ---
#
# **Visual Reading Technique**
#
# **Step 1:** Locate the tallest bar in each histogram
# - A: tallest bar at x ≈ 10
# - B: tallest bar at x ≈ 2
# - C: tallest bar at x ≈ 10
#
# **Step 2:** Read that x-value from the axis
# - A: x = 10 → λ = 10
# - B: x = 2 → λ = 2 ✓
# - C: x = 10 → λ = 10
#
# **Step 3:** Match to the target (λ = 2)
# - Only B has peak at x = 2 → **Answer is B**
#
# ---
#
# **Common Patterns for Lambda Recognition**
#
# **λ = 2:**
# - Peak at x ≈ 2
# - Narrow distribution (spread 0–5 mainly)
# - Very low y-axis probabilities (because outcomes are concentrated)
# - Real example: 2 customer arrivals per hour
#
# **λ = 10:**
# - Peak at x ≈ 10
# - Moderate spread (spread 5–15 mainly)
# - Medium y-axis probabilities
# - Real example: 10 website visits per minute
#
# **λ = 50:**
# - Peak at x ≈ 50
# - Wide spread (spread 40–60 mainly)
# - Low y-axis probabilities (spread across many values)
# - Real example: 50 orders per day
#
# **Pattern:** As λ increases:
# - Peak moves RIGHT on x-axis
# - Spread increases
# - Y-axis probabilities decrease (same probability distributed over more outcomes)
#
# ---
#
# **💡 Why This Matters**
#
# In real analytics, you'll often see a histogram and need to instantly identify λ:
#
# 1. **Forecasting:** "Here's a Poisson histogram of daily customer orders. What's the expected value (lambda)?"
#    - Look at the peak → that's your λ → that's your forecast
#
# 2. **Quality control:** "This is our defect count histogram. What's the average defect rate (lambda)?"
#    - Find the peak → read x-value → that's λ
#
# 3. **Resource planning:** "Website traffic follows Poisson. This histogram shows visits per hour. How many servers do we need for average traffic?"
#    - Peak location = λ = expected number of visits per hour → guides server capacity
#
# **Interview readiness:**
#
# Recruiter: *"We've collected data on customer service calls per hour over a month. Here's the histogram of the Poisson distribution. What's lambda?"*
#
# **Your answer:** "I'd look for the peak of the histogram on the x-axis. Wherever the tallest bar is located — that x-value is lambda. If the peak is at 15 calls per hour, then λ = 15, meaning we expect 15 calls on average and should staff accordingly."
#
# This shows you understand the direct connection between visual histogram and parameter value.
#
# ---
#
# **✅ RECAP**
# - **Peak = Lambda:** In Poisson histograms, the peak always occurs at x = λ
# - **Recognition rule:** Find tallest bar → read its x-value → that's λ
# - **Why it works:** λ is both the average (expected value) AND the most likely outcome (mode)
# - **As λ increases:** Peak moves right, spread increases, individual probabilities decrease
# - **Common trap:** Confusing y-axis height with x-axis location; always read x-position of peak
# - **Real pattern:** Poisson histogram tells you everything — just read the peak position
# - **Interview signal:** "What's lambda?" → "Where's the peak?" → instant answer
#
# ---
#
# ## 📊 CHAPTER 3 MASTERY STATEMENT
#
# **Chapter 3 built the foundation of discrete and continuous probability distributions with a focus on recognizing and applying them.**
#
# Starting from the **binomial distribution** (fixed trials, binary outcomes — Lessons 1–4), through the **normal distribution** (continuous, symmetric, ubiquitous — Lessons 5–9), to the **Central Limit Theorem** (the bridge connecting all distributions to normality — Lessons 10–12), and finishing with the **Poisson distribution** (random events at constant rate — Lessons 13–16) — this chapter trained both theory and pattern recognition.
#
# **What this chapter established:**
# - Every dataset can be classified into a distribution family (binomial, normal, Poisson, etc.)
# - Distribution parameters (n, p, μ, σ, λ) fully determine the shape and probabilities
# - The Central Limit Theorem is the most powerful principle in statistics — it makes parametric testing possible
# - Visual literacy: You can instantly recognize a distribution shape and extract its parameters
#
# **The key mental shift:** From "probability is a calculation" (Chapter 2) to "distributions are models of reality" (Chapter 3). You now see data as generated by distributions and can match the right model to the right phenomenon.
#
# **Chapter 3 complete: 1,000 / 1,000 XP ✅**
#
# | Chapter | Lessons | XP | Status |
# |---|---|---|---|
# | Ch1: Summary Statistics | 12/12 | 750/750 | ✅ |
# | Ch2: Probability & Distributions | 13/13 | 750/750 | ✅ |
# | Ch3: More Distributions & CLT | 16/16 | 1,000/1,000 | ✅ |
# | Ch4: Hypothesis Testing & Correlation | 0/15 | 0/950 | ⏳ |
# | **Total** | **41/56** | **2,500/3,450** | **72.5%** |
#
# ---
#
# **🔗 Connection to Chapter 4**
# - **Chapter 3** taught you to recognize and work with distributions
# - **Chapter 4** will teach you to **test** hypotheses using distributions (z-tests, t-tests, correlation)
# - Everything Chapter 4 does relies on Chapter 3 foundations: CLT, normal distribution, and parameter estimation

# %% [markdown]
# # Data Storytelling — Skill Track
#
# **Platform:** DataCamp
# **Type:** Theory + Case Studies (Courses 3 & 4 include Python/CSV)
# **Duration:** 6 hours | 4 courses
# **Certification:** None
#
# ---
#
# **Track Description:**
# Dive into the world of data storytelling and learn how to transform raw information into compelling narratives.
# This track is the communication layer — it answers the question: once you have the insight, how do you make someone care?
#
# ---
#
# ## Table of Contents
#
# 1. [Course 1: Communicating Data Insights](#course-1)
# 2. [Course 2: Data Storytelling Concepts](#course-2)
# 3. [Course 3: Case Study — College Majors](#course-3)
# 4. [Course 4: Case Study — Green Businesses](#course-4)
#
# ---
#
# > 📌 **How to use this notebook:**
# > Courses 1 and 2 are pure theory — concepts and frameworks.
# > Courses 3 and 4 are case studies with real datasets — we will connect them to CSV files when we reach them.
# > Every concept here directly feeds the storytelling block we add to all practical exercises.

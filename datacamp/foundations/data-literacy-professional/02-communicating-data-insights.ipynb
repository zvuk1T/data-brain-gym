# %% [markdown]
# ## Course 2: Communicating Data Insights <a id="course-2"></a>
#
# **Level:** Basic | **Updated:** December 2025
# **Duration:** 2 hr | 12 videos | 38 exercises | 78,113 participants
# **XP:** 2600 | **Status:** ✅ Complete
# **Part of tracks:** Data Literacy Professional · Data Storytelling
# **Instructor:** Joe Franklin (Head of Business Insights Curriculum at DataCamp)
#
# > 🎯 **Key question this course answers:** How do you communicate data insights clearly and compellingly?
#
# **Course description:**
# Data-driven organizations consistently rely on insights to inspire action and drive change. Communicating these insights clearly and effectively is becoming increasingly important to stand out in our data-rich environment. This non-technical course will give you the skills to feel confident in understanding and communicating data insights. You'll learn why insights from data are valuable to organizations, how to select the proper method for sharing your knowledge with others, and how to distinguish between the four types of communication. Next, you will uncover why visualizations are one of the most powerful tools for communicating data insights and how to apply best practices behind compelling visualizations. You'll finish by diving into data storytelling — narrative, visualizations, and context — to become an expert communicator with data.
#
# ---
#
# ### Chapter 1: Communicating Information
#
# *In this chapter, you will learn about how we communicate with each other and begin developing best practices for sharing data insights.*
# *Arc: L1–4 → communication types · L5–7 → insight framework · L8–11 → audience analysis*
#
# | # | Lesson | Type | XP |
# |---|--------|------|----|
# | 1 | How is knowledge shared | 🎬 Video | 50 |
# | 2 | Communication types | 📝 Exercise | 50 |
# | 3 | Communication journey | 📝 Exercise | 100 |
# | 4 | Becoming a more effective communicator | 📝 Exercise | 50 |
# | 5 | Data insights | 🎬 Video | 50 |
# | 6 | Insightful characteristics | 📝 Exercise | 50 |
# | 7 | Insightful journey | 📝 Exercise | 100 |
# | 8 | Getting to know your audience | 🎬 Video | 50 |
# | 9 | Audience information | 📝 Exercise | 100 |
# | 10 | Factoring importance | 📝 Exercise | 50 |
# | 11 | Communication framework | 📝 Exercise | 100 |
#
# ---
#
# ### Chapter 2: Effective Data Visuals
#
# *In this chapter, you'll explore and understand the principles guiding simple visualizations and discover the goals and impact of effective data visuals.*
# *Arc: L1–3 → why visuals + planning · L4–6 → foundation chart types · L7–9 → advanced visuals · L10–12 → guiding principles*
#
# | # | Lesson | Type | XP |
# |---|--------|------|----|
# | 1 | Visualizing Success | 🎬 Video | 50 |
# | 2 | Visual impact | 📝 Exercise | 50 |
# | 3 | Building a plan | 📝 Exercise | 100 |
# | 4 | Beginning visualization | 🎬 Video | 50 |
# | 5 | Charting basics | 📝 Exercise | 50 |
# | 6 | Plotting the course | 📝 Exercise | 100 |
# | 7 | Advanced visuals | 🎬 Video | 50 |
# | 8 | Seeking Alignment | 📝 Exercise | 50 |
# | 9 | Finding a vision | 📝 Exercise | 100 |
# | 10 | Guiding principles of visualization | 🎬 Video | 50 |
# | 11 | Navigating priorities | 📝 Exercise | 50 |
# | 12 | Visualization best practices | 📝 Exercise | 100 |
#
# ---
#
# ### Chapter 3: Storytelling with Data
#
# *In this chapter, you'll learn about data storytelling and how it's a powerful tool for communicating data insights. You will understand the power and importance of telling a good story and walk through an example of data storytelling in action.*
# *Arc: L1–3 → what storytelling is · L4–6 → keys + structure · L7–10 → storytelling in action · L11–15 → group framework + wrap-up*
#
# | # | Lesson | Type | XP |
# |---|--------|------|----|
# | 1 | Data storytelling | 🎬 Video | 50 |
# | 2 | Building a story | 📝 Exercise | 50 |
# | 3 | Important call | 📝 Exercise | 100 |
# | 4 | Keys to a good story | 🎬 Video | 50 |
# | 5 | Defining the goal | 📝 Exercise | 50 |
# | 6 | Narrative and context | 📝 Exercise | 100 |
# | 7 | Storytelling in action | 🎬 Video | 50 |
# | 8 | Telling a good story | 📝 Exercise | 50 |
# | 9 | Guiding a story | 📝 Exercise | 100 |
# | 10 | Delivering a story | 📝 Exercise | 100 |
# | 11 | Data storytelling group framework | 🎬 Video | 50 |
# | 12 | Organizing success | 📝 Exercise | 50 |
# | 13 | Aligning roles | 📝 Exercise | 100 |
# | 14 | Teamwork for success | 📝 Exercise | 100 |
# | 15 | Wrap-up | 🎬 Video | 50 |

# %% [markdown]
# #### Chapter 1 — Lesson 1: How is knowledge shared *(Video / 50 XP)*
#
# > 🎬 [Watch on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/communicating-information?ex=1) *(requires login)*
#
# ---
#
# **🎯 GOAL — What is this lesson about?**
# Establish the four types of communication — written, visual, nonverbal, verbal — their strengths, weaknesses, and keys to success. The foundation for everything that follows in this course.
#
# ---
#
# **🧠 Mental Map — The 4 Types of Communication**
#
# ```
# COMMUNICATION
# ├── WRITTEN
# │   ├── Key 1: appropriate format — match complexity to message
# │   ├── Key 2: conciseness — clear statement + only what supports it
# │   └── Challenge: balancing detail vs. brevity is the hardest part
# │
# ├── VISUAL
# │   ├── Charts, graphs, pictures, videos, infographics
# │   ├── Most common in the digital era — widest reach, easiest to digest
# │   ├── Key: fewer elements → less distraction → clearer message
# │   ├── Challenge: picking the right format — extensive guidelines, easy to get wrong
# │   └── Best use: hook attention → pair with written to deliver depth
# │
# ├── VERBAL
# │   ├── Spoken and heard
# │   ├── Key 1: right tone for the audience
# │   ├── Key 2: consistent message
# │   ├── Strength: real-time flexibility — pivot, highlight, connect in the moment
# │   └── ⚠️ Rigid scripts waste the medium — flexibility is the whole point
# │
# └── NONVERBAL
#     ├── Facial expressions, posture, eye contact
#     ├── NOT the speaker's tool — it is the audience's signal
#     └── Function: measures whether the message is landing or missing the mark
# ```
#
# > *Adept communicators blend all four methods — no single type is sufficient on its own. Visual hooks attention. Written delivers depth. Verbal creates connection. Nonverbal closes the feedback loop.*
#
# ---
#
# **💡 Why this matters**
# Every analyst eventually has to communicate findings to someone who did not run the analysis. Knowing which communication type to use — and when to combine them — determines whether insights drive action or get ignored. A technically perfect analysis presented in the wrong format, at the wrong level of detail, with no awareness of audience signals is wasted work. This framework is the lens through which every communication decision in the rest of the course is made.
#
# **✅ RECAP**
# - 4 types: Written, Visual, Nonverbal, Verbal — each with distinct strengths and failure modes
# - Visual is the widest-reaching and easiest to digest — but picking the right format is the hardest challenge
# - Verbal's greatest strength is real-time flexibility — following a rigid script destroys that advantage
# - Nonverbal is the audience's feedback channel, not the speaker's tool — watch it to know if the message is landing
# - Key question: *"Which combination of communication types serves this audience and this message?"*

# %% [markdown]
# #### Chapter 1 — Lesson 2: Communication types *(Exercise / 50 XP)*
#
# > 📝 [Practice on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/communicating-information?ex=2) *(requires login)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Ability to identify inaccurate claims about communication types — specifically recognising when a strength is misrepresented as a limitation.
#
# ---
#
# **📋 Scenario**
# Blending different communication styles creates powerful messaging. Which of the following is **not** an accurate summary of the type of communication someone may utilize when sharing information?
#
# ---
#
# **✅ Solution**
#
# | Answer | Accurate? | Why |
# |--------|-----------|-----|
# | Verbal communication relies on being adaptable to best reach the audience | ✅ Accurate | Verbal's defining strength is real-time adaptability — strong communicators modify delivery to meet audience needs |
# | **Visual communication isn't formal enough to be taken seriously on its own and requires other forms to be effective** | ❌ **NOT accurate — correct answer** | Visual is used at every level of organizations; it can stand alone and be paired with others to *increase* impact — not because it *requires* them |
# | Written communication is useful as both a primary method and a secondary supporting method | ✅ Accurate | Written is very flexible in its role — works as the main vehicle or as supporting documentation |
# | Nonverbal communication helps communicators focus their message | ✅ Accurate | Nonverbal signals how well information is being relayed — gives the speaker feedback to adjust |
#
# > ⚠️ The trap: confusing *"can be paired with others"* with *"requires others to be taken seriously."* Pairing is a choice to increase impact. Requiring others would mean visual communication is inherently insufficient — which is the opposite of what the course teaches.
#
# ---
#
# **💡 Why this matters**
# Analysts often treat charts as supplements — something added to a written report to look better. This exercise corrects that assumption directly: visual communication operates at every level of an organization and needs no apology. A well-built chart can be the primary communication vehicle. Understanding this changes how you structure presentations — the visual is not decoration, it is the message.
#
# ---
#
# **✅ RECAP**
# - The NOT accurate claim: visual communication "isn't formal enough" and "requires other forms" — both wrong
# - Visual communication stands alone and is used at every level of organizations
# - Pairing visuals with other forms *increases* impact — it is a deliberate choice, not a structural necessity
# - Written is highly flexible: works as the primary vehicle or as supporting context
# - Nonverbal is a feedback signal — it tells the communicator whether the message is landing

# %% [markdown]
# #### Chapter 1 — Lesson 3: Communication journey *(Exercise / 100 XP)*
#
# > 📝 [Practice on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/communicating-information?ex=3) *(requires login)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Ability to sequence communication types in the correct order as they appear in a real interaction — including recognising non-verbal cues as a reactive, not proactive, communication act.
#
# ---
#
# **📋 Scenario**
# Tyler, a marketing intern for a national bakery, is sharing results with a coworker Matt. Starting with the earliest, arrange the types of communication Tyler utilized or *reacted to* in order to deliver or guide his messaging.
#
# Events in the story:
# 1. Tyler decides a video call is the best way to talk through his findings
# 2. During the call, Tyler sees Matt looking away and messaging other coworkers — Matt isn't engaged
# 3. Tyler follows up with a quick email containing a **chart** of the results, grabbing Matt's attention
# 4. Matt asks for more info — Tyler sends the rest of the **written report**
#
# ---
#
# **✅ Solution — correct order**
#
# | Order | Communication type | Event in story | Why this type |
# |-------|-------------------|----------------|---------------|
# | 1st | **Verbal** | Video call to talk through findings | Spoken and heard — video call is verbal |
# | 2nd | **Non-verbal** | Tyler sees Matt looking away, messaging others | Non-verbal cues are the audience's signal — Tyler is *reacting* to Matt's disengagement |
# | 3rd | **Visual** | Follow-up email with a chart | Charts and graphs = visual communication; the chart is what grabs Matt's attention |
# | 4th | **Written** | Sends the full written report | Anything communicated through text — the report is written |
#
# > ⚠️ The trap here is the email + chart combo. The email is *written*, but what grabs attention is the *chart* — making the primary communication act in that step visual. The written report comes last as a separate, distinct step.
#
# ---
#
# **💡 Why this matters**
# Real communication rarely uses one type at a time. Tyler's journey shows how a single business interaction naturally flows through verbal → nonverbal → visual → written — each type triggered by what the previous one revealed. Noticing that Matt's nonverbal cues (disengagement) caused Tyler to switch strategy is the key analytical move: good communicators read feedback signals and adapt. That is the loop the course is building toward.
#
# ---
#
# **✅ RECAP**
# - Correct order: Verbal → Non-verbal → Visual → Written
# - Non-verbal was not Tyler's tool — it was Matt's signal that Tyler *read* to change his approach
# - The chart (visual) comes before the report (written) — both appear in the follow-up phase but visual grabs attention first
# - Real communication is adaptive: each type informs the next move
# - Key principle: *non-verbal cues are the feedback signal that tells you whether to switch strategy*

# %% [markdown]
# #### Chapter 1 — Lesson 4: Becoming a more effective communicator *(Exercise / 50 XP)*
#
# > 📝 [Practice on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/communicating-information?ex=4) *(requires login)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Ability to distinguish between genuine communication guidelines and a statement that inverts a core principle — specifically the rule that visuals must simplify, not mirror, complexity.
#
# ---
#
# **📋 Scenario**
# When trying to improve communication methods, it is important to consider the strengths and weaknesses of each of the four types. Which of the following is **not** a guideline for improving communication?
#
# ---
#
# **✅ Solution**
#
# | Answer | Guideline? | Why |
# |--------|-----------|-----|
# | Rely on tone to connect with the audience | ✅ Valid guideline | Verbal communication adapts tone to the needs of the audience — tone is the primary lever |
# | Balance simplicity with sufficient background information | ✅ Valid guideline | Written communication relies on succinct delivery — balancing brevity with enough context is the core written challenge |
# | **Rely on complex visualizations to simplify concepts** | ❌ **NOT a guideline — correct answer** | Visual communication's job is to *simplify* complex ideas into easily consumable imagery — the visual itself should be simple, not complex |
# | Remain flexible during delivery | ✅ Valid guideline | Verbal communication adapts in real time — flexibility during delivery is the medium's defining strength |
#
# > ⚠️ The trap: *"rely on complex visualizations to simplify concepts"* sounds logical — use a detailed visual to handle a detailed topic. But the guideline is the opposite: the visual should reduce complexity, not mirror it. A complex visualization creates a new barrier instead of removing the original one.
#
# ---
#
# **💡 Why this matters**
# Every time an analyst builds a chart with 12 variables, 3 colour scales, and no clear title, they have violated this guideline. The instinct is to show everything — to prove the analysis was thorough. The result is a chart that requires explanation to read, which means the visual has failed its one job: making the insight immediately accessible. Simplicity in visualisation is not a design preference — it is the functional requirement.
#
# ---
#
# **✅ RECAP**
# - Visual communication guideline: simplify complex ideas into easily consumable imagery — the visual is not complex, the concept is
# - Verbal guideline: adapt tone + remain flexible — the audience shapes the delivery in real time
# - Written guideline: balance simplicity with sufficient background — brevity without context is confusion
# - Nonverbal function: reveals how the message is being perceived — it is a reading tool, not a delivery tool
# - The NOT guideline: "rely on complex visualizations" — complexity in the visual defeats the purpose of using a visual

# %% [markdown]
# #### Chapter 1 — Lesson 5: Data insights *(Video / 50 XP)*
#
# > 🎬 [Watch on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/communicating-information?ex=5) *(requires login)*
#
# ---
#
# **🎯 GOAL — What is this lesson about?**
# Define what a data insight is, show how insights are uncovered through a 6-step process, and establish the three best practices that make insights communicable and actionable.
#
# ---
#
# **🧠 Mental Map — From Data to Insight**
#
# ```
# DATA INSIGHT
# │  Definition: deep understanding of a situation
# │  Purpose: drive change from within, in a structured way
# │
# ├── HOW INSIGHTS ARE UNCOVERED — 6-step process
# │   ├── 1. Collect    → gather data on a business problem
# │   ├── 2. Organise   → structure the data
# │   ├── 3. Analyse    → distil through analytical techniques → underlying knowledge
# │   ├── 4. Apply      → connect knowledge to business actions → actionable insight
# │   ├── 5. Communicate → share the insight + action plan
# │   └── 6. Observe    → monitor the outcome
# │   ⚠️ Every insight must be shared to impact an organisation — unshared insight = zero value
# │
# ├── WHAT INSIGHTS LOOK LIKE — examples
# │   ├── Right product mix for next year's sales forecast
# │   ├── Minimising risk while managing expenses
# │   ├── Optimising employee overtime scheduling
# │   └── Managing supply chain disruptions
# │   → Insights can be high-level operational OR minor — both are valuable
# │
# └── 3 BEST PRACTICES for communicating insights
#     ├── 1. Tie to business objectives → shared language, built-in context
#     ├── 2. Add supporting information → same insight looks different per stakeholder
#     │      ⚠️ One size fits all suits no one — tailor per audience
#     └── 3. Keep it simple → simple + actionable > complex + unactionable
# ```
#
# > *The analysis phase varies most between situations. But the end requirement is always the same: the insight must be communicated. Everything else is preparation.*
#
# ---
#
# **💡 Why this matters**
# Most analysts think their job ends at step 4 — applying knowledge to produce an insight. But steps 5 and 6 (communicate and observe) are where the insight actually creates value. An insight that lives in a spreadsheet changes nothing. The three best practices exist because communication is where insights most commonly fail: too abstract (no business objective grounding), too uniform (one version for all stakeholders), or too complex (can't be acted on). Every data role is, at its core, an insight communication role.
#
# **✅ RECAP**
# - Insight = deep understanding of a situation → enables structured change
# - 6-step process: Collect → Organise → Analyse → Apply → Communicate → Observe
# - Step 5 (Communicate) is not optional — an unshared insight has zero organisational impact
# - Best practice 1: always tie to business objectives — shared language reduces friction
# - Best practice 2: tailor per stakeholder — one size fits all suits no one
# - Best practice 3: simple and actionable beats complex and theoretically complete

# %% [markdown]
# #### Chapter 1 — Lesson 6: Insightful characteristics *(Exercise / 50 XP)*
#
# > 📝 [Practice on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/communicating-information?ex=6) *(requires login)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Ability to distinguish the required characteristics of an actionable insight from a statement that describes scale of impact — which is not a required property.
#
# ---
#
# **📋 Scenario**
# Which of the following is **not** a required characteristic of an actionable insight?
#
# ---
#
# **✅ Solution**
#
# | Answer | Required? | Why |
# |--------|-----------|-----|
# | Possesses a clear set of actions that can be taken as a result of the findings | ✅ Required | Actionability is definitional — an insight that cannot be acted on is not actionable |
# | Focuses on simplicity to enhance communication | ✅ Required | Insights strive for ease of sharing and comprehension — complexity blocks action |
# | **Creates large impacts on business processes and procedures** | ❌ **NOT required — correct answer** | Insights can be minor and still valuable — impact size is not a requirement; actionability and relevance are |
# | Relates to business objectives and outcomes | ✅ Required | Insights must support change with data and utilise common organisational language — business objectives provide the anchor |
#
# > ⚠️ The trap: "large impact" sounds like what makes an insight worth communicating. But the course explicitly states that insights can impact minor outcomes and still be valuable. Scale is not a quality criterion — actionability, simplicity, and alignment to objectives are.
#
# ---
#
# **💡 Why this matters**
# Waiting for "big enough" insights before communicating is one of the most common ways analysts delay impact. Small, clearly communicated, actionable findings — tied to a business objective — are more valuable than large, complex, unactionable ones. The three required properties (actionable, simple, aligned to objectives) are a checklist for every insight before it is shared. Scale is a nice-to-have, not a gate.
#
# ---
#
# **✅ RECAP**
# - Required characteristics: actionable (clear next steps) + simple (easy to share) + aligned to business objectives
# - NOT required: large impact — insights can be minor and still valuable
# - The test for an insight: can someone act on it? Is it understandable? Does it connect to something the organisation cares about?
# - Common mistake: withholding small insights waiting for something "big enough" — small insights compound

# %% [markdown]
# #### Chapter 1 — Lesson 7: Insightful journey *(Exercise / 100 XP)*
#
# > 📝 [Practice on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/communicating-information?ex=7) *(requires login)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Ability to apply the 6-step insight discovery process to a real scenario — sequencing tasks from business question through to sharing findings.
#
# ---
#
# **📋 Scenario**
# Gabriel is working on improving his organisation's approach to scheduling resources. His organisation is looking for a data-driven solution and tasks him with uncovering insights to guide their decision.
#
# **Task:** Arrange Gabriel's tasks in the correct order to create a strong data-driven insight.
#
# ---
#
# **✅ Solution — correct order**
#
# | Order | Step | Gabriel's action | Process stage |
# |-------|------|-----------------|---------------|
# | 1st | **Collect** | Gabriel considers two different approaches to how his organisation can improve their scheduling process | Define the business question — the starting point before any data is touched |
# | 2nd | **Organise** | Gabriel identifies, collects and organises data relevant to his inquiry | Gather and structure the right data for the question |
# | 3rd | **Analyse** | Gabriel analyses his dataset revealing the factors that influence scheduling success | Distil data through analytical techniques to uncover underlying knowledge |
# | 4th | **Apply** | Gabriel selects the best method to communicate his insights | Translate knowledge into an actionable insight + choose the delivery format |
# | 5th | **Communicate** | Gabriel shares his insights with his organisation and responds to any questions that arise | Share the insight and action plan — where value is actually created |
#
# > ⚠️ Step 1 is a *business question* step, not a data collection step — Gabriel is considering two approaches before touching any data. The question must exist before the data is sought. Collecting the right data requires a strong business-oriented question.
#
# ---
#
# **💡 Why this matters**
# Gabriel's story maps directly onto the 6-step process from L5 — but makes it tangible. The most important observation: step 1 is framing the business question, not collecting data. This is the most commonly skipped step in practice — analysts go straight to the data they have rather than first defining what they need. The result is robust datasets analysed in great detail that answer the wrong question. The process starts with the question, not the data.
#
# ---
#
# **✅ RECAP**
# - Correct order: Business question → Collect & Organise → Analyse → Apply → Communicate
# - Step 1 is framing the question — not collecting data; strong insights require strong business-oriented questions
# - Strong insights require robust datasets analysed in great detail — but only after the right question is defined
# - Sharing is the final and essential step — the goal of a data-driven organisation is to share insights effectively
# - The process mirrors L5's 6-step framework applied to a real scheduling problem

# %% [markdown]
# #### Chapter 1 — Lesson 8: Getting to know your audience *(Video / 50 XP)*
#
# > 🎬 [Watch on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/communicating-information?ex=8) *(requires login)*
#
# ---
#
# **🎯 GOAL — What is this lesson about?**
# Introduce a 3-question audience analysis framework and show how it shapes communication strategy — using Harold at Buildingsway as a concrete example with three distinct stakeholders.
#
# ---
#
# **🧠 Mental Map — Audience Analysis Framework**
#
# ```
# AUDIENCE ANALYSIS — 3 questions before any communication plan
# │
# ├── Q1: What ROLES does your audience perform?
# │   └── Role determines what the insight means to them
# │       and what decisions they need to make from it
# │
# ├── Q2: What do they ALREADY KNOW — and what do they NEED TO KNOW?
# │   └── Technical depth varies per stakeholder
# │       → match depth to background, focus on what moves them
# │
# └── Q3: How well does your audience KNOW YOU?
#     └── Prior relationship determines formality and trust baseline
#         → new relationship = more iterations, more formal
#
# ↓  applied to: HAROLD at BUILDINGSWAY
#    Insight: focus on indoor treehouses + retractable roofs
#
# ├── PAUL (Head of Analytics)
# │   Role: evaluates new methods → skeptical of Harold's research approach
# │   Know: little about initiative; solid technical background
# │   Need: deep process and analytics justification
# │   Relationship: first time working together → formal, allow more iterations
# │
# ├── YURI (Warehouse Manager)
# │   Role: sources materials for each job
# │   Know: non-technical; results-level only
# │   Need: what items to stock + expected availability
# │   Relationship: existing — no adjustment needed
# │
# └── LORRAINE (Head of Sales)
#     Role: drives sales of building options
#     Know: non-technical; results-level only
#     Need: anticipated popularity of new options
#     Relationship: existing — no adjustment needed
# ```
#
# > *The three questions are not exhaustive — they are a starting spark. The goal is to get into the mindset of the audience before designing the communication, not after.*
#
# ---
#
# **💡 Why this matters**
# Harold has one insight: indoor treehouses + retractable roofs. But he needs three completely different conversations to communicate it. Paul needs to trust the methodology. Yuri needs to know what to order. Lorraine needs to know what will sell. Same data, three framings — because the audience is the communication. Analysts who skip this step deliver one presentation to three different people and wonder why only one of them acted on it.
#
# **✅ RECAP**
# - 3 audience questions: What roles? What do they know/need? How well do they know you?
# - Same insight → different framing per stakeholder — one-size-fits-all suits no one
# - Technical depth must match the audience: Paul → deep process; Yuri + Lorraine → results only
# - Prior relationship calibrates formality and number of iterations needed
# - Buildingsway running example: Harold, Paul, Yuri, Lorraine — returns in Ch3 storytelling in action

# %% [markdown]
# #### Chapter 1 — Lesson 9: Audience information *(Exercise / 100 XP)*
#
# > 📝 [Practice on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/communicating-information?ex=9) *(requires login)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Ability to distinguish audience information that helps calibrate a communication strategy from information that is personally irrelevant — applying the L8 audience analysis framework to a new stakeholder.
#
# ---
#
# **📋 Scenario**
# Harold, an analyst at Buildingsway, is working on a presentation for a new stakeholder, Elise. Harold has never met Elise and is reaching out to her and his contacts within Buildingsway to gather information to prepare.
#
# **Task:** Determine what information is useful for Harold and what information won't help him in communicating his insights.
#
# ---
#
# **✅ Solution**
#
# | Information | Category | Why |
# |-------------|----------|-----|
# | Elise prefers to read reports before any meetings | ✅ **Useful** | Communication format preference — tells Harold how to structure the pre-meeting material |
# | Elise is the new indoor treehouse designer | ✅ **Useful** | Her role directly relates to Harold's insight (indoor treehouses) — understanding her responsibilities shapes what she needs to know |
# | Elise is familiar with the demand for indoor treehouses and wants to know what options customers are requesting the most | ✅ **Useful** | What she already knows + what she needs to know — maps directly to Q2 of the audience framework |
# | Elise's favourite breed of dog | ❌ **Not useful** | Personal preference with no connection to her role, knowledge, or communication needs |
# | Where Elise's office is located | ❌ **Not useful** | Logistical detail — does not help Harold understand Elise's perspective, needs, or communication style |
#
# > *Knowing your audience allows you to: maintain expectations and anticipate needs; understand the impact of insights on their role; determine what they know and need to know; leverage shared background to iterate toward success.*
#
# ---
#
# **💡 Why this matters**
# Harold has never met Elise — so he is doing the right thing: gathering information before designing the communication. The three useful items map directly onto the L8 framework: format preference (how to communicate), role (why this insight matters to her), and what she knows/needs (what depth and angle to take). The two not-useful items are personal details — they say nothing about how to land an insight effectively. Preparation is not about knowing everything about a person; it is about knowing what shapes their perspective on your specific message.
#
# ---
#
# **✅ RECAP**
# - Useful audience information maps to: communication format preference, role and responsibilities, prior knowledge and information needs
# - Not useful: personal details unrelated to role or communication style
# - Harold is meeting Elise for the first time — the L8 rule applies: more formal, allow more iterations
# - Buildingsway running example continues: Harold → Paul, Yuri, Lorraine (L8) → now Elise (L9)
# - Key question before any presentation: *"What do I know about this person's role, knowledge, and preferences?"*

# %% [markdown]
# #### Chapter 1 — Lesson 10: Factoring importance *(Exercise / 50 XP)*
#
# > 📝 [Practice on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/communicating-information?ex=10) *(requires login)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Ability to identify the single most important factor in communicating data insights — distinguishing the audience-centred principle from other valid but secondary considerations.
#
# ---
#
# **📋 Scenario**
# Communicating insights has many different factors that come together and interact heavily with each other. What is the most important aspect to consider when communicating data insights?
#
# ---
#
# **✅ Solution**
#
# | Answer | Verdict | Why |
# |--------|---------|-----|
# | **How the message interacts with the intended recipients** | ✅ **Correct** | Communicating data insights requires changing your approach based on the needs of who you are communicating with — the audience is the primary factor that shapes everything else |
# | The expected complexity of the insights | ❌ | Complexity is a factor — but it is secondary to the audience. Complexity determines depth; the audience determines framing, format, and tone |
# | What format the insights will be utilised to communicate the insights | ❌ | Format is important but derived from the audience — you choose the format because of who will receive it, not independently |
# | The relationship between the insights and business objectives | ❌ | Alignment to business objectives is a best practice (L5) — but it is a property of the insight itself, not the most important communication factor |
#
# > *All four options are real considerations — this question tests prioritisation, not elimination. The audience is primary because every other decision flows from it: complexity, format, and framing all change based on who is in the room.*
#
# ---
#
# **💡 Why this matters**
# Format, complexity, and business alignment are all legitimate things to think about before communicating. But they are answers to the question "how should I communicate?" — and that question cannot be answered without first asking "who am I communicating with?" The audience is the constraint that makes all other decisions meaningful. Harold's three different conversations with Paul, Yuri, and Lorraine are the proof: same insight, completely different approaches — because the recipients changed.
#
# ---
#
# **✅ RECAP**
# - Most important factor: how the message interacts with the intended recipients — the audience is the primary lens
# - All other factors (complexity, format, business alignment) are derived from audience understanding
# - Changing your approach based on audience needs is not optional — it is the definition of effective communication
# - Key question before any communication: *"Who is receiving this, and what do they need from it?"*

# %% [markdown]
# #### Chapter 1 — Lesson 11: Communication framework *(Exercise / 100 XP)*
#
# > 📝 [Practice on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/communicating-information?ex=11) *(requires login)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Ability to sequence the 5 steps of the communication framework in the correct order — applying the three-principle structure (understand audience → understand message → understand how to share) to a concrete client scenario.
#
# ---
#
# **📋 Scenario**
# Kevin is creating a presentation for a new client he has never met before. This client is interested in signing up for Kevin's analytics service and wants to know key details before making the purchase. Kevin needs to determine how he should approach communicating with the client to earn their business.
#
# **Task:** Place the steps of the communication framework in the correct order for Kevin.
#
# ---
#
# **✅ Solution — correct order**
#
# | Order | Step | Framework principle |
# |-------|------|-------------------|
# | 1st | Understand the client's needs better — what details are most important to them and how do they want to explore these details | **Understand your audience** — Q1/Q2/Q3 from L8: role, knowledge, relationship |
# | 2nd | Compile insights and supporting information to give a complete picture of the information | **Understand the message** — what insight + what context is needed for this specific audience |
# | 3rd | Determine what method(s) of communication highlight the underlying insights the best | **Understand how to share** — format decision flows from audience + message, not the other way around |
# | 4th | Communicate the key information to the client and gather feedback | **Deliver + listen** — share the message and open the feedback loop |
# | 5th | Iterate and improve to find the best message | **Refine** — use feedback to improve; communication is not one-shot |
#
# > *The three key steps for success: understand your audience → understand the message you want to share → understand how to best share your message. Steps 4 and 5 are the execution and iteration that follow.*
#
# ---
#
# **💡 Why this matters**
# Kevin has never met this client — exactly Harold's situation with Elise in L9. The framework makes the process explicit: you cannot decide what format to use (step 3) before you understand what the client needs (step 1) and what you need to communicate (step 2). Skipping to format first is the most common mistake in presentation preparation — choosing slide templates before knowing who will see them. The framework forces the right order: audience → message → medium → deliver → refine.
#
# ---
#
# **✅ RECAP**
# - 5-step framework: Understand audience → Compile message → Choose format → Communicate + gather feedback → Iterate
# - 3 principles underlying the framework: understand audience / understand message / understand how to share
# - Format is step 3 — never step 1. Format decisions follow audience and message decisions
# - Iteration (step 5) is built in — communication is a loop, not a one-time event
# - Kevin's situation (new client, never met) triggers the L8 rule: more formal, allow more iterations
#
# ---
#
# > ✅ **Chapter 1 complete.** All 11 lessons of *Communicating Information* covered.
# > 3 video lessons · 8 exercise/practice lessons · 650 XP

# %% [markdown]
# ---
#
# ### 📋 Chapter 1 Recap — Communicating Information
#
# **The chapter in 4 sentences:**
# Communication happens across four types — Written, Visual, Verbal, Nonverbal — each with distinct strengths, failure modes, and guidelines; no single type is sufficient alone. A data insight is a deep understanding of a situation uncovered through a 6-step process, and it has zero value until it is communicated. The three best practices for communicating insights — tie to business objectives, add supporting context, keep it simple — exist because the same insight lands completely differently depending on how it is framed. The most important factor in all of this is the audience: their role, their prior knowledge, and their relationship with you determine every other decision — format, depth, tone, and how many iterations you will need.
#
# **Mental map — Chapter 1 structure:**
#
# ```
# CHAPTER 1 — COMMUNICATING INFORMATION
# │
# ├── HOW WE COMMUNICATE (L1–L4)
# │   ├── 4 types: Written · Visual · Verbal · Nonverbal
# │   ├── Each has a strength + a failure mode + a guideline
# │   └── Effective = matching type to message and audience
# │
# ├── WHAT WE COMMUNICATE (L5–L7)
# │   ├── Insight = deep understanding → actionable + simple + tied to objectives
# │   ├── 6-step process: Collect → Organise → Analyse → Apply → Communicate → Observe
# │   └── Unshared insight = zero organisational value
# │
# └── WHO WE COMMUNICATE WITH (L8–L11)
#     ├── 3 audience questions: Roles? Knowledge/needs? Relationship?
#     ├── 5-step framework: Audience → Message → Format → Deliver → Iterate
#     ├── Running example: Harold / Buildingsway / Paul · Yuri · Lorraine · Elise
#     └── Most important factor: how the message interacts with the intended recipients
# ```
#
# **Key principle from this chapter:**
# The audience is not the last thing you think about — it is the first. Every other decision (format, depth, complexity, framing) is derived from understanding who is in the room and what they need from your insight.

# %% [markdown]
# #### Chapter 2 — Lesson 1: Visualizing Success *(Video / 50 XP)*
#
# > 🎬 [Watch on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/effective-data-visuals?ex=1) *(requires login)*
#
# ---
#
# **🎯 GOAL — What is this lesson about?**
# Establish *why* visualizations work — the brain processes visual patterns faster than raw numbers — and show that summary statistics alone can actively mislead, making plotting not optional but necessary.
#
# ---
#
# **🧠 Mental Map — Why Visualizations Matter**
#
# ```
# WHY VISUALIZATIONS MATTER
# │
# ├── THE COGNITIVE ARGUMENT
# │   ├── Raw array of numbers → brain must count manually → slow, error-prone
# │   ├── Highlight one value visually → instant pattern recognition, no counting needed
# │   └── A well-placed graphic opens a gateway to deeper understanding
# │       → visualizations translate data into a form the brain is built to process
# │
# ├── WHAT VISUALIZATIONS DO
# │   ├── Aggregate and summarize → trends and patterns become immediately visible
# │   ├── Reduce complexity — as the dataset grows, the chart stays equally readable
# │   └── Replace raw data as the primary medium for communicating data insights
# │
# ├── POSITIVE IMPACT CHAIN
# │   ├── Decision makers → react faster → better decisions
# │   ├── Broader appeal → reaches more stakeholders, inspires action
# │   └── More honest than mean/median → single-measure aggregation hides distribution
# │       → plots reveal what averages conceal
# │
# └── ⚠️ THE DATASAURUS LESSON — looks can be deceiving
#     ├── Two datasets: identical mean, median, and summary stats
#     ├── Plotted: one is a dinosaur, the other is a star
#     ├── 12 different charts — all share the same summary information
#     └── Rule: always plot your data — summary stats never show the whole picture
# ```
#
# > *Aggregating data into singular measures like mean and median doesn't show the whole picture and can easily mislead you to draw the wrong conclusions. Only the plot reveals the full distribution.*
#
# ---
#
# **💡 Why this matters**
# In practice, two products, two regions, or two cohorts can share an identical average while having completely different distributions — one healthy, one broken. An analyst who relies solely on summary statistics will miss this entirely and recommend the wrong action. The Datasaurus example (same stats, wildly different shapes) makes this concrete: the chart is not decoration to add after the analysis is done — it is part of the analysis. Visualizing data is how you verify that your summary statistics are actually telling the truth.
#
# ---
#
# **✅ RECAP**
# - Visualizations work because the brain processes visual patterns faster than raw numbers — this is cognitive, not aesthetic
# - Primary function: aggregate and summarize → make trends and patterns visible; complexity reduces even as data grows
# - Summary statistics (mean, median) collapse distributions into single numbers — and can actively mislead
# - The Datasaurus: 12 charts, identical summary stats, completely different shapes — always plot your data
# - Rule: a visualization is not the final step of communication — it is a required step of analysis

# %% [markdown]
# #### Chapter 2 — Lesson 2: Visual impact *(Exercise / 50 XP)*
#
# > 📝 [Practice on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/effective-data-visuals?ex=2) *(requires login)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Ability to identify the correct reason to use a visualization over raw data or numerical summaries — specifically distinguishing the legitimate function of a visual from manipulative or logistically false claims.
#
# ---
#
# **📋 Scenario**
# Visualizations are essential to sharing knowledge and insights in the modern data-saturated world. Which of the following is a reason to leverage a visualization over looking at the complete dataset or a numerical summary of a dataset?
#
# ---
#
# **✅ Solution**
#
# | Answer | Verdict | Why |
# |--------|---------|-----|
# | It is much easier to make a strong visualization than compute summary information | ❌ Not a reason | Ease of creation is not a reason to use a visual over summary stats — this is logistically false and irrelevant to the purpose of visualization |
# | Visualizations are harder to disprove and allow you to make the audience agree with your point of view | ❌ Not a reason | This describes manipulation, not communication — the purpose of a visual is clarity, not persuasion by obscuring alternative interpretations |
# | **Visualizations make it easier to understand trends and patterns in the dataset** | ✅ **Correct** | This is the core function: aggregate and summarize → make trends and patterns immediately visible and accessible |
# | Visuals prevent the audience from interrogating your data and finding errors | ❌ Not a reason | The opposite is true — good visuals invite interrogation; hiding errors is not a valid communication goal |
#
# > *Hint from DataCamp: The objective of a visualization is to simplify and highlight insights within a dataset.*
#
# ---
#
# **💡 Why this matters**
# The three wrong answers each describe a different kind of misuse of visualizations — logistical laziness, audience manipulation, and obscuring errors. All three are real temptations in practice. An analyst under pressure can unconsciously build a chart that hides distribution problems, or frame a visual to steer a conclusion. The correct answer — making trends and patterns easier to understand — is the only one that aligns with the fundamental purpose: reduce complexity so the insight is accessible, not to make the analysis look better than it is.
#
# ---
#
# **✅ RECAP**
# - Correct reason: visualizations make it easier to understand trends and patterns — that is their core function
# - Not a reason: ease of creation (irrelevant), manipulation (unethical), hiding errors (opposite of good practice)
# - Objective of a visualization: simplify and highlight insights — not to replace rigour, but to communicate it
# - Common mistake: using visuals to obscure rather than reveal — the test is whether the chart invites or deflects interrogation

# %% [markdown]
# #### Chapter 2 — Lesson 3: Building a plan *(Exercise / 100 XP)*
#
# > 📝 [Practice on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/effective-data-visuals?ex=3) *(requires login)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Ability to sort justifications for using visualizations into correct and incorrect — distinguishing the three legitimate outcomes of visualization usage from two statements that misrepresent how visuals work.
#
# ---
#
# **📋 Scenario**
# Paul is looking to leverage visualizations more and is preparing an action plan for his organisation to incorporate them more into their research. Reviewing his action plan, Paul realises some of his justifications for increased visualization usage missed the mark.
#
# **Task:** Sort Paul's action plan into correct and incorrect reasons for utilising visualization more often.
#
# ---
#
# **✅ Solution**
#
# | Statement | Category | Why |
# |-----------|----------|-----|
# | Decisions can be made much quicker with quality visualizations | ✅ **Correct** | Speed of decision-making is a direct positive outcome of visualization — patterns visible at a glance, no manual tallying |
# | Large and small datasets can be easily simplified the same way with effective visuals | ✅ **Correct** | Scalability is a core property — the summarised chart stays equally readable whether the underlying dataset grows or not |
# | Visualizations show a more complete picture than other types of aggregation techniques | ✅ **Correct** | Visualizations reveal distribution and shape that single-measure aggregations (mean, median) hide — the Datasaurus principle |
# | Patterns are harder to find but allow for better decision making | ❌ **Incorrect** | The opposite — visualizations make patterns *easier* to find; difficulty of pattern-finding contradicts the core value proposition |
# | A select group of decision makers will benefit greatly from using visualizations | ❌ **Incorrect** | Visual information appeals to a *broader* range of decision makers, not a select group — wider appeal is one of the three positive impacts from L1 |
#
# > *Hint from DataCamp — Outcomes of visualization usage: faster and better decision making · wider appeal to decision makers · compile more complete picture than simple aggregations.*
#
# ---
#
# **💡 Why this matters**
# Paul's two incorrect justifications are subtle — they are not obviously wrong. "Patterns are harder to find" sounds like it could be defending rigour. "A select group benefits" sounds like it could be targeting communication. But both invert the actual properties of visualizations: patterns become *easier* to find, and appeal becomes *broader*. Recognising these inversions requires knowing the three outcomes well enough to catch when they are flipped. This is the kind of distinction that matters in a business case for data investment — arguing for visualization based on incorrect properties will be challenged immediately.
#
# ---
#
# **✅ RECAP**
# - Three correct outcomes: faster decisions · same simplification for any dataset size · more complete picture than aggregation alone
# - Two incorrect: patterns harder to find (inverted) · only select group benefits (inverted)
# - Scalability is explicit: small and large datasets simplify the same way — visual complexity does not grow with data volume
# - Datasaurus principle reinforced: visualizations show what mean/median hide — the complete picture, not just the centre
# - Wider appeal is a positive impact — visuals reach more stakeholders, not fewer

# %% [markdown]
# #### Chapter 2 — Lesson 4: Beginning visualization *(Video / 50 XP)*
#
# > 🎬 [Watch on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/effective-data-visuals?ex=4) *(requires login)*
#
# ---
#
# **🎯 GOAL — What is this lesson about?**
# Introduce three foundational chart types — bar chart, histogram, scatter plot — and establish when to use each based on the type of underlying data and the question being asked.
#
# ---
#
# **🧠 Mental Map — 3 Foundation Chart Types**
#
# ```
# FOUNDATION CHART TYPES
# │
# ├── BAR CHART
# │   ├── Underlying data: CATEGORICAL (labels — e.g. visitor type, country, payment method)
# │   ├── Bar height: summary statistic per label — most commonly frequency/count
# │   ├── Other summaries valid: e.g. average sale price by payment method
# │   ├── Visual feature: intentional gaps between bars (bars are discrete categories)
# │   └── Power: breakdown at a glance + inspires new avenues of discovery
# │       e.g. "contactless is highest average — but how often is it used?"
# │
# ├── HISTOGRAM
# │   ├── Underlying data: NUMERICAL (continuous values broken into equal-width bins)
# │   ├── Bar height: frequency of data points that fall within each bin range
# │   ├── Visual feature: NO intentional gaps — a gap means no data in that bin
# │   └── Key difference from bar chart: data is numerical, not categorical
# │       → same visual shape, completely different underlying logic
# │
# └── SCATTER PLOT
#     ├── Underlying data: TWO NUMERICAL VARIABLES
#     ├── Axes: one variable on horizontal, other on vertical
#     ├── Each point: one data record plotted at its (x, y) position
#     └── Goal: detect RELATIONSHIPS between the two variables
#         e.g. TV watching hours (x) vs exam score (y) → strong negative relationship
#         → drawing that conclusion from raw data would require parsing every point
#         → the scatter plot shows the entire dataset at once
# ```
#
# > ⚠️ *Bar charts and histograms look nearly identical at a glance — the distinguishing test is the underlying data type: categorical → bar chart, numerical → histogram. Gaps confirm which you're looking at.*
#
# ---
#
# **💡 Why this matters**
# Choosing the wrong chart type for the data is one of the most common errors in data communication — and one of the hardest for a non-technical audience to catch. A histogram used for categorical data, or a bar chart used for a distribution, will produce a chart that looks reasonable but answers the wrong question. These three chart types are the foundation for everything in the chapter: understanding when each applies is the prerequisite for every chart choice that follows.
#
# ---
#
# **✅ RECAP**
# - Bar chart → categorical data → frequency or other summary per label → gaps between bars
# - Histogram → numerical data → bin frequencies → no intentional gaps (gap = empty bin)
# - Scatter plot → two numerical variables → relationships and correlations → whole dataset visible at once
# - Bar chart vs histogram: identical shape, completely different underlying data logic — the test is the data type
# - Scatter plots make relationship detection effortless — what would take manual parsing becomes immediately visible

# %% [markdown]
# #### Chapter 2 — Lesson 5: Charting basics *(Exercise / 50 XP)*
#
# > 📝 [Practice on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/effective-data-visuals?ex=5) *(requires login)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Ability to identify an incorrect statement about the three foundation chart types — specifically catching the claim that limits bar charts to frequency only, which contradicts what L4 explicitly demonstrated.
#
# ---
#
# **📋 Scenario**
# Determining which visualization is suitable for an underlying dataset is an essential skill for visualization success. Which of the following is **not** a correct statement about the basic charts covered in this lesson?
#
# ---
#
# **✅ Solution**
#
# | Answer | Verdict | Why |
# |--------|---------|-----|
# | Bar charts display information about categorical data | ✅ Correct | Bar charts require categorical underlying data — this is their defining property |
# | Scatter plots illustrate the relationship between two numerical variables | ✅ Correct | Relationship detection between two numerical variables is the scatter plot's entire purpose |
# | **Bar charts only show frequency information about the underlying data** | ❌ **NOT correct — correct answer** | Bar charts can represent *many different summaries* per category — frequency/count is just the most common. L4 showed average sale price by payment method as a bar chart |
# | Histograms focus on counting numerical data separated into different buckets | ✅ Correct | Histograms bin numerical data and show the frequency (count) of values in each bin range |
#
# > ⚠️ The trap: frequency is the *most common* bar chart summary — it is easy to conflate "most common" with "only possible." L4 explicitly showed a bar chart of average sale price — not a count. Bar charts are capable of representing many different summaries for each group.
#
# ---
#
# **💡 Why this matters**
# In practice, bar charts are one of the most versatile chart types precisely because they are not limited to counts. Average, sum, median, percentage — any summary statistic per category can be shown as a bar chart. An analyst who only thinks of bar charts as frequency tools will reach for the wrong chart when showing, say, average revenue by region or median response time by team. Knowing the full capability of a chart type is what enables the right chart choice.
#
# ---
#
# **✅ RECAP**
# - Bar chart → categorical data → *any* summary per label (count is common, not exclusive)
# - Histogram → numerical data → bins → frequency count per bin — gaps mean empty bins
# - Scatter plot → two numerical variables → relationship detection
# - NOT correct: "bar charts *only* show frequency" — they show many different summaries
# - Hint confirms: bar charts are capable of representing many different summaries for each group

# %% [markdown]
# #### Chapter 2 — Lesson 6: Plotting the course *(Exercise / 100 XP)*
#
# > 📝 [Practice on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/effective-data-visuals?ex=6) *(requires login)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Ability to match real business objectives to the correct chart type — applying the L4 decision framework (categorical vs numerical, one variable vs two) to concrete analyst scenarios.
#
# ---
#
# **📋 Scenario**
# Julia is a data analyst for a chain of home improvement stores. She is creating charts for her organisation and wants to utilise simple visualizations to present her data. After compiling a list of her data assets and objectives, she selects the best visual for each.
#
# **Task:** Sort Julia's objectives into the correct chart type: Bar Chart, Histogram, or Scatterplot.
#
# ---
#
# **✅ Solution**
#
# | Objective | Chart type | Why |
# |-----------|-----------|-----|
# | Visualize counts of orders based on their source (online, in store, over the phone) | **Bar Chart** | Source type is categorical — bar chart shows summary (count) per label |
# | Display the average sales amount for each store location from highest to lowest | **Bar Chart** | Store location is categorical — bar chart shows a non-frequency summary (average) per label |
# | Understand the distribution of sales for credit card purchasers | **Histogram** | Sales amount is numerical — histogram bins the values and shows frequency distribution |
# | Plot the relationship between sales of drywall versus the sales of paint | **Scatterplot** | Two numerical variables — scatter plot detects the relationship between them |
# | Detect a potential relationship between the sales volume of concrete sold and the total order size | **Scatterplot** | Two numerical variables — scatter plot reveals whether a relationship exists |
#
# > *Decision rule from the hint: Bar charts and histograms → one variable each. Scatter plots → two variables. Bar charts → categorical. Histograms and scatter plots → numerical.*
#
# ---
#
# **💡 Why this matters**
# Julia's five objectives cover exactly the three chart types from L4 — and two of them (the bar charts) look superficially similar but test different things: one is a count, the other is an average. Both are bar charts because both involve a categorical variable (order source, store location) and a summary per category. The histogram and scatter plots are both about numerical data — but histogram works with one variable's distribution, scatter plot works with the relationship between two. Getting this wrong in practice means delivering a chart that looks reasonable but answers a different question than the one being asked.
#
# ---
#
# **✅ RECAP**
# - Bar chart: categorical variable + any summary per label (count or average or other) → both Julia objectives
# - Histogram: one numerical variable → distribution across bins → credit card sales distribution
# - Scatter plot: two numerical variables → relationship between them → drywall vs paint, concrete vs order size
# - Decision shortcuts: one variable → bar or histogram; two variables → scatter; categorical → bar; numerical → histogram or scatter
# - The bar chart is more flexible than it looks — average, count, sum, median all work as the bar height

# %% [markdown]
# #### Chapter 2 — Lesson 7: Advanced visuals *(Video / 50 XP)*
#
# > 🎬 [Watch on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/effective-data-visuals?ex=7) *(requires login)*
#
# ---
#
# **🎯 GOAL — What is this lesson about?**
# Show how stacked and 100% stacked bar charts extend the basic bar chart to reveal multi-category breakdowns — and establish the principle that different chart variants answer different questions for different audiences.
#
# ---
#
# **🧠 Mental Map — Stacked Bar Chart Evolution**
#
# ```
# BAR CHART EVOLUTION
# │
# ├── BASIC BAR CHART
# │   ├── One categorical variable → one summary per label
# │   ├── Limitation: can only show one category at a time
# │   └── Example: total revenue by source (gift shop / ticket / cafeteria)
# │             OR total revenue by museum — but not both at once
# │
# ├── STACKED BAR CHART
# │   ├── Adds a second categorical variable as colour dimension
# │   ├── Combines two separate bar charts into one
# │   ├── Shows: absolute values + breakdown by sub-category in the same view
# │   └── Example insight unlocked: contemporary art museum earns MORE from gift shop
# │       than ticket sales — invisible in the basic bar chart
# │       → museum of modern art cafeteria severely underperforming vs others
# │
# └── 100% STACKED BAR CHART
#     ├── Scales each bar to 100% → shows share of total, not raw amounts
#     ├── Removes absolute size differences — focuses purely on proportional breakdown
#     ├── Different question: "what % does each source represent?" vs "how much total?"
#     └── Example insight shift: modern art cafeteria looks severely low in raw values
#         → at revenue share level, it is closer to the photography museum than it appeared
#         → same data, different frame, different conclusion — both valid for different decisions
#
# ↓  PRINCIPLE
#    Both variants are useful — they answer different questions for different audiences
#    Remain flexible: try many chart approaches, see what each uncovers
#    Many variations of core chart types exist — explore them
# ```
#
# > *A solid visual engages the viewer and makes them want to know more about the dataset. The stacked bar chart's colour dimension is what makes the hidden insight (gift shop > tickets at contemporary art) visible at all.*
#
# ---
#
# **💡 Why this matters**
# The shift from stacked to 100% stacked is a precision tool for changing the analytical question without changing the data. A business stakeholder comparing museum performance might look at the raw stacked chart and flag modern art's cafeteria as a problem. The 100% view reveals that the problem is less severe than it looks in absolute terms — the share is similar to another museum. That is a different conversation, with different implications for investment decisions. Knowing which chart frame to use — and why — is what separates an analyst from someone who just makes charts.
#
# ---
#
# **✅ RECAP**
# - Basic bar chart → one categorical variable → one summary per label → limited to one category at a time
# - Stacked bar chart → two categorical variables → absolute values + sub-category breakdown in one view
# - 100% stacked bar chart → proportional share per sub-category → removes absolute size, reveals relative weight
# - Same data, two frames, two different questions — both valid, both useful, for different audiences
# - Principle: remain curious, try multiple chart types — variations of core types often unlock hidden insights

# %% [markdown]
# #### Chapter 2 — Lesson 8: Seeking Alignment *(Exercise / 50 XP)*
#
# > 📝 [Practice on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/effective-data-visuals?ex=8) *(requires login)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Ability to identify a statement that describes misuse of stacked bar charts — distinguishing the three legitimate outcomes from a claim that describes fabricating relationships rather than revealing them.
#
# ---
#
# **📋 Scenario**
# Stacking bar charts allows for a different view of a dataset compared to side-by-side bar charts. Which of the following **isn't** a desired outcome when stacking bar charts?
#
# ---
#
# **✅ Solution**
#
# | Answer | Verdict | Why |
# |--------|---------|-----|
# | Slice the data on two categorical variables instead of one | ✅ Desired outcome | The entire purpose of stacking — add a second categorical variable as the colour dimension |
# | **Create associations in the dataset that aren't present** | ❌ **NOT desired — correct answer** | Visualizations reveal what is in the data — they do not invent relationships. Creating associations that aren't present is manipulation, not analysis |
# | Compare the relative impact of categorical variables by different categorical variable | ✅ Desired outcome | Comparing relative impact across sub-categories is exactly what stacked (and 100% stacked) charts enable |
# | Combine two charts into one and uncover hidden insights | ✅ Desired outcome | L7 demonstrated this directly — the stacked museum chart combined two separate bar charts and revealed the gift shop > tickets insight at contemporary art |
#
# > ⚠️ The trap: stacked bar charts *do* reveal associations — that is their value. The key word is "aren't present." Revealing associations that exist is the goal. Fabricating ones that do not is a misuse of any visualization.
#
# ---
#
# **💡 Why this matters**
# The line between revealing a pattern and manufacturing one is where analytical integrity lives. A stacked bar chart that shows a real breakdown is doing its job. A chart designed to make sub-categories appear related when they are not — through misleading scales, cherry-picked groupings, or false colour associations — is doing damage. The hint confirms the purpose: stacked bar charts work by displaying multiple categories of data in a condensed manner to allow for *different types of comparisons* — comparisons of what actually exists, not what the analyst wants to exist.
#
# ---
#
# **✅ RECAP**
# - Stacked bar charts: slice on two categorical variables · compare relative impact · combine charts + uncover hidden insights
# - NOT a desired outcome: creating associations that aren't in the data — that is fabrication, not visualization
# - The distinction: *revealing* relationships vs *inventing* them — visualizations are discovery tools, not persuasion tools
# - Hint: stacked bar charts display multiple categories in condensed form to allow different types of comparisons
# - Every chart type can be misused — the test is always: does this reflect the data or distort it?

# %% [markdown]
# #### Chapter 2 — Lesson 9: Finding a vision *(Exercise / 100 XP)*
#
# > 📝 [Practice on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/effective-data-visuals?ex=9) *(requires login)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Ability to match a business objective and dataset to the correct bar chart variant — applying the three-way decision rule (one categorical variable vs two vs relative impact) to five concrete scenarios.
#
# ---
#
# **📋 Scenario**
# Constructing visuals with a goal in mind greatly reduces the amount of effort to obtain an insightful outcome. In many cases it is possible to know which type of the three bar chart styles is appropriate by looking at the desired outcome and the available data.
#
# **Task:** Match each dataset and objective with the appropriate bar chart style.
#
# ---
#
# **✅ Solution**
#
# | Objective | Chart type | Why |
# |-----------|-----------|-----|
# | Display the total ticket sales by ticket type | **Simple bar chart** | One categorical variable (ticket type) → one summary per label → basic bar chart |
# | Investigate the average height for each corn variety | **Simple bar chart** | One categorical variable (corn variety) → summary (average height) per label → basic bar chart |
# | Compare the total sales by line of business for each branch location | **Stacked bar chart** | Two categorical variables (line of business + branch location) → absolute totals with sub-category breakdown |
# | Investigate the total ticket sales by ticket type for each movie release | **Stacked bar chart** | Two categorical variables (ticket type + movie release) → absolute totals with sub-category breakdown |
# | Compare the relative performance of different menu items for each restaurant in the tri-state area | **100% stacked bar chart** | Relative performance across categories → proportional share, not raw amounts → 100% stacked |
#
# ---
#
# **💡 Why this matters**
# The three bar chart variants form a decision tree that any analyst can apply before building a chart. One variable and absolute values → simple. Two variables and absolute values → stacked. Two variables and relative share → 100% stacked. The "relative performance" signal in the last objective is the key diagnostic: when the question is about proportion rather than raw amount, the 100% stacked chart is the correct tool. Getting this right means the chart answers the actual question being asked — not a related but different one.
#
# ---
#
# **✅ RECAP**
# - Simple bar chart: one categorical variable → any summary per label (count, average, total)
# - Stacked bar chart: two categorical variables → absolute breakdown of sub-categories within each group
# - 100% stacked bar chart: two categorical variables → *relative* share of sub-categories within each group
# - Decision signal: if the objective uses "relative," "proportion," or "performance compared to" → 100% stacked
# - Constructing with a goal in mind: the objective determines the chart type before the data is touched

# %% [markdown]
# #### Chapter 2 — Lesson 10: Guiding principles of visualization *(Video / 50 XP)*
#
# > 🎬 [Watch on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/effective-data-visuals?ex=10) *(requires login)*
#
# ---
#
# **🎯 GOAL — What is this lesson about?**
# Establish three guiding principles for building impactful visualizations: show trends not specific values, avoid unnecessary complexity, and meet audience expectations — with the pie chart as the canonical example of what happens when these principles are violated.
#
# ---
#
# **🧠 Mental Map — Guiding Principles of Visualization**
#
# ```
# GUIDING PRINCIPLES OF VISUALIZATION
# │
# ├── PRINCIPLE 1: SHOW TRENDS, NOT SPECIFIC VALUES
# │   ├── Visualizations are for general understanding → quickly understood and actioned
# │   ├── If a visual requires exact numbers to be useful → it has failed its purpose
# │   ├── PIE CHART as the canonical failure case:
# │   │   ├── Human brains cannot intuitively compare areas of different pie slices
# │   │   ├── Fix attempt: overlay exact values onto slices
# │   │   └── Result: reading raw numbers — same as raw data but with more steps
# │   └── Fix: switch to a bar chart → preserves messaging without requiring exact values
# │       → "Visualizations are appetizers to the larger insights meal, not the entire meal"
# │
# ├── PRINCIPLE 2: AVOID UNNECESSARY COMPLEXITY
# │   ├── Rule: aim for "too simplistic" over "overly complicated" when in doubt
# │   ├── Two sources of complexity to eliminate:
# │   │   ├── Format: trying to do too much in one chart — complex formats require more from the audience
# │   │   └── Decoration: gridlines, busy colour schemes, 3D effects, excessive chart decorations
# │   └── Practical test: look at your chart and ask — "are there any unnecessary elements I can remove?"
# │       → removing 3D bars, pivoting orientation, shrinking reference lines → same data, clearer signal
# │
# └── PRINCIPLE 3: MEET AUDIENCE EXPECTATIONS
#     ├── Visualization is a two-way street — the audience must be able to receive it
#     ├── Deviating severely from the organisation's communication paradigm = poor reception
#     ├── Make minor, iterative improvements — include the audience in the process
#     └── Better: audience-in-mind iterations > checklist without the audience
# ```
#
# > *Complex formats are powerful but require more from the audience to understand — and may not achieve the desired effect. Simplicity is not a limitation; it is the delivery mechanism.*
#
# ---
#
# **💡 Why this matters**
# The pie chart lesson is a practical warning that most analysts encounter early and often. The instinct to overlay numbers onto a pie chart feels like a solution — but it is actually a confession that the chart is not working. Once you need to add the numbers, the visual is doing no work and should be replaced. The same logic applies to complexity in general: every element that requires the audience to work harder is a barrier between the insight and the action. The three principles are not aesthetic preferences — they are functional requirements for communication.
#
# ---
#
# **✅ RECAP**
# - Principle 1: show trends, not specific values — if the chart requires exact numbers to be useful, it has failed
# - Pie chart failure pattern: can't compare slice areas → overlay numbers → now reading raw data with extra steps → use a bar chart instead
# - Principle 2: simplicity over complexity — both in chart format and in decorative elements (3D, gridlines, colour noise)
# - Practical rule: when in doubt, aim for too simple rather than too complex
# - Principle 3: meet audience expectations — minor iterative improvements with the audience beat a complexity checklist without them

# %% [markdown]
# #### Chapter 2 — Lesson 11: Navigating priorities *(Exercise / 50 XP)*
#
# > 📝 [Practice on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/effective-data-visuals?ex=11) *(requires login)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Ability to identify the question that does NOT belong in the visualization evaluation checklist — distinguishing the three valid guiding questions from one that directly contradicts Principle 3 (meet audience expectations).
#
# ---
#
# **📋 Scenario**
# Visualizing data is a complex area with many competing priorities and objectives. When constructing a visual or evaluating a new visualization technique, which is **not** a question you should consider?
#
# ---
#
# **✅ Solution**
#
# | Answer | Verdict | Why |
# |--------|---------|-----|
# | **How can I drastically change the standard format for presenting this data?** | ❌ **NOT a question to ask — correct answer** | L10 Principle 3 explicitly states: deviating severely from the organisation's communication paradigm leads to poor reception. Drastic change is the opposite of the guidance |
# | Is the chart too complex for its intended purpose? | ✅ Valid question | Directly maps to L10 Principle 2 — check whether complexity is serving the audience or creating barriers |
# | What is my audience expecting? | ✅ Valid question | Directly maps to L10 Principle 3 — meet audience expectations, include them in the iteration process |
# | Am I focusing too much on specific information at the expense of the overall trends? | ✅ Valid question | Directly maps to L10 Principle 1 — visualizations show trends, not specific values; pie chart failure pattern |
#
# > *Hint from DataCamp — Effective visuals aim to strike a balance between: too specific vs too broad · necessary and unnecessary complexity · audience expectations and other best practices · organisational standards and areas for refinement.*
#
# ---
#
# **💡 Why this matters**
# The three valid questions are a direct operationalisation of the three principles from L10 — one question per principle. The invalid question ("drastically change the standard format") is memorable precisely because it sounds like innovation. But in visualization communication, innovation without audience alignment is just noise. The principle is: make minor, iterative improvements that the audience can follow — not dramatic departures that require re-education before the insight can land.
#
# ---
#
# **✅ RECAP**
# - Valid questions: Is it too complex? · What does the audience expect? · Am I showing trends or specifics?
# - NOT valid: "How can I drastically change the standard format?" — drastic deviation = poor reception (L10 Principle 3)
# - Each valid question maps to one of the three guiding principles from L10
# - Effective visuals balance four tensions: specific vs broad · complexity · audience expectations · organisational standards
# - Innovation in visualization = minor iterative improvement with the audience, not unilateral departure from the standard

# %% [markdown]
# #### Chapter 2 — Lesson 12: Visualization best practices *(Exercise / 100 XP)*
#
# > 📝 [Practice on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/effective-data-visuals?ex=12) *(requires login)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Ability to evaluate a real analyst's workflow and sort her steps into best practices and areas needing improvement — applying all three guiding principles from L10 to concrete actions.
#
# ---
#
# **📋 Scenario**
# Leslie is working on building her visualization skills to become an expert at communicating big ideas with her team. She recently completed a visualization for a presentation and it wasn't as well received as she thought it would be. Leslie documented her workflow and identified steps she could have done differently.
#
# **Task:** Review Leslie's visualization workflow and determine where she needs to improve and where she already employs best practices.
#
# ---
#
# **✅ Solution**
#
# | Step | Category | Why |
# |------|----------|-----|
# | Determine the right mix of technical and non-technical information based on intended audience | ✅ **Best Practice** | Audience analysis before building — maps to the audience-first principle (Ch1) and L10 Principle 3: meet expectations |
# | Employ simplified colour schemes to convey the intended messaging without distraction | ✅ **Best Practice** | Directly applies L10 Principle 2 — eliminate unnecessary decorative complexity; colour is a powerful tool that should aid, not distract |
# | Design the visualization to be shared beyond the initial presentation | ✅ **Best Practice** | Designing for portability means the visual must stand alone — no verbal scaffolding — which requires it to be clear and self-explanatory |
# | Select her favourite chart, a histogram, before analysing the data | ❌ **Needs Improvement** | Chart type must follow the data and objective — selecting a format before analysis reverses the correct process (L4/L9: goal determines chart type) |
# | Deviate from her organisation's standard report layout | ❌ **Needs Improvement** | Direct violation of L10 Principle 3 — drastic deviation from organisational standards leads to poor reception (L11 confirmed: "drastically change the standard format" is not a valid question) |
#
# > *Hint — Thoughtful analysis is required to select the best visual · knowing your audience is one of the most overlooked best practices · colour, wielded correctly, is a powerful tool.*
#
# ---
#
# **💡 Why this matters**
# Leslie's two mistakes are the most common ones: choosing the chart type before looking at the data (format-first thinking) and deviating from organisational standards in the belief that a better chart will be better received regardless of context. Both mistakes prioritise the analyst's preferences over the audience's needs. The three best practices flip this: audience mix, colour for clarity, and portability are all decisions made in service of the person receiving the insight, not the person building it.
#
# ---
#
# **✅ RECAP**
# - Best practices: audience analysis before building · simplified colour for clarity · design for portability beyond the room
# - Needs improvement: choosing chart type before seeing the data (format-first) · deviating from organisational standards
# - Format-first thinking is a recurring trap — the data and objective must determine the chart, not preference
# - Colour is a powerful tool: used correctly it aids comprehension; used incorrectly it creates distraction
# - Organisational standards exist for a reason — minor improvements within them outperform departures from them
#
# ---
#
# > ✅ **Chapter 2 complete.** All 12 lessons of *Effective Data Visuals* covered.
# > 4 video lessons · 8 exercise/practice lessons · 800 XP

# %% [markdown]
# ---
#
# ### 📋 Chapter 2 Recap — Effective Data Visuals
#
# **The chapter in 4 sentences:**
# Visualizations work because the human brain processes visual patterns faster than raw numbers — they aggregate and summarize data so trends become immediately visible, and they reveal distributions that summary statistics like mean and median actively hide. Three foundation chart types cover most business needs: bar charts for categorical summaries, histograms for numerical distributions, and scatter plots for relationships between two variables — each extended by variants like stacked and 100% stacked bar charts that answer progressively more specific questions. The guiding principles that make a visualization effective are the same regardless of chart type: show trends not specific values, eliminate unnecessary complexity, and meet the audience's expectations. Format-first thinking — selecting a chart before seeing the data, or deviating from organisational standards without audience buy-in — is the most common way technically correct visualizations fail to land.
#
# **Mental map — Chapter 2 structure:**
#
# ```
# CHAPTER 2 — EFFECTIVE DATA VISUALS
# │
# ├── WHY VISUALIZATIONS (L1–L3)
# │   ├── Brain processes visual patterns faster than raw numbers
# │   ├── Aggregate and summarize → trends visible, complexity reduced
# │   ├── Reveal what mean/median hide → Datasaurus principle
# │   └── Purpose: simplify and highlight insights — not manipulate or obscure
# │
# ├── FOUNDATION CHART TYPES (L4–L6)
# │   ├── Bar chart → categorical data → any summary per label
# │   ├── Histogram → numerical data → bin frequencies → no intentional gaps
# │   ├── Scatter plot → two numerical variables → relationships
# │   └── Decision rule: data type + number of variables → chart type
# │
# ├── ADVANCED CHART TYPES (L7–L9)
# │   ├── Stacked bar → two categorical variables → absolute breakdown
# │   ├── 100% stacked bar → two categorical variables → relative share
# │   └── Signal: "relative" or "proportion" in the objective → 100% stacked
# │
# └── GUIDING PRINCIPLES (L10–L12)
#     ├── Principle 1: trends not specific values → pie chart failure pattern
#     ├── Principle 2: simplify format + eliminate decorative complexity
#     ├── Principle 3: meet audience expectations → minor iterations, not drastic departures
#     └── Trap: format-first thinking — chart type follows data + objective, never precedes them
# ```
#
# **Key principle from this chapter:**
# A visualization is not successful because it looks good — it is successful because it answers the right question for the right audience without requiring them to work to extract the insight. Every element that adds friction between the chart and the conclusion is a failure of communication, not a display of rigour.

# %% [markdown]
# ---
#
# ### Chapter 3 — Storytelling with Data: Intro
#
# *Written after all 15 lessons — deferred synthesis, not a preview.*
#
# **What this chapter does:**
# Chapters 1 and 2 built the two raw materials: the insight (knowing what to say and to whom) and the visual (knowing how to show it). Chapter 3 answers the question those two chapters leave open: *how do you make it matter?* The answer is data storytelling — binding visualization, narrative, and context into a single purposeful communication that doesn't just inform but moves people to act.
#
# **The chapter's internal logic:**
#
# ```
# CHAPTER 3 — STORYTELLING WITH DATA
# │
# ├── WHAT DATA STORYTELLING IS (L1–L3)
# │   ├── L1: Definition — 3 components (Visualization · Narrative · Context)
# │   │       3 advantages: easier to understand · inspires action · sticks longer
# │   ├── L2: Building a story — identify the 3 components in a real story
# │   └── L3: Important call — distinguish accurate takeaways from misreadings
# │
# ├── KEYS TO A GOOD STORY (L4–L6)
# │   ├── L4: Keys to a good story — Narrative defined (≠ description; must inspire action)
# │   │       Context defined (background + relative insight + impact on rest of org)
# │   │       Visualization = equal parts art and science
# │   ├── L5: Defining the goal — the story's objective determines everything that follows
# │   └── L6: Narrative and context — separate the two; know which element does what job
# │
# ├── STORYTELLING IN ACTION (L7–L10)
# │   ├── L7: Storytelling in action — 3 universal principles: text · colour · simplicity
# │   │       Running example: meal delivery company signups
# │   ├── L8: Telling a good story — identify correct storytelling principles
# │   ├── L9: Guiding a story — sequence the 5-step story construction process
# │   └── L10: Delivering a story — evaluate a real story against best practice criteria
# │
# └── GROUP FRAMEWORK + WRAP-UP (L11–L15)
#     ├── L11: Group framework — 4 roles: SME · Visualizer · Analyst · Reviewer
#     │        Flexibility rule: rotate > lock; everyone contributes regardless of skill
#     ├── L12: Organizing success — avoid locking roles; rotating builds all capabilities
#     ├── L13: Aligning roles — match member strengths to the right role; misalignment wastes skill
#     ├── L14: Teamwork for success — apply the full role framework to a real team scenario
#     └── L15: Wrap-up — Ch1 (what to say + to whom) · Ch2 (how to show it) · Ch3 (how to make it matter)
# ```
#
# **The one thing this chapter adds that the others couldn't:**
# A technically perfect insight shown in a technically perfect chart still fails if it has no narrative — no call to action, no context, no reason the audience should care. Data storytelling is not a formatting upgrade. It is the final layer that converts analysis into influence.

# %% [markdown]
# #### Chapter 3 — Lesson 1: Data storytelling *(Video / 50 XP)*
#
# > 🎬 [Watch on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/storytelling-with-data-3?ex=1) *(requires login)*
#
# ---
#
# **🎯 GOAL — What is this lesson about?**
# Define data storytelling as visualization + narrative + context, establish its three advantages over standalone visuals (easier to understand, inspires action, sticks longer), and prove each with concrete evidence.
#
# ---
#
# **🧠 Mental Map — Why Data Storytelling**
#
# ```
# DATA STORYTELLING
# │  Definition: robust visualizations + background context + narrative
# │  = more potent than standalone visualization
# │
# ├── THE PROBLEM IT SOLVES
# │   ├── Standalone visualization: hard to parse, no context, unclear what is good/bad
# │   └── Data story: same data + "what changed" + "what it means" + "what to do next"
# │       → patient care example: pain index chart alone = confusing
# │                               pain index + narrative = "care improved dramatically, expand these practices"
# │
# ├── 3 KEY ADVANTAGES
# │   │
# │   ├── 1. EASIER TO UNDERSTAND
# │   │   ├── Pairs visual (easy to process) with written narrative and context
# │   │   └── Wider audience: no need to know the details behind the visualization to understand it
# │   │
# │   ├── 2. INSPIRES ACTION
# │   │   ├── People are more likely to engage and be persuaded by a story than by raw numbers
# │   │   └── Save the Children experiment:
# │   │       ├── Data alone → avg donation: $1.14
# │   │       └── Story → avg donation: $2.38 — more than double
# │   │
# │   └── 3. STICKS LONGER (retention)
# │       ├── Numbers alone are almost impossible to remember
# │       ├── Stanford crime statistics study:
# │       │   ├── Statistics alone → 5% remembered after 10 minutes
# │       │   └── Story → 63% remembered after 10 minutes
# │       └── The idea sticks; the number does not
# ```
#
# > *Data stories turn excess data into action. In an environment of information overload, the story is what determines whether the insight changes anything.*
#
# ---
#
# **💡 Why this matters**
# The Save the Children and Stanford studies are not marketing anecdotes — they are evidence that the format of communication changes outcomes, not just comprehension. An analyst who presents raw data or a standalone chart to a decision-maker is working against the biology of how people retain and act on information. Data storytelling is not a presentation skill layered on top of analysis — it is part of the analysis chain. The insight that never inspires action is, organisationally, the same as no insight at all.
#
# ---
#
# **✅ RECAP**
# - Data story = visualization + narrative + context — more potent than any of the three alone
# - Advantage 1: easier to understand — wider audience, no technical background required
# - Advantage 2: inspires action — Save the Children: story doubled donation vs data alone ($1.14 → $2.38)
# - Advantage 3: sticks longer — Stanford: 5% recall statistics, 63% recall stories after 10 minutes
# - The insight that does not inspire action has zero organisational value — storytelling is how you close that gap

# %% [markdown]
# #### Chapter 3 — Lesson 2: Building a story *(Exercise / 50 XP)*
#
# > 📝 [Practice on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/storytelling-with-data-3?ex=2) *(requires login)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Ability to identify a false claim about data storytelling — specifically catching the statement that conflates trust with persuasion, which is not one of the three advantages established in L1.
#
# ---
#
# **📋 Scenario**
# You recently started working at Buildingsway. On your first day you are asked to brief the team on data storytelling. You compile a presentation and list out the reasons why data storytelling is so powerful. Looking over your list you realise one of your statements is **false**. Select which one it is.
#
# ---
#
# **✅ Solution**
#
# | Answer | Verdict | Why |
# |--------|---------|-----|
# | A compelling data story will inspire customers to buy more than giving them data alone to make purchasing decisions | ✅ True | Directly maps to L1 Advantage 2 — inspires action; the Save the Children experiment proved that stories drive more action than data alone |
# | **Colleagues will trust a data story more than if you present raw data instead** | ❌ **False — correct answer** | Trust is not one of the three advantages of data storytelling. The three are: easier to understand, inspires action, sticks longer. Trust is a property of the analyst and the data — not a guaranteed outcome of the format |
# | Data stories are more memorable and will help your insights be remembered | ✅ True | Directly maps to L1 Advantage 3 — retention; Stanford study: 63% remembered stories vs 5% for statistics alone |
# | Your insights will be easier to understand for the audience | ✅ True | Directly maps to L1 Advantage 1 — easier to understand; pairs visual with narrative, widens the audience |
#
# > *Hint — Data stories utilise visualizations, narrative and context to create memorable exchanges of insights that drive action.*
#
# ---
#
# **💡 Why this matters**
# The false statement is plausible — it sounds reasonable that a well-structured story would build trust. But trust in data communication comes from data quality, methodology transparency, and the analyst's credibility — not from the format. A data story built on flawed data is not more trustworthy than raw data showing the same flaw. The three advantages of storytelling (comprehension, action, retention) are about what happens in the audience's mind — not about the relationship between analyst and audience. Keeping these distinct prevents overconfidence in format as a substitute for rigour.
#
# ---
#
# **✅ RECAP**
# - Three true advantages: inspires action · more memorable · easier to understand — all three confirmed here
# - False: "colleagues will trust a data story more" — trust is not a property of the storytelling format
# - Trust comes from data quality and analyst credibility — format does not create trust; it amplifies what is already there
# - Buildingsway running example continues: now the learner is an analyst on their first day briefing the team
# - Hint reinforces the definition: data stories = visualizations + narrative + context → memorable + action-driving

# %% [markdown]
# #### Chapter 3 — Lesson 3: Important call *(Exercise / 100 XP)*
#
# > 📝 [Practice on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/storytelling-with-data-3?ex=3) *(requires login)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Ability to identify which colleagues accurately understood the L1 presentation content — distinguishing feedback that reflects the three real advantages from feedback that introduces ideas not covered or that misrepresents the content.
#
# ---
#
# **📋 Scenario**
# After your presentation at Buildingsway on data storytelling, you asked the audience to share what they learned and how they plan to leverage data stories. Some colleagues missed parts of the presentation due to an important client call.
#
# **Task:** Identify who attended the whole meeting and who missed parts, based on their feedback.
#
# > *Hint — Your presentation focused on how data storytelling will enable colleagues to create memorable stories that convey intricate ideas easily and have a lasting impact on their audience.*
#
# ---
#
# **✅ Solution**
#
# | Colleague | Bucket | Why |
# |-----------|--------|-----|
# | Brett — excited for a straightforward method to share his complex insights | ✅ **Attended** | Maps to Advantage 1: easier to understand — data stories convey intricate ideas easily to a wider audience |
# | Paul — likes that data stories make his intensely researched insights more memorable | ✅ **Attended** | Maps to Advantage 3: sticks longer — memorable stories help insights be retained after the presentation |
# | Steve — looking forward to using data stories to drive more sales with his customers | ✅ **Attended** | Maps to Advantage 2: inspires action — stories drive people to act more than data alone (Save the Children evidence) |
# | Fred — likes that he can pack lots of insights into one data story | ❌ **Missed parts** | L1 established the opposite: a data story tells a *single* clear insight — "a story tells a single insight" was explicit. Packing lots of insights defeats the clarity advantage |
# | Meredith — can't wait to rely *solely* on data storytelling for communicating | ❌ **Missed parts** | "Solely" was never part of the presentation. Data storytelling is a powerful tool — it complements other forms of communication; replacing all communication with one method was not the message |
#
# ---
#
# **💡 Why this matters**
# Fred's mistake is subtle and common: assuming that if one story is good, more insights in the same story must be better. But the clarity advantage of a data story comes from its focus — one insight, clearly communicated. Adding more insights reintroduces the complexity that the story format was designed to remove. Meredith's mistake is over-application: treating a powerful tool as the only tool. Both errors are cases where the listener heard "this is powerful" and extrapolated beyond what was actually taught. Recognising these misreadings is a real skill in communication — knowing not just what you said, but what people took away.
#
# ---
#
# **✅ RECAP**
# - Attended: Brett (easy to understand) · Paul (memorable) · Steve (drives action) — all three advantages correctly identified
# - Missed: Fred (packing multiple insights) · Meredith (relying solely on storytelling)
# - Data stories tell a *single* insight clearly — multiplying insights destroys the clarity advantage
# - Data storytelling is powerful *in combination* with other methods — not as a replacement for all communication
# - Buildingsway running example: now the learner is presenting to their own team and reading the room

# %% [markdown]
# #### Chapter 3 — Lesson 4: Keys to a good story *(Video / 50 XP)*
#
# > 🎬 [Watch on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/storytelling-with-data-3?ex=4) *(requires login)*
#
# ---
#
# **🎯 GOAL — What is this lesson about?**
# Define data storytelling precisely, break it into its three structural components (Visualization, Context, Narrative), and establish what each one must do — with Narrative as the most commonly misunderstood element.
#
# ---
#
# **🧠 Mental Map — Three Elements of a Data Story**
#
# ```
# DATA STORYTELLING
# │  Definition: a method of communicating data insights
# │              tailored to a specific audience
# │              with an overarching narrative
# │  Goal: deep understanding of business problem
# │        → form a narrative supported by data
# │        → deliver to intended audience
# │
# ├── 1. VISUALIZATION
# │   ├── Share trends and patterns — familiar, easy to understand
# │   ├── Do not force the audience to heavily interrogate the data
# │   └── Makes up a large portion of the overall story → strong visual = strong foundation
# │
# ├── 2. CONTEXT
# │   ├── Paints the story as part of a larger initiative
# │   ├── Grounds the audience's understanding of the broader picture
# │   ├── Rule: focus only on what is essential to understand the narrative
# │   │         do not explain every portion of the analysis
# │   └── Must unify the data story to business objectives and outcomes
# │       → the more you know your audience, the more relevant your context
# │
# └── 3. NARRATIVE
#     ├── The voice given to the underlying dataset
#     ├── ⚠️ Common myth: "data should always be objective and doesn't need a voice"
#     │   → People don't make decisions on data alone — they need to connect with the message
#     ├── Objective: give a clear and convincing view of the dataset
#     │             explain why the findings are significant
#     │             inspire action
#     └── Function: call to action — outlines the next steps for the audience
#
# ↓  IN PRACTICE — pain management example revisited
#    Visualization → draws attention, shows the before/after shift clearly
#    Paragraph     → Context first (what changed in procedures)
#                    Narrative follows (these practices should be expanded to all patients)
# ```
#
# > *Narrative is where most new data storytellers struggle — the belief that data speaks for itself is a myth. Data does not connect; narrative does. The narrative is what turns an observation into a call to action.*
#
# ---
#
# **💡 Why this matters**
# The three-element structure is what separates a data story from a dashboard. A dashboard shows the visualization. A report adds context. A data story adds narrative — the layer that tells the audience not just what happened and why it matters, but what they should do about it. The narrative is also the most personal element: it requires the analyst to take a position, which is uncomfortable. But without it, the insight is complete as information and incomplete as communication.
#
# ---
#
# **✅ RECAP**
# - Data storytelling: insights + specific audience + overarching narrative — definition not universal but consistent in intent
# - Three elements: Visualization (trends, familiar format) · Context (essential background, tied to objectives) · Narrative (voice, call to action)
# - Context rule: focus only on what is essential — do not explain the full analysis; connect it to what the audience cares about
# - Narrative myth debunked: data does not speak for itself — people need narrative to connect and act
# - Narrative function: clear + convincing view → why it's significant → next steps for the audience

# %% [markdown]
# #### Chapter 3 — Lesson 5: Defining the goal *(Exercise / 50 XP)*
#
# > 📝 [Practice on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/storytelling-with-data-3?ex=5) *(requires login)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Ability to identify which statement does NOT describe the objective of the three data storytelling components — distinguishing the three real goals from a claim that introduces the analyst's effort as a communication objective.
#
# ---
#
# **📋 Scenario**
# Data storytelling focuses on defining three key components — narrative, visualization, and context — to communicate data insights. These components each achieve a specific goal for the story. Which of the following **does not** describe the objective of the three components?
#
# ---
#
# **✅ Solution**
#
# | Answer | Verdict | Why |
# |--------|---------|-----|
# | **Illustrate to the audience how difficult it was to uncover the insights** | ❌ **NOT an objective — correct answer** | The difficulty of the analysis is irrelevant to the audience. The three components exist to communicate the insight — not to demonstrate the analyst's effort or justify their work |
# | Connect business objectives to the outcome of the analysis | ✅ Valid objective | Maps directly to Context from L4: context must unify the data story to business objectives and outcomes |
# | Provide clear guidance on the next steps the audience should take | ✅ Valid objective | Maps directly to Narrative from L4: narrative serves as a call to action and outlines next steps for the audience |
# | Condense large amounts of information into a visually appealing format | ✅ Valid objective | Maps directly to Visualization from L4: share trends in a familiar format that doesn't force the audience to interrogate the data |
#
# > *Hint — The purpose of the three components: visualizations to share the story in a familiar format · context to show the story as part of larger efforts · narrative to provide the data a guided voice.*
#
# ---
#
# **💡 Why this matters**
# "Illustrating how difficult it was to uncover the insights" is a trap because it appeals to the analyst's instinct to justify their work. In practice, audiences do not care about the process — they care about the finding and what to do with it. Communicating difficulty is a form of self-referencing that adds no value to the insight and can actually undermine the story by shifting focus from the conclusion to the method. The three components are entirely audience-facing. The analyst's effort is invisible in a well-crafted data story.
#
# ---
#
# **✅ RECAP**
# - Three valid objectives: connect to business objectives (Context) · guide next steps (Narrative) · condense into accessible format (Visualization)
# - NOT an objective: illustrating how difficult the analysis was — the audience does not need to know the effort
# - Rule: data storytelling components are audience-facing — they serve comprehension and action, not analyst credibility
# - The analyst's process is invisible in a good story — only the insight and its implications should be visible
# - Hint confirms component roles: familiar format · part of larger efforts · guided voice

# %% [markdown]
# #### Chapter 3 — Lesson 6: Narrative and context *(Exercise / 100 XP)*
#
# > 📝 [Practice on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/storytelling-with-data-3?ex=6) *(requires login)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Ability to classify real data story excerpts as Narrative, Context, or Neither — applying the L4 definitions to distinguish a call to action from background information from raw data with no storytelling function.
#
# ---
#
# **📋 Scenario**
# Data stories come in many shapes and sizes; identifying the key parts of a story is essential to evaluating and growing your data storytelling skills. You decide to focus on distinguishing between what is narrative and what is context.
#
# **Task:** Classify each excerpt as Narrative, Context, or Neither.
#
# ---
#
# **✅ Solution**
#
# | Excerpt | Classification | Why |
# |---------|----------------|-----|
# | Due to the overall savings, all lines of business should change technology providers immediately | **Narrative** | A call to action — tells the audience what to do with the insight; gives the data a guided voice |
# | The revised menu isn't as popular as expected; we should review other menu options and see how they perform | **Narrative** | Recommendation and next steps — outlines the action the audience should take based on the finding |
# | All employees were asked to evaluate their technology usage as part of a branch-wide initiative to reduce costs | **Context** | Background and larger initiative — paints the story as part of broader organisational effort; connects to business objectives |
# | During the pandemic, sales shifted dramatically, and our sales team members collected information to serve their customers better | **Context** | Background circumstance — grounds the audience's understanding of why this data exists and what it was collected for |
# | The total number of SUVs sold on the lot was 5,237 | **Neither** | Raw data point — no voice, no direction, no background; it is a number without a story function |
# | Data was collected from March to April | **Neither** | Methodological detail — not a call to action (Narrative) and not a broader business initiative (Context); it is a data collection note |
#
# > *Hint — Narratives give data insights a voice and outline next steps. Context connects the insights to larger business objectives and provides the necessary background for the audience.*
#
# ---
#
# **💡 Why this matters**
# The "Neither" category is the most instructive. Both neither items look like they could belong in a data story — one is a fact about the dataset, the other is a data collection window. But neither one does the work of a story component: they don't frame the broader picture (Context) and they don't guide action (Narrative). A data story is not a report — not every true statement belongs in it. The discipline of excluding raw data points and methodological notes is what keeps the story focused on the insight and the action, not the process.
#
# ---
#
# **✅ RECAP**
# - Narrative: gives data a voice + outlines next steps + call to action → "should change provider" / "should review options"
# - Context: connects to larger initiative + business objectives + grounds understanding → branch-wide cost initiative / pandemic sales shift
# - Neither: raw data point or methodological note — true, but no storytelling function → "5,237 SUVs" / "March to April"
# - Key distinction: a fact about the data is not the same as a reason to care about the data (Context) or a direction to act (Narrative)
# - Discipline of exclusion: not every true statement belongs in a data story — only what serves comprehension and action

# %% [markdown]
# #### Chapter 3 — Lesson 7: Storytelling in action *(Video / 50 XP)*
#
# > 🎬 [Watch on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/storytelling-with-data-3?ex=7) *(requires login)*
#
# ---
#
# **🎯 GOAL — What is this lesson about?**
# Walk through the complete data story creation process — from raw data to polished story — using the Buildingsway competitor survey as a concrete example, and establish the three universal principles for improving any data story.
#
# ---
#
# **🧠 Mental Map — Building a Data Story**
#
# ```
# DATA STORY CREATION PROCESS
# │
# ├── STEP 1 — WHAT ARE WE TRYING TO CONVEY?
# │   └── Define the insight or objective before touching the visualization
# │       Buildingsway: show the difference between Buildingsway and competitors
# │                     across key areas of the ordering process (scored 0–1)
# │
# ├── STEP 2 — WHAT IS THE BEST VISUALIZATION?
# │   ├── Scatter plot → "clear as mud" — no observable patterns, more confusing than raw data
# │   ├── Line chart  → doesn't make sense — no time dimension in the dataset
# │   ├── Bar chart   → promising but hard to parse — two bars per category, doesn't add much
# │   ├── Difference chart → focus only on the gap between Buildingsway and competitors
# │   │                      → much easier to read; refined focus
# │   └── Sorted difference chart → sort by value → pattern emerges immediately
# │       NARRATIVE FOUND: poorly rated areas cluster around staff interactions
# │       → invest in staffing; edge is in materials/construction; staff is biggest gap
# │
# └── STEP 3 — THREE UNIVERSAL IMPROVEMENT PRINCIPLES
#     │
#     ├── 1. ADD TEXT
#     │   ├── Explainer paragraph: clearly outlines findings and next steps
#     │   ├── Additional header added to guide the eye
#     │   └── Visuals shouldn't sit alone — text is powerful and often overlooked
#     │
#     ├── 2. USE COLOUR INTENTIONALLY
#     │   ├── Draw the eye into both text and visual simultaneously
#     │   ├── ⚠️ Don't overdo it — colour is potent; some organisations resist heavy use
#     │   └── Strong and subtle colour usage is a significant differentiator
#     │
#     └── 3. SIMPLIFY VISUAL ELEMENTS
#         ├── Remove gridlines — not adding valuable information
#         ├── Enlarge labels — easier to scan
#         └── Result: cleaner, more focused, easier to read
# ```
#
# > *The narrative was not planned in advance — it emerged from sorting the chart. The process of refining the visualization is also the process of discovering what the data is actually saying.*
#
# ---
#
# **💡 Why this matters**
# The Buildingsway example shows that the "best" chart is rarely the first one tried. Four chart types were tested before landing on the sorted difference chart — and the narrative only became clear after sorting. This is the real workflow: start with a question, iterate on the visual, let the pattern reveal itself, then build the story around what you find. The three improvement principles (text, colour, simplicity) are not cosmetic — they are the difference between a chart that requires explanation and a story that stands on its own.
#
# ---
#
# **✅ RECAP**
# - Two-step start: what to convey → best visualization to achieve it
# - Chart iteration is normal: scatter → line → bar → difference → sorted — the right chart reveals itself
# - Narrative discovery: sorting the chart showed staff interactions as the weak cluster — not known at the start
# - Three universal improvement principles: add text (explainer + header) · colour intentionally · simplify elements
# - A story that needs to be explained in a meeting has not yet been finished — text, colour, and simplicity make it self-contained

# %% [markdown]
# #### Chapter 3 — Lesson 8: Telling a good story *(Exercise / 50 XP)*
#
# > 📝 [Practice on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/storytelling-with-data-3?ex=8) *(requires login)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Ability to identify the guideline that should NOT be followed when creating a data story — catching the claim that contradicts the audience-first principle established throughout the course.
#
# ---
#
# **📋 Scenario**
# Data storytelling is an expansive topic with many interesting best practices and guidelines. Which of the following guidelines should you **not** follow when creating a data story?
#
# ---
#
# **✅ Solution**
#
# | Answer | Verdict | Why |
# |--------|---------|-----|
# | **Plan the same message for all audiences** | ❌ **Should NOT follow — correct answer** | The entire audience analysis framework (Ch1 L8–L11) and the data storytelling definition (L4: "tailored to a specific audience") both require adapting the message to the audience — one-size-fits-all is explicitly wrong |
# | Reflect on the objective of your story to select the perfect presentation method | ✅ Should follow | Step 1 of the L7 two-step process: define what you are trying to convey before choosing the visualization |
# | Eliminate extraneous visual information | ✅ Should follow | L7 Principle 3 + L10 Principle 2: simplify visual elements — remove gridlines, unnecessary decoration, anything not adding value |
# | Utilise colour to enhance your message | ✅ Should follow | L7 Principle 2: use colour intentionally — draw the eye, enhance the message; strong subtle colour is a significant differentiator |
#
# > *Hint — Data stories rely on intentionally created visuals that guide the audience towards the central message.*
#
# ---
#
# **💡 Why this matters**
# "Plan the same message for all audiences" is the most persistent bad habit in data communication — and one that the course has been correcting since Chapter 1. The same insight lands differently for Paul (technical, sceptical), Yuri (operational, non-technical), and Lorraine (sales-focused). Harold knew this at Buildingsway. The data storytelling definition from L4 explicitly includes "tailored to a specific audience" as a core requirement. A story that ignores who is in the room will be heard but not acted on.
#
# ---
#
# **✅ RECAP**
# - Should NOT follow: plan the same message for all audiences — tailoring is definitional to data storytelling
# - Should follow: reflect on objective → choose method · eliminate extraneous elements · use colour intentionally
# - All three valid guidelines trace back directly to L7's two-step process and three improvement principles
# - "One-size-fits-all suits no one" — first stated in L5 (Ch1), reinforced again here in Ch3
# - The audience is always the first variable — every other decision (format, colour, complexity) follows from it

# %% [markdown]
# #### Chapter 3 — Lesson 9: Guiding a story *(Exercise / 100 XP)*
#
# > 📝 [Practice on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/storytelling-with-data-3?ex=9) *(requires login)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Ability to sequence the five steps of building a data story in the correct order — applying the principle that a targeted question must precede data collection, and that communication is always the final, non-optional step.
#
# ---
#
# **📋 Scenario**
# Putting a data story together requires parsing a lot of information and guidelines and utilising them at the right moment to build the best story you can.
#
# **Task:** Arrange the steps of building a data story in the correct order.
#
# ---
#
# **✅ Solution — correct order**
#
# | Order | Step | Why this position |
# |-------|------|-------------------|
# | 1st | **Ask an interesting question** | The question must exist before data is sought — you need a target to know what data is relevant (mirrors the insight process from Ch1 L7) |
# | 2nd | **Get the data** | Once the question is defined, collect the data that backs it up — data collection is purposeful, not exploratory |
# | 3rd | **Explore the data** | Understand what is in the dataset — distributions, patterns, anomalies — before modelling |
# | 4th | **Model the data** | Apply analytical techniques to extract meaning — this is where insight is uncovered |
# | 5th | **Communicate and visualize the results** | All insights must be shared to inspire action — communication is the final, non-optional step |
#
# > *Hint — Before you can uncover insights you have to start with a targeted question and a dataset that backs up the question. All insights need to be shared to inspire action.*
#
# ---
#
# **💡 Why this matters**
# The sequence mirrors the 6-step insight discovery process from Ch1 L7 (Collect → Organise → Analyse → Apply → Communicate → Observe) — but now reframed through the storytelling lens. The critical insight is the same in both: the process starts with a question, not with data. Analysts who begin by opening a dataset without a defined question generate a lot of exploration but rarely a clean narrative. The question is the story's spine — everything else is built around it. And communication at step 5 is not optional — an insight that is modelled but not communicated has zero organisational impact.
#
# ---
#
# **✅ RECAP**
# - Correct order: Ask → Get → Explore → Model → Communicate and visualise
# - Step 1 is always the question — targeted, interesting, business-relevant; data collection follows the question
# - Communication is always last and always required — unshared insight = zero impact (reinforces Ch1 L5)
# - This sequence is the data storytelling operationalisation of the Ch1 insight discovery process
# - The story is built around the question — without it, there is no narrative spine to attach anything to

# %% [markdown]
# #### Chapter 3 — Lesson 10: Delivering a story *(Exercise / 100 XP)*
#
# > 📝 [Practice on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/storytelling-with-data-3?ex=10) *(requires login)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Ability to evaluate a real data story against best practices — identifying which elements are already strong and which still need improvement, using the three universal principles from L7 as the evaluation framework.
#
# ---
#
# **📋 Scenario**
# A meal delivery company is working on understanding their signups in greater detail and constructed the following data story:
#
# - **Visuals:** A line chart (total signups over time) + a stacked bar chart (breakdown by channel: Direct to Consumer, Partner, Retail, Online)
# - **Text:** *"Since the launch in 2016, signups have fluctuated heavily as the business strategy matured. Shifting from direct to consumer towards partners are responsible for the recent increase in overall signups."*
#
# **Task:** Determine whether each element achieves best practice or requires improvement.
#
# ---
#
# **✅ Solution**
#
# | Element | Category | Why |
# |---------|----------|-----|
# | Provide sufficient backstory to anchor the story in context | ✅ **Best Practice** | The paragraph explains the business history (launch 2016, strategy matured, channel shift) — grounds the audience in the broader picture (L4 Context objective) |
# | Incorporate text to emphasise the messaging | ✅ **Best Practice** | The story includes an explanatory paragraph alongside the visuals — text is not missing (L7 Principle 1: add text) |
# | Present simplified visual elements | ❌ **Requires Improvement** | Two charts with a busy multi-colour stacked bar scheme — complex, visually noisy; L7 Principle 3 and L10 Principle 2 both call for simplification |
# | Deliver a strong narrative | ❌ **Requires Improvement** | The paragraph is descriptive (what happened) but lacks a call to action (what to do next) — L4 established that narrative must inspire action and outline next steps, not just explain the data |
#
# ---
#
# **💡 Why this matters**
# The text in this story is doing the work of Context but not Narrative. Describing what happened ("channel shift drove the increase") tells the audience what occurred — but a strong Narrative would add "therefore, we should..." or "the next step is...". This is the most common gap in analyst communication: stopping at explanation and not completing the loop to recommendation. The visual complexity issue is equally instructive — two charts with many colours feels thorough, but forces the audience to do work that the story should be doing for them.
#
# ---
#
# **✅ RECAP**
# - Best practice already achieved: sufficient backstory (context) · text incorporated
# - Requires improvement: simplified visual elements (too complex, busy colours) · strong narrative (descriptive not prescriptive)
# - Context ≠ Narrative: explaining what happened is Context; telling the audience what to do is Narrative
# - A story without a call to action is a report — the recommendation is what makes it a story
# - Evaluation framework: text (L7 P1) · colour (L7 P2) · simplicity (L7 P3) · narrative voice (L4) · context (L4)

# %% [markdown]
# #### Chapter 3 — Lesson 11: Data storytelling group framework *(Video / 50 XP)*
#
# > 🎬 [Watch on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/storytelling-with-data-3?ex=11) *(requires login)*
#
# ---
#
# **🎯 GOAL — What is this lesson about?**
# Show how data storytelling's three components map onto four team roles — and establish that roles are flexible, overlap is normal, and rotating them is more valuable than rigidly following a structure.
#
# ---
#
# **🧠 Mental Map — Data Storytelling Team Roles**
#
# ```
# DATA STORYTELLING — 4 TEAM ROLES
# │  Three components (Narrative · Context · Visualization) → four roles
# │
# ├── SUBJECT MATTER EXPERT (SME)
# │   ├── Owns: NARRATIVE + CONTEXT
# │   ├── Narrative: the overarching message the data story is trying to convey
# │   ├── Context: how insights relate to the rest of the organisation + background for understanding
# │   ├── Requires: intimate connection to the business problem
# │   └── ⚠️ SME ≠ Analyst — deep business knowledge doesn't require technical skill, and vice versa
# │
# ├── VISUALIZER
# │   ├── Owns: VISUALIZATION
# │   ├── Creates visuals that showcase the SME's vision for the insights
# │   ├── Works closely with SME to understand what needs to be shown
# │   └── Visualisation = equal parts art and science
# │
# ├── ANALYST
# │   ├── Supports: technical insight discovery + research for follow-up questions
# │   ├── Uncovers insights for the SME; answers analytical questions from the audience
# │   └── ⚠️ Technical skill to uncover insight ≠ ability to build compelling narrative or business context
# │       → the two roles exist because they require different capabilities
# │
# └── REVIEWER
#     ├── Acts as: the audience
#     ├── Helps the team iterate on the story by providing an outside perspective
#     ├── Best when: unfamiliar with the dataset or insights — can catch incorrect assumptions
#     └── Function: surface gaps between what the team thinks the story says and what the audience hears
#
# ↓  FLEXIBILITY RULE
#    People can serve multiple roles — a team of four is not required
#    Rotating roles and learning from each other > following a checklist
#    Find a group you feel comfortable with and start there
# ```
#
# > *The distinction between SME and Analyst is the most important: having robust technical skill to find an insight doesn't automatically mean knowing what it means for the business — or how to tell the story of it.*
#
# ---
#
# **💡 Why this matters**
# Most data teams are implicitly doing all four roles — but without naming them or rotating them intentionally. An analyst who is always the analyst never develops the narrative instinct. A visualizer who never reviews a story never learns where visuals lose the audience. The framework is not a bureaucratic structure — it is a lens for deliberate skill development. The reviewer role is especially underused: having someone unfamiliar with the data read the story before it goes to the real audience is one of the cheapest and most effective quality controls in data communication.
#
# ---
#
# **✅ RECAP**
# - Four roles: SME (narrative + context) · Visualizer (visualization) · Analyst (technical insight) · Reviewer (audience proxy)
# - SME ≠ Analyst: business depth and technical depth are distinct skills — the team benefits from separating them
# - Reviewer role: unfamiliar with the data → catches assumptions the team has stopped seeing → essential quality control
# - Flexibility: people can hold multiple roles; rotating is more valuable than rigid assignment
# - Goal: invest in storytelling skills as a team — individual strengths cover different components of the story

# %% [markdown]
# #### Chapter 3 — Lesson 12: Organizing success *(Exercise / 50 XP)*
#
# > 📝 [Practice on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/storytelling-with-data-3?ex=12) *(requires login)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Ability to identify what to avoid when forming a data storytelling group — catching the behaviour that directly contradicts the flexibility rule from L11.
#
# ---
#
# **📋 Scenario**
# Communicating data insights with data storytelling is a challenging skill to master. Working with a group of peers significantly improves your chances of success. You decide to form a group to refine your skills together. Working in your group, what should you **avoid** doing to be successful?
#
# ---
#
# **✅ Solution**
#
# | Answer | Verdict | Why |
# |--------|---------|-----|
# | **Allow everyone to select from one of the common roles and don't allow them to switch** | ❌ **Should AVOID — correct answer** | L11's flexibility rule explicitly states: rotating roles and learning from each other is more valuable than rigid assignment. Locking people into one role prevents skill development and removes the cross-role perspective that makes the group valuable |
# | Start small, and add members as more people become interested | ✅ Should do | L11: find a group you feel comfortable with and start there — storytelling groups can vary greatly in size |
# | Bring in people from all across your organisation | ✅ Should do | Different perspectives create valuable assessments — cross-functional viewpoints strengthen the reviewer role and catch assumptions |
# | Give lots of feedback and ways to improve based on each member's area of strength | ✅ Should do | Highlighting strengths and identifying growth areas is the core of team-based skill development from L11 |
#
# > *Hint — Storytelling groups can vary greatly in size and composition. Different perspectives create an opportunity for valuable assessments.*
#
# ---
#
# **💡 Why this matters**
# Rigid role assignment feels organised — it creates clear ownership and accountability. But in a skill development context, it is counterproductive. The analyst who never plays the reviewer never learns to see their work from the audience's perspective. The SME who never tries visualisation never develops visual intuition. The flexibility rule is not about avoiding structure — it is about using the group as a learning laboratory, not just a production line.
#
# ---
#
# **✅ RECAP**
# - Should AVOID: locking roles — rotating is more valuable than rigid assignment (L11 flexibility rule)
# - Should do: start small · bring cross-functional perspectives · give strength-based feedback
# - Role rotation is deliberate skill development — each role builds a different capability
# - Group size and composition can vary — start with who you have, not with the ideal four-person structure
# - Different perspectives are an asset: people unfamiliar with the data are the best reviewers

# %% [markdown]
# #### Chapter 3 — Lesson 13: Aligning roles *(Exercise / 100 XP)*
#
# > 📝 [Practice on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/storytelling-with-data-3?ex=13) *(requires login)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Ability to evaluate role assignments in a data storytelling team — identifying when skills are correctly matched to roles and when they are misaligned or when someone is incorrectly excluded.
#
# ---
#
# **📋 Scenario**
# Holly is forming a new group of colleagues to work on their data storytelling skills together. She asks each prospective member what their strengths are to match them to the group.
#
# | Member | Strength |
# |--------|----------|
# | Julius | Fantastic analytical capabilities — excels at uncovering deep insights |
# | Reggie | Extensive business knowledge — knows all the important initiatives |
# | Erwin | Adept at creating convincing graphs and charts |
# | Holly | New to the team — unfamiliar with analytics and insights |
#
# **Task:** Look over Holly's assignments and identify which should be revised.
#
# ---
#
# **✅ Solution**
#
# | Assignment | Category | Why |
# |------------|----------|-----|
# | Julius is assigned the analyst role to discover and support insights | ✅ **Optimal** | Julius's analytical capability maps directly to the Analyst role — uncovers insights, answers technical questions |
# | Reggie will serve as SME to create the narrative and context for the story | ✅ **Optimal** | Reggie's deep business knowledge and awareness of initiatives maps directly to the SME role — owns narrative and context |
# | Holly won't have a role — she is too new to contribute to the team | ❌ **Needs revision** | L11 explicitly states: everyone can contribute regardless of skill. Holly's unfamiliarity with the data makes her the *ideal* Reviewer — she represents the audience's perspective and can surface assumptions the team has stopped seeing |
# | Erwin will serve as Reviewer to see how the narrative and context support the overall story | ❌ **Needs revision** | Erwin's strength is creating graphs and charts — that maps to the Visualizer role, not Reviewer. Assigning Erwin to Reviewer wastes the visualization skill and leaves the Visualizer role unfilled |
#
# > *Hint — Within a group, someone can serve more than one role · start with any amount of members · rotate roles and learn collectively · everyone can contribute regardless of skill.*
#
# ---
#
# **💡 Why this matters**
# Both errors are instructive in opposite ways. Holly is excluded because she is "too new" — but her lack of familiarity is precisely what makes her valuable as a Reviewer; she is the closest proxy to the real audience. Erwin is assigned to the wrong role — not because the Reviewer role is unimportant, but because Erwin's skill is in visualization and that strength is being misallocated. Good team design matches strengths to roles while recognising that the "weakest" member by technical skill is often the most valuable for audience testing.
#
# ---
#
# **✅ RECAP**
# - Optimal assignments: Julius → Analyst (analytical skill) · Reggie → SME (business depth)
# - Needs revision: Holly excluded (wrong — her newness = ideal Reviewer perspective) · Erwin as Reviewer (wrong — Erwin's skill = Visualizer)
# - Key rule: everyone can contribute regardless of skill — unfamiliarity is an asset in the Reviewer role
# - Role alignment: map each person's actual strength to the role that requires it; misalignment wastes the skill
# - Holly's "weakness" is Erwin's opportunity: Erwin becomes Visualizer, Holly becomes Reviewer — both contribute

# %% [markdown]
# #### Chapter 3 — Lesson 14: Teamwork for success *(Exercise / 100 XP)*
#
# > 📝 [Practice on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/storytelling-with-data-3?ex=14) *(requires login)*
#
# ---
#
# **🎯 GOAL — What does this exercise test?**
# Ability to apply the L11 role framework in a real team context — mapping each team member's described skill to the correct role and the correct set of tasks.
#
# ---
#
# **📋 Scenario**
# Caroline is improving her team's data storytelling skills and has devised a task list. Each task needs to be assigned to the right team member.
#
# | Member | Skill profile |
# |--------|---------------|
# | Lisa | Data expert — clear vision of the dataset and insights |
# | George | Business expert — comprehensive view of how insights impact other business areas; unfamiliar with the inner workings of the dataset |
# | Leslie | Visualization expert — advanced understanding of communicating data clearly and concisely to reach the intended audience |
#
# **Task:** Match each task from Caroline's task list to the correct team member.
#
# ---
#
# **✅ Solution**
#
# | Task | Assigned to | Role (L11) | Why |
# |------|-------------|------------|-----|
# | Discover insights based on analytical findings | **Lisa** | Analyst | Lisa's data expertise maps directly to the Analyst role — uncovers insights from the dataset |
# | Provide a concise narrative for the audience to follow | **Lisa** | Analyst | Lisa's clear vision of the insights equips her to translate them into a concise, audience-facing narrative |
# | Establish the impact the story depicts on the rest of the organization | **George** | SME | Business expert = SME; communicating business-wide impact is the SME's domain (context component) |
# | Review the entire data story to ensure the desired message is reaching the intended audience | **George** | Reviewer | George is unfamiliar with the dataset's inner workings → closest proxy to the real audience → ideal Reviewer |
# | Select the best graphs and charts to convey the narrative | **Leslie** | Visualizer | Visualization expertise maps directly to the Visualizer role — choosing the right chart for the story |
# | Eliminate excessive visual information based on peer feedback | **Leslie** | Visualizer | Iterating on and simplifying visuals based on feedback is a core Visualizer responsibility |
#
# ---
#
# **💡 Why this matters**
# George's dual role is the most instructive mapping here. He is assigned as both SME (business impact task) and Reviewer (audience alignment check) — valid because L11 explicitly allows people to hold multiple roles. More importantly, George's apparent weakness — being unfamiliar with how the data works internally — is precisely what makes him a strong Reviewer. The person least close to the data is often the most reliable audience proxy. Lisa's narrative task is equally worth noting: the analyst with the clearest view of the insights is often the best person to articulate them concisely, even if the broader business narrative typically belongs to the SME.
#
# ---
#
# **✅ RECAP**
# - Lisa (Analyst): discovers insights + provides concise narrative — data clarity enables both tasks
# - George (SME + Reviewer): establishes business impact + reviews audience alignment — business depth + data unfamiliarity = dual role
# - Leslie (Visualizer): selects best charts + eliminates excessive visuals — both tasks draw on the same visual expertise
# - Unfamiliarity is an asset: George's weak spot (no inner data knowledge) makes him the team's best audience proxy
# - Multiple roles per person is valid and expected — the framework is a tool for skill development, not a rigid org chart

# %% [markdown]
# #### Chapter 3 — Lesson 15: Wrap-up *(Video / 50 XP)*
#
# > 🎬 [Watch on DataCamp](https://campus.datacamp.com/courses/communicating-data-insights/storytelling-with-data-3?ex=15) *(requires login)*
#
# ---
#
# **🎯 GOAL — What is this lesson about?**
# Close the course by tracing the arc across all three chapters — how knowledge is shared, how visuals make it compelling, how data storytelling binds it into something that drives action.
#
# ---
#
# The course moved through three layers: first, the mechanics of how people communicate and what makes an insight worth sharing (Ch1); then, how to make that insight visible — the principles behind charts, colour, simplicity, and the audience's cognitive load (Ch2); finally, how narrative, context, and visualization combine into a story that doesn't just inform but moves people to act (Ch3). The group framework at the end is a reminder that these three layers require three different types of skill — and that building them deliberately, as a team, is how they compound.
#
# ---
#
# **💡 Why this matters**
# Most analysts leave a course like this having learned a checklist — four communication types, five chart principles, three storytelling components. The more durable takeaway is the underlying logic: every decision in data communication is an act of respect for the audience's time and attention. Clarity, simplicity, narrative, context — these are not style choices. They are the difference between insight that changes a decision and insight that gets filed away.
#
# ---
#
# **✅ RECAP**
# - Ch1: communication types · insight characteristics · audience analysis — the foundation of knowing *what* to say and *to whom*
# - Ch2: visual impact · chart selection · guiding principles — the foundation of knowing *how* to show it
# - Ch3: storytelling components · keys to a good story · group framework — the foundation of knowing *how to make it matter*
# - The three chapters are sequential dependencies: no good story without the right insight; no impactful insight without the right visual; no compelling visual without knowing your audience
# - Next step: apply the techniques — the framework only becomes skill through practice

# %% [markdown]
# ---
#
# > ✅ **Chapter 3 complete.** All 15 lessons of *Storytelling with Data* covered.
# > 4 video lessons · 11 exercise/practice lessons · 900 XP
#
# ---
#
# ### Chapter 3 — Recap
#
# **The chapter in 4 sentences:**
# Data storytelling is the combination of visualization, narrative, and context — the three components that together do what a chart alone cannot: explain what changed, why it matters, and what to do next. A good story requires a defined goal, a narrative that moves the audience to action (not just describes what happened), and context that anchors the insight to the organisation's wider reality. Three universal principles govern the execution: add explanatory text, use colour to direct attention, eliminate everything that isn't doing necessary work. And because storytelling is a team sport, four roles — SME, Visualizer, Analyst, Reviewer — distribute the three required skills across people, with flexibility and rotation more valuable than rigid assignment.
#
# **Mental map — Chapter 3 structure:**
#
# ```
# CHAPTER 3 — STORYTELLING WITH DATA
# │
# ├── WHAT IS A DATA STORY (L1–L3)
# │   ├── 3 components: Visualization + Narrative + Context = data story
# │   ├── 3 advantages: easier to understand · inspires action · sticks longer
# │   └── One story = one insight — clarity requires focus, not volume
# │
# ├── WHAT MAKES A GOOD STORY (L4–L6)
# │   ├── Narrative ≠ description → must outline impact + call to action
# │   ├── Context = background + relative insight + organisational impact
# │   ├── Visualization = equal parts art and science
# │   └── Story objective = the lens every element is built through
# │
# ├── STORYTELLING IN ACTION (L7–L10)
# │   ├── 3 principles: add text · use colour intentionally · simplify
# │   ├── 5-step sequence: Ask → Get → Explore → Model → Communicate
# │   ├── Evaluation lens: text (P1) · colour (P2) · simplicity (P3) · narrative voice · context
# │   └── Stopping at description = a report; adding recommendation = a story
# │
# └── GROUP FRAMEWORK (L11–L15)
#     ├── 4 roles: SME (narrative + context) · Visualizer · Analyst · Reviewer
#     ├── SME ≠ Analyst: business depth and technical depth are distinct
#     ├── Reviewer's value = unfamiliarity with the data → best audience proxy
#     ├── Flexibility rule: rotate > lock; multiple roles per person is valid
#     └── Everyone contributes regardless of skill — newness is an asset in review
# ```
#
# **Key principle from this chapter:**
# A story without a call to action is a report. The recommendation — what the audience should *do* — is what separates communication that drives decisions from communication that gets filed away.
#
# ---
#
# > ✅ **Course 2 complete.** All 3 chapters · 38 lessons · 2600 XP
# > *Communicating Data Insights — Joe Franklin*

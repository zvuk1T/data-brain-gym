# %% [markdown]
# # Data Skills for Business — Skill Track
#
# **Platform:** DataCamp
# **Type:** Theory — no coding required
# **Duration:** 17 hours | 6 courses
# **Participants:** 50,615
#
# ---
#
# **Track Description:**
# Learn core data concepts, understand how to answer real-world questions using data, and become a more confident data-driven decision-maker within your organization.
# This track is the organisational layer — it answers: how do data, people, governance and ethics interact inside a business?
#
# ---
#
# ## Table of Contents
#
# 1. [Course 1: Introduction to Data](#course-1)
# 2. [Course 2: Introduction to Data Literacy](#course-2)
# 3. [Course 3: Introduction to AI for Work](#course-3)
# 4. [Course 4: Data Governance Concepts](#course-4)
# 5. [Course 5: Introduction to Data Ethics](#course-5)
# 6. [Course 6: Data Management Concepts](#course-6)
#
# ---
#
# > 📌 **How to use this notebook:**
# > This is the business context layer. Every concept here explains why data decisions have organisational consequences — ownership, quality, trust, ethics, governance.
# > These concepts are the difference between a technician who runs queries and an analyst who understands their impact.
